# %% [markdown]
# # Experiment 27 — Solar Expansion Across Three Strong Backbones
#
# ## 목적
#
# 현재까지의 48-condition evidence를 Solar-Energy로 확장합니다.
#
# Backbones:
#
# \[
# \{
# \mathrm{PatchTST},
# \mathrm{iTransformer},
# \mathrm{TimeMixer}
# \}
# \]
#
# Forecast horizons:
#
# \[
# H\in\{96,192,336,720\}
# \]
#
# 따라서 새로운 평가 조건은
#
# \[
# 3\times4=12
# \]
#
# 개입니다.
#
# ---
#
# # 중요한 해석상의 구분
#
# Solar는 새로운 architecture를 개발하는 과정에서 이미 여러 번 사용한
# **development dataset**입니다.
#
# 따라서 Experiment 27의 Solar 결과는:
#
# - strong-backbone continuity 확인
# - 현재 frozen method의 development-regime characterization
# - 48-condition evidence와 protocol-level 연결
#
# 에는 사용할 수 있지만,
#
# > completely independent confirmatory dataset
#
# 으로 간주하지 않습니다.
#
# 향후 Exchange와 Traffic이 더 중요한 독립 dataset expansion evidence가 됩니다.
#
# ---
#
# # Frozen historical-memory method
#
# 구조를 변경하지 않습니다.
#
# \[
# \boxed{
# \text{EmbeddingOnly Predictive Retrieval}
# \rightarrow
# \text{Uniform Top-10 Historical Forecast}
# \rightarrow
# \text{Cross-Fitted Adaptive Gate}
# \rightarrow
# \text{Validation-Calibrated Shrinkage}
# }
# \]
#
# Retriever는 기존 Solar development experiments에서 이미 학습한 checkpoint를
# 그대로 고정합니다.
#
# - full retriever: Experiment 10
# - fold retrievers: Experiment 12
# - retrieval lookback \(L_R=96\)
# - Top-\(K=10\)
# - memory stride 24
# - 3 chronological OOF folds
# - gate feature dimension 26
# - shrinkage grid \(\{0,.25,.5,.75,1\}\)
#
# **Retriever는 backbone별로 다시 학습하지 않습니다.**
#
# Backbone마다 새로 학습되는 것은:
#
# 1. strong direct forecaster
# 2. prefix-only fold direct forecasters
# 3. cross-fitted adaptive gate
#
# 뿐입니다.
#
# ---
#
# # Direct backbone policy
#
# Solar test 결과를 보기 전에 다음 설정을 prospectively freeze합니다.
#
# ### PatchTST
#
# 기존 strong PatchTST evidence와 동일한 official supervised implementation을 사용합니다.
#
# - direct lookback \(L_D=336\)
# - high-dimensional recipe를 사용
# - patch length 16
# - stride 8
# - \(d_{\mathrm{model}}=128\)
# - 3 encoder layers
# - 16 heads
# - \(d_{\mathrm{ff}}=256\)
# - RevIN
# - Adam + OneCycleLR
# - validation-only checkpoint selection
#
# ### iTransformer
#
# 기존 strong iTransformer evidence와 동일한 official implementation을 사용합니다.
#
# - direct lookback \(L_D=96\)
# - 3 encoder layers
# - \(d_{\mathrm{model}}=512\)
# - \(d_{\mathrm{ff}}=512\)
# - 8 heads
# - Adam
# - type-1 learning-rate schedule
# - validation-only checkpoint selection
#
# ### TimeMixer
#
# 기존 strong TimeMixer evidence와 동일한 official implementation을 사용합니다.
#
# - direct lookback \(L_D=96\)
# - channel independence
# - 3 down-sampling layers
# - average pooling, window 2
# - \(d_{\mathrm{model}}=16\)
# - \(d_{\mathrm{ff}}=32\)
# - 3 encoder layers
# - Adam + OneCycleLR
# - validation-only checkpoint selection
#
# Solar 결과를 본 뒤 backbone별 hyperparameter를 바꾸지 않습니다.
#
# ---
#
# # Data protocol
#
# Standard Solar-Energy benchmark:
#
# - 137 channels
# - 70% train
# - 10% validation
# - 20% test
# - train-only standardization
# - all test origins
# - stride 1
# - all channels
# - \(H=\{96,192,336,720\}\)
#
# At validation:
#
# \[
# \text{retrieval memory}=\text{train only}
# \]
#
# At test:
#
# \[
# \text{retrieval memory}=\text{train+validation only}
# \]
#
# Candidate admissibility:
#
# \[
# t_i+H\le \text{memory boundary}
# \]
#
# No rolling test-label memory is used.

# %%
from pathlib import Path
from types import SimpleNamespace
from contextlib import nullcontext

import gc
import importlib
import math
import os
import random
import subprocess
import sys
import time
import warnings

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

warnings.filterwarnings(
    "ignore"
)

pd.set_option(
    "display.max_columns",
    260,
)

pd.set_option(
    "display.width",
    560,
)

DEVICE = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

DATASET = "Solar"

BACKBONES = [
    "PatchTST",
    "iTransformer",
    "TimeMixer",
]

HORIZONS = [
    96,
    192,
    336,
    720,
]

RET_SEQ_LEN = 96

TOP_K = 10
MEMORY_STRIDE = 24
OOF_ANCHOR_STRIDE = 4

FOLDS = [
    (
        0.55,
        0.70,
    ),
    (
        0.70,
        0.85,
    ),
    (
        0.85,
        1.00,
    ),
]

# Frozen predictive representation.
REP_PATCH_LEN = 16
REP_PATCH_STRIDE = 16
REP_D_MODEL = 64
REP_N_HEADS = 4
REP_LAYERS = 2
REP_D_FF = 128
REP_DROPOUT = 0.1
REP_DIM = 64

REP_NUM_PATCHES = (
    1
    + (
        RET_SEQ_LEN
        - REP_PATCH_LEN
    )
    // REP_PATCH_STRIDE
)

# Frozen gate.
GATE_DIM = 26
GATE_LR = 1e-3
GATE_WD = 1e-4
GATE_BATCH = 8192
GATE_MAX_EPOCHS = 50
GATE_PATIENCE = 7

ALPHA_GRID = np.round(
    np.arange(
        0.0,
        1.0001,
        0.1,
    ),
    10,
)

LAMBDA_GRID = np.array(
    [
        0.0,
        0.25,
        0.50,
        0.75,
        1.00,
    ],
    dtype=np.float32,
)

TARGET_RETRIEVAL_PAIRS = 672

EPS = 1e-8

RETRIEVER_USE_AMP = (
    torch.cuda.is_available()
)

CROSSFIT_SEED = 2727

RESUME = True
FORCE = False

BOOTSTRAP_REPLICATES = 5000
BOOTSTRAP_BLOCK_LEN = 24
BOOTSTRAP_SEED = 272700

ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "solar_three_backbone_frozen_historical_memory"
)

ROOT.mkdir(
    parents=True,
    exist_ok=True,
)

SHARED_MEMORY_EMB_DIR = (
    ROOT
    / "shared_memory_embeddings"
)

SHARED_MEMORY_EMB_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

ARTIFACT_DIR = (
    ROOT
    / "artifacts"
)

ARTIFACT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

SUMMARY_PATH = (
    ROOT
    / "summary.csv"
)

BOOTSTRAP_PATH = (
    ROOT
    / "bootstrap.csv"
)

CURRENT_BACKBONE = None
DIRS = None

# Conservative direct inference blocks.
DIRECT_ANCHOR_BLOCK = {
    "PatchTST":
        16,
    "iTransformer":
        16,
    "TimeMixer":
        16,
}

print(
    "Device:",
    DEVICE,
)

print(
    "Output:",
    ROOT,
)
# Out:
# Device: cuda
# Output: /data/dataset/strong_forecaster/solar_three_backbone_frozen_historical_memory

# %% [markdown]
# ## 1. Locate and load Solar-Energy

# %%
SOLAR_CANDIDATES = [
    Path(
        "/data/Time-Series-Library/"
        "dataset/Solar/solar_AL.txt"
    ),
    Path(
        "/data/Time-Series-Library_v2/"
        "dataset/Solar/solar_AL.txt"
    ),
    Path(
        "/code/Time-Series-Library/"
        "dataset/Solar/solar_AL.txt"
    ),
    Path(
        "/data/dataset/Solar/"
        "solar_AL.txt"
    ),
    Path(
        "/data/dataset/"
        "solar_AL.txt"
    ),
]

SOLAR_PATH = next(
    (
        p
        for p in SOLAR_CANDIDATES
        if p.is_file()
    ),
    None,
)

if SOLAR_PATH is None:
    print(
        "Attempted paths:"
    )

    for p in SOLAR_CANDIDATES:
        print(
            " -",
            p,
        )

    raise FileNotFoundError(
        "Could not find Solar-Energy solar_AL.txt."
    )


def load_solar_txt(
    path,
):
    df = pd.read_csv(
        path,
        header=None,
    )

    if df.shape[
        1
    ] == 1:
        df = pd.read_csv(
            path,
            header=None,
            sep=r"\s+",
        )

    df = df.apply(
        pd.to_numeric,
        errors="coerce",
    )

    df = (
        df.replace(
            [
                np.inf,
                -np.inf,
            ],
            np.nan,
        )
        .interpolate(
            axis=0,
            limit_direction="both",
        )
        .ffill()
        .bfill()
    )

    if df.shape[
        1
    ] != 137:
        raise ValueError(
            "Expected 137 Solar channels, got "
            f"{df.shape[1]}."
        )

    return df


raw_df = load_solar_txt(
    SOLAR_PATH
)

raw = raw_df.to_numpy(
    dtype=np.float32,
)

n_time, n_channels = (
    raw.shape
)

train_end = int(
    0.70
    * n_time
)

num_test = int(
    0.20
    * n_time
)

val_end = (
    n_time
    - num_test
)

test_end = n_time

train_mean = raw[
    :train_end
].mean(
    axis=0,
).astype(
    np.float32
)

train_std = raw[
    :train_end
].std(
    axis=0,
    ddof=0,
).astype(
    np.float32
)

if np.any(
    train_std
    <= 1e-6
):
    bad = np.where(
        train_std
        <= 1e-6
    )[
        0
    ]

    raise ValueError(
        "Degenerate Solar training channels: "
        f"{bad[:20]}"
    )

z_full = (
    (
        raw
        - train_mean[
            None,
            :
        ]
    )
    / train_std[
        None,
        :
    ]
).astype(
    np.float32
)

# Solar benchmark has no explicit timestamp column.
# Current three direct models do not require time marks for Solar.
marks = np.zeros(
    (
        n_time,
        0,
    ),
    dtype=np.float32,
)

DATA = {
    "Solar": {
        "name":
            "Solar",
        "path":
            SOLAR_PATH,
        "raw":
            raw,
        "z":
            z_full,
        "marks":
            marks,
        "n_channels":
            n_channels,
        "train_end":
            train_end,
        "val_end":
            val_end,
        "test_end":
            test_end,
    }
}

display(
    pd.DataFrame([
        {
            "Split":
                "Train",
            "Start":
                0,
            "EndExclusive":
                train_end,
            "Length":
                train_end,
        },
        {
            "Split":
                "Validation",
            "Start":
                train_end,
            "EndExclusive":
                val_end,
            "Length":
                val_end
                - train_end,
        },
        {
            "Split":
                "Test",
            "Start":
                val_end,
            "EndExclusive":
                test_end,
            "Length":
                test_end
                - val_end,
        },
    ])
)

print(
    "Solar path:",
    SOLAR_PATH,
)

print(
    "Shape:",
    raw.shape,
)
# Out:
#         Split  Start  EndExclusive  Length
# 0       Train      0         36792   36792
# 1  Validation  36792         42048    5256
# 2        Test  42048         52560   10512
# Solar path: /data/Time-Series-Library/dataset/Solar/solar_AL.txt
# Shape: (52560, 137)

# %% [markdown]
# ## 2. Prefix-only normalization for cross-fitting

# %%
def prefix_normalize(
    raw_array,
    prefix,
):
    prefix = int(
        prefix
    )

    mean = raw_array[
        :prefix
    ].mean(
        axis=0,
    ).astype(
        np.float32
    )

    std = raw_array[
        :prefix
    ].std(
        axis=0,
        ddof=0,
    ).astype(
        np.float32
    )

    if np.any(
        std
        <= 1e-6
    ):
        raise ValueError(
            f"Degenerate prefix channel at prefix={prefix}."
        )

    z = (
        (
            raw_array
            - mean[
                None,
                :
            ]
        )
        / std[
            None,
            :
        ]
    ).astype(
        np.float32
    )

    return (
        z,
        {
            "Mean":
                mean,
            "Std":
                std,
            "Prefix":
                prefix,
        },
    )


def eval_anchors(
    start,
    end,
    horizon,
    stride=1,
    lookback=RET_SEQ_LEN,
):
    return np.arange(
        max(
            int(
                start
            ),
            int(
                lookback
            ),
        ),
        int(
            end
        )
        - int(
            horizon
        )
        + 1,
        int(
            stride
        ),
        dtype=np.int64,
    )

# %% [markdown]
# ## 3. Official backbone repositories

# %%
BASE = Path(
    "/code/stock_regime_retrieval/"
    "strong_forecaster"
)

REPO_CANDIDATES = {
    "PatchTST": [
        BASE
        / "PatchTST_official",
        Path(
            "/code/PatchTST_official"
        ),
        Path(
            "/data/PatchTST_official"
        ),
    ],

    "iTransformer": [
        BASE
        / "iTransformer_official",
        Path(
            "/code/iTransformer"
        ),
        Path(
            "/data/iTransformer"
        ),
    ],

    "TimeMixer": [
        BASE
        / "TimeMixer_official",
        Path(
            "/code/TimeMixer"
        ),
        Path(
            "/data/TimeMixer"
        ),
    ],
}

REPO_URLS = {
    "PatchTST":
        "https://github.com/yuqinie98/PatchTST.git",
    "iTransformer":
        "https://github.com/thuml/iTransformer.git",
    "TimeMixer":
        "https://github.com/kwuking/TimeMixer.git",
}

EXPECTED_FILES = {
    "PatchTST":
        Path(
            "PatchTST_supervised/"
            "models/PatchTST.py"
        ),
    "iTransformer":
        Path(
            "model/"
            "iTransformer.py"
        ),
    "TimeMixer":
        Path(
            "models/"
            "TimeMixer.py"
        ),
}

REPOS = {}

for backbone in BACKBONES:
    repo = next(
        (
            p
            for p in REPO_CANDIDATES[
                backbone
            ]
            if (
                p
                / EXPECTED_FILES[
                    backbone
                ]
            ).is_file()
        ),
        None,
    )

    if repo is None:
        repo = REPO_CANDIDATES[
            backbone
        ][
            0
        ]

        repo.parent.mkdir(
            parents=True,
            exist_ok=True,
        )

        print(
            f"Cloning {backbone} -> {repo}"
        )

        subprocess.run(
            [
                "git",
                "clone",
                "--depth",
                "1",
                REPO_URLS[
                    backbone
                ],
                str(
                    repo
                ),
            ],
            check=True,
        )

    REPOS[
        backbone
    ] = repo

repo_rows = []

for backbone, repo in REPOS.items():
    try:
        commit = subprocess.check_output(
            [
                "git",
                "-C",
                str(
                    repo
                ),
                "rev-parse",
                "HEAD",
            ],
            text=True,
        ).strip()
    except Exception:
        commit = "unknown"

    repo_rows.append({
        "Backbone":
            backbone,
        "Repository":
            str(
                repo
            ),
        "Commit":
            commit,
    })

display(
    pd.DataFrame(
        repo_rows
    )
)

pd.DataFrame(
    repo_rows
).to_csv(
    ARTIFACT_DIR
    / "backbone_repository_commits.csv",
    index=False,
)
# Out:
#        Backbone                                         Repository                                    Commit
# 0      PatchTST  /code/stock_regime_retrieval/strong_forecaster...  204c21efe0b39603ad6e2ca640ef5896646ab1a9
# 1  iTransformer  /code/stock_regime_retrieval/strong_forecaster...  c2426e68ca13f74aaec08045c5c724d8ad328124
# 2     TimeMixer  /code/stock_regime_retrieval/strong_forecaster...  e24610583b36fdd8c76cc17a8df4e65759a5f460

# %% [markdown]
# ## 4. Prespecified direct recipes
#
# Solar test metric은 아직 보지 않은 상태에서 아래 recipe를 고정합니다.
#
# PatchTST는 기존 high-dimensional strong recipe를,
# iTransformer는 기존 high-dimensional strong recipe를,
# TimeMixer는 기존 high-dimensional official-style recipe를 사용합니다.
#
# 이 Experiment 27 안에서는 test 결과를 근거로 recipe를 변경하지 않습니다.

# %%
DIRECT_RECIPES = {
    "PatchTST": {
        "seq_len":
            336,
        "label_len":
            48,
        "batch_size":
            32,
        "eval_batch":
            32,
        "train_epochs":
            100,
        "patience":
            10,
        "learning_rate":
            1e-4,
        "weight_decay":
            0.0,
        "scheduler":
            "TST",
        "pct_start":
            0.2,
        "seed":
            2021,

        "e_layers":
            3,
        "n_heads":
            16,
        "d_model":
            128,
        "d_ff":
            256,
        "dropout":
            0.2,
        "fc_dropout":
            0.2,
        "head_dropout":
            0.0,
        "patch_len":
            16,
        "stride":
            8,
    },

    "iTransformer": {
        "seq_len":
            96,
        "label_len":
            48,
        "batch_size":
            16,
        "eval_batch":
            16,
        "train_epochs":
            10,
        "patience":
            3,
        "learning_rate":
            5e-4,
        "weight_decay":
            0.0,
        "scheduler":
            "type1",
        "seed":
            2023,

        "e_layers":
            3,
        "n_heads":
            8,
        "d_model":
            512,
        "d_ff":
            512,
        "dropout":
            0.1,
        "factor":
            1,
    },

    "TimeMixer": {
        "seq_len":
            96,
        "label_len":
            0,
        "batch_size":
            128,
        "eval_batch":
            128,
        "train_epochs":
            20,
        "patience":
            10,
        "learning_rate":
            0.01,
        "weight_decay":
            0.0,
        "scheduler":
            "OneCycle",
        "pct_start":
            0.2,
        "seed":
            2021,

        "e_layers":
            3,
        "n_heads":
            8,
        "d_model":
            16,
        "d_ff":
            32,
        "dropout":
            0.1,
        "factor":
            3,

        "down_sampling_layers":
            3,
        "down_sampling_window":
            2,
        "down_sampling_method":
            "avg",
    },
}

display(
    pd.DataFrame(
        DIRECT_RECIPES
    ).T
)
# Out:
#              seq_len label_len batch_size eval_batch train_epochs patience learning_rate weight_decay scheduler pct_start  seed e_layers n_heads d_model d_ff dropout fc_dropout head_dropout patch_len stride factor down_sampling_layers down_sampling_window down_sampling_method
# PatchTST         336        48         32         32          100       10        0.0001          0.0       TST       0.2  2021        3      16     128  256     0.2        0.2          0.0        16      8    NaN                  NaN                  NaN                  NaN
# iTransformer      96        48         16         16           10        3        0.0005          0.0     type1       NaN  2023        3       8     512  512     0.1        NaN          NaN       NaN    NaN      1                  NaN                  NaN                  NaN
# TimeMixer         96         0        128        128           20       10          0.01          0.0  OneCycle       0.2  2021        3       8      16   32     0.1        NaN          NaN       NaN    NaN      3                    3                    2                  avg

# %% [markdown]
# ## 5. Backbone import activation

# %%
ACTIVE_MODEL_CLASS = None
ACTIVE_REPO = None


def clear_forecasting_modules():
    prefixes = [
        "models",
        "model",
        "layers",
        "utils",
        "data_provider",
        "exp",
        "experiments",
    ]

    for module_name in list(
        sys.modules.keys()
    ):
        if any(
            module_name
            == p
            or module_name.startswith(
                p
                + "."
            )
            for p in prefixes
        ):
            del sys.modules[
                module_name
            ]


def activate_backbone(
    backbone,
):
    global ACTIVE_MODEL_CLASS
    global ACTIVE_REPO

    clear_forecasting_modules()

    # Remove all known forecasting repositories from sys.path.
    repo_paths = []

    for b, r in REPOS.items():
        if b == "PatchTST":
            repo_paths.append(
                str(
                    r
                    / "PatchTST_supervised"
                )
            )
        else:
            repo_paths.append(
                str(
                    r
                )
            )

    sys.path[:] = [
        p
        for p in sys.path
        if p not in repo_paths
    ]

    if backbone == "PatchTST":
        root = (
            REPOS[
                backbone
            ]
            / "PatchTST_supervised"
        )

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "models.PatchTST"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    elif backbone == "iTransformer":
        root = REPOS[
            backbone
        ]

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "model.iTransformer"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    elif backbone == "TimeMixer":
        root = REPOS[
            backbone
        ]

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "models.TimeMixer"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    else:
        raise ValueError(
            backbone
        )

    print(
        f"Activated {backbone}: "
        f"{Path(module.__file__).resolve()}"
    )

    return ACTIVE_MODEL_CLASS

# %% [markdown]
# ## 6. Direct-model construction and forward pass

# %%
def set_seed(
    seed,
):
    random.seed(
        int(
            seed
        )
    )

    np.random.seed(
        int(
            seed
        )
    )

    torch.manual_seed(
        int(
            seed
        )
    )

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(
            int(
                seed
            )
        )

    torch.backends.cudnn.benchmark = False


def load_torch(
    path,
):
    try:
        return torch.load(
            path,
            map_location=DEVICE,
            weights_only=False,
        )
    except TypeError:
        return torch.load(
            path,
            map_location=DEVICE,
        )


def direct_config(
    backbone,
    horizon,
):
    r = DIRECT_RECIPES[
        backbone
    ]

    if backbone == "PatchTST":
        return SimpleNamespace(
            enc_in=
                n_channels,
            seq_len=
                r[
                    "seq_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            e_layers=
                r[
                    "e_layers"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            d_model=
                r[
                    "d_model"
                ],
            d_ff=
                r[
                    "d_ff"
                ],
            dropout=
                r[
                    "dropout"
                ],
            fc_dropout=
                r[
                    "fc_dropout"
                ],
            head_dropout=
                r[
                    "head_dropout"
                ],
            individual=
                0,
            patch_len=
                r[
                    "patch_len"
                ],
            stride=
                r[
                    "stride"
                ],
            padding_patch=
                "end",
            revin=
                1,
            affine=
                0,
            subtract_last=
                0,
            decomposition=
                0,
            kernel_size=
                25,
        )

    if backbone == "iTransformer":
        return SimpleNamespace(
            task_name=
                "long_term_forecast",
            seq_len=
                r[
                    "seq_len"
                ],
            label_len=
                r[
                    "label_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            enc_in=
                n_channels,
            dec_in=
                n_channels,
            c_out=
                n_channels,
            d_model=
                r[
                    "d_model"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            e_layers=
                r[
                    "e_layers"
                ],
            d_layers=
                1,
            d_ff=
                r[
                    "d_ff"
                ],
            moving_avg=
                25,
            factor=
                r[
                    "factor"
                ],
            distil=
                True,
            dropout=
                r[
                    "dropout"
                ],
            embed=
                "timeF",
            freq=
                "h",
            activation=
                "gelu",
            output_attention=
                False,
            use_norm=
                1,
            class_strategy=
                "projection",
        )

    if backbone == "TimeMixer":
        return SimpleNamespace(
            task_name=
                "long_term_forecast",
            seq_len=
                r[
                    "seq_len"
                ],
            label_len=
                r[
                    "label_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            top_k=
                5,
            num_kernels=
                6,
            enc_in=
                n_channels,
            dec_in=
                n_channels,
            c_out=
                n_channels,
            d_model=
                r[
                    "d_model"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            e_layers=
                r[
                    "e_layers"
                ],
            d_layers=
                1,
            d_ff=
                r[
                    "d_ff"
                ],
            moving_avg=
                25,
            factor=
                r[
                    "factor"
                ],
            distil=
                True,
            dropout=
                r[
                    "dropout"
                ],
            embed=
                "timeF",
            freq=
                "h",
            activation=
                "gelu",
            output_attention=
                False,
            channel_independence=
                1,
            decomp_method=
                "moving_avg",
            use_norm=
                1,
            down_sampling_layers=
                r[
                    "down_sampling_layers"
                ],
            down_sampling_window=
                r[
                    "down_sampling_window"
                ],
            down_sampling_method=
                r[
                    "down_sampling_method"
                ],
            use_future_temporal_feature=
                0,
            features=
                "M",
        )

    raise ValueError(
        backbone
    )


def build_direct_model(
    backbone,
    horizon,
):
    if ACTIVE_MODEL_CLASS is None:
        raise RuntimeError(
            "Call activate_backbone() first."
        )

    cfg = direct_config(
        backbone,
        horizon,
    )

    model = ACTIVE_MODEL_CLASS(
        cfg
    ).float().to(
        DEVICE
    )

    return (
        model,
        cfg,
    )


def direct_seq_len(
    backbone,
):
    return int(
        DIRECT_RECIPES[
            backbone
        ][
            "seq_len"
        ]
    )


def make_direct_batch(
    z,
    anchors,
    backbone,
    horizon,
):
    anchors = np.asarray(
        anchors,
        dtype=np.int64,
    )

    L = direct_seq_len(
        backbone
    )

    x_idx = (
        anchors[
            :,
            None
        ]
        - L
        + np.arange(
            L
        )[
            None,
            :
        ]
    )

    y_idx = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    x = z[
        x_idx,
        :
    ].astype(
        np.float32
    )

    y = z[
        y_idx,
        :
    ].astype(
        np.float32
    )

    return (
        x,
        y,
    )


def forward_direct(
    backbone,
    model,
    x,
    y,
    horizon,
):
    x_t = torch.from_numpy(
        x
    ).to(
        DEVICE
    )

    y_t = torch.from_numpy(
        y
    ).to(
        DEVICE
    )

    if backbone == "PatchTST":
        pred = model(
            x_t
        )[
            :,
            -horizon:,
            :
        ]

    elif backbone == "iTransformer":
        label_len = DIRECT_RECIPES[
            backbone
        ][
            "label_len"
        ]

        dec_inp = torch.cat(
            [
                x_t[
                    :,
                    -label_len:,
                    :
                ],
                torch.zeros_like(
                    y_t
                ),
            ],
            dim=1,
        )

        pred = model(
            x_t,
            None,
            dec_inp,
            None,
        )[
            :,
            -horizon:,
            :
        ]

    elif backbone == "TimeMixer":
        pred = model(
            x_t,
            None,
            None,
            None,
        )[
            :,
            -horizon:,
            :
        ]

    else:
        raise ValueError(
            backbone
        )

    return (
        pred.float(),
        y_t.float(),
        x_t,
    )


@torch.no_grad()
def direct_residual_block(
    model,
    z,
    marks_unused,
    anchors,
    horizon,
):
    backbone = CURRENT_BACKBONE

    x, y = make_direct_batch(
        z,
        anchors,
        backbone,
        horizon,
    )

    pred, true, x_t = forward_direct(
        backbone,
        model,
        x,
        y,
        horizon,
    )

    current = x_t[
        :,
        -1:,
        :
    ].float()

    return (
        pred
        - current,
        true
        - current,
    )

# %% [markdown]
# ## 7. Full direct baseline training

# %%
def backbone_dirs(
    backbone,
):
    root = (
        ROOT
        / backbone
    )

    dirs = {
        "root":
            root,
        "full_direct":
            root
            / "full_direct",
        "fold_direct":
            root
            / "fold_direct",
        "oof":
            root
            / "oof",
        "validation":
            root
            / "validation",
        "memory_emb":
            SHARED_MEMORY_EMB_DIR,
        "gate":
            root
            / "gate",
        "history":
            root
            / "history",
        "paired":
            root
            / "paired_test",
        "channel":
            root
            / "channel_test",
        "calibration":
            root
            / "calibration",
    }

    for p in dirs.values():
        if isinstance(
            p,
            Path,
        ):
            p.mkdir(
                parents=True,
                exist_ok=True,
            )

    return dirs


def full_direct_path(
    backbone,
    horizon,
):
    return (
        backbone_dirs(
            backbone
        )[
            "full_direct"
        ]
        / (
            f"Solar_{backbone}_"
            f"H{horizon}.pt"
        )
    )


def full_direct_history_path(
    backbone,
    horizon,
):
    return (
        backbone_dirs(
            backbone
        )[
            "history"
        ]
        / (
            f"Solar_{backbone}_"
            f"H{horizon}_full.csv"
        )
    )


def train_anchors_for_direct(
    backbone,
    boundary,
    horizon,
):
    L = direct_seq_len(
        backbone
    )

    return np.arange(
        L,
        int(
            boundary
        )
        - int(
            horizon
        )
        + 1,
        dtype=np.int64,
    )


@torch.no_grad()
def evaluate_direct_anchors(
    backbone,
    model,
    z,
    anchors,
    horizon,
    batch_size,
):
    model.eval()

    sse = 0.0
    sae = 0.0
    n = 0

    batch_mse = []

    for i in range(
        0,
        len(
            anchors
        ),
        batch_size,
    ):
        a = anchors[
            i:
            i+batch_size
        ]

        x, y = make_direct_batch(
            z,
            a,
            backbone,
            horizon,
        )

        pred, true, _ = forward_direct(
            backbone,
            model,
            x,
            y,
            horizon,
        )

        e = (
            pred
            - true
        )

        batch_mse.append(
            float(
                (
                    e
                    * e
                ).mean()
            )
        )

        sse += float(
            (
                e
                * e
            ).sum()
        )

        sae += float(
            e.abs().sum()
        )

        n += e.numel()

    return {
        "MSE":
            sse
            / n,
        "MAE":
            sae
            / n,
        "BatchAverageMSE":
            float(
                np.mean(
                    batch_mse
                )
            ),
        "Windows":
            len(
                anchors
            ),
    }


def set_epoch_lr_type1(
    optimizer,
    base_lr,
    epoch,
):
    lr = (
        base_lr
        * (
            0.5
            ** max(
                0,
                epoch
                - 1,
            )
        )
    )

    for group in optimizer.param_groups:
        group[
            "lr"
        ] = lr

    return lr


def train_or_load_full_direct(
    backbone,
    horizon,
):
    path = full_direct_path(
        backbone,
        horizon,
    )

    r = DIRECT_RECIPES[
        backbone
    ]

    model, cfg = build_direct_model(
        backbone,
        horizon,
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        ckpt = load_torch(
            path
        )

        model.load_state_dict(
            ckpt[
                "StateDict"
            ]
        )

        model.eval()

        print(
            f"Loaded full direct | "
            f"{backbone} H={horizon} | "
            f"best={ckpt['BestValMSE']:.6f}"
            f"@{ckpt['BestEpoch']}"
        )

        return (
            model,
            ckpt,
        )

    set_seed(
        r[
            "seed"
        ]
    )

    train_anchors = (
        train_anchors_for_direct(
            backbone,
            train_end,
            horizon,
        )
    )

    val_anchors = eval_anchors(
        train_end,
        val_end,
        horizon,
        stride=1,
        lookback=
            direct_seq_len(
                backbone
            ),
    )

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=
            r[
                "learning_rate"
            ],
        weight_decay=
            r[
                "weight_decay"
            ],
    )

    scheduler = None

    if r[
        "scheduler"
    ] in {
        "TST",
        "OneCycle",
    }:
        steps_per_epoch = max(
            1,
            int(
                np.ceil(
                    len(
                        train_anchors
                    )
                    / r[
                        "batch_size"
                    ]
                )
            ),
        )

        scheduler = (
            torch.optim.lr_scheduler.OneCycleLR(
                optimizer,
                steps_per_epoch=
                    steps_per_epoch,
                pct_start=
                    r[
                        "pct_start"
                    ],
                epochs=
                    r[
                        "train_epochs"
                    ],
                max_lr=
                    r[
                        "learning_rate"
                    ],
            )
        )

    best_val = float(
        "inf"
    )

    best_epoch = -1
    best_state = None
    wait = 0
    history = []

    rng = np.random.default_rng(
        r[
            "seed"
        ]
        + horizon
    )

    for epoch in range(
        1,
        r[
            "train_epochs"
        ]
        + 1,
    ):
        model.train()

        if r[
            "scheduler"
        ] == "type1":
            current_lr = set_epoch_lr_type1(
                optimizer,
                r[
                    "learning_rate"
                ],
                epoch,
            )

        order = rng.permutation(
            train_anchors
        )

        losses = []
        t0 = time.time()

        for left in range(
            0,
            len(
                order
            ),
            r[
                "batch_size"
            ],
        ):
            a = order[
                left:
                left
                + r[
                    "batch_size"
                ]
            ]

            if len(
                a
            ) == 0:
                continue

            x, y = make_direct_batch(
                z_full,
                a,
                backbone,
                horizon,
            )

            optimizer.zero_grad(
                set_to_none=True
            )

            pred, true, _ = forward_direct(
                backbone,
                model,
                x,
                y,
                horizon,
            )

            loss = F.mse_loss(
                pred,
                true,
            )

            loss.backward()
            optimizer.step()

            if scheduler is not None:
                scheduler.step()

            losses.append(
                float(
                    loss.item()
                )
            )

        val = evaluate_direct_anchors(
            backbone,
            model,
            z_full,
            val_anchors,
            horizon,
            r[
                "eval_batch"
            ],
        )

        # Validation-only global MSE checkpoint selection.
        val_mse = val[
            "MSE"
        ]

        if (
            best_state is None
            or val_mse
            < best_val
            - 1e-12
        ):
            best_val = val_mse
            best_epoch = epoch

            best_state = {
                k:
                    v.detach()
                    .cpu()
                    .clone()
                for k, v
                in model.state_dict().items()
            }

            wait = 0
        else:
            wait += 1

        if scheduler is not None:
            current_lr = optimizer.param_groups[
                0
            ][
                "lr"
            ]

        history.append({
            "Epoch":
                epoch,
            "TrainMSE":
                float(
                    np.mean(
                        losses
                    )
                ),
            "ValMSE":
                val_mse,
            "ValMAE":
                val[
                    "MAE"
                ],
            "BestValMSE":
                best_val,
            "BestEpoch":
                best_epoch,
            "LR":
                current_lr,
            "Seconds":
                time.time()
                - t0,
        })

        pd.DataFrame(
            history
        ).to_csv(
            full_direct_history_path(
                backbone,
                horizon,
            ),
            index=False,
        )

        print(
            f"{backbone:12s} "
            f"H={horizon:3d} "
            f"ep={epoch:03d} | "
            f"train={history[-1]['TrainMSE']:.6f} | "
            f"val={val_mse:.6f} | "
            f"best={best_val:.6f}@{best_epoch} | "
            f"wait={wait}/{r['patience']}"
        )

        if (
            wait
            >= r[
                "patience"
            ]
        ):
            break

    if best_state is None:
        raise RuntimeError(
            f"No full direct checkpoint for "
            f"{backbone} H={horizon}."
        )

    model.load_state_dict(
        best_state
    )

    model.eval()

    ckpt = {
        "Backbone":
            backbone,
        "Dataset":
            "Solar",
        "Horizon":
            int(
                horizon
            ),
        "SeqLen":
            direct_seq_len(
                backbone
            ),
        "BestEpoch":
            int(
                best_epoch
            ),
        "BestValMSE":
            float(
                best_val
            ),
        "Recipe":
            r,
        "StateDict":
            best_state,
    }

    torch.save(
        ckpt,
        path,
    )

    return (
        model,
        ckpt,
    )

# %% [markdown]
# ## 8. Full direct baseline preflight

# %%
direct_baseline_rows = []

for backbone in BACKBONES:
    CURRENT_BACKBONE = (
        backbone
    )

    DIRS = backbone_dirs(
        backbone
    )

    activate_backbone(
        backbone
    )

    for horizon in HORIZONS:
        model, ckpt = (
            train_or_load_full_direct(
                backbone,
                horizon,
            )
        )

        test_anchors = eval_anchors(
            val_end,
            test_end,
            horizon,
            stride=1,
            lookback=
                direct_seq_len(
                    backbone
                ),
        )

        direct_test = (
            evaluate_direct_anchors(
                backbone,
                model,
                z_full,
                test_anchors,
                horizon,
                DIRECT_RECIPES[
                    backbone
                ][
                    "eval_batch"
                ],
            )
        )

        direct_baseline_rows.append({
            "Backbone":
                backbone,
            "Dataset":
                "Solar",
            "Horizon":
                horizon,
            "SeqLen":
                direct_seq_len(
                    backbone
                ),
            "BestEpoch":
                ckpt[
                    "BestEpoch"
                ],
            "BestValMSE":
                ckpt[
                    "BestValMSE"
                ],
            "DirectTestMSE":
                direct_test[
                    "MSE"
                ],
            "DirectTestMAE":
                direct_test[
                    "MAE"
                ],
            "TestWindows":
                direct_test[
                    "Windows"
                ],
        })

        print(
            f"DIRECT | {backbone:12s} "
            f"H={horizon:3d} | "
            f"MSE={direct_test['MSE']:.6f} | "
            f"MAE={direct_test['MAE']:.6f}"
        )

        del (
            model,
            ckpt,
        )

        gc.collect()

        if torch.cuda.is_available():
            torch.cuda.empty_cache()


direct_baseline_df = pd.DataFrame(
    direct_baseline_rows
)

direct_baseline_df.to_csv(
    ROOT
    / "direct_baselines.csv",
    index=False,
)

display(
    direct_baseline_df
)
# Out:
# Activated PatchTST: /code/stock_regime_retrieval/strong_forecaster/PatchTST_official/PatchTST_supervised/models/PatchTST.py
# Loaded full direct | PatchTST H=96 | best=0.151971@19
# DIRECT | PatchTST     H= 96 | MSE=0.183429 | MAE=0.246145
# Loaded full direct | PatchTST H=192 | best=0.154251@30
# DIRECT | PatchTST     H=192 | MSE=0.188770 | MAE=0.240918
# Loaded full direct | PatchTST H=336 | best=0.166381@27
# DIRECT | PatchTST     H=336 | MSE=0.199593 | MAE=0.253637
# Loaded full direct | PatchTST H=720 | best=0.160741@43
# DIRECT | PatchTST     H=720 | MSE=0.213913 | MAE=0.260529
# Activated iTransformer: /code/stock_regime_retrieval/strong_forecaster/iTransformer_official/model/iTransformer.py
# Loaded full direct | iTransformer H=96 | best=0.153130@6
# DIRECT | iTransformer H= 96 | MSE=0.204083 | MAE=0.229920
# Loaded full direct | iTransformer H=192 | best=0.173252@6
# DIRECT | iTransformer H=192 | MSE=0.244628 | MAE=0.263545
# Loaded full direct | iTransformer H=336 | best=0.178269@5
# DIRECT | iTransformer H=336 | MSE=0.252072 | MAE=0.275291
# Loaded full direct | iTransformer H=720 | best=0.176509@10
# DIRECT | iTransformer H=720 | MSE=0.252617 | MAE=0.275918
# Activated TimeMixer: /code/stock_regime_retrieval/strong_forecaster/TimeMixer_official/models/TimeMixer.py
# Loaded full direct | TimeMixer H=96 | best=0.157489@17
# DIRECT | TimeMixer    H= 96 | MSE=0.195299 | MAE=0.241748
# Loaded full direct | TimeMixer H=192 | best=0.176387@16
# DIRECT | TimeMixer    H=192 | MSE=0.228547 | MAE=0.269627
# Loaded full direct | TimeMixer H=336 | best=0.183921@12
# DIRECT | TimeMixer    H=336 | MSE=0.255755 | MAE=0.288708
# Loaded full direct | TimeMixer H=720 | best=0.182301@15
# DIRECT | TimeMixer    H=720 | MSE=0.253337 | MAE=0.286785
#         Backbone Dataset  Horizon  SeqLen  BestEpoch  BestValMSE  DirectTestMSE  DirectTestMAE  TestWindows
# 0       PatchTST   Solar       96     336         19    0.151971       0.183429       0.246145        10417
# 1       PatchTST   Solar      192     336         30    0.154251       0.188770       0.240918        10321
# 2       PatchTST   Solar      336     336         27    0.166381       0.199593       0.253637        10177
# 3       PatchTST   Solar      720     336         43    0.160741       0.213913       0.260529         9793
# 4   iTransformer   Solar       96      96          6    0.153130       0.204083       0.229920        10417
# 5   iTransformer   Solar      192      96          6    0.173252       0.244628       0.263545        10321
# 6   iTransformer   Solar      336      96          5    0.178269       0.252072       0.275291        10177
# 7   iTransformer   Solar      720      96         10    0.176509       0.252617       0.275918         9793
# 8      TimeMixer   Solar       96      96         17    0.157489       0.195299       0.241748        10417
# 9      TimeMixer   Solar      192      96         16    0.176387       0.228547       0.269627        10321
# 10     TimeMixer   Solar      336      96         12    0.183921       0.255755       0.288708        10177
# 11     TimeMixer   Solar      720      96         15    0.182301       0.253337       0.286785         9793

# %% [markdown]
# ## 9. Frozen Solar predictive retriever checkpoints
#
# 이 실험에서는 Solar에서 이미 학습된 retriever를 그대로 사용합니다.
#
# 이는 계산을 줄이기 위한 것뿐 아니라,
# **backbone을 바꿀 때 retriever를 재튜닝하지 않는다는 연구 질문**을 유지하기 위한 것입니다.
#
# 다만 Solar 자체가 development dataset이라는 점 때문에,
# 이 결과는 Exchange/Traffic과 같은 independent confirmation으로 세지 않습니다.

# %%
def inv_softplus(
    x,
):
    return math.log(
        math.exp(
            float(
                x
            )
        )
        - 1.0
    )


class PredictivePatchEncoder(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.patch_proj = nn.Linear(
            REP_PATCH_LEN,
            REP_D_MODEL,
        )

        self.pos_embed = nn.Parameter(
            torch.zeros(
                1,
                REP_NUM_PATCHES,
                REP_D_MODEL,
            )
        )

        nn.init.trunc_normal_(
            self.pos_embed,
            std=0.02,
        )

        layer = nn.TransformerEncoderLayer(
            d_model=
                REP_D_MODEL,
            nhead=
                REP_N_HEADS,
            dim_feedforward=
                REP_D_FF,
            dropout=
                REP_DROPOUT,
            activation=
                "gelu",
            batch_first=
                True,
            norm_first=
                True,
        )

        self.encoder = nn.TransformerEncoder(
            layer,
            num_layers=
                REP_LAYERS,
        )

        self.norm = nn.LayerNorm(
            REP_D_MODEL
        )

        self.proj = nn.Linear(
            REP_D_MODEL,
            REP_DIM,
        )

    def forward(
        self,
        x,
    ):
        p = x.unfold(
            1,
            REP_PATCH_LEN,
            REP_PATCH_STRIDE,
        )

        h = (
            self.patch_proj(
                p
            )
            + self.pos_embed[
                :,
                :p.shape[
                    1
                ],
            ]
        )

        h = self.encoder(
            h
        ).mean(
            dim=1
        )

        h = self.proj(
            self.norm(
                h
            )
        )

        return F.normalize(
            h,
            dim=-1,
            eps=1e-8,
        )


class EmbeddingOnlyRetriever(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.encoder = (
            PredictivePatchEncoder()
        )

        self.raw_gamma = nn.Parameter(
            torch.tensor(
                inv_softplus(
                    1.0
                ),
                dtype=torch.float32,
            )
        )

    @property
    def gamma(
        self,
    ):
        return F.softplus(
            self.raw_gamma
        )

    def encode(
        self,
        x,
    ):
        return self.encoder(
            x
        )


def ret_amp():
    if RETRIEVER_USE_AMP:
        return torch.autocast(
            device_type="cuda",
            dtype=torch.float16,
        )

    return nullcontext()




EXP10_SOLAR_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "solar_predictive_representation"
)

EXP12_SOLAR_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "solar_crossfit_adaptive_gate"
)

EXP10_SOLAR_CKPT = (
    EXP10_SOLAR_ROOT
    / "checkpoints"
)

EXP12_SOLAR_FOLD_RET = (
    EXP12_SOLAR_ROOT
    / "fold_retriever_checkpoints"
)


def full_retriever_ckpt_path(
    name,
    horizon,
):
    if name != "Solar":
        raise ValueError(
            name
        )

    return (
        EXP10_SOLAR_CKPT
        / (
            f"Solar_L96_H{horizon}_"
            "EmbeddingOnly_Listwise_seed0.pt"
        )
    )


def fold_retriever_ckpt_path(
    name,
    horizon,
    fold,
):
    if name != "Solar":
        raise ValueError(
            name
        )

    return (
        EXP12_SOLAR_FOLD_RET
        / (
            f"Solar_H{horizon}_"
            f"Fold{fold}_"
            "EmbeddingOnly.pt"
        )
    )


def load_frozen_retriever(
    path,
):
    if not Path(
        path
    ).is_file():
        raise FileNotFoundError(
            path
        )

    ckpt = load_torch(
        path
    )

    model = EmbeddingOnlyRetriever().to(
        DEVICE
    )

    state = (
        ckpt[
            "StateDict"
        ]
        if isinstance(
            ckpt,
            dict,
        )
        and "StateDict"
        in ckpt
        else ckpt
    )

    # Backward-compatible checkpoint key handling.
    #
    # The frozen retriever checkpoints from the earlier experiments
    # were saved with:
    #   encoder.out_norm.* / encoder.out_proj.*
    # while this notebook's PredictivePatchEncoder currently exposes:
    #   encoder.norm.* / encoder.proj.*
    #
    # The modules are architecturally identical; only the attribute
    # names differ. Remap the legacy keys and still load strictly so
    # that any real architecture mismatch is not silently ignored.
    state = dict(
        state
    )

    legacy_to_current = {
        "encoder.out_norm.weight":
            "encoder.norm.weight",
        "encoder.out_norm.bias":
            "encoder.norm.bias",
        "encoder.out_proj.weight":
            "encoder.proj.weight",
        "encoder.out_proj.bias":
            "encoder.proj.bias",
    }

    for old_key, new_key in legacy_to_current.items():
        if (
            old_key in state
            and new_key not in state
        ):
            state[
                new_key
            ] = state.pop(
                old_key
            )

    model.load_state_dict(
        state,
        strict=True,
    )

    model.eval()

    for p in model.parameters():
        p.requires_grad_(
            False
        )

    return (
        model,
        ckpt,
    )

# %%
retriever_preflight_rows = []

for horizon in HORIZONS:
    retriever_preflight_rows.append({
        "Horizon":
            horizon,
        "Kind":
            "Full",
        "Path":
            str(
                full_retriever_ckpt_path(
                    "Solar",
                    horizon,
                )
            ),
        "Exists":
            full_retriever_ckpt_path(
                "Solar",
                horizon,
            ).is_file(),
    })

    for fold in range(
        1,
        4,
    ):
        retriever_preflight_rows.append({
            "Horizon":
                horizon,
            "Kind":
                f"Fold{fold}",
            "Path":
                str(
                    fold_retriever_ckpt_path(
                        "Solar",
                        horizon,
                        fold,
                    )
                ),
            "Exists":
                fold_retriever_ckpt_path(
                    "Solar",
                    horizon,
                    fold,
                ).is_file(),
        })


retriever_preflight = pd.DataFrame(
    retriever_preflight_rows
)

display(
    retriever_preflight
)

missing = retriever_preflight[
    ~retriever_preflight[
        "Exists"
    ]
]

if len(
    missing
):
    raise FileNotFoundError(
        "Missing existing Solar frozen retriever checkpoint(s). "
        "Experiment 10/12 checkpoints are required before Experiment 27."
    )

print(
    "PASS: all 4 full + 12 fold Solar retriever checkpoints exist."
)
# Out:
#     Horizon   Kind                                               Path  Exists
# 0        96   Full  /data/dataset/strong_forecaster/solar_predicti...    True
# 1        96  Fold1  /data/dataset/strong_forecaster/solar_crossfit...    True
# 2        96  Fold2  /data/dataset/strong_forecaster/solar_crossfit...    True
# 3        96  Fold3  /data/dataset/strong_forecaster/solar_crossfit...    True
# 4       192   Full  /data/dataset/strong_forecaster/solar_predicti...    True
# 5       192  Fold1  /data/dataset/strong_forecaster/solar_crossfit...    True
# 6       192  Fold2  /data/dataset/strong_forecaster/solar_crossfit...    True
# 7       192  Fold3  /data/dataset/strong_forecaster/solar_crossfit...    True
# 8       336   Full  /data/dataset/strong_forecaster/solar_predicti...    True
# 9       336  Fold1  /data/dataset/strong_forecaster/solar_crossfit...    True
# 10      336  Fold2  /data/dataset/strong_forecaster/solar_crossfit...    True
# 11      336  Fold3  /data/dataset/strong_forecaster/solar_crossfit...    True
# 12      720   Full  /data/dataset/strong_forecaster/solar_predicti...    True
# 13      720  Fold1  /data/dataset/strong_forecaster/solar_crossfit...    True
# 14      720  Fold2  /data/dataset/strong_forecaster/solar_crossfit...    True
# 15      720  Fold3  /data/dataset/strong_forecaster/solar_crossfit...    True
# PASS: all 4 full + 12 fold Solar retriever checkpoints exist.

# %% [markdown]
# ## 10. Retrieval time-series utilities

# %%
def retrieval_anchor_batch(
    name,
):
    C = DATA[
        name
    ][
        "n_channels"
    ]

    return max(
        1,
        TARGET_RETRIEVAL_PAIRS
        // C,
    )


def batch_pattern(
    x,
):
    x = np.asarray(
        x,
        np.float32,
    )

    xc = (
        x
        - x.mean(
            axis=-1,
            keepdims=True,
        )
    )

    n = np.linalg.norm(
        xc,
        axis=-1,
        keepdims=True,
    )

    return np.where(
        n > EPS,
        xc
        / np.maximum(
            n,
            EPS,
        ),
        0.0,
    ).astype(
        np.float32
    )


def context7(
    x,
):
    x = np.asarray(
        x,
        np.float32,
    )

    short = max(
        8,
        RET_SEQ_LEN
        // 4,
    )

    m = x.mean(
        axis=-1
    )

    s = (
        x.std(
            axis=-1
        )
        + EPS
    )

    f1 = (
        x[
            ...,
            -1
        ]
        - m
    ) / s

    f2 = (
        x[
            ...,
            -short:
        ].mean(
            axis=-1
        )
        - m
    ) / s

    f3 = (
        x[
            ...,
            -1
        ]
        - x[
            ...,
            -short
        ]
    ) / s

    f4 = (
        x[
            ...,
            -1
        ]
        - x[
            ...,
            0
        ]
    ) / s

    df = np.diff(
        x,
        axis=-1,
    )

    ds = np.diff(
        x[
            ...,
            -short:
        ],
        axis=-1,
    )

    f5 = (
        ds.std(
            axis=-1
        )
        + EPS
    ) / (
        df.std(
            axis=-1
        )
        + EPS
    )

    t = np.linspace(
        -1.0,
        1.0,
        RET_SEQ_LEN,
        dtype=np.float32,
    )

    t = (
        t
        - t.mean()
    )

    f6 = (
        np.sum(
            t
            * (
                x
                - m[
                    ...,
                    None
                ]
            ),
            axis=-1,
        )
        / (
            np.sum(
                t
                * t
            )
            + EPS
        )
    ) / s

    a = x[
        ...,
        :-1
    ]

    b = x[
        ...,
        1:
    ]

    a = (
        a
        - a.mean(
            axis=-1,
            keepdims=True,
        )
    )

    b = (
        b
        - b.mean(
            axis=-1,
            keepdims=True,
        )
    )

    f7 = np.sum(
        a
        * b,
        axis=-1,
    ) / (
        np.sqrt(
            np.sum(
                a
                * a,
                axis=-1,
            )
            * np.sum(
                b
                * b,
                axis=-1,
            )
        )
        + EPS
    )

    return np.stack(
        [
            f1,
            f2,
            f3,
            f4,
            f5,
            f6,
            f7,
        ],
        axis=-1,
    ).astype(
        np.float32
    )


def extract_channel(
    z,
    c,
    anchors,
    horizon,
):
    anchors = np.asarray(
        anchors,
        np.int64,
    )

    pi = (
        anchors[
            :,
            None
        ]
        - RET_SEQ_LEN
        + np.arange(
            RET_SEQ_LEN
        )[
            None,
            :
        ]
    )

    fi = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    past = z[
        pi,
        c,
    ].astype(
        np.float32
    )

    future = z[
        fi,
        c,
    ].astype(
        np.float32
    )

    current = z[
        anchors
        - 1,
        c,
    ].astype(
        np.float32
    )

    future_residual = (
        future
        - current[
            :,
            None
        ]
    ).astype(
        np.float32
    )

    return (
        past,
        future_residual,
    )


def build_memory(
    z,
    channels,
    boundary,
    horizon,
):
    memory_anchors = np.arange(
        RET_SEQ_LEN,
        int(
            boundary
        )
        - horizon
        + 1,
        MEMORY_STRIDE,
        dtype=np.int64,
    )

    if len(
        memory_anchors
    ) < TOP_K:
        raise ValueError(
            "Insufficient admissible memory."
        )

    past = np.empty(
        (
            channels,
            len(
                memory_anchors
            ),
            RET_SEQ_LEN,
        ),
        dtype=np.float32,
    )

    pattern = np.empty_like(
        past
    )

    future = np.empty(
        (
            channels,
            len(
                memory_anchors
            ),
            horizon,
        ),
        dtype=np.float32,
    )

    for c in range(
        channels
    ):
        p, f = extract_channel(
            z,
            c,
            memory_anchors,
            horizon,
        )

        past[
            c
        ] = p

        pattern[
            c
        ] = batch_pattern(
            p
        )

        future[
            c
        ] = f

    return {
        "anchors":
            memory_anchors,
        "past":
            past,
        "pattern":
            pattern,
        "future":
            future,
        "M":
            len(
                memory_anchors
            ),
        "boundary":
            int(
                boundary
            ),
    }


def query_pairs(
    z,
    anchors,
    channels,
    horizon,
):
    anchors = np.asarray(
        anchors,
        np.int64,
    )

    channels = np.asarray(
        channels,
        np.int64,
    )

    pi = (
        anchors[
            :,
            None
        ]
        - RET_SEQ_LEN
        + np.arange(
            RET_SEQ_LEN
        )[
            None,
            :
        ]
    )

    fi = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    past = z[
        pi,
        channels[
            :,
            None
        ],
    ].astype(
        np.float32
    )

    future = z[
        fi,
        channels[
            :,
            None
        ],
    ].astype(
        np.float32
    )

    current = z[
        anchors
        - 1,
        channels,
    ].astype(
        np.float32
    )

    true_residual = (
        future
        - current[
            :,
            None
        ]
    ).astype(
        np.float32
    )

    return (
        past,
        batch_pattern(
            past
        ),
        context7(
            past
        ),
        true_residual,
    )

# %% [markdown]
# ## 11. Shared cached memory embeddings

# %%
@torch.no_grad()
def encode_np(
    model,
    x,
    chunk=512,
):
    parts = []

    for i in range(
        0,
        len(
            x
        ),
        chunk,
    ):
        t = torch.from_numpy(
            x[
                i:
                i+chunk
            ]
        ).to(
            DEVICE
        )

        with ret_amp():
            e = model.encode(
                t
            ).float()

        parts.append(
            e.cpu()
        )

        del (
            t,
            e,
        )

    return torch.cat(
        parts,
        dim=0,
    ).numpy().astype(
        np.float32
    )


def memory_embedding_path(
    name,
    horizon,
    tag,
):
    return (
        SHARED_MEMORY_EMB_DIR
        / (
            f"{name}_H{horizon}_"
            f"{tag}_emb.npy"
        )
    )


@torch.no_grad()
def memory_gpu_cached(
    name,
    horizon,
    tag,
    model,
    memory,
    channels,
):
    path = memory_embedding_path(
        name,
        horizon,
        tag,
    )

    expected = (
        channels,
        memory[
            "M"
        ],
        REP_DIM,
    )

    emb_np = None

    if (
        path.exists()
        and RESUME
        and not FORCE
    ):
        candidate = np.load(
            path,
            mmap_mode=None,
        )

        if (
            tuple(
                candidate.shape
            )
            == expected
        ):
            emb_np = candidate.astype(
                np.float32,
                copy=False,
            )

            print(
                "Loaded memory embedding:",
                path.name,
            )

    if emb_np is None:
        emb_np = np.empty(
            expected,
            dtype=np.float32,
        )

        print(
            "Building memory embedding:",
            path.name,
            expected,
        )

        for c in range(
            channels
        ):
            emb_np[
                c
            ] = encode_np(
                model,
                memory[
                    "past"
                ][
                    c
                ],
            )

            if (
                c == 0
                or (
                    c + 1
                )
                % 50
                == 0
                or (
                    c + 1
                    == channels
                )
            ):
                print(
                    f"  channel "
                    f"{c+1}/{channels}"
                )

        np.save(
            path,
            emb_np,
        )

    return {
        "emb":
            torch.from_numpy(
                emb_np
            ).to(
                DEVICE
            ),
        "pattern":
            torch.from_numpy(
                memory[
                    "pattern"
                ]
            ).to(
                DEVICE
            ),
        "future":
            torch.from_numpy(
                memory[
                    "future"
                ]
            ).to(
                DEVICE
            ),
    }

# %% [markdown]
# ## 12. Frozen retrieval inference

# %%
@torch.no_grad()
def retrieve(
    model,
    memory_gpu_obj,
    z,
    anchors,
    channels,
    horizon,
):
    (
        past,
        pattern,
        ctx,
        true,
    ) = query_pairs(
        z,
        anchors,
        channels,
        horizon,
    )

    past_t = torch.from_numpy(
        past
    ).to(
        DEVICE
    )

    pattern_t = torch.from_numpy(
        pattern
    ).to(
        DEVICE
    )

    with ret_amp():
        qemb = model.encode(
            past_t
        )

    qemb = qemb.float()

    memb = memory_gpu_obj[
        "emb"
    ][
        channels
    ]

    sim = torch.bmm(
        qemb[
            :,
            None,
            :
        ],
        memb.transpose(
            1,
            2,
        ),
    ).squeeze(
        1
    )

    score = (
        model.gamma
        * sim
    )

    idx = torch.topk(
        score,
        TOP_K,
        dim=1,
    ).indices

    row = torch.arange(
        len(
            channels
        ),
        device=DEVICE,
    )[
        :,
        None
    ]

    pfull = torch.bmm(
        pattern_t[
            :,
            None,
            :
        ],
        memory_gpu_obj[
            "pattern"
        ][
            channels
        ].transpose(
            1,
            2,
        ),
    ).squeeze(
        1
    )

    return {
        "score":
            score[
                row,
                idx
            ],
        "sim":
            sim[
                row,
                idx
            ],
        "pattern":
            pfull[
                row,
                idx
            ],
        "cand":
            memory_gpu_obj[
                "future"
            ][
                channels[
                    :,
                    None
                ],
                idx,
            ],
        "ctx":
            torch.from_numpy(
                ctx
            ).to(
                DEVICE
            ),
        "true":
            torch.from_numpy(
                true
            ).to(
                DEVICE
            ),
    }

# %% [markdown]
# ## 13. Frozen 26-dimensional adaptive gate

# %%
class CrossFitAdaptiveGate(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(
                GATE_DIM,
                64,
            ),
            nn.LayerNorm(
                64
            ),
            nn.GELU(),
            nn.Dropout(
                0.1
            ),
            nn.Linear(
                64,
                32,
            ),
            nn.GELU(),
            nn.Dropout(
                0.1
            ),
            nn.Linear(
                32,
                1,
            ),
        )

        nn.init.normal_(
            self.net[
                -1
            ].weight,
            mean=0.0,
            std=1e-3,
        )

        nn.init.constant_(
            self.net[
                -1
            ].bias,
            math.log(
                0.1
                / 0.9
            ),
        )

    def forward(
        self,
        x,
    ):
        return torch.sigmoid(
            self.net(
                x
            ).squeeze(
                -1
            )
        )


def score_entropy(
    s,
):
    p = torch.softmax(
        s,
        dim=1,
    )

    return (
        -(
            p
            * torch.log(
                p.clamp_min(
                    1e-8
                )
            )
        ).sum(
            dim=1
        )
        / math.log(
            TOP_K
        )
    )


def feature_cosine(
    a,
    b,
):
    return (
        (
            a
            * b
        ).sum(
            dim=1
        )
        / (
            torch.sqrt(
                (
                    a
                    * a
                ).sum(
                    dim=1
                )
                + 1e-8
            )
            * torch.sqrt(
                (
                    b
                    * b
                ).sum(
                    dim=1
                )
                + 1e-8
            )
        )
    )


def gate_features(
    r,
    retrieval,
    direct,
):
    s = r[
        "score"
    ]

    sim = r[
        "sim"
    ]

    pattern = r[
        "pattern"
    ]

    sorted_s = torch.sort(
        s,
        dim=1,
        descending=True,
    ).values

    cand_std = r[
        "cand"
    ].std(
        dim=1,
        unbiased=False,
    )

    disp_rms = torch.sqrt(
        (
            cand_std
            * cand_std
        ).mean(
            dim=1
        )
        + 1e-8
    )

    disp_mean = cand_std.mean(
        dim=1
    )

    direct_rms = torch.sqrt(
        (
            direct
            * direct
        ).mean(
            dim=1
        )
        + 1e-8
    )

    retrieval_rms = torch.sqrt(
        (
            retrieval
            * retrieval
        ).mean(
            dim=1
        )
        + 1e-8
    )

    disagreement = (
        retrieval
        - direct
    )

    disagreement_rms = torch.sqrt(
        (
            disagreement
            * disagreement
        ).mean(
            dim=1
        )
        + 1e-8
    )

    relative_disagreement = (
        disagreement_rms
        / (
            direct_rms
            + retrieval_rms
            + 1e-6
        )
    )

    scalars = torch.stack(
        [
            s.mean(
                dim=1
            ),
            s.std(
                dim=1,
                unbiased=False,
            ),
            s.max(
                dim=1
            ).values,
            sorted_s[
                :,
                0
            ]
            - sorted_s[
                :,
                1
            ],
            s.max(
                dim=1
            ).values
            - s.mean(
                dim=1
            ),
            score_entropy(
                s
            ),
            sim.mean(
                dim=1
            ),
            sim.std(
                dim=1,
                unbiased=False,
            ),
            sim.max(
                dim=1
            ).values,
            pattern.mean(
                dim=1
            ),
            pattern.std(
                dim=1,
                unbiased=False,
            ),
            pattern.max(
                dim=1
            ).values,
            disp_rms,
            disp_mean,
            direct_rms,
            retrieval_rms,
            disagreement_rms,
            relative_disagreement,
            feature_cosine(
                direct,
                retrieval,
            ),
        ],
        dim=1,
    )

    out = torch.cat(
        [
            r[
                "ctx"
            ],
            scalars,
        ],
        dim=1,
    )

    if out.shape[
        1
    ] != GATE_DIM:
        raise RuntimeError(
            f"Gate feature dimension mismatch: "
            f"{out.shape}"
        )

    return out


def abc_terms(
    direct,
    retrieval,
    true,
):
    e = (
        direct
        - true
    )

    delta = (
        retrieval
        - direct
    )

    return torch.stack(
        [
            (
                e
                * e
            ).mean(
                dim=1
            ),
            (
                e
                * delta
            ).mean(
                dim=1
            ),
            (
                delta
                * delta
            ).mean(
                dim=1
            ),
        ],
        dim=1,
    )

# %% [markdown]
# ## 14. Fold-specific direct training

# %%
def fold_direct_path(
    name,
    horizon,
    fold,
):
    return (
        DIRS[
            "fold_direct"
        ]
        / (
            f"{name}_{CURRENT_BACKBONE}_"
            f"H{horizon}_F{fold}.pt"
        )
    )


def fold_direct_history_path(
    horizon,
    fold,
):
    return (
        DIRS[
            "history"
        ]
        / (
            f"Solar_{CURRENT_BACKBONE}_"
            f"H{horizon}_F{fold}_direct.csv"
        )
    )


def train_fold_direct(
    backbone,
    horizon,
    z,
    prefix,
    fixed_epochs,
    fold,
):
    path = fold_direct_path(
        "Solar",
        horizon,
        fold,
    )

    r = DIRECT_RECIPES[
        backbone
    ]

    model, cfg = build_direct_model(
        backbone,
        horizon,
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        ckpt = load_torch(
            path
        )

        model.load_state_dict(
            ckpt[
                "StateDict"
            ]
        )

        model.eval()

        print(
            "Loaded fold direct:",
            path.name,
        )

        return (
            model,
            ckpt,
        )

    seed = (
        r[
            "seed"
        ]
        + 10_000
        + horizon
        * 10
        + fold
    )

    set_seed(
        seed
    )

    anchors = train_anchors_for_direct(
        backbone,
        prefix,
        horizon,
    )

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=
            r[
                "learning_rate"
            ],
        weight_decay=
            r[
                "weight_decay"
            ],
    )

    scheduler = None

    if r[
        "scheduler"
    ] in {
        "TST",
        "OneCycle",
    }:
        steps_per_epoch = max(
            1,
            int(
                np.ceil(
                    len(
                        anchors
                    )
                    / r[
                        "batch_size"
                    ]
                )
            ),
        )

        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer,
            steps_per_epoch=
                steps_per_epoch,
            pct_start=
                r[
                    "pct_start"
                ],
            # Preserve the full-model schedule budget.
            epochs=
                r[
                    "train_epochs"
                ],
            max_lr=
                r[
                    "learning_rate"
                ],
        )

    rng = np.random.default_rng(
        seed
        + 1
    )

    history = []

    for epoch in range(
        1,
        int(
            fixed_epochs
        )
        + 1,
    ):
        model.train()

        if r[
            "scheduler"
        ] == "type1":
            current_lr = set_epoch_lr_type1(
                optimizer,
                r[
                    "learning_rate"
                ],
                epoch,
            )

        order = rng.permutation(
            anchors
        )

        losses = []
        t0 = time.time()

        for left in range(
            0,
            len(
                order
            ),
            r[
                "batch_size"
            ],
        ):
            a = order[
                left:
                left
                + r[
                    "batch_size"
                ]
            ]

            if len(
                a
            ) == 0:
                continue

            x, y = make_direct_batch(
                z,
                a,
                backbone,
                horizon,
            )

            optimizer.zero_grad(
                set_to_none=True
            )

            pred, true, _ = forward_direct(
                backbone,
                model,
                x,
                y,
                horizon,
            )

            loss = F.mse_loss(
                pred,
                true,
            )

            loss.backward()
            optimizer.step()

            if scheduler is not None:
                scheduler.step()

            losses.append(
                float(
                    loss.item()
                )
            )

        if scheduler is not None:
            current_lr = optimizer.param_groups[
                0
            ][
                "lr"
            ]

        history.append({
            "Epoch":
                epoch,
            "TrainMSE":
                float(
                    np.mean(
                        losses
                    )
                ),
            "LR":
                current_lr,
            "Seconds":
                time.time()
                - t0,
        })

        pd.DataFrame(
            history
        ).to_csv(
            fold_direct_history_path(
                horizon,
                fold,
            ),
            index=False,
        )

        print(
            f"Fold {backbone:12s} "
            f"H={horizon:3d} F{fold} "
            f"ep={epoch:02d}/{fixed_epochs} | "
            f"train={history[-1]['TrainMSE']:.6f}"
        )

    model.eval()

    state = {
        k:
            v.detach()
            .cpu()
            .clone()
        for k, v
        in model.state_dict().items()
    }

    ckpt = {
        "Backbone":
            backbone,
        "Dataset":
            "Solar",
        "Horizon":
            horizon,
        "Fold":
            fold,
        "Prefix":
            int(
                prefix
            ),
        "FixedEpochs":
            int(
                fixed_epochs
            ),
        "Seed":
            seed,
        "StateDict":
            state,
    }

    torch.save(
        ckpt,
        path,
    )

    return (
        model,
        ckpt,
    )

# %% [markdown]
# ## 15. Efficient OOF gate-data collection

# %%
@torch.no_grad()
def collect_gate_data(
    data,
    horizon,
    direct_model,
    retriever,
    memory_gpu_obj,
    z,
    anchors,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    ret_block = retrieval_anchor_batch(
        name
    )

    direct_block = DIRECT_ANCHOR_BLOCK[
        CURRENT_BACKBONE
    ]

    features = []
    abcs = []
    anchors_out = []
    channels_out = []

    for outer in range(
        0,
        len(
            anchors
        ),
        direct_block,
    ):
        a_big = anchors[
            outer:
            outer+direct_block
        ]

        direct_big, true_big = (
            direct_residual_block(
                direct_model,
                z,
                data[
                    "marks"
                ],
                a_big,
                horizon,
            )
        )

        # [A, H, C] -> [A, C, H]
        direct_big = direct_big.permute(
            0,
            2,
            1,
        ).contiguous()

        true_big = true_big.permute(
            0,
            2,
            1,
        ).contiguous()

        for inner in range(
            0,
            len(
                a_big
            ),
            ret_block,
        ):
            a = a_big[
                inner:
                inner+ret_block
            ]

            A = len(
                a
            )

            pair_anchor = np.repeat(
                a,
                C,
            )

            pair_channel = np.tile(
                np.arange(
                    C,
                    dtype=np.int64,
                ),
                A,
            )

            r = retrieve(
                retriever,
                memory_gpu_obj,
                z,
                pair_anchor,
                pair_channel,
                horizon,
            )

            retrieval = r[
                "cand"
            ].mean(
                dim=1
            )

            d = direct_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            t = true_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            # Strong consistency check:
            # direct true residual must match retrieval true residual.
            max_true_diff = float(
                (
                    t
                    - r[
                        "true"
                    ]
                ).abs().max()
            )

            if (
                max_true_diff
                > 2e-5
            ):
                raise RuntimeError(
                    f"True residual mismatch: "
                    f"{max_true_diff}"
                )

            feat = gate_features(
                r,
                retrieval,
                d,
            )

            abc = abc_terms(
                d,
                retrieval,
                t,
            )

            features.append(
                feat.cpu()
                .numpy()
                .astype(
                    np.float32
                )
            )

            abcs.append(
                abc.cpu()
                .numpy()
                .astype(
                    np.float32
                )
            )

            anchors_out.append(
                pair_anchor
            )

            channels_out.append(
                pair_channel
            )

            del (
                r,
                retrieval,
                d,
                t,
                feat,
                abc,
            )

        del (
            direct_big,
            true_big,
        )

    return {
        "feature":
            np.concatenate(
                features,
                axis=0,
            ),
        "abc":
            np.concatenate(
                abcs,
                axis=0,
            ),
        "anchor":
            np.concatenate(
                anchors_out,
                axis=0,
            ),
        "channel":
            np.concatenate(
                channels_out,
                axis=0,
            ),
    }

# %% [markdown]
# ## 16. OOF and validation caches

# %%
def oof_cache_path(
    name,
    horizon,
    fold,
):
    return (
        DIRS[
            "oof"
        ]
        / (
            f"{name}_H{horizon}_"
            f"F{fold}_oof.npz"
        )
    )


def val_cache_path(
    name,
    horizon,
):
    return (
        DIRS[
            "validation"
        ]
        / (
            f"{name}_H{horizon}_"
            "validation.npz"
        )
    )


def build_oof_fold(
    data,
    horizon,
    fold,
    p0,
    p1,
    fixed_epochs,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    out_path = oof_cache_path(
        name,
        horizon,
        fold,
    )

    if (
        out_path.exists()
        and RESUME
        and not FORCE
    ):
        obj = np.load(
            out_path
        )

        print(
            "Loaded OOF cache:",
            out_path.name,
        )

        return {
            key:
                obj[
                    key
                ]
            for key in [
                "feature",
                "abc",
                "anchor",
                "channel",
            ]
        }

    prefix = int(
        p0
        * data[
            "train_end"
        ]
    )

    oof_end = int(
        p1
        * data[
            "train_end"
        ]
    )

    z, prefix_scaler = prefix_normalize(
        data[
            "raw"
        ],
        prefix,
    )

    direct_model, _ = (
        train_fold_direct(
            CURRENT_BACKBONE,
            horizon,
            z,
            prefix,
            fixed_epochs,
            fold,
        )
    )

    retriever, _ = load_frozen_retriever(
        fold_retriever_ckpt_path(
            name,
            horizon,
            fold,
        )
    )

    memory = build_memory(
        z,
        C,
        prefix,
        horizon,
    )

    memory_gpu_obj = memory_gpu_cached(
        name,
        horizon,
        (
            f"F{fold}_"
            f"prefix{prefix}"
        ),
        retriever,
        memory,
        C,
    )

    anchors = eval_anchors(
        prefix,
        oof_end,
        horizon,
        stride=
            OOF_ANCHOR_STRIDE,
    )

    print(
        f"OOF {name} H={horizon} F{fold}: "
        f"prefix={prefix}, "
        f"end={oof_end}, "
        f"anchors={len(anchors)}, "
        f"pairs={len(anchors)*C}, "
        f"memory/C={memory['M']}"
    )

    out = collect_gate_data(
        data,
        horizon,
        direct_model,
        retriever,
        memory_gpu_obj,
        z,
        anchors,
    )

    np.savez_compressed(
        out_path,
        **out,
    )

    del (
        direct_model,
        retriever,
        memory,
        memory_gpu_obj,
        prefix_scaler,
        z,
    )

    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return out


def build_validation_cache(
    data,
    horizon,
    direct_model,
    retriever,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    path = val_cache_path(
        name,
        horizon,
    )

    if (
        path.exists()
        and RESUME
        and not FORCE
    ):
        obj = np.load(
            path
        )

        print(
            "Loaded validation cache:",
            path.name,
        )

        return {
            key:
                obj[
                    key
                ]
            for key in [
                "feature",
                "abc",
                "anchor",
                "channel",
            ]
        }

    memory = build_memory(
        data[
            "z"
        ],
        C,
        data[
            "train_end"
        ],
        horizon,
    )

    memory_gpu_obj = memory_gpu_cached(
        name,
        horizon,
        "validation_train_memory",
        retriever,
        memory,
        C,
    )

    anchors = eval_anchors(
        data[
            "train_end"
        ],
        data[
            "val_end"
        ],
        horizon,
        stride=1,
    )

    print(
        f"Validation {name} H={horizon}: "
        f"anchors={len(anchors)}, "
        f"pairs={len(anchors)*C}, "
        f"memory/C={memory['M']}"
    )

    out = collect_gate_data(
        data,
        horizon,
        direct_model,
        retriever,
        memory_gpu_obj,
        data[
            "z"
        ],
        anchors,
    )

    np.savez_compressed(
        path,
        **out,
    )

    del (
        memory,
        memory_gpu_obj,
    )

    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return out

# %% [markdown]
# ## 17. Cross-fitted gate and validation-only calibration

# %%
def fit_feature_scaler(
    x,
):
    median = np.median(
        x,
        axis=0,
    ).astype(
        np.float32
    )

    q25 = np.percentile(
        x,
        25,
        axis=0,
    )

    q75 = np.percentile(
        x,
        75,
        axis=0,
    )

    iqr = (
        q75
        - q25
    ).astype(
        np.float32
    )

    iqr = np.where(
        iqr < 1e-5,
        1.0,
        iqr,
    ).astype(
        np.float32
    )

    return (
        median,
        iqr,
    )


def scale_features(
    x,
    median,
    iqr,
):
    return np.clip(
        (
            x
            - median
        )
        / iqr,
        -8.0,
        8.0,
    ).astype(
        np.float32
    )


def gate_loss(
    alpha,
    abc,
):
    return (
        abc[
            :,
            0
        ]
        + 2.0
        * alpha
        * abc[
            :,
            1
        ]
        + alpha
        * alpha
        * abc[
            :,
            2
        ]
    ).mean()


def gate_checkpoint_path(
    name,
    horizon,
):
    return (
        DIRS[
            "gate"
        ]
        / (
            f"{name}_H{horizon}_"
            "gate.pt"
        )
    )


def train_gate_epoch(
    model,
    optimizer,
    x,
    abc,
    rng,
):
    model.train()

    order = rng.permutation(
        len(
            x
        )
    )

    losses = []

    for i in range(
        0,
        len(
            order
        ),
        GATE_BATCH,
    ):
        ids = order[
            i:
            i+GATE_BATCH
        ]

        xt = torch.from_numpy(
            x[
                ids
            ]
        ).to(
            DEVICE
        )

        at = torch.from_numpy(
            abc[
                ids
            ]
        ).to(
            DEVICE
        )

        optimizer.zero_grad(
            set_to_none=True
        )

        alpha = model(
            xt
        )

        loss = gate_loss(
            alpha,
            at,
        )

        loss.backward()
        optimizer.step()

        losses.append(
            float(
                loss.item()
            )
        )

        del (
            xt,
            at,
            alpha,
            loss,
        )

    return float(
        np.mean(
            losses
        )
    )


@torch.no_grad()
def evaluate_gate(
    model,
    x,
    abc,
):
    model.eval()

    total = 0.0
    n = 0
    alpha_sum = 0.0

    for i in range(
        0,
        len(
            x
        ),
        GATE_BATCH,
    ):
        xt = torch.from_numpy(
            x[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        at = torch.from_numpy(
            abc[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        alpha = model(
            xt
        )

        each = (
            at[
                :,
                0
            ]
            + 2.0
            * alpha
            * at[
                :,
                1
            ]
            + alpha
            * alpha
            * at[
                :,
                2
            ]
        )

        total += float(
            each.sum()
        )

        n += len(
            alpha
        )

        alpha_sum += float(
            alpha.sum()
        )

        del (
            xt,
            at,
            alpha,
            each,
        )

    return (
        total
        / n,
        alpha_sum
        / n,
    )


def train_crossfit_gate(
    name,
    horizon,
    oof_x,
    oof_abc,
    val_x,
    val_abc,
):
    path = gate_checkpoint_path(
        name,
        horizon,
    )

    if (
        path.exists()
        and RESUME
        and not FORCE
    ):
        ckpt = load_torch(
            path
        )

        model = CrossFitAdaptiveGate().to(
            DEVICE
        )

        model.load_state_dict(
            ckpt[
                "StateDict"
            ]
        )

        model.eval()

        print(
            "Loaded gate:",
            path.name,
        )

        return (
            model,
            ckpt,
        )

    median, iqr = fit_feature_scaler(
        oof_x
    )

    train_x = scale_features(
        oof_x,
        median,
        iqr,
    )

    valid_x = scale_features(
        val_x,
        median,
        iqr,
    )

    seed = (
        CROSSFIT_SEED
        + horizon
        * 3000
        + sum(
            map(
                ord,
                name,
            )
        )
    )

    set_seed(
        seed
    )

    model = CrossFitAdaptiveGate().to(
        DEVICE
    )

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=GATE_LR,
        weight_decay=GATE_WD,
    )

    rng = np.random.default_rng(
        seed
        + 1
    )

    best = float(
        "inf"
    )

    best_epoch = -1
    wait = 0
    history = []

    for epoch in range(
        1,
        GATE_MAX_EPOCHS
        + 1,
    ):
        train_mse = train_gate_epoch(
            model,
            optimizer,
            train_x,
            oof_abc,
            rng,
        )

        val_mse, mean_alpha = evaluate_gate(
            model,
            valid_x,
            val_abc,
        )

        history.append({
            "Epoch":
                epoch,
            "OOFTrainMSE":
                train_mse,
            "ValMSE":
                val_mse,
            "ValMeanAlpha":
                mean_alpha,
        })

        if (
            val_mse
            < best
            - 1e-10
        ):
            best = val_mse
            best_epoch = epoch
            wait = 0
        else:
            wait += 1

        print(
            f"Gate {name:11s} H={horizon:3d} "
            f"ep={epoch:02d} "
            f"OOF={train_mse:.6f} "
            f"val={val_mse:.6f} "
            f"alpha={mean_alpha:.3f} "
            f"best={best:.6f}@{best_epoch}"
        )

        if (
            wait
            >= GATE_PATIENCE
        ):
            break

    # Reinitialize and fit only on OOF for the
    # validation-selected number of epochs.
    set_seed(
        seed
    )

    final = CrossFitAdaptiveGate().to(
        DEVICE
    )

    final_opt = torch.optim.AdamW(
        final.parameters(),
        lr=GATE_LR,
        weight_decay=GATE_WD,
    )

    final_rng = np.random.default_rng(
        seed
        + 2
    )

    for _ in range(
        best_epoch
    ):
        train_gate_epoch(
            final,
            final_opt,
            train_x,
            oof_abc,
            final_rng,
        )

    final.eval()

    ckpt = {
        "BestEpoch":
            best_epoch,
        "BestValMSE":
            best,
        "FeatureMedian":
            median,
        "FeatureIQR":
            iqr,
        "StateDict": {
            k:
                v.detach()
                .cpu()
                .clone()
            for k, v
            in final.state_dict().items()
        },
    }

    torch.save(
        ckpt,
        path,
    )

    pd.DataFrame(
        history
    ).to_csv(
        DIRS[
            "history"
        ]
        / (
            f"{name}_H{horizon}_"
            "gate_history.csv"
        ),
        index=False,
    )

    return (
        final,
        ckpt,
    )


def mse_scalar(
    abc,
    alpha,
):
    A = abc.astype(
        np.float64
    )

    x = float(
        alpha
    )

    return float(
        np.mean(
            A[
                :,
                0
            ]
            + 2.0
            * x
            * A[
                :,
                1
            ]
            + x
            * x
            * A[
                :,
                2
            ]
        )
    )


def choose_scalar(
    abc,
):
    rows = []

    best_alpha = None
    best_mse = float(
        "inf"
    )

    for alpha in ALPHA_GRID:
        mse = mse_scalar(
            abc,
            alpha,
        )

        rows.append({
            "Alpha":
                float(
                    alpha
                ),
            "MSE":
                mse,
        })

        if (
            mse
            < best_mse
            - 1e-10
        ):
            best_mse = mse
            best_alpha = float(
                alpha
            )

    return (
        best_alpha,
        pd.DataFrame(
            rows
        ),
    )


@torch.no_grad()
def gate_alpha(
    model,
    ckpt,
    x,
):
    sx = scale_features(
        x,
        ckpt[
            "FeatureMedian"
        ],
        ckpt[
            "FeatureIQR"
        ],
    )

    outputs = []

    for i in range(
        0,
        len(
            sx
        ),
        GATE_BATCH,
    ):
        t = torch.from_numpy(
            sx[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        outputs.append(
            model(
                t
            ).cpu()
            .numpy()
        )

        del t

    return np.concatenate(
        outputs
    ).astype(
        np.float32
    )


def mse_pair(
    abc,
    alpha,
):
    A = abc.astype(
        np.float64
    )

    x = np.asarray(
        alpha,
        dtype=np.float64,
    )

    return float(
        np.mean(
            A[
                :,
                0
            ]
            + 2.0
            * x
            * A[
                :,
                1
            ]
            + x
            * x
            * A[
                :,
                2
            ]
        )
    )


def choose_lambda(
    abc,
    gate_alpha_values,
    scalar_alpha,
):
    rows = []

    best_lambda = None
    best_mse = float(
        "inf"
    )

    for lmb in LAMBDA_GRID:
        alpha = (
            (
                1.0
                - float(
                    lmb
                )
            )
            * scalar_alpha
            + float(
                lmb
            )
            * gate_alpha_values
        )

        mse = mse_pair(
            abc,
            alpha,
        )

        rows.append({
            "Lambda":
                float(
                    lmb
                ),
            "MSE":
                mse,
            "MeanAlpha":
                float(
                    alpha.mean()
                ),
        })

        if (
            mse
            < best_mse
            - 1e-10
        ):
            best_mse = mse
            best_lambda = float(
                lmb
            )

    return (
        best_lambda,
        pd.DataFrame(
            rows
        ),
    )

# %% [markdown]
# ## 18. Final test and Oracle diagnostic

# %%
def empty_stat():
    return {
        "sse":
            0.0,
        "sae":
            0.0,
        "n":
            0,
    }


def update_stat(
    stat,
    pred,
    true,
):
    e = (
        pred
        - true
    )

    stat[
        "sse"
    ] += float(
        (
            e
            * e
        ).sum()
    )

    stat[
        "sae"
    ] += float(
        e.abs().sum()
    )

    stat[
        "n"
    ] += e.numel()


def finish_stat(
    stat,
):
    return (
        stat[
            "sse"
        ]
        / stat[
            "n"
        ],
        stat[
            "sae"
        ]
        / stat[
            "n"
        ],
    )


def oracle_alpha_and_prediction(
    direct,
    retrieval,
    true,
):
    e = (
        direct
        - true
    )

    delta = (
        retrieval
        - direct
    )

    alpha = torch.clamp(
        -(
            e
            * delta
        ).sum(
            dim=1
        )
        / (
            (
                delta
                * delta
            ).sum(
                dim=1
            )
            + 1e-8
        ),
        0.0,
        1.0,
    )

    pred = (
        direct
        + alpha[
            :,
            None
        ]
        * delta
    )

    return (
        alpha,
        pred,
    )


@torch.no_grad()
def test_evaluate(
    data,
    horizon,
    direct_model,
    retriever,
    memory_gpu_obj,
    gate,
    gate_ckpt,
    scalar_alpha,
    shrink_lambda,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    direct_block = DIRECT_ANCHOR_BLOCK[
        CURRENT_BACKBONE
    ]

    ret_block = retrieval_anchor_batch(
        name
    )

    anchors = eval_anchors(
        data[
            "val_end"
        ],
        data[
            "test_end"
        ],
        horizon,
        stride=1,
    )

    keys = [
        "Direct",
        "Retrieval",
        "Scalar",
        "RawAdaptive",
        "ShrinkAdaptive",
        "Oracle",
    ]

    stats = {
        key:
            empty_stat()
        for key in keys
    }

    anchor_mse = {
        key:
            []
        for key in keys
    }

    channel_sse_direct = np.zeros(
        C,
        dtype=np.float64,
    )

    channel_sse_shrink = np.zeros(
        C,
        dtype=np.float64,
    )

    channel_count = np.zeros(
        C,
        dtype=np.int64,
    )

    raw_alpha_sum = 0.0
    shrink_alpha_sum = 0.0
    oracle_alpha_sum = 0.0
    oracle_positive = 0
    n_pairs = 0

    processed = 0

    for outer in range(
        0,
        len(
            anchors
        ),
        direct_block,
    ):
        a_big = anchors[
            outer:
            outer+direct_block
        ]

        direct_big, true_big = (
            direct_residual_block(
                direct_model,
                data[
                    "z"
                ],
                data[
                    "marks"
                ],
                a_big,
                horizon,
            )
        )

        direct_big = direct_big.permute(
            0,
            2,
            1,
        ).contiguous()

        true_big = true_big.permute(
            0,
            2,
            1,
        ).contiguous()

        # anchor-level MSE accumulators within this direct block
        block_anchor_sums = {
            key:
                torch.zeros(
                    len(
                        a_big
                    ),
                    device=DEVICE,
                    dtype=torch.float64,
                )
            for key in keys
        }

        for inner in range(
            0,
            len(
                a_big
            ),
            ret_block,
        ):
            a = a_big[
                inner:
                inner+ret_block
            ]

            A = len(
                a
            )

            pair_anchor = np.repeat(
                a,
                C,
            )

            pair_channel = np.tile(
                np.arange(
                    C,
                    dtype=np.int64,
                ),
                A,
            )

            r = retrieve(
                retriever,
                memory_gpu_obj,
                data[
                    "z"
                ],
                pair_anchor,
                pair_channel,
                horizon,
            )

            retrieval = r[
                "cand"
            ].mean(
                dim=1
            )

            direct = direct_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            true = true_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            scalar = (
                direct
                + scalar_alpha
                * (
                    retrieval
                    - direct
                )
            )

            features = gate_features(
                r,
                retrieval,
                direct,
            ).cpu().numpy().astype(
                np.float32
            )

            scaled = scale_features(
                features,
                gate_ckpt[
                    "FeatureMedian"
                ],
                gate_ckpt[
                    "FeatureIQR"
                ],
            )

            gate_alpha_values = gate(
                torch.from_numpy(
                    scaled
                ).to(
                    DEVICE
                )
            )

            shrink_alpha_values = (
                (
                    1.0
                    - shrink_lambda
                )
                * scalar_alpha
                + shrink_lambda
                * gate_alpha_values
            )

            raw_adaptive = (
                direct
                + gate_alpha_values[
                    :,
                    None
                ]
                * (
                    retrieval
                    - direct
                )
            )

            shrink_adaptive = (
                direct
                + shrink_alpha_values[
                    :,
                    None
                ]
                * (
                    retrieval
                    - direct
                )
            )

            (
                oracle_alpha,
                oracle,
            ) = oracle_alpha_and_prediction(
                direct,
                retrieval,
                true,
            )

            predictions = {
                "Direct":
                    direct,
                "Retrieval":
                    retrieval,
                "Scalar":
                    scalar,
                "RawAdaptive":
                    raw_adaptive,
                "ShrinkAdaptive":
                    shrink_adaptive,
                "Oracle":
                    oracle,
            }

            for key, pred in predictions.items():
                update_stat(
                    stats[
                        key
                    ],
                    pred,
                    true,
                )

                per_anchor = (
                    (
                        (
                            pred
                            - true
                        )
                        ** 2
                    )
                    .reshape(
                        A,
                        C,
                        horizon,
                    )
                    .mean(
                        dim=(
                            1,
                            2,
                        )
                    )
                    .double()
                )

                block_anchor_sums[
                    key
                ][
                    inner:
                    inner+A
                ] = per_anchor

            direct_e2 = (
                (
                    direct
                    - true
                )
                ** 2
            ).reshape(
                A,
                C,
                horizon,
            )

            shrink_e2 = (
                (
                    shrink_adaptive
                    - true
                )
                ** 2
            ).reshape(
                A,
                C,
                horizon,
            )

            channel_sse_direct += (
                direct_e2.sum(
                    dim=(
                        0,
                        2,
                    )
                ).cpu()
                .numpy()
            )

            channel_sse_shrink += (
                shrink_e2.sum(
                    dim=(
                        0,
                        2,
                    )
                ).cpu()
                .numpy()
            )

            channel_count += (
                A
                * horizon
            )

            raw_alpha_sum += float(
                gate_alpha_values.sum()
            )

            shrink_alpha_sum += float(
                shrink_alpha_values.sum()
            )

            oracle_alpha_sum += float(
                oracle_alpha.sum()
            )

            oracle_positive += int(
                (
                    oracle_alpha
                    > 0.01
                ).sum()
            )

            n_pairs += len(
                gate_alpha_values
            )

            del (
                r,
                retrieval,
                direct,
                true,
                scalar,
                features,
                scaled,
                gate_alpha_values,
                shrink_alpha_values,
                raw_adaptive,
                shrink_adaptive,
                oracle_alpha,
                oracle,
                predictions,
                direct_e2,
                shrink_e2,
            )

        for key in keys:
            anchor_mse[
                key
            ].extend(
                block_anchor_sums[
                    key
                ].cpu()
                .numpy()
                .astype(
                    np.float32
                )
                .tolist()
            )

        processed += len(
            a_big
        )

        if (
            processed
            == len(
                a_big
            )
            or processed
            % 500
            < len(
                a_big
            )
            or processed
            == len(
                anchors
            )
        ):
            print(
                f"  test anchors "
                f"{processed}/{len(anchors)}"
            )

        del (
            direct_big,
            true_big,
            block_anchor_sums,
        )

    return {
        "anchors":
            anchors,
        "metrics": {
            key:
                finish_stat(
                    value
                )
            for key, value
            in stats.items()
        },
        "anchor_mse": {
            key:
                np.asarray(
                    value,
                    dtype=np.float32,
                )
            for key, value
            in anchor_mse.items()
        },
        "channel_direct_mse":
            channel_sse_direct
            / channel_count,
        "channel_shrink_mse":
            channel_sse_shrink
            / channel_count,
        "raw_mean_alpha":
            raw_alpha_sum
            / n_pairs,
        "shrink_mean_alpha":
            shrink_alpha_sum
            / n_pairs,
        "oracle_mean_alpha":
            oracle_alpha_sum
            / n_pairs,
        "oracle_positive_fraction":
            oracle_positive
            / n_pairs,
    }

# %% [markdown]
# ## 19. Paired moving-block bootstrap

# %%
def moving_block_bootstrap(
    difference,
    n_boot=5000,
    block=24,
    seed=222222,
):
    x = np.asarray(
        difference,
        dtype=np.float64,
    )

    n = len(
        x
    )

    L = min(
        block,
        n,
    )

    rng = np.random.default_rng(
        seed
    )

    n_blocks = int(
        np.ceil(
            n
            / L
        )
    )

    max_start = max(
        1,
        n
        - L
        + 1,
    )

    boot = np.empty(
        n_boot,
        dtype=np.float64,
    )

    for b in range(
        n_boot
    ):
        starts = rng.integers(
            0,
            max_start,
            size=n_blocks,
        )

        sample = np.concatenate(
            [
                x[
                    s:
                    s+L
                ]
                for s in starts
            ]
        )[
            :n
        ]

        boot[
            b
        ] = sample.mean()

    return {
        "MeanImprovement":
            float(
                x.mean()
            ),
        "CI_Low":
            float(
                np.quantile(
                    boot,
                    0.025,
                )
            ),
        "CI_High":
            float(
                np.quantile(
                    boot,
                    0.975,
                )
            ),
    }

# %% [markdown]
# # 20. Main Experiment — 3 backbones × 4 horizons
#
# 각 backbone × horizon 조건에서:
#
# 1. full direct checkpoint load
# 2. frozen full retriever load
# 3. three chronological OOF folds
# 4. backbone-specific cross-fitted gate
# 5. validation-only scalar \(\alpha_0\)
# 6. validation-only shrinkage \(\lambda\)
# 7. test memory = train + validation
# 8. all stride-1 test origins
# 9. moving-block bootstrap
# 10. channel diagnostics
# 11. 즉시 summary 저장
#
# 을 수행합니다.
#
# `RESUME=True`이면:
#
# - full direct checkpoint
# - fold direct checkpoint
# - OOF cache
# - validation cache
# - shared retrieval-memory embedding
# - gate checkpoint
#
# 를 재사용합니다.

# %%
existing = (
    pd.read_csv(
        SUMMARY_PATH
    )
    if (
        RESUME
        and SUMMARY_PATH.is_file()
    )
    else pd.DataFrame()
)

summary_rows = (
    existing.to_dict(
        "records"
    )
    if len(
        existing
    )
    else []
)

bootstrap_existing = (
    pd.read_csv(
        BOOTSTRAP_PATH
    )
    if (
        RESUME
        and BOOTSTRAP_PATH.is_file()
    )
    else pd.DataFrame()
)

bootstrap_rows = (
    bootstrap_existing.to_dict(
        "records"
    )
    if len(
        bootstrap_existing
    )
    else []
)


def completed(
    backbone,
    horizon,
):
    if not len(
        existing
    ):
        return False

    return bool(
        (
            (
                existing[
                    "Backbone"
                ]
                == backbone
            )
            & (
                existing[
                    "Horizon"
                ]
                == horizon
            )
        ).any()
    )


for backbone in BACKBONES:
    CURRENT_BACKBONE = (
        backbone
    )

    DIRS = backbone_dirs(
        backbone
    )

    activate_backbone(
        backbone
    )

    for horizon in HORIZONS:
        if completed(
            backbone,
            horizon,
        ):
            print(
                f"SKIP completed | "
                f"{backbone} H={horizon}"
            )
            continue

        print(
            "\n"
            + "="
            * 150
        )

        print(
            f"EXPERIMENT 27 | SOLAR | "
            f"{backbone} | H={horizon}"
        )

        print(
            "="
            * 150
        )

        t_condition = time.time()

        direct_model, direct_ckpt = (
            train_or_load_full_direct(
                backbone,
                horizon,
            )
        )

        retriever, retriever_ckpt = (
            load_frozen_retriever(
                full_retriever_ckpt_path(
                    "Solar",
                    horizon,
                )
            )
        )

        # ---------------------------------------------------------
        # Chronological OOF.
        # ---------------------------------------------------------
        oof_parts = []

        for fold, (
            p0,
            p1,
        ) in enumerate(
            FOLDS,
            start=1,
        ):
            out = build_oof_fold(
                DATA[
                    "Solar"
                ],
                horizon,
                fold,
                p0,
                p1,
                int(
                    direct_ckpt[
                        "BestEpoch"
                    ]
                ),
            )

            oof_parts.append(
                out
            )

        oof_x = np.concatenate(
            [
                p[
                    "feature"
                ]
                for p in oof_parts
            ],
            axis=0,
        ).astype(
            np.float32
        )

        oof_abc = np.concatenate(
            [
                p[
                    "abc"
                ]
                for p in oof_parts
            ],
            axis=0,
        ).astype(
            np.float32
        )

        # ---------------------------------------------------------
        # Validation-only integration selection.
        # ---------------------------------------------------------
        val = build_validation_cache(
            DATA[
                "Solar"
            ],
            horizon,
            direct_model,
            retriever,
        )

        gate, gate_ckpt = (
            train_crossfit_gate(
                "Solar",
                horizon,
                oof_x,
                oof_abc,
                val[
                    "feature"
                ],
                val[
                    "abc"
                ],
            )
        )

        scalar_alpha, scalar_curve = (
            choose_scalar(
                val[
                    "abc"
                ]
            )
        )

        val_gate_alpha = gate_alpha(
            gate,
            gate_ckpt,
            val[
                "feature"
            ],
        )

        shrink_lambda, lambda_curve = (
            choose_lambda(
                val[
                    "abc"
                ],
                val_gate_alpha,
                scalar_alpha,
            )
        )

        scalar_val_mse = mse_scalar(
            val[
                "abc"
            ],
            scalar_alpha,
        )

        raw_val_mse = mse_pair(
            val[
                "abc"
            ],
            val_gate_alpha,
        )

        final_val_alpha = (
            (
                1.0
                - shrink_lambda
            )
            * scalar_alpha
            + shrink_lambda
            * val_gate_alpha
        )

        shrink_val_mse = mse_pair(
            val[
                "abc"
            ],
            final_val_alpha,
        )

        calibration = (
            lambda_curve.copy()
        )

        calibration[
            "Backbone"
        ] = backbone

        calibration[
            "Dataset"
        ] = "Solar"

        calibration[
            "Horizon"
        ] = horizon

        calibration[
            "ScalarAlpha"
        ] = scalar_alpha

        calibration.to_csv(
            DIRS[
                "calibration"
            ]
            / (
                f"Solar_H{horizon}_"
                "lambda_curve.csv"
            ),
            index=False,
        )

        print(
            f"Validation | alpha0={scalar_alpha:.1f} | "
            f"lambda={shrink_lambda:.2f} | "
            f"scalar={scalar_val_mse:.6f} | "
            f"rawGate={raw_val_mse:.6f} | "
            f"shrink={shrink_val_mse:.6f}"
        )

        # ---------------------------------------------------------
        # Test memory: train + validation only.
        # ---------------------------------------------------------
        test_memory = build_memory(
            z_full,
            n_channels,
            val_end,
            horizon,
        )

        test_memory_gpu = memory_gpu_cached(
            "Solar",
            horizon,
            "test_trainval_memory",
            retriever,
            test_memory,
            n_channels,
        )

        test = test_evaluate(
            DATA[
                "Solar"
            ],
            horizon,
            direct_model,
            retriever,
            test_memory_gpu,
            gate,
            gate_ckpt,
            scalar_alpha,
            shrink_lambda,
        )

        metrics = test[
            "metrics"
        ]

        direct_mse, direct_mae = metrics[
            "Direct"
        ]

        retrieval_mse, retrieval_mae = metrics[
            "Retrieval"
        ]

        scalar_mse, scalar_mae = metrics[
            "Scalar"
        ]

        raw_mse, raw_mae = metrics[
            "RawAdaptive"
        ]

        ours_mse, ours_mae = metrics[
            "ShrinkAdaptive"
        ]

        oracle_mse, oracle_mae = metrics[
            "Oracle"
        ]

        # ---------------------------------------------------------
        # Moving-block bootstrap.
        # Positive = Direct MSE > Ours MSE.
        # ---------------------------------------------------------
        diff = (
            test[
                "anchor_mse"
            ][
                "Direct"
            ]
            - test[
                "anchor_mse"
            ][
                "ShrinkAdaptive"
            ]
        )

        boot = moving_block_bootstrap(
            diff,
            n_boot=
                BOOTSTRAP_REPLICATES,
            block=
                BOOTSTRAP_BLOCK_LEN,
            seed=
                BOOTSTRAP_SEED
                + horizon
                + 10000
                * BACKBONES.index(
                    backbone
                ),
        )

        bootstrap_rows = [
            r
            for r in bootstrap_rows
            if not (
                r.get(
                    "Backbone"
                )
                == backbone
                and int(
                    r.get(
                        "Horizon",
                        -1,
                    )
                )
                == horizon
            )
        ]

        bootstrap_rows.append({
            "Backbone":
                backbone,
            "Dataset":
                "Solar",
            "Horizon":
                horizon,
            "Comparison":
                "Direct-ShrinkAdaptive",
            "MeanImprovement":
                boot[
                    "MeanImprovement"
                ],
            "CI_Low":
                boot[
                    "CI_Low"
                ],
            "CI_High":
                boot[
                    "CI_High"
                ],
            "SignificantPositive":
                bool(
                    boot[
                        "CI_Low"
                    ]
                    > 0
                ),
            "SignificantNegative":
                bool(
                    boot[
                        "CI_High"
                    ]
                    < 0
                ),
            "BlockLen":
                BOOTSTRAP_BLOCK_LEN,
            "Replicates":
                BOOTSTRAP_REPLICATES,
        })

        # ---------------------------------------------------------
        # Channel diagnostics.
        # ---------------------------------------------------------
        channel_df = pd.DataFrame({
            "Channel":
                np.arange(
                    n_channels
                ),
            "Direct_MSE":
                test[
                    "channel_direct_mse"
                ],
            "Ours_MSE":
                test[
                    "channel_shrink_mse"
                ],
        })

        channel_df[
            "Gain_pct"
        ] = (
            100.0
            * (
                channel_df[
                    "Direct_MSE"
                ]
                - channel_df[
                    "Ours_MSE"
                ]
            )
            / channel_df[
                "Direct_MSE"
            ]
        )

        channel_df.to_csv(
            DIRS[
                "channel"
            ]
            / (
                f"Solar_H{horizon}_"
                "channel.csv"
            ),
            index=False,
        )

        improved_channel_fraction = float(
            (
                channel_df[
                    "Ours_MSE"
                ]
                < channel_df[
                    "Direct_MSE"
                ]
            ).mean()
        )

        oracle_headroom = (
            100.0
            * (
                direct_mse
                - oracle_mse
            )
            / direct_mse
        )

        row = {
            "Backbone":
                backbone,
            "Dataset":
                "Solar",
            "Horizon":
                horizon,
            "DirectSeqLen":
                direct_seq_len(
                    backbone
                ),
            "RetrievalSeqLen":
                RET_SEQ_LEN,

            "Direct_MSE":
                direct_mse,
            "ShrinkAdaptive_MSE":
                ours_mse,
            "Direct_MAE":
                direct_mae,
            "ShrinkAdaptive_MAE":
                ours_mae,

            "Retrieval_MSE":
                retrieval_mse,
            "Retrieval_MAE":
                retrieval_mae,
            "Scalar_MSE":
                scalar_mse,
            "Scalar_MAE":
                scalar_mae,
            "RawAdaptive_MSE":
                raw_mse,
            "RawAdaptive_MAE":
                raw_mae,
            "Oracle_MSE":
                oracle_mse,
            "Oracle_MAE":
                oracle_mae,

            "ScalarAlpha":
                scalar_alpha,
            "ShrinkLambda":
                shrink_lambda,
            "RawMeanAlpha":
                test[
                    "raw_mean_alpha"
                ],
            "ShrinkMeanAlpha":
                test[
                    "shrink_mean_alpha"
                ],

            "MSEGain_pct":
                100.0
                * (
                    direct_mse
                    - ours_mse
                )
                / direct_mse,

            "MAEGain_pct":
                100.0
                * (
                    direct_mae
                    - ours_mae
                )
                / direct_mae,

            "OracleHeadroomFromDirect_pct":
                oracle_headroom,

            "ImprovedChannelFraction":
                improved_channel_fraction,

            "GateBestEpoch":
                gate_ckpt[
                    "BestEpoch"
                ],

            "DirectBestEpoch":
                direct_ckpt[
                    "BestEpoch"
                ],

            "OOFPairs":
                len(
                    oof_x
                ),

            "TestAnchors":
                len(
                    test[
                        "anchors"
                    ]
                ),

            "TestMemoryPerChannel":
                test_memory[
                    "M"
                ],

            "RuntimeMinutes":
                (
                    time.time()
                    - t_condition
                )
                / 60.0,
        }

        summary_rows = [
            r
            for r in summary_rows
            if not (
                r.get(
                    "Backbone"
                )
                == backbone
                and int(
                    r.get(
                        "Horizon",
                        -1,
                    )
                )
                == horizon
            )
        ]

        summary_rows.append(
            row
        )

        np.savez_compressed(
            DIRS[
                "paired"
            ]
            / (
                f"Solar_H{horizon}_"
                "anchor_mse.npz"
            ),
            Anchors=
                test[
                    "anchors"
                ],
            Direct=
                test[
                    "anchor_mse"
                ][
                    "Direct"
                ],
            Retrieval=
                test[
                    "anchor_mse"
                ][
                    "Retrieval"
                ],
            Scalar=
                test[
                    "anchor_mse"
                ][
                    "Scalar"
                ],
            RawAdaptive=
                test[
                    "anchor_mse"
                ][
                    "RawAdaptive"
                ],
            ShrinkAdaptive=
                test[
                    "anchor_mse"
                ][
                    "ShrinkAdaptive"
                ],
            Oracle=
                test[
                    "anchor_mse"
                ][
                    "Oracle"
                ],
        )

        pd.DataFrame(
            summary_rows
        ).sort_values(
            [
                "Backbone",
                "Horizon",
            ]
        ).to_csv(
            SUMMARY_PATH,
            index=False,
        )

        pd.DataFrame(
            bootstrap_rows
        ).sort_values(
            [
                "Backbone",
                "Horizon",
            ]
        ).to_csv(
            BOOTSTRAP_PATH,
            index=False,
        )

        print(
            "\nFINAL | "
            f"{backbone} H={horizon} | "
            f"Direct={direct_mse:.6f} | "
            f"Ours={ours_mse:.6f} | "
            f"Gain={row['MSEGain_pct']:+.3f}% | "
            f"CI=[{boot['CI_Low']:.6f}, "
            f"{boot['CI_High']:.6f}]"
        )

        del (
            direct_model,
            retriever,
            gate,
            test_memory,
            test_memory_gpu,
            test,
            val,
            oof_parts,
            oof_x,
            oof_abc,
        )

        gc.collect()

        if torch.cuda.is_available():
            torch.cuda.empty_cache()
# Out:
# Activated PatchTST: /code/stock_regime_retrieval/strong_forecaster/PatchTST_official/PatchTST_supervised/models/PatchTST.py
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | PatchTST | H=96
# ======================================================================================================================================================
# Loaded full direct | PatchTST H=96 | best=0.151971@19
# Fold PatchTST     H= 96 F1 ep=01/19 | train=0.506873
# Fold PatchTST     H= 96 F1 ep=02/19 | train=0.322984
# Fold PatchTST     H= 96 F1 ep=03/19 | train=0.281868
# Fold PatchTST     H= 96 F1 ep=04/19 | train=0.266577
# Fold PatchTST     H= 96 F1 ep=05/19 | train=0.257587
# Fold PatchTST     H= 96 F1 ep=06/19 | train=0.250163
# Fold PatchTST     H= 96 F1 ep=07/19 | train=0.245145
# Fold PatchTST     H= 96 F1 ep=08/19 | train=0.238596
# Fold PatchTST     H= 96 F1 ep=09/19 | train=0.232495
# Fold PatchTST     H= 96 F1 ep=10/19 | train=0.228189
# Fold PatchTST     H= 96 F1 ep=11/19 | train=0.223433
# Fold PatchTST     H= 96 F1 ep=12/19 | train=0.219794
# Fold PatchTST     H= 96 F1 ep=13/19 | train=0.217722
# Fold PatchTST     H= 96 F1 ep=14/19 | train=0.215282
# Fold PatchTST     H= 96 F1 ep=15/19 | train=0.212513
# Fold PatchTST     H= 96 F1 ep=16/19 | train=0.210977
# Fold PatchTST     H= 96 F1 ep=17/19 | train=0.208345
# Fold PatchTST     H= 96 F1 ep=18/19 | train=0.205982
# Fold PatchTST     H= 96 F1 ep=19/19 | train=0.204570
# Building memory embedding: Solar_H96_F1_prefix20235_emb.npy (137, 836, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=96 F1: prefix=20235, end=25754, anchors=1356, pairs=185772, memory/C=836
# Fold PatchTST     H= 96 F2 ep=01/19 | train=0.421442
# Fold PatchTST     H= 96 F2 ep=02/19 | train=0.260710
# Fold PatchTST     H= 96 F2 ep=03/19 | train=0.235485
# Fold PatchTST     H= 96 F2 ep=04/19 | train=0.224445
# Fold PatchTST     H= 96 F2 ep=05/19 | train=0.217376
# Fold PatchTST     H= 96 F2 ep=06/19 | train=0.212532
# Fold PatchTST     H= 96 F2 ep=07/19 | train=0.206224
# Fold PatchTST     H= 96 F2 ep=08/19 | train=0.200611
# Fold PatchTST     H= 96 F2 ep=09/19 | train=0.195299
# Fold PatchTST     H= 96 F2 ep=10/19 | train=0.191003
# Fold PatchTST     H= 96 F2 ep=11/19 | train=0.187474
# Fold PatchTST     H= 96 F2 ep=12/19 | train=0.184522
# Fold PatchTST     H= 96 F2 ep=13/19 | train=0.182553
# Fold PatchTST     H= 96 F2 ep=14/19 | train=0.180200
# Fold PatchTST     H= 96 F2 ep=15/19 | train=0.177972
# Fold PatchTST     H= 96 F2 ep=16/19 | train=0.177084
# Fold PatchTST     H= 96 F2 ep=17/19 | train=0.174664
# Fold PatchTST     H= 96 F2 ep=18/19 | train=0.173309
# Fold PatchTST     H= 96 F2 ep=19/19 | train=0.171487
# Building memory embedding: Solar_H96_F2_prefix25754_emb.npy (137, 1066, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=96 F2: prefix=25754, end=31273, anchors=1356, pairs=185772, memory/C=1066
# Fold PatchTST     H= 96 F3 ep=01/19 | train=0.384357
# Fold PatchTST     H= 96 F3 ep=02/19 | train=0.239420
# Fold PatchTST     H= 96 F3 ep=03/19 | train=0.218576
# Fold PatchTST     H= 96 F3 ep=04/19 | train=0.209133
# Fold PatchTST     H= 96 F3 ep=05/19 | train=0.202294
# Fold PatchTST     H= 96 F3 ep=06/19 | train=0.196289
# Fold PatchTST     H= 96 F3 ep=07/19 | train=0.190957
# Fold PatchTST     H= 96 F3 ep=08/19 | train=0.185792
# Fold PatchTST     H= 96 F3 ep=09/19 | train=0.180993
# Fold PatchTST     H= 96 F3 ep=10/19 | train=0.177277
# Fold PatchTST     H= 96 F3 ep=11/19 | train=0.174724
# Fold PatchTST     H= 96 F3 ep=12/19 | train=0.172138
# Fold PatchTST     H= 96 F3 ep=13/19 | train=0.170392
# Fold PatchTST     H= 96 F3 ep=14/19 | train=0.168859
# Fold PatchTST     H= 96 F3 ep=15/19 | train=0.167077
# Fold PatchTST     H= 96 F3 ep=16/19 | train=0.165783
# Fold PatchTST     H= 96 F3 ep=17/19 | train=0.164345
# Fold PatchTST     H= 96 F3 ep=18/19 | train=0.162884
# Fold PatchTST     H= 96 F3 ep=19/19 | train=0.161143
# Building memory embedding: Solar_H96_F3_prefix31273_emb.npy (137, 1296, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=96 F3: prefix=31273, end=36792, anchors=1356, pairs=185772, memory/C=1296
# Building memory embedding: Solar_H96_validation_train_memory_emb.npy (137, 1526, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# Validation Solar H=96: anchors=5161, pairs=707057, memory/C=1526
# Gate Solar       H= 96 ep=01 OOF=0.113964 val=0.151225 alpha=0.051 best=0.151225@1
# Gate Solar       H= 96 ep=02 OOF=0.112265 val=0.149406 alpha=0.068 best=0.149406@2
# Gate Solar       H= 96 ep=03 OOF=0.111273 val=0.149324 alpha=0.076 best=0.149324@3
# Gate Solar       H= 96 ep=04 OOF=0.111072 val=0.149193 alpha=0.079 best=0.149193@4
# Gate Solar       H= 96 ep=05 OOF=0.110835 val=0.149157 alpha=0.079 best=0.149157@5
# Gate Solar       H= 96 ep=06 OOF=0.110648 val=0.149058 alpha=0.077 best=0.149058@6
# Gate Solar       H= 96 ep=07 OOF=0.110828 val=0.149029 alpha=0.078 best=0.149029@7
# Gate Solar       H= 96 ep=08 OOF=0.110514 val=0.149049 alpha=0.071 best=0.149029@7
# Gate Solar       H= 96 ep=09 OOF=0.110675 val=0.149058 alpha=0.072 best=0.149029@7
# Gate Solar       H= 96 ep=10 OOF=0.110573 val=0.148991 alpha=0.077 best=0.148991@10
# Gate Solar       H= 96 ep=11 OOF=0.110711 val=0.148884 alpha=0.075 best=0.148884@11
# Gate Solar       H= 96 ep=12 OOF=0.110480 val=0.149029 alpha=0.078 best=0.148884@11
# Gate Solar       H= 96 ep=13 OOF=0.110594 val=0.148938 alpha=0.077 best=0.148884@11
# Gate Solar       H= 96 ep=14 OOF=0.110433 val=0.148874 alpha=0.076 best=0.148874@14
# Gate Solar       H= 96 ep=15 OOF=0.110469 val=0.149000 alpha=0.077 best=0.148874@14
# Gate Solar       H= 96 ep=16 OOF=0.110557 val=0.148878 alpha=0.075 best=0.148874@14
# Gate Solar       H= 96 ep=17 OOF=0.110617 val=0.148854 alpha=0.081 best=0.148854@17
# Gate Solar       H= 96 ep=18 OOF=0.110608 val=0.148997 alpha=0.077 best=0.148854@17
# Gate Solar       H= 96 ep=19 OOF=0.110556 val=0.148871 alpha=0.080 best=0.148854@17
# Gate Solar       H= 96 ep=20 OOF=0.110418 val=0.148744 alpha=0.081 best=0.148744@20
# Gate Solar       H= 96 ep=21 OOF=0.110493 val=0.148922 alpha=0.082 best=0.148744@20
# Gate Solar       H= 96 ep=22 OOF=0.110443 val=0.148831 alpha=0.081 best=0.148744@20
# Gate Solar       H= 96 ep=23 OOF=0.110674 val=0.148885 alpha=0.089 best=0.148744@20
# Gate Solar       H= 96 ep=24 OOF=0.110419 val=0.148911 alpha=0.080 best=0.148744@20
# Gate Solar       H= 96 ep=25 OOF=0.110285 val=0.149018 alpha=0.088 best=0.148744@20
# Gate Solar       H= 96 ep=26 OOF=0.110462 val=0.148880 alpha=0.088 best=0.148744@20
# Gate Solar       H= 96 ep=27 OOF=0.110319 val=0.148858 alpha=0.092 best=0.148744@20
# Validation | alpha0=0.0 | lambda=1.00 | scalar=0.151971 | rawGate=0.148911 | shrink=0.148911
# Building memory embedding: Solar_H96_test_trainval_memory_emb.npy (137, 1745, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
#   test anchors 16/10417
#   test anchors 512/10417
#   test anchors 1008/10417
#   test anchors 1504/10417
#   test anchors 2000/10417
#   test anchors 2512/10417
#   test anchors 3008/10417
#   test anchors 3504/10417
#   test anchors 4000/10417
#   test anchors 4512/10417
#   test anchors 5008/10417
#   test anchors 5504/10417
#   test anchors 6000/10417
#   test anchors 6512/10417
#   test anchors 7008/10417
#   test anchors 7504/10417
#   test anchors 8000/10417
#   test anchors 8512/10417
#   test anchors 9008/10417
#   test anchors 9504/10417
#   test anchors 10000/10417
#   test anchors 10417/10417
#
# FINAL | PatchTST H=96 | Direct=0.183429 | Ours=0.180450 | Gain=+1.624% | CI=[-0.001281, 0.007369]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | PatchTST | H=192
# ======================================================================================================================================================
# Loaded full direct | PatchTST H=192 | best=0.154251@30
# Fold PatchTST     H=192 F1 ep=01/30 | train=0.506192
# Fold PatchTST     H=192 F1 ep=02/30 | train=0.331311
# Fold PatchTST     H=192 F1 ep=03/30 | train=0.295068
# Fold PatchTST     H=192 F1 ep=04/30 | train=0.280116
# Fold PatchTST     H=192 F1 ep=05/30 | train=0.271391
# Fold PatchTST     H=192 F1 ep=06/30 | train=0.264613
# Fold PatchTST     H=192 F1 ep=07/30 | train=0.259253
# Fold PatchTST     H=192 F1 ep=08/30 | train=0.254584
# Fold PatchTST     H=192 F1 ep=09/30 | train=0.250716
# Fold PatchTST     H=192 F1 ep=10/30 | train=0.245951
# Fold PatchTST     H=192 F1 ep=11/30 | train=0.242706
# Fold PatchTST     H=192 F1 ep=12/30 | train=0.239073
# Fold PatchTST     H=192 F1 ep=13/30 | train=0.236252
# Fold PatchTST     H=192 F1 ep=14/30 | train=0.234056
# Fold PatchTST     H=192 F1 ep=15/30 | train=0.231888
# Fold PatchTST     H=192 F1 ep=16/30 | train=0.229092
# Fold PatchTST     H=192 F1 ep=17/30 | train=0.226748
# Fold PatchTST     H=192 F1 ep=18/30 | train=0.224323
# Fold PatchTST     H=192 F1 ep=19/30 | train=0.222611
# Fold PatchTST     H=192 F1 ep=20/30 | train=0.220463
# Fold PatchTST     H=192 F1 ep=21/30 | train=0.219028
# Fold PatchTST     H=192 F1 ep=22/30 | train=0.216651
# Fold PatchTST     H=192 F1 ep=23/30 | train=0.216070
# Fold PatchTST     H=192 F1 ep=24/30 | train=0.213888
# Fold PatchTST     H=192 F1 ep=25/30 | train=0.212433
# Fold PatchTST     H=192 F1 ep=26/30 | train=0.211410
# Fold PatchTST     H=192 F1 ep=27/30 | train=0.210715
# Fold PatchTST     H=192 F1 ep=28/30 | train=0.209345
# Fold PatchTST     H=192 F1 ep=29/30 | train=0.208339
# Fold PatchTST     H=192 F1 ep=30/30 | train=0.207327
# Building memory embedding: Solar_H192_F1_prefix20235_emb.npy (137, 832, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=192 F1: prefix=20235, end=25754, anchors=1332, pairs=182484, memory/C=832
# Fold PatchTST     H=192 F2 ep=01/30 | train=0.423378
# Fold PatchTST     H=192 F2 ep=02/30 | train=0.271619
# Fold PatchTST     H=192 F2 ep=03/30 | train=0.247240
# Fold PatchTST     H=192 F2 ep=04/30 | train=0.236157
# Fold PatchTST     H=192 F2 ep=05/30 | train=0.228969
# Fold PatchTST     H=192 F2 ep=06/30 | train=0.223417
# Fold PatchTST     H=192 F2 ep=07/30 | train=0.217960
# Fold PatchTST     H=192 F2 ep=08/30 | train=0.213658
# Fold PatchTST     H=192 F2 ep=09/30 | train=0.209877
# Fold PatchTST     H=192 F2 ep=10/30 | train=0.205482
# Fold PatchTST     H=192 F2 ep=11/30 | train=0.202535
# Fold PatchTST     H=192 F2 ep=12/30 | train=0.199647
# Fold PatchTST     H=192 F2 ep=13/30 | train=0.196733
# Fold PatchTST     H=192 F2 ep=14/30 | train=0.195092
# Fold PatchTST     H=192 F2 ep=15/30 | train=0.192691
# Fold PatchTST     H=192 F2 ep=16/30 | train=0.190906
# Fold PatchTST     H=192 F2 ep=17/30 | train=0.188550
# Fold PatchTST     H=192 F2 ep=18/30 | train=0.187245
# Fold PatchTST     H=192 F2 ep=19/30 | train=0.185957
# Fold PatchTST     H=192 F2 ep=20/30 | train=0.184480
# Fold PatchTST     H=192 F2 ep=21/30 | train=0.183175
# Fold PatchTST     H=192 F2 ep=22/30 | train=0.181514
# Fold PatchTST     H=192 F2 ep=23/30 | train=0.180142
# Fold PatchTST     H=192 F2 ep=24/30 | train=0.179346
# Fold PatchTST     H=192 F2 ep=25/30 | train=0.178629
# Fold PatchTST     H=192 F2 ep=26/30 | train=0.177549
# Fold PatchTST     H=192 F2 ep=27/30 | train=0.176809
# Fold PatchTST     H=192 F2 ep=28/30 | train=0.175958
# Fold PatchTST     H=192 F2 ep=29/30 | train=0.174977
# Fold PatchTST     H=192 F2 ep=30/30 | train=0.173833
# Building memory embedding: Solar_H192_F2_prefix25754_emb.npy (137, 1062, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=192 F2: prefix=25754, end=31273, anchors=1332, pairs=182484, memory/C=1062
# Fold PatchTST     H=192 F3 ep=01/30 | train=0.393963
# Fold PatchTST     H=192 F3 ep=02/30 | train=0.248305
# Fold PatchTST     H=192 F3 ep=03/30 | train=0.227952
# Fold PatchTST     H=192 F3 ep=04/30 | train=0.218893
# Fold PatchTST     H=192 F3 ep=05/30 | train=0.212876
# Fold PatchTST     H=192 F3 ep=06/30 | train=0.207374
# Fold PatchTST     H=192 F3 ep=07/30 | train=0.202538
# Fold PatchTST     H=192 F3 ep=08/30 | train=0.198104
# Fold PatchTST     H=192 F3 ep=09/30 | train=0.194391
# Fold PatchTST     H=192 F3 ep=10/30 | train=0.191266
# Fold PatchTST     H=192 F3 ep=11/30 | train=0.188693
# Fold PatchTST     H=192 F3 ep=12/30 | train=0.186628
# Fold PatchTST     H=192 F3 ep=13/30 | train=0.184075
# Fold PatchTST     H=192 F3 ep=14/30 | train=0.183144
# Fold PatchTST     H=192 F3 ep=15/30 | train=0.181443
# Fold PatchTST     H=192 F3 ep=16/30 | train=0.179592
# Fold PatchTST     H=192 F3 ep=17/30 | train=0.178241
# Fold PatchTST     H=192 F3 ep=18/30 | train=0.176354
# Fold PatchTST     H=192 F3 ep=19/30 | train=0.174959
# Fold PatchTST     H=192 F3 ep=20/30 | train=0.173514
# Fold PatchTST     H=192 F3 ep=21/30 | train=0.171927
# Fold PatchTST     H=192 F3 ep=22/30 | train=0.170637
# Fold PatchTST     H=192 F3 ep=23/30 | train=0.169823
# Fold PatchTST     H=192 F3 ep=24/30 | train=0.168170
# Fold PatchTST     H=192 F3 ep=25/30 | train=0.167445
# Fold PatchTST     H=192 F3 ep=26/30 | train=0.166493
# Fold PatchTST     H=192 F3 ep=27/30 | train=0.165447
# Fold PatchTST     H=192 F3 ep=28/30 | train=0.164458
# Fold PatchTST     H=192 F3 ep=29/30 | train=0.164235
# Fold PatchTST     H=192 F3 ep=30/30 | train=0.162960
# Building memory embedding: Solar_H192_F3_prefix31273_emb.npy (137, 1292, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=192 F3: prefix=31273, end=36792, anchors=1332, pairs=182484, memory/C=1292
# Building memory embedding: Solar_H192_validation_train_memory_emb.npy (137, 1522, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# Validation Solar H=192: anchors=5065, pairs=693905, memory/C=1522
# Gate Solar       H=192 ep=01 OOF=0.116683 val=0.153770 alpha=0.069 best=0.153770@1
# Gate Solar       H=192 ep=02 OOF=0.115095 val=0.153122 alpha=0.075 best=0.153122@2
# Gate Solar       H=192 ep=03 OOF=0.114698 val=0.153056 alpha=0.082 best=0.153056@3
# Gate Solar       H=192 ep=04 OOF=0.114556 val=0.153081 alpha=0.089 best=0.153056@3
# Gate Solar       H=192 ep=05 OOF=0.114473 val=0.153069 alpha=0.090 best=0.153056@3
# Gate Solar       H=192 ep=06 OOF=0.114407 val=0.153019 alpha=0.089 best=0.153019@6
# Gate Solar       H=192 ep=07 OOF=0.114360 val=0.153167 alpha=0.103 best=0.153019@6
# Gate Solar       H=192 ep=08 OOF=0.114330 val=0.153057 alpha=0.092 best=0.153019@6
# Gate Solar       H=192 ep=09 OOF=0.114286 val=0.153233 alpha=0.105 best=0.153019@6
# Gate Solar       H=192 ep=10 OOF=0.114257 val=0.153199 alpha=0.104 best=0.153019@6
# Gate Solar       H=192 ep=11 OOF=0.114233 val=0.153229 alpha=0.106 best=0.153019@6
# Gate Solar       H=192 ep=12 OOF=0.114202 val=0.153219 alpha=0.106 best=0.153019@6
# Gate Solar       H=192 ep=13 OOF=0.114184 val=0.153435 alpha=0.114 best=0.153019@6
# Validation | alpha0=0.0 | lambda=0.75 | scalar=0.154251 | rawGate=0.153078 | shrink=0.152874
# Building memory embedding: Solar_H192_test_trainval_memory_emb.npy (137, 1741, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
#   test anchors 16/10321
#   test anchors 512/10321
#   test anchors 1008/10321
#   test anchors 1504/10321
#   test anchors 2000/10321
#   test anchors 2512/10321
#   test anchors 3008/10321
#   test anchors 3504/10321
#   test anchors 4000/10321
#   test anchors 4512/10321
#   test anchors 5008/10321
#   test anchors 5504/10321
#   test anchors 6000/10321
#   test anchors 6512/10321
#   test anchors 7008/10321
#   test anchors 7504/10321
#   test anchors 8000/10321
#   test anchors 8512/10321
#   test anchors 9008/10321
#   test anchors 9504/10321
#   test anchors 10000/10321
#   test anchors 10321/10321
#
# FINAL | PatchTST H=192 | Direct=0.188770 | Ours=0.187718 | Gain=+0.557% | CI=[-0.001870, 0.003871]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | PatchTST | H=336
# ======================================================================================================================================================
# Loaded full direct | PatchTST H=336 | best=0.166381@27
# Fold PatchTST     H=336 F1 ep=01/27 | train=0.510927
# Fold PatchTST     H=336 F1 ep=02/27 | train=0.342152
# Fold PatchTST     H=336 F1 ep=03/27 | train=0.304904
# Fold PatchTST     H=336 F1 ep=04/27 | train=0.289104
# Fold PatchTST     H=336 F1 ep=05/27 | train=0.281014
# Fold PatchTST     H=336 F1 ep=06/27 | train=0.274630
# Fold PatchTST     H=336 F1 ep=07/27 | train=0.270829
# Fold PatchTST     H=336 F1 ep=08/27 | train=0.266805
# Fold PatchTST     H=336 F1 ep=09/27 | train=0.262670
# Fold PatchTST     H=336 F1 ep=10/27 | train=0.259403
# Fold PatchTST     H=336 F1 ep=11/27 | train=0.255697
# Fold PatchTST     H=336 F1 ep=12/27 | train=0.252531
# Fold PatchTST     H=336 F1 ep=13/27 | train=0.248784
# Fold PatchTST     H=336 F1 ep=14/27 | train=0.246415
# Fold PatchTST     H=336 F1 ep=15/27 | train=0.242926
# Fold PatchTST     H=336 F1 ep=16/27 | train=0.241450
# Fold PatchTST     H=336 F1 ep=17/27 | train=0.240026
# Fold PatchTST     H=336 F1 ep=18/27 | train=0.237320
# Fold PatchTST     H=336 F1 ep=19/27 | train=0.235260
# Fold PatchTST     H=336 F1 ep=20/27 | train=0.233097
# Fold PatchTST     H=336 F1 ep=21/27 | train=0.231457
# Fold PatchTST     H=336 F1 ep=22/27 | train=0.229778
# Fold PatchTST     H=336 F1 ep=23/27 | train=0.227965
# Fold PatchTST     H=336 F1 ep=24/27 | train=0.227165
# Fold PatchTST     H=336 F1 ep=25/27 | train=0.225692
# Fold PatchTST     H=336 F1 ep=26/27 | train=0.224770
# Fold PatchTST     H=336 F1 ep=27/27 | train=0.223494
# Building memory embedding: Solar_H336_F1_prefix20235_emb.npy (137, 826, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=336 F1: prefix=20235, end=25754, anchors=1296, pairs=177552, memory/C=826
# Fold PatchTST     H=336 F2 ep=01/27 | train=0.425253
# Fold PatchTST     H=336 F2 ep=02/27 | train=0.278740
# Fold PatchTST     H=336 F2 ep=03/27 | train=0.254456
# Fold PatchTST     H=336 F2 ep=04/27 | train=0.242506
# Fold PatchTST     H=336 F2 ep=05/27 | train=0.235787
# Fold PatchTST     H=336 F2 ep=06/27 | train=0.230233
# Fold PatchTST     H=336 F2 ep=07/27 | train=0.225057
# Fold PatchTST     H=336 F2 ep=08/27 | train=0.221154
# Fold PatchTST     H=336 F2 ep=09/27 | train=0.216833
# Fold PatchTST     H=336 F2 ep=10/27 | train=0.213867
# Fold PatchTST     H=336 F2 ep=11/27 | train=0.210439
# Fold PatchTST     H=336 F2 ep=12/27 | train=0.208621
# Fold PatchTST     H=336 F2 ep=13/27 | train=0.206189
# Fold PatchTST     H=336 F2 ep=14/27 | train=0.204271
# Fold PatchTST     H=336 F2 ep=15/27 | train=0.202695
# Fold PatchTST     H=336 F2 ep=16/27 | train=0.200486
# Fold PatchTST     H=336 F2 ep=17/27 | train=0.198164
# Fold PatchTST     H=336 F2 ep=18/27 | train=0.196677
# Fold PatchTST     H=336 F2 ep=19/27 | train=0.194960
# Fold PatchTST     H=336 F2 ep=20/27 | train=0.193193
# Fold PatchTST     H=336 F2 ep=21/27 | train=0.192110
# Fold PatchTST     H=336 F2 ep=22/27 | train=0.190627
# Fold PatchTST     H=336 F2 ep=23/27 | train=0.189705
# Fold PatchTST     H=336 F2 ep=24/27 | train=0.188426
# Fold PatchTST     H=336 F2 ep=25/27 | train=0.188549
# Fold PatchTST     H=336 F2 ep=26/27 | train=0.186688
# Fold PatchTST     H=336 F2 ep=27/27 | train=0.186062
# Building memory embedding: Solar_H336_F2_prefix25754_emb.npy (137, 1056, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=336 F2: prefix=25754, end=31273, anchors=1296, pairs=177552, memory/C=1056
# Fold PatchTST     H=336 F3 ep=01/27 | train=0.387509
# Fold PatchTST     H=336 F3 ep=02/27 | train=0.256551
# Fold PatchTST     H=336 F3 ep=03/27 | train=0.236018
# Fold PatchTST     H=336 F3 ep=04/27 | train=0.225849
# Fold PatchTST     H=336 F3 ep=05/27 | train=0.218784
# Fold PatchTST     H=336 F3 ep=06/27 | train=0.213429
# Fold PatchTST     H=336 F3 ep=07/27 | train=0.208644
# Fold PatchTST     H=336 F3 ep=08/27 | train=0.204632
# Fold PatchTST     H=336 F3 ep=09/27 | train=0.201445
# Fold PatchTST     H=336 F3 ep=10/27 | train=0.198418
# Fold PatchTST     H=336 F3 ep=11/27 | train=0.195424
# Fold PatchTST     H=336 F3 ep=12/27 | train=0.193376
# Fold PatchTST     H=336 F3 ep=13/27 | train=0.191829
# Fold PatchTST     H=336 F3 ep=14/27 | train=0.190272
# Fold PatchTST     H=336 F3 ep=15/27 | train=0.188366
# Fold PatchTST     H=336 F3 ep=16/27 | train=0.187122
# Fold PatchTST     H=336 F3 ep=17/27 | train=0.185670
# Fold PatchTST     H=336 F3 ep=18/27 | train=0.184011
# Fold PatchTST     H=336 F3 ep=19/27 | train=0.182320
# Fold PatchTST     H=336 F3 ep=20/27 | train=0.181305
# Fold PatchTST     H=336 F3 ep=21/27 | train=0.179742
# Fold PatchTST     H=336 F3 ep=22/27 | train=0.179058
# Fold PatchTST     H=336 F3 ep=23/27 | train=0.177681
# Fold PatchTST     H=336 F3 ep=24/27 | train=0.176921
# Fold PatchTST     H=336 F3 ep=25/27 | train=0.176044
# Fold PatchTST     H=336 F3 ep=26/27 | train=0.175316
# Fold PatchTST     H=336 F3 ep=27/27 | train=0.174364
# Building memory embedding: Solar_H336_F3_prefix31273_emb.npy (137, 1286, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=336 F3: prefix=31273, end=36792, anchors=1296, pairs=177552, memory/C=1286
# Building memory embedding: Solar_H336_validation_train_memory_emb.npy (137, 1516, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# Validation Solar H=336: anchors=4921, pairs=674177, memory/C=1516
# Gate Solar       H=336 ep=01 OOF=0.123935 val=0.165541 alpha=0.094 best=0.165541@1
# Gate Solar       H=336 ep=02 OOF=0.122536 val=0.165296 alpha=0.082 best=0.165296@2
# Gate Solar       H=336 ep=03 OOF=0.121967 val=0.165388 alpha=0.085 best=0.165296@2
# Gate Solar       H=336 ep=04 OOF=0.121652 val=0.165411 alpha=0.094 best=0.165296@2
# Gate Solar       H=336 ep=05 OOF=0.121546 val=0.165499 alpha=0.090 best=0.165296@2
# Gate Solar       H=336 ep=06 OOF=0.121276 val=0.165406 alpha=0.089 best=0.165296@2
# Gate Solar       H=336 ep=07 OOF=0.121238 val=0.165330 alpha=0.086 best=0.165296@2
# Gate Solar       H=336 ep=08 OOF=0.121392 val=0.165357 alpha=0.091 best=0.165296@2
# Gate Solar       H=336 ep=09 OOF=0.121213 val=0.165362 alpha=0.088 best=0.165296@2
# Validation | alpha0=0.0 | lambda=1.00 | scalar=0.166381 | rawGate=0.165341 | shrink=0.165341
# Building memory embedding: Solar_H336_test_trainval_memory_emb.npy (137, 1735, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
#   test anchors 16/10177
#   test anchors 512/10177
#   test anchors 1008/10177
#   test anchors 1504/10177
#   test anchors 2000/10177
#   test anchors 2512/10177
#   test anchors 3008/10177
#   test anchors 3504/10177
#   test anchors 4000/10177
#   test anchors 4512/10177
#   test anchors 5008/10177
#   test anchors 5504/10177
#   test anchors 6000/10177
#   test anchors 6512/10177
#   test anchors 7008/10177
#   test anchors 7504/10177
#   test anchors 8000/10177
#   test anchors 8512/10177
#   test anchors 9008/10177
#   test anchors 9504/10177
#   test anchors 10000/10177
#   test anchors 10177/10177
#
# FINAL | PatchTST H=336 | Direct=0.199593 | Ours=0.195821 | Gain=+1.890% | CI=[0.002087, 0.005385]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | PatchTST | H=720
# ======================================================================================================================================================
# Loaded full direct | PatchTST H=720 | best=0.160741@43
# Fold PatchTST     H=720 F1 ep=01/43 | train=0.518866
# Fold PatchTST     H=720 F1 ep=02/43 | train=0.345128
# Fold PatchTST     H=720 F1 ep=03/43 | train=0.309109
# Fold PatchTST     H=720 F1 ep=04/43 | train=0.294524
# Fold PatchTST     H=720 F1 ep=05/43 | train=0.285232
# Fold PatchTST     H=720 F1 ep=06/43 | train=0.279030
# Fold PatchTST     H=720 F1 ep=07/43 | train=0.274164
# Fold PatchTST     H=720 F1 ep=08/43 | train=0.270118
# Fold PatchTST     H=720 F1 ep=09/43 | train=0.267027
# Fold PatchTST     H=720 F1 ep=10/43 | train=0.263866
# Fold PatchTST     H=720 F1 ep=11/43 | train=0.260972
# Fold PatchTST     H=720 F1 ep=12/43 | train=0.258123
# Fold PatchTST     H=720 F1 ep=13/43 | train=0.254986
# Fold PatchTST     H=720 F1 ep=14/43 | train=0.253219
# Fold PatchTST     H=720 F1 ep=15/43 | train=0.251404
# Fold PatchTST     H=720 F1 ep=16/43 | train=0.249491
# Fold PatchTST     H=720 F1 ep=17/43 | train=0.247969
# Fold PatchTST     H=720 F1 ep=18/43 | train=0.246048
# Fold PatchTST     H=720 F1 ep=19/43 | train=0.244367
# Fold PatchTST     H=720 F1 ep=20/43 | train=0.242794
# Fold PatchTST     H=720 F1 ep=21/43 | train=0.241200
# Fold PatchTST     H=720 F1 ep=22/43 | train=0.239726
# Fold PatchTST     H=720 F1 ep=23/43 | train=0.238667
# Fold PatchTST     H=720 F1 ep=24/43 | train=0.237497
# Fold PatchTST     H=720 F1 ep=25/43 | train=0.235883
# Fold PatchTST     H=720 F1 ep=26/43 | train=0.234923
# Fold PatchTST     H=720 F1 ep=27/43 | train=0.234019
# Fold PatchTST     H=720 F1 ep=28/43 | train=0.232885
# Fold PatchTST     H=720 F1 ep=29/43 | train=0.231523
# Fold PatchTST     H=720 F1 ep=30/43 | train=0.231106
# Fold PatchTST     H=720 F1 ep=31/43 | train=0.229830
# Fold PatchTST     H=720 F1 ep=32/43 | train=0.229315
# Fold PatchTST     H=720 F1 ep=33/43 | train=0.228389
# Fold PatchTST     H=720 F1 ep=34/43 | train=0.227168
# Fold PatchTST     H=720 F1 ep=35/43 | train=0.226321
# Fold PatchTST     H=720 F1 ep=36/43 | train=0.225315
# Fold PatchTST     H=720 F1 ep=37/43 | train=0.224811
# Fold PatchTST     H=720 F1 ep=38/43 | train=0.224002
# Fold PatchTST     H=720 F1 ep=39/43 | train=0.223194
# Fold PatchTST     H=720 F1 ep=40/43 | train=0.222339
# Fold PatchTST     H=720 F1 ep=41/43 | train=0.221867
# Fold PatchTST     H=720 F1 ep=42/43 | train=0.220966
# Fold PatchTST     H=720 F1 ep=43/43 | train=0.220305
# Building memory embedding: Solar_H720_F1_prefix20235_emb.npy (137, 810, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=720 F1: prefix=20235, end=25754, anchors=1200, pairs=164400, memory/C=810
# Fold PatchTST     H=720 F2 ep=01/43 | train=0.436724
# Fold PatchTST     H=720 F2 ep=02/43 | train=0.286031
# Fold PatchTST     H=720 F2 ep=03/43 | train=0.259700
# Fold PatchTST     H=720 F2 ep=04/43 | train=0.245701
# Fold PatchTST     H=720 F2 ep=05/43 | train=0.238859
# Fold PatchTST     H=720 F2 ep=06/43 | train=0.232813
# Fold PatchTST     H=720 F2 ep=07/43 | train=0.228427
# Fold PatchTST     H=720 F2 ep=08/43 | train=0.224402
# Fold PatchTST     H=720 F2 ep=09/43 | train=0.221364
# Fold PatchTST     H=720 F2 ep=10/43 | train=0.217822
# Fold PatchTST     H=720 F2 ep=11/43 | train=0.215407
# Fold PatchTST     H=720 F2 ep=12/43 | train=0.213141
# Fold PatchTST     H=720 F2 ep=13/43 | train=0.211147
# Fold PatchTST     H=720 F2 ep=14/43 | train=0.208668
# Fold PatchTST     H=720 F2 ep=15/43 | train=0.207305
# Fold PatchTST     H=720 F2 ep=16/43 | train=0.205679
# Fold PatchTST     H=720 F2 ep=17/43 | train=0.203894
# Fold PatchTST     H=720 F2 ep=18/43 | train=0.202354
# Fold PatchTST     H=720 F2 ep=19/43 | train=0.201433
# Fold PatchTST     H=720 F2 ep=20/43 | train=0.199485
# Fold PatchTST     H=720 F2 ep=21/43 | train=0.198780
# Fold PatchTST     H=720 F2 ep=22/43 | train=0.197528
# Fold PatchTST     H=720 F2 ep=23/43 | train=0.196665
# Fold PatchTST     H=720 F2 ep=24/43 | train=0.195509
# Fold PatchTST     H=720 F2 ep=25/43 | train=0.194261
# Fold PatchTST     H=720 F2 ep=26/43 | train=0.193520
# Fold PatchTST     H=720 F2 ep=27/43 | train=0.192354
# Fold PatchTST     H=720 F2 ep=28/43 | train=0.191808
# Fold PatchTST     H=720 F2 ep=29/43 | train=0.190847
# Fold PatchTST     H=720 F2 ep=30/43 | train=0.190336
# Fold PatchTST     H=720 F2 ep=31/43 | train=0.189527
# Fold PatchTST     H=720 F2 ep=32/43 | train=0.188503
# Fold PatchTST     H=720 F2 ep=33/43 | train=0.187882
# Fold PatchTST     H=720 F2 ep=34/43 | train=0.187016
# Fold PatchTST     H=720 F2 ep=35/43 | train=0.186387
# Fold PatchTST     H=720 F2 ep=36/43 | train=0.185630
# Fold PatchTST     H=720 F2 ep=37/43 | train=0.184808
# Fold PatchTST     H=720 F2 ep=38/43 | train=0.184182
# Fold PatchTST     H=720 F2 ep=39/43 | train=0.183379
# Fold PatchTST     H=720 F2 ep=40/43 | train=0.182708
# Fold PatchTST     H=720 F2 ep=41/43 | train=0.181993
# Fold PatchTST     H=720 F2 ep=42/43 | train=0.181368
# Fold PatchTST     H=720 F2 ep=43/43 | train=0.180641
# Building memory embedding: Solar_H720_F2_prefix25754_emb.npy (137, 1040, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=720 F2: prefix=25754, end=31273, anchors=1200, pairs=164400, memory/C=1040
# Fold PatchTST     H=720 F3 ep=01/43 | train=0.394465
# Fold PatchTST     H=720 F3 ep=02/43 | train=0.261614
# Fold PatchTST     H=720 F3 ep=03/43 | train=0.239601
# Fold PatchTST     H=720 F3 ep=04/43 | train=0.228905
# Fold PatchTST     H=720 F3 ep=05/43 | train=0.222550
# Fold PatchTST     H=720 F3 ep=06/43 | train=0.217642
# Fold PatchTST     H=720 F3 ep=07/43 | train=0.212858
# Fold PatchTST     H=720 F3 ep=08/43 | train=0.209073
# Fold PatchTST     H=720 F3 ep=09/43 | train=0.206389
# Fold PatchTST     H=720 F3 ep=10/43 | train=0.204092
# Fold PatchTST     H=720 F3 ep=11/43 | train=0.201388
# Fold PatchTST     H=720 F3 ep=12/43 | train=0.199456
# Fold PatchTST     H=720 F3 ep=13/43 | train=0.197442
# Fold PatchTST     H=720 F3 ep=14/43 | train=0.195808
# Fold PatchTST     H=720 F3 ep=15/43 | train=0.194318
# Fold PatchTST     H=720 F3 ep=16/43 | train=0.193019
# Fold PatchTST     H=720 F3 ep=17/43 | train=0.191431
# Fold PatchTST     H=720 F3 ep=18/43 | train=0.190557
# Fold PatchTST     H=720 F3 ep=19/43 | train=0.188777
# Fold PatchTST     H=720 F3 ep=20/43 | train=0.187350
# Fold PatchTST     H=720 F3 ep=21/43 | train=0.186331
# Fold PatchTST     H=720 F3 ep=22/43 | train=0.185376
# Fold PatchTST     H=720 F3 ep=23/43 | train=0.184113
# Fold PatchTST     H=720 F3 ep=24/43 | train=0.183281
# Fold PatchTST     H=720 F3 ep=25/43 | train=0.182436
# Fold PatchTST     H=720 F3 ep=26/43 | train=0.181636
# Fold PatchTST     H=720 F3 ep=27/43 | train=0.180893
# Fold PatchTST     H=720 F3 ep=28/43 | train=0.179975
# Fold PatchTST     H=720 F3 ep=29/43 | train=0.179489
# Fold PatchTST     H=720 F3 ep=30/43 | train=0.178780
# Fold PatchTST     H=720 F3 ep=31/43 | train=0.177974
# Fold PatchTST     H=720 F3 ep=32/43 | train=0.177507
# Fold PatchTST     H=720 F3 ep=33/43 | train=0.176881
# Fold PatchTST     H=720 F3 ep=34/43 | train=0.176096
# Fold PatchTST     H=720 F3 ep=35/43 | train=0.175519
# Fold PatchTST     H=720 F3 ep=36/43 | train=0.174994
# Fold PatchTST     H=720 F3 ep=37/43 | train=0.174408
# Fold PatchTST     H=720 F3 ep=38/43 | train=0.173703
# Fold PatchTST     H=720 F3 ep=39/43 | train=0.173323
# Fold PatchTST     H=720 F3 ep=40/43 | train=0.172579
# Fold PatchTST     H=720 F3 ep=41/43 | train=0.171971
# Fold PatchTST     H=720 F3 ep=42/43 | train=0.171346
# Fold PatchTST     H=720 F3 ep=43/43 | train=0.170958
# Building memory embedding: Solar_H720_F3_prefix31273_emb.npy (137, 1270, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# OOF Solar H=720 F3: prefix=31273, end=36792, anchors=1200, pairs=164400, memory/C=1270
# Building memory embedding: Solar_H720_validation_train_memory_emb.npy (137, 1500, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
# Validation Solar H=720: anchors=4537, pairs=621569, memory/C=1500
# Gate Solar       H=720 ep=01 OOF=0.125696 val=0.160108 alpha=0.104 best=0.160108@1
# Gate Solar       H=720 ep=02 OOF=0.124634 val=0.159983 alpha=0.099 best=0.159983@2
# Gate Solar       H=720 ep=03 OOF=0.124102 val=0.160000 alpha=0.100 best=0.159983@2
# Gate Solar       H=720 ep=04 OOF=0.123963 val=0.159950 alpha=0.098 best=0.159950@4
# Gate Solar       H=720 ep=05 OOF=0.123815 val=0.159996 alpha=0.104 best=0.159950@4
# Gate Solar       H=720 ep=06 OOF=0.123712 val=0.159991 alpha=0.101 best=0.159950@4
# Gate Solar       H=720 ep=07 OOF=0.123670 val=0.160031 alpha=0.102 best=0.159950@4
# Gate Solar       H=720 ep=08 OOF=0.123595 val=0.160047 alpha=0.105 best=0.159950@4
# Gate Solar       H=720 ep=09 OOF=0.123586 val=0.159987 alpha=0.107 best=0.159950@4
# Gate Solar       H=720 ep=10 OOF=0.123502 val=0.159977 alpha=0.104 best=0.159950@4
# Gate Solar       H=720 ep=11 OOF=0.123492 val=0.160047 alpha=0.105 best=0.159950@4
# Validation | alpha0=0.0 | lambda=0.75 | scalar=0.160741 | rawGate=0.159949 | shrink=0.159802
# Building memory embedding: Solar_H720_test_trainval_memory_emb.npy (137, 1719, 64)
#   channel 1/137
#   channel 50/137
#   channel 100/137
#   channel 137/137
#   test anchors 16/9793
#   test anchors 512/9793
#   test anchors 1008/9793
#   test anchors 1504/9793
#   test anchors 2000/9793
#   test anchors 2512/9793
#   test anchors 3008/9793
#   test anchors 3504/9793
#   test anchors 4000/9793
#   test anchors 4512/9793
#   test anchors 5008/9793
#   test anchors 5504/9793
#   test anchors 6000/9793
#   test anchors 6512/9793
#   test anchors 7008/9793
#   test anchors 7504/9793
#   test anchors 8000/9793
#   test anchors 8512/9793
#   test anchors 9008/9793
#   test anchors 9504/9793
#   test anchors 9793/9793
#
# FINAL | PatchTST H=720 | Direct=0.213913 | Ours=0.209384 | Gain=+2.117% | CI=[0.002738, 0.006251]
# Activated iTransformer: /code/stock_regime_retrieval/strong_forecaster/iTransformer_official/model/iTransformer.py
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | iTransformer | H=96
# ======================================================================================================================================================
# Loaded full direct | iTransformer H=96 | best=0.153130@6
# Fold iTransformer H= 96 F1 ep=01/6 | train=0.333222
# Fold iTransformer H= 96 F1 ep=02/6 | train=0.265499
# Fold iTransformer H= 96 F1 ep=03/6 | train=0.239981
# Fold iTransformer H= 96 F1 ep=04/6 | train=0.222360
# Fold iTransformer H= 96 F1 ep=05/6 | train=0.208533
# Fold iTransformer H= 96 F1 ep=06/6 | train=0.200524
# Loaded memory embedding: Solar_H96_F1_prefix20235_emb.npy
# OOF Solar H=96 F1: prefix=20235, end=25754, anchors=1356, pairs=185772, memory/C=836
# Fold iTransformer H= 96 F2 ep=01/6 | train=0.280863
# Fold iTransformer H= 96 F2 ep=02/6 | train=0.222846
# Fold iTransformer H= 96 F2 ep=03/6 | train=0.201040
# Fold iTransformer H= 96 F2 ep=04/6 | train=0.186729
# Fold iTransformer H= 96 F2 ep=05/6 | train=0.175686
# Fold iTransformer H= 96 F2 ep=06/6 | train=0.169098
# Loaded memory embedding: Solar_H96_F2_prefix25754_emb.npy
# OOF Solar H=96 F2: prefix=25754, end=31273, anchors=1356, pairs=185772, memory/C=1066
# Fold iTransformer H= 96 F3 ep=01/6 | train=0.256677
# Fold iTransformer H= 96 F3 ep=02/6 | train=0.204269
# Fold iTransformer H= 96 F3 ep=03/6 | train=0.185912
# Fold iTransformer H= 96 F3 ep=04/6 | train=0.173107
# Fold iTransformer H= 96 F3 ep=05/6 | train=0.163601
# Fold iTransformer H= 96 F3 ep=06/6 | train=0.157769
# Loaded memory embedding: Solar_H96_F3_prefix31273_emb.npy
# OOF Solar H=96 F3: prefix=31273, end=36792, anchors=1356, pairs=185772, memory/C=1296
# Loaded memory embedding: Solar_H96_validation_train_memory_emb.npy
# Validation Solar H=96: anchors=5161, pairs=707057, memory/C=1526
# Gate Solar       H= 96 ep=01 OOF=0.127647 val=0.149112 alpha=0.118 best=0.149112@1
# Gate Solar       H= 96 ep=02 OOF=0.122603 val=0.150314 alpha=0.133 best=0.149112@1
# Gate Solar       H= 96 ep=03 OOF=0.120710 val=0.149829 alpha=0.143 best=0.149112@1
# Gate Solar       H= 96 ep=04 OOF=0.119946 val=0.150863 alpha=0.163 best=0.149112@1
# Gate Solar       H= 96 ep=05 OOF=0.119477 val=0.149674 alpha=0.148 best=0.149112@1
# Gate Solar       H= 96 ep=06 OOF=0.119245 val=0.149099 alpha=0.145 best=0.149099@6
# Gate Solar       H= 96 ep=07 OOF=0.119167 val=0.148657 alpha=0.141 best=0.148657@7
# Gate Solar       H= 96 ep=08 OOF=0.118701 val=0.148695 alpha=0.146 best=0.148657@7
# Gate Solar       H= 96 ep=09 OOF=0.118818 val=0.149217 alpha=0.151 best=0.148657@7
# Gate Solar       H= 96 ep=10 OOF=0.118570 val=0.148806 alpha=0.148 best=0.148657@7
# Gate Solar       H= 96 ep=11 OOF=0.118588 val=0.149465 alpha=0.159 best=0.148657@7
# Gate Solar       H= 96 ep=12 OOF=0.118378 val=0.149785 alpha=0.156 best=0.148657@7
# Gate Solar       H= 96 ep=13 OOF=0.118330 val=0.148842 alpha=0.151 best=0.148657@7
# Gate Solar       H= 96 ep=14 OOF=0.118133 val=0.149067 alpha=0.157 best=0.148657@7
# Validation | alpha0=0.1 | lambda=0.75 | scalar=0.152437 | rawGate=0.148719 | shrink=0.147655
# Loaded memory embedding: Solar_H96_test_trainval_memory_emb.npy
#   test anchors 16/10417
#   test anchors 512/10417
#   test anchors 1008/10417
#   test anchors 1504/10417
#   test anchors 2000/10417
#   test anchors 2512/10417
#   test anchors 3008/10417
#   test anchors 3504/10417
#   test anchors 4000/10417
#   test anchors 4512/10417
#   test anchors 5008/10417
#   test anchors 5504/10417
#   test anchors 6000/10417
#   test anchors 6512/10417
#   test anchors 7008/10417
#   test anchors 7504/10417
#   test anchors 8000/10417
#   test anchors 8512/10417
#   test anchors 9008/10417
#   test anchors 9504/10417
#   test anchors 10000/10417
#   test anchors 10417/10417
#
# FINAL | iTransformer H=96 | Direct=0.204083 | Ours=0.182722 | Gain=+10.467% | CI=[0.012270, 0.030900]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | iTransformer | H=192
# ======================================================================================================================================================
# Loaded full direct | iTransformer H=192 | best=0.173252@6
# Fold iTransformer H=192 F1 ep=01/6 | train=0.369852
# Fold iTransformer H=192 F1 ep=02/6 | train=0.298901
# Fold iTransformer H=192 F1 ep=03/6 | train=0.272920
# Fold iTransformer H=192 F1 ep=04/6 | train=0.255797
# Fold iTransformer H=192 F1 ep=05/6 | train=0.244016
# Fold iTransformer H=192 F1 ep=06/6 | train=0.236748
# Loaded memory embedding: Solar_H192_F1_prefix20235_emb.npy
# OOF Solar H=192 F1: prefix=20235, end=25754, anchors=1332, pairs=182484, memory/C=832
# Fold iTransformer H=192 F2 ep=01/6 | train=0.312023
# Fold iTransformer H=192 F2 ep=02/6 | train=0.248572
# Fold iTransformer H=192 F2 ep=03/6 | train=0.226525
# Fold iTransformer H=192 F2 ep=04/6 | train=0.211301
# Fold iTransformer H=192 F2 ep=05/6 | train=0.201193
# Fold iTransformer H=192 F2 ep=06/6 | train=0.194945
# Loaded memory embedding: Solar_H192_F2_prefix25754_emb.npy
# OOF Solar H=192 F2: prefix=25754, end=31273, anchors=1332, pairs=182484, memory/C=1062
# Fold iTransformer H=192 F3 ep=01/6 | train=0.287326
# Fold iTransformer H=192 F3 ep=02/6 | train=0.230922
# Fold iTransformer H=192 F3 ep=03/6 | train=0.209502
# Fold iTransformer H=192 F3 ep=04/6 | train=0.196709
# Fold iTransformer H=192 F3 ep=05/6 | train=0.187435
# Fold iTransformer H=192 F3 ep=06/6 | train=0.181837
# Loaded memory embedding: Solar_H192_F3_prefix31273_emb.npy
# OOF Solar H=192 F3: prefix=31273, end=36792, anchors=1332, pairs=182484, memory/C=1292
# Loaded memory embedding: Solar_H192_validation_train_memory_emb.npy
# Validation Solar H=192: anchors=5065, pairs=693905, memory/C=1522
# Gate Solar       H=192 ep=01 OOF=0.136439 val=0.165684 alpha=0.129 best=0.165684@1
# Gate Solar       H=192 ep=02 OOF=0.131904 val=0.164531 alpha=0.169 best=0.164531@2
# Gate Solar       H=192 ep=03 OOF=0.130403 val=0.164233 alpha=0.172 best=0.164233@3
# Gate Solar       H=192 ep=04 OOF=0.129819 val=0.164205 alpha=0.181 best=0.164205@4
# Gate Solar       H=192 ep=05 OOF=0.129459 val=0.164056 alpha=0.177 best=0.164056@5
# Gate Solar       H=192 ep=06 OOF=0.129172 val=0.163781 alpha=0.170 best=0.163781@6
# Gate Solar       H=192 ep=07 OOF=0.128926 val=0.163856 alpha=0.178 best=0.163781@6
# Gate Solar       H=192 ep=08 OOF=0.128735 val=0.163910 alpha=0.178 best=0.163781@6
# Gate Solar       H=192 ep=09 OOF=0.128567 val=0.163920 alpha=0.183 best=0.163781@6
# Gate Solar       H=192 ep=10 OOF=0.128414 val=0.163803 alpha=0.186 best=0.163781@6
# Gate Solar       H=192 ep=11 OOF=0.128266 val=0.163661 alpha=0.182 best=0.163661@11
# Gate Solar       H=192 ep=12 OOF=0.128137 val=0.163765 alpha=0.179 best=0.163661@11
# Gate Solar       H=192 ep=13 OOF=0.128032 val=0.164021 alpha=0.187 best=0.163661@11
# Gate Solar       H=192 ep=14 OOF=0.127911 val=0.163627 alpha=0.182 best=0.163627@14
# Gate Solar       H=192 ep=15 OOF=0.127799 val=0.163773 alpha=0.180 best=0.163627@14
# Gate Solar       H=192 ep=16 OOF=0.127718 val=0.163840 alpha=0.174 best=0.163627@14
# Gate Solar       H=192 ep=17 OOF=0.127615 val=0.164075 alpha=0.185 best=0.163627@14
# Gate Solar       H=192 ep=18 OOF=0.127523 val=0.163898 alpha=0.183 best=0.163627@14
# Gate Solar       H=192 ep=19 OOF=0.127459 val=0.164280 alpha=0.185 best=0.163627@14
# Gate Solar       H=192 ep=20 OOF=0.127373 val=0.164317 alpha=0.190 best=0.163627@14
# Gate Solar       H=192 ep=21 OOF=0.127304 val=0.164191 alpha=0.187 best=0.163627@14
# Validation | alpha0=0.1 | lambda=0.75 | scalar=0.170534 | rawGate=0.163805 | shrink=0.162908
# Loaded memory embedding: Solar_H192_test_trainval_memory_emb.npy
#   test anchors 16/10321
#   test anchors 512/10321
#   test anchors 1008/10321
#   test anchors 1504/10321
#   test anchors 2000/10321
#   test anchors 2512/10321
#   test anchors 3008/10321
#   test anchors 3504/10321
#   test anchors 4000/10321
#   test anchors 4512/10321
#   test anchors 5008/10321
#   test anchors 5504/10321
#   test anchors 6000/10321
#   test anchors 6512/10321
#   test anchors 7008/10321
#   test anchors 7504/10321
#   test anchors 8000/10321
#   test anchors 8512/10321
#   test anchors 9008/10321
#   test anchors 9504/10321
#   test anchors 10000/10321
#   test anchors 10321/10321
#
# FINAL | iTransformer H=192 | Direct=0.244628 | Ours=0.213126 | Gain=+12.877% | CI=[0.021953, 0.041997]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | iTransformer | H=336
# ======================================================================================================================================================
# Loaded full direct | iTransformer H=336 | best=0.178269@5
# Fold iTransformer H=336 F1 ep=01/5 | train=0.388533
# Fold iTransformer H=336 F1 ep=02/5 | train=0.313479
# Fold iTransformer H=336 F1 ep=03/5 | train=0.288011
# Fold iTransformer H=336 F1 ep=04/5 | train=0.272839
# Fold iTransformer H=336 F1 ep=05/5 | train=0.261992
# Loaded memory embedding: Solar_H336_F1_prefix20235_emb.npy
# OOF Solar H=336 F1: prefix=20235, end=25754, anchors=1296, pairs=177552, memory/C=826
# Fold iTransformer H=336 F2 ep=01/5 | train=0.327713
# Fold iTransformer H=336 F2 ep=02/5 | train=0.261161
# Fold iTransformer H=336 F2 ep=03/5 | train=0.238609
# Fold iTransformer H=336 F2 ep=04/5 | train=0.224918
# Fold iTransformer H=336 F2 ep=05/5 | train=0.216071
# Loaded memory embedding: Solar_H336_F2_prefix25754_emb.npy
# OOF Solar H=336 F2: prefix=25754, end=31273, anchors=1296, pairs=177552, memory/C=1056
# Fold iTransformer H=336 F3 ep=01/5 | train=0.301688
# Fold iTransformer H=336 F3 ep=02/5 | train=0.240020
# Fold iTransformer H=336 F3 ep=03/5 | train=0.219980
# Fold iTransformer H=336 F3 ep=04/5 | train=0.207588
# Fold iTransformer H=336 F3 ep=05/5 | train=0.199721
# Loaded memory embedding: Solar_H336_F3_prefix31273_emb.npy
# OOF Solar H=336 F3: prefix=31273, end=36792, anchors=1296, pairs=177552, memory/C=1286
# Loaded memory embedding: Solar_H336_validation_train_memory_emb.npy
# Validation Solar H=336: anchors=4921, pairs=674177, memory/C=1516
# Gate Solar       H=336 ep=01 OOF=0.137120 val=0.171833 alpha=0.175 best=0.171833@1
# Gate Solar       H=336 ep=02 OOF=0.133086 val=0.171327 alpha=0.187 best=0.171327@2
# Gate Solar       H=336 ep=03 OOF=0.131840 val=0.170805 alpha=0.167 best=0.170805@3
# Gate Solar       H=336 ep=04 OOF=0.131276 val=0.171154 alpha=0.182 best=0.170805@3
# Gate Solar       H=336 ep=05 OOF=0.131013 val=0.171232 alpha=0.180 best=0.170805@3
# Gate Solar       H=336 ep=06 OOF=0.130576 val=0.170916 alpha=0.179 best=0.170805@3
# Gate Solar       H=336 ep=07 OOF=0.130431 val=0.170800 alpha=0.173 best=0.170800@7
# Gate Solar       H=336 ep=08 OOF=0.130412 val=0.170964 alpha=0.185 best=0.170800@7
# Gate Solar       H=336 ep=09 OOF=0.130212 val=0.171153 alpha=0.188 best=0.170800@7
# Gate Solar       H=336 ep=10 OOF=0.130085 val=0.170726 alpha=0.175 best=0.170726@10
# Gate Solar       H=336 ep=11 OOF=0.130057 val=0.170957 alpha=0.184 best=0.170726@10
# Gate Solar       H=336 ep=12 OOF=0.129930 val=0.170618 alpha=0.174 best=0.170618@12
# Gate Solar       H=336 ep=13 OOF=0.129847 val=0.170635 alpha=0.173 best=0.170618@12
# Gate Solar       H=336 ep=14 OOF=0.129596 val=0.170750 alpha=0.178 best=0.170618@12
# Gate Solar       H=336 ep=15 OOF=0.129793 val=0.170912 alpha=0.184 best=0.170618@12
# Gate Solar       H=336 ep=16 OOF=0.129745 val=0.170656 alpha=0.178 best=0.170618@12
# Gate Solar       H=336 ep=17 OOF=0.129500 val=0.170578 alpha=0.177 best=0.170578@17
# Gate Solar       H=336 ep=18 OOF=0.129448 val=0.170742 alpha=0.179 best=0.170578@17
# Gate Solar       H=336 ep=19 OOF=0.129611 val=0.170921 alpha=0.181 best=0.170578@17
# Gate Solar       H=336 ep=20 OOF=0.129503 val=0.170511 alpha=0.174 best=0.170511@20
# Gate Solar       H=336 ep=21 OOF=0.129456 val=0.171168 alpha=0.181 best=0.170511@20
# Gate Solar       H=336 ep=22 OOF=0.129475 val=0.171088 alpha=0.181 best=0.170511@20
# Gate Solar       H=336 ep=23 OOF=0.129482 val=0.170967 alpha=0.182 best=0.170511@20
# Gate Solar       H=336 ep=24 OOF=0.129407 val=0.170619 alpha=0.176 best=0.170511@20
# Gate Solar       H=336 ep=25 OOF=0.129381 val=0.170717 alpha=0.174 best=0.170511@20
# Gate Solar       H=336 ep=26 OOF=0.129210 val=0.171141 alpha=0.187 best=0.170511@20
# Gate Solar       H=336 ep=27 OOF=0.129330 val=0.170961 alpha=0.180 best=0.170511@20
# Validation | alpha0=0.1 | lambda=0.75 | scalar=0.176340 | rawGate=0.170697 | shrink=0.170090
# Loaded memory embedding: Solar_H336_test_trainval_memory_emb.npy
#   test anchors 16/10177
#   test anchors 512/10177
#   test anchors 1008/10177
#   test anchors 1504/10177
#   test anchors 2000/10177
#   test anchors 2512/10177
#   test anchors 3008/10177
#   test anchors 3504/10177
#   test anchors 4000/10177
#   test anchors 4512/10177
#   test anchors 5008/10177
#   test anchors 5504/10177
#   test anchors 6000/10177
#   test anchors 6512/10177
#   test anchors 7008/10177
#   test anchors 7504/10177
#   test anchors 8000/10177
#   test anchors 8512/10177
#   test anchors 9008/10177
#   test anchors 9504/10177
#   test anchors 10000/10177
#   test anchors 10177/10177
#
# FINAL | iTransformer H=336 | Direct=0.252072 | Ours=0.216806 | Gain=+13.991% | CI=[0.027903, 0.043691]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | iTransformer | H=720
# ======================================================================================================================================================
# Loaded full direct | iTransformer H=720 | best=0.176509@10
# Fold iTransformer H=720 F1 ep=01/10 | train=0.387675
# Fold iTransformer H=720 F1 ep=02/10 | train=0.314666
# Fold iTransformer H=720 F1 ep=03/10 | train=0.292972
# Fold iTransformer H=720 F1 ep=04/10 | train=0.280781
# Fold iTransformer H=720 F1 ep=05/10 | train=0.273213
# Fold iTransformer H=720 F1 ep=06/10 | train=0.268787
# Fold iTransformer H=720 F1 ep=07/10 | train=0.266362
# Fold iTransformer H=720 F1 ep=08/10 | train=0.265198
# Fold iTransformer H=720 F1 ep=09/10 | train=0.264374
# Fold iTransformer H=720 F1 ep=10/10 | train=0.264113
# Loaded memory embedding: Solar_H720_F1_prefix20235_emb.npy
# OOF Solar H=720 F1: prefix=20235, end=25754, anchors=1200, pairs=164400, memory/C=810
# Fold iTransformer H=720 F2 ep=01/10 | train=0.324624
# Fold iTransformer H=720 F2 ep=02/10 | train=0.260512
# Fold iTransformer H=720 F2 ep=03/10 | train=0.240741
# Fold iTransformer H=720 F2 ep=04/10 | train=0.230312
# Fold iTransformer H=720 F2 ep=05/10 | train=0.224168
# Fold iTransformer H=720 F2 ep=06/10 | train=0.220567
# Fold iTransformer H=720 F2 ep=07/10 | train=0.218675
# Fold iTransformer H=720 F2 ep=08/10 | train=0.217732
# Fold iTransformer H=720 F2 ep=09/10 | train=0.217150
# Fold iTransformer H=720 F2 ep=10/10 | train=0.216903
# Loaded memory embedding: Solar_H720_F2_prefix25754_emb.npy
# ...
# Fold TimeMixer    H=192 F3 ep=08/16 | train=0.224591
# Fold TimeMixer    H=192 F3 ep=09/16 | train=0.224030
# Fold TimeMixer    H=192 F3 ep=10/16 | train=0.221895
# Fold TimeMixer    H=192 F3 ep=11/16 | train=0.218842
# Fold TimeMixer    H=192 F3 ep=12/16 | train=0.217479
# Fold TimeMixer    H=192 F3 ep=13/16 | train=0.216244
# Fold TimeMixer    H=192 F3 ep=14/16 | train=0.213724
# Fold TimeMixer    H=192 F3 ep=15/16 | train=0.212438
# Fold TimeMixer    H=192 F3 ep=16/16 | train=0.211016
# Loaded memory embedding: Solar_H192_F3_prefix31273_emb.npy
# OOF Solar H=192 F3: prefix=31273, end=36792, anchors=1332, pairs=182484, memory/C=1292
# Loaded memory embedding: Solar_H192_validation_train_memory_emb.npy
# Validation Solar H=192: anchors=5065, pairs=693905, memory/C=1522
# Gate Solar       H=192 ep=01 OOF=0.150048 val=0.171648 alpha=0.108 best=0.171648@1
# Gate Solar       H=192 ep=02 OOF=0.144726 val=0.171605 alpha=0.140 best=0.171605@2
# Gate Solar       H=192 ep=03 OOF=0.143201 val=0.171672 alpha=0.155 best=0.171605@2
# Gate Solar       H=192 ep=04 OOF=0.142471 val=0.172059 alpha=0.174 best=0.171605@2
# Gate Solar       H=192 ep=05 OOF=0.141996 val=0.171941 alpha=0.185 best=0.171605@2
# Gate Solar       H=192 ep=06 OOF=0.141699 val=0.172076 alpha=0.189 best=0.171605@2
# Gate Solar       H=192 ep=07 OOF=0.141485 val=0.172772 alpha=0.207 best=0.171605@2
# Gate Solar       H=192 ep=08 OOF=0.141333 val=0.172164 alpha=0.191 best=0.171605@2
# Gate Solar       H=192 ep=09 OOF=0.141201 val=0.172959 alpha=0.209 best=0.171605@2
# Validation | alpha0=0.1 | lambda=0.75 | scalar=0.175108 | rawGate=0.171899 | shrink=0.170740
# Loaded memory embedding: Solar_H192_test_trainval_memory_emb.npy
#   test anchors 16/10321
#   test anchors 512/10321
#   test anchors 1008/10321
#   test anchors 1504/10321
#   test anchors 2000/10321
#   test anchors 2512/10321
#   test anchors 3008/10321
#   test anchors 3504/10321
#   test anchors 4000/10321
#   test anchors 4512/10321
#   test anchors 5008/10321
#   test anchors 5504/10321
#   test anchors 6000/10321
#   test anchors 6512/10321
#   test anchors 7008/10321
#   test anchors 7504/10321
#   test anchors 8000/10321
#   test anchors 8512/10321
#   test anchors 9008/10321
#   test anchors 9504/10321
#   test anchors 10000/10321
#   test anchors 10321/10321
#
# FINAL | TimeMixer H=192 | Direct=0.228547 | Ours=0.219061 | Gain=+4.151% | CI=[0.002735, 0.016665]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | TimeMixer | H=336
# ======================================================================================================================================================
# Loaded full direct | TimeMixer H=336 | best=0.183921@12
# Fold TimeMixer    H=336 F1 ep=01/12 | train=0.905873
# Fold TimeMixer    H=336 F1 ep=02/12 | train=0.372057
# Fold TimeMixer    H=336 F1 ep=03/12 | train=0.340127
# Fold TimeMixer    H=336 F1 ep=04/12 | train=0.327016
# Fold TimeMixer    H=336 F1 ep=05/12 | train=0.315115
# Fold TimeMixer    H=336 F1 ep=06/12 | train=0.311902
# Fold TimeMixer    H=336 F1 ep=07/12 | train=0.307646
# Fold TimeMixer    H=336 F1 ep=08/12 | train=0.302350
# Fold TimeMixer    H=336 F1 ep=09/12 | train=0.300375
# Fold TimeMixer    H=336 F1 ep=10/12 | train=0.296361
# Fold TimeMixer    H=336 F1 ep=11/12 | train=0.294628
# Fold TimeMixer    H=336 F1 ep=12/12 | train=0.292305
# Loaded memory embedding: Solar_H336_F1_prefix20235_emb.npy
# OOF Solar H=336 F1: prefix=20235, end=25754, anchors=1296, pairs=177552, memory/C=826
# Fold TimeMixer    H=336 F2 ep=01/12 | train=0.669519
# Fold TimeMixer    H=336 F2 ep=02/12 | train=0.313257
# Fold TimeMixer    H=336 F2 ep=03/12 | train=0.289821
# Fold TimeMixer    H=336 F2 ep=04/12 | train=0.279945
# Fold TimeMixer    H=336 F2 ep=05/12 | train=0.268139
# Fold TimeMixer    H=336 F2 ep=06/12 | train=0.260762
# Fold TimeMixer    H=336 F2 ep=07/12 | train=0.258008
# Fold TimeMixer    H=336 F2 ep=08/12 | train=0.253514
# Fold TimeMixer    H=336 F2 ep=09/12 | train=0.251634
# Fold TimeMixer    H=336 F2 ep=10/12 | train=0.248224
# Fold TimeMixer    H=336 F2 ep=11/12 | train=0.245865
# Fold TimeMixer    H=336 F2 ep=12/12 | train=0.243826
# Loaded memory embedding: Solar_H336_F2_prefix25754_emb.npy
# OOF Solar H=336 F2: prefix=25754, end=31273, anchors=1296, pairs=177552, memory/C=1056
# Fold TimeMixer    H=336 F3 ep=01/12 | train=0.624207
# Fold TimeMixer    H=336 F3 ep=02/12 | train=0.288082
# Fold TimeMixer    H=336 F3 ep=03/12 | train=0.265269
# Fold TimeMixer    H=336 F3 ep=04/12 | train=0.256277
# Fold TimeMixer    H=336 F3 ep=05/12 | train=0.248884
# Fold TimeMixer    H=336 F3 ep=06/12 | train=0.243075
# Fold TimeMixer    H=336 F3 ep=07/12 | train=0.238738
# Fold TimeMixer    H=336 F3 ep=08/12 | train=0.236465
# Fold TimeMixer    H=336 F3 ep=09/12 | train=0.233775
# Fold TimeMixer    H=336 F3 ep=10/12 | train=0.231583
# Fold TimeMixer    H=336 F3 ep=11/12 | train=0.230965
# Fold TimeMixer    H=336 F3 ep=12/12 | train=0.228836
# Loaded memory embedding: Solar_H336_F3_prefix31273_emb.npy
# OOF Solar H=336 F3: prefix=31273, end=36792, anchors=1296, pairs=177552, memory/C=1286
# Loaded memory embedding: Solar_H336_validation_train_memory_emb.npy
# Validation Solar H=336: anchors=4921, pairs=674177, memory/C=1516
# Gate Solar       H=336 ep=01 OOF=0.153082 val=0.178148 alpha=0.135 best=0.178148@1
# Gate Solar       H=336 ep=02 OOF=0.147728 val=0.178036 alpha=0.142 best=0.178036@2
# Gate Solar       H=336 ep=03 OOF=0.146401 val=0.177650 alpha=0.137 best=0.177650@3
# Gate Solar       H=336 ep=04 OOF=0.145774 val=0.177806 alpha=0.159 best=0.177650@3
# Gate Solar       H=336 ep=05 OOF=0.145671 val=0.177375 alpha=0.149 best=0.177375@5
# Gate Solar       H=336 ep=06 OOF=0.145075 val=0.177246 alpha=0.151 best=0.177246@6
# Gate Solar       H=336 ep=07 OOF=0.144893 val=0.177464 alpha=0.155 best=0.177246@6
# Gate Solar       H=336 ep=08 OOF=0.144898 val=0.177095 alpha=0.155 best=0.177095@8
# Gate Solar       H=336 ep=09 OOF=0.144790 val=0.177326 alpha=0.162 best=0.177095@8
# Gate Solar       H=336 ep=10 OOF=0.144777 val=0.177673 alpha=0.166 best=0.177095@8
# Gate Solar       H=336 ep=11 OOF=0.144737 val=0.177129 alpha=0.168 best=0.177095@8
# Gate Solar       H=336 ep=12 OOF=0.144626 val=0.176942 alpha=0.157 best=0.176942@12
# Gate Solar       H=336 ep=13 OOF=0.144496 val=0.177180 alpha=0.168 best=0.176942@12
# Gate Solar       H=336 ep=14 OOF=0.144281 val=0.177237 alpha=0.168 best=0.176942@12
# Gate Solar       H=336 ep=15 OOF=0.144371 val=0.176970 alpha=0.162 best=0.176942@12
# Gate Solar       H=336 ep=16 OOF=0.144528 val=0.177108 alpha=0.170 best=0.176942@12
# Gate Solar       H=336 ep=17 OOF=0.144312 val=0.177339 alpha=0.172 best=0.176942@12
# Gate Solar       H=336 ep=18 OOF=0.144216 val=0.177116 alpha=0.171 best=0.176942@12
# Gate Solar       H=336 ep=19 OOF=0.144357 val=0.177270 alpha=0.175 best=0.176942@12
# Validation | alpha0=0.1 | lambda=0.75 | scalar=0.181839 | rawGate=0.177067 | shrink=0.176253
# Loaded memory embedding: Solar_H336_test_trainval_memory_emb.npy
#   test anchors 16/10177
#   test anchors 512/10177
#   test anchors 1008/10177
#   test anchors 1504/10177
#   test anchors 2000/10177
#   test anchors 2512/10177
#   test anchors 3008/10177
#   test anchors 3504/10177
#   test anchors 4000/10177
#   test anchors 4512/10177
#   test anchors 5008/10177
#   test anchors 5504/10177
#   test anchors 6000/10177
#   test anchors 6512/10177
#   test anchors 7008/10177
#   test anchors 7504/10177
#   test anchors 8000/10177
#   test anchors 8512/10177
#   test anchors 9008/10177
#   test anchors 9504/10177
#   test anchors 10000/10177
#   test anchors 10177/10177
#
# FINAL | TimeMixer H=336 | Direct=0.255755 | Ours=0.233141 | Gain=+8.842% | CI=[0.016781, 0.028967]
#
# ======================================================================================================================================================
# EXPERIMENT 27 | SOLAR | TimeMixer | H=720
# ======================================================================================================================================================
# Loaded full direct | TimeMixer H=720 | best=0.182301@15
# Fold TimeMixer    H=720 F1 ep=01/15 | train=0.648979
# Fold TimeMixer    H=720 F1 ep=02/15 | train=0.359419
# Fold TimeMixer    H=720 F1 ep=03/15 | train=0.335273
# Fold TimeMixer    H=720 F1 ep=04/15 | train=0.324587
# Fold TimeMixer    H=720 F1 ep=05/15 | train=0.315525
# Fold TimeMixer    H=720 F1 ep=06/15 | train=0.309631
# Fold TimeMixer    H=720 F1 ep=07/15 | train=0.304512
# Fold TimeMixer    H=720 F1 ep=08/15 | train=0.300461
# Fold TimeMixer    H=720 F1 ep=09/15 | train=0.298194
# Fold TimeMixer    H=720 F1 ep=10/15 | train=0.296330
# Fold TimeMixer    H=720 F1 ep=11/15 | train=0.293217
# Fold TimeMixer    H=720 F1 ep=12/15 | train=0.292241
# Fold TimeMixer    H=720 F1 ep=13/15 | train=0.289148
# Fold TimeMixer    H=720 F1 ep=14/15 | train=0.287556
# Fold TimeMixer    H=720 F1 ep=15/15 | train=0.286431
# Loaded memory embedding: Solar_H720_F1_prefix20235_emb.npy
# OOF Solar H=720 F1: prefix=20235, end=25754, anchors=1200, pairs=164400, memory/C=810
# Fold TimeMixer    H=720 F2 ep=01/15 | train=0.567482
# Fold TimeMixer    H=720 F2 ep=02/15 | train=0.309786
# Fold TimeMixer    H=720 F2 ep=03/15 | train=0.287594
# Fold TimeMixer    H=720 F2 ep=04/15 | train=0.275752
# Fold TimeMixer    H=720 F2 ep=05/15 | train=0.265010
# Fold TimeMixer    H=720 F2 ep=06/15 | train=0.259246
# Fold TimeMixer    H=720 F2 ep=07/15 | train=0.255266
# Fold TimeMixer    H=720 F2 ep=08/15 | train=0.251021
# Fold TimeMixer    H=720 F2 ep=09/15 | train=0.249909
# Fold TimeMixer    H=720 F2 ep=10/15 | train=0.246467
# Fold TimeMixer    H=720 F2 ep=11/15 | train=0.245111
# Fold TimeMixer    H=720 F2 ep=12/15 | train=0.242719
# Fold TimeMixer    H=720 F2 ep=13/15 | train=0.241002
# Fold TimeMixer    H=720 F2 ep=14/15 | train=0.239271
# Fold TimeMixer    H=720 F2 ep=15/15 | train=0.237852
# Loaded memory embedding: Solar_H720_F2_prefix25754_emb.npy
# OOF Solar H=720 F2: prefix=25754, end=31273, anchors=1200, pairs=164400, memory/C=1040
# Fold TimeMixer    H=720 F3 ep=01/15 | train=0.717305
# Fold TimeMixer    H=720 F3 ep=02/15 | train=0.292399
# Fold TimeMixer    H=720 F3 ep=03/15 | train=0.270654
# Fold TimeMixer    H=720 F3 ep=04/15 | train=0.259140
# Fold TimeMixer    H=720 F3 ep=05/15 | train=0.248894
# Fold TimeMixer    H=720 F3 ep=06/15 | train=0.242900
# Fold TimeMixer    H=720 F3 ep=07/15 | train=0.238587
# Fold TimeMixer    H=720 F3 ep=08/15 | train=0.235899
# Fold TimeMixer    H=720 F3 ep=09/15 | train=0.233350
# Fold TimeMixer    H=720 F3 ep=10/15 | train=0.232550
# Fold TimeMixer    H=720 F3 ep=11/15 | train=0.229906
# Fold TimeMixer    H=720 F3 ep=12/15 | train=0.228736
# Fold TimeMixer    H=720 F3 ep=13/15 | train=0.226533
# Fold TimeMixer    H=720 F3 ep=14/15 | train=0.225391
# Fold TimeMixer    H=720 F3 ep=15/15 | train=0.224070
# Loaded memory embedding: Solar_H720_F3_prefix31273_emb.npy
# OOF Solar H=720 F3: prefix=31273, end=36792, anchors=1200, pairs=164400, memory/C=1270
# Loaded memory embedding: Solar_H720_validation_train_memory_emb.npy
# Validation Solar H=720: anchors=4537, pairs=621569, memory/C=1500
# Gate Solar       H=720 ep=01 OOF=0.151543 val=0.178323 alpha=0.131 best=0.178323@1
# Gate Solar       H=720 ep=02 OOF=0.147272 val=0.176342 alpha=0.104 best=0.176342@2
# Gate Solar       H=720 ep=03 OOF=0.145737 val=0.175736 alpha=0.110 best=0.175736@3
# Gate Solar       H=720 ep=04 OOF=0.145253 val=0.175360 alpha=0.117 best=0.175360@4
# Gate Solar       H=720 ep=05 OOF=0.144878 val=0.175284 alpha=0.114 best=0.175284@5
# Gate Solar       H=720 ep=06 OOF=0.144608 val=0.175218 alpha=0.107 best=0.175218@6
# Gate Solar       H=720 ep=07 OOF=0.144460 val=0.175219 alpha=0.113 best=0.175218@6
# Gate Solar       H=720 ep=08 OOF=0.144343 val=0.174954 alpha=0.117 best=0.174954@8
# Gate Solar       H=720 ep=09 OOF=0.144235 val=0.174827 alpha=0.113 best=0.174827@9
# Gate Solar       H=720 ep=10 OOF=0.144083 val=0.174812 alpha=0.115 best=0.174812@10
# Gate Solar       H=720 ep=11 OOF=0.144049 val=0.174747 alpha=0.112 best=0.174747@11
# Gate Solar       H=720 ep=12 OOF=0.143926 val=0.174752 alpha=0.109 best=0.174747@11
# Gate Solar       H=720 ep=13 OOF=0.143927 val=0.174629 alpha=0.118 best=0.174629@13
# Gate Solar       H=720 ep=14 OOF=0.143821 val=0.174569 alpha=0.117 best=0.174569@14
# Gate Solar       H=720 ep=15 OOF=0.143805 val=0.174530 alpha=0.113 best=0.174530@15
# Gate Solar       H=720 ep=16 OOF=0.143816 val=0.174383 alpha=0.113 best=0.174383@16
# Gate Solar       H=720 ep=17 OOF=0.143731 val=0.174428 alpha=0.113 best=0.174383@16
# Gate Solar       H=720 ep=18 OOF=0.143701 val=0.174318 alpha=0.116 best=0.174318@18
# Gate Solar       H=720 ep=19 OOF=0.143662 val=0.174252 alpha=0.118 best=0.174252@19
# Gate Solar       H=720 ep=20 OOF=0.143625 val=0.174095 alpha=0.118 best=0.174095@20
# Gate Solar       H=720 ep=21 OOF=0.143575 val=0.174240 alpha=0.116 best=0.174095@20
# Gate Solar       H=720 ep=22 OOF=0.143607 val=0.174087 alpha=0.115 best=0.174087@22
# Gate Solar       H=720 ep=23 OOF=0.143517 val=0.173954 alpha=0.119 best=0.173954@23
# Gate Solar       H=720 ep=24 OOF=0.143512 val=0.173919 alpha=0.114 best=0.173919@24
# Gate Solar       H=720 ep=25 OOF=0.143451 val=0.173843 alpha=0.114 best=0.173843@25
# Gate Solar       H=720 ep=26 OOF=0.143416 val=0.173801 alpha=0.115 best=0.173801@26
# Gate Solar       H=720 ep=27 OOF=0.143390 val=0.173807 alpha=0.118 best=0.173801@26
# Gate Solar       H=720 ep=28 OOF=0.143371 val=0.173697 alpha=0.118 best=0.173697@28
# Gate Solar       H=720 ep=29 OOF=0.143336 val=0.173709 alpha=0.117 best=0.173697@28
# Gate Solar       H=720 ep=30 OOF=0.143299 val=0.173648 alpha=0.121 best=0.173648@30
# Gate Solar       H=720 ep=31 OOF=0.143286 val=0.173664 alpha=0.122 best=0.173648@30
# Gate Solar       H=720 ep=32 OOF=0.143252 val=0.173662 alpha=0.124 best=0.173648@30
# Gate Solar       H=720 ep=33 OOF=0.143213 val=0.173655 alpha=0.128 best=0.173648@30
# Gate Solar       H=720 ep=34 OOF=0.143213 val=0.173648 alpha=0.121 best=0.173648@30
# Gate Solar       H=720 ep=35 OOF=0.143194 val=0.173656 alpha=0.118 best=0.173648@30
# Gate Solar       H=720 ep=36 OOF=0.143201 val=0.173551 alpha=0.119 best=0.173551@36
# Gate Solar       H=720 ep=37 OOF=0.143139 val=0.173567 alpha=0.124 best=0.173551@36
# Gate Solar       H=720 ep=38 OOF=0.143097 val=0.173515 alpha=0.119 best=0.173515@38
# Gate Solar       H=720 ep=39 OOF=0.143153 val=0.173539 alpha=0.117 best=0.173515@38
# Gate Solar       H=720 ep=40 OOF=0.143164 val=0.173556 alpha=0.120 best=0.173515@38
# Gate Solar       H=720 ep=41 OOF=0.143132 val=0.173517 alpha=0.121 best=0.173515@38
# Gate Solar       H=720 ep=42 OOF=0.143114 val=0.173477 alpha=0.122 best=0.173477@42
# Gate Solar       H=720 ep=43 OOF=0.143079 val=0.173516 alpha=0.122 best=0.173477@42
# Gate Solar       H=720 ep=44 OOF=0.143074 val=0.173546 alpha=0.121 best=0.173477@42
# Gate Solar       H=720 ep=45 OOF=0.143017 val=0.173453 alpha=0.121 best=0.173453@45
# Gate Solar       H=720 ep=46 OOF=0.143060 val=0.173667 alpha=0.122 best=0.173453@45
# Gate Solar       H=720 ep=47 OOF=0.143040 val=0.173548 alpha=0.120 best=0.173453@45
# Gate Solar       H=720 ep=48 OOF=0.143040 val=0.173525 alpha=0.116 best=0.173453@45
# Gate Solar       H=720 ep=49 OOF=0.142991 val=0.173591 alpha=0.117 best=0.173453@45
# Gate Solar       H=720 ep=50 OOF=0.142997 val=0.173444 alpha=0.123 best=0.173444@50
# Validation | alpha0=0.1 | lambda=1.00 | scalar=0.180803 | rawGate=0.173491 | shrink=0.173491
# Loaded memory embedding: Solar_H720_test_trainval_memory_emb.npy
#   test anchors 16/9793
#   test anchors 512/9793
#   test anchors 1008/9793
#   test anchors 1504/9793
#   test anchors 2000/9793
#   test anchors 2512/9793
#   test anchors 3008/9793
#   test anchors 3504/9793
#   test anchors 4000/9793
#   test anchors 4512/9793
#   test anchors 5008/9793
#   test anchors 5504/9793
#   test anchors 6000/9793
#   test anchors 6512/9793
#   test anchors 7008/9793
#   test anchors 7504/9793
#   test anchors 8000/9793
#   test anchors 8512/9793
#   test anchors 9008/9793
#   test anchors 9504/9793
#   test anchors 9793/9793
#
# FINAL | TimeMixer H=720 | Direct=0.253337 | Ours=0.240181 | Gain=+5.193% | CI=[0.006902, 0.019541]

# %% [markdown]
# ## 21. Exact 12-condition completion audit

# %%
summary = pd.read_csv(
    SUMMARY_PATH
)

expected = pd.MultiIndex.from_product(
    [
        BACKBONES,
        HORIZONS,
    ],
    names=[
        "Backbone",
        "Horizon",
    ],
).to_frame(
    index=False
)

present = summary[
    [
        "Backbone",
        "Horizon",
    ]
].drop_duplicates()

missing = expected.merge(
    present,
    on=[
        "Backbone",
        "Horizon",
    ],
    how="left",
    indicator=True,
)

missing = missing[
    missing[
        "_merge"
    ]
    == "left_only"
]

if len(
    missing
):
    display(
        missing
    )

    raise RuntimeError(
        "Not all 12 Solar conditions are complete."
    )

if len(
    summary
) != 12:
    raise RuntimeError(
        f"Expected 12 summary rows, found {len(summary)}."
    )

print(
    "PASS: exactly 12 Solar backbone × horizon conditions."
)

display(
    summary.sort_values(
        [
            "Backbone",
            "Horizon",
        ]
    )
)
# Out:
# PASS: exactly 12 Solar backbone × horizon conditions.
#         Backbone Dataset  Horizon  DirectSeqLen  RetrievalSeqLen  Direct_MSE  ShrinkAdaptive_MSE  Direct_MAE  ShrinkAdaptive_MAE  Retrieval_MSE  Retrieval_MAE  Scalar_MSE  Scalar_MAE  RawAdaptive_MSE  RawAdaptive_MAE  Oracle_MSE  Oracle_MAE  ScalarAlpha  ShrinkLambda  RawMeanAlpha  ShrinkMeanAlpha  MSEGain_pct  MAEGain_pct  OracleHeadroomFromDirect_pct  ImprovedChannelFraction  GateBestEpoch  DirectBestEpoch  OOFPairs  TestAnchors  TestMemoryPerChannel  RuntimeMinutes
# 0       PatchTST   Solar       96           336               96    0.183429            0.180450    0.246145            0.243917       0.343494       0.343833    0.183429    0.246145         0.180450         0.243917    0.145192    0.217253          0.0          1.00      0.143601         0.143601     1.623971     0.904999                     20.845484                 0.802920             20               19    557316        10417                  1745      114.224443
# 1       PatchTST   Solar      192           336               96    0.188770            0.187718    0.240918            0.241148       0.352643       0.345604    0.188770    0.240918         0.190833         0.242949    0.158413    0.223673          0.0          0.75      0.193703         0.145277     0.557470    -0.095153                     16.081684                 0.700730              6               30    547452        10321                  1741      179.476448
# 2       PatchTST   Solar      336           336               96    0.199593            0.195821    0.253637            0.250760       0.368407       0.352304    0.199593    0.253637         0.195821         0.250760    0.171902    0.236542          0.0          1.00      0.109407         0.109407     1.889864     1.134536                     13.873974                 0.992701              2               27    532656        10177                  1735      163.485395
# 3       PatchTST   Solar      720           336               96    0.213913            0.209384    0.260529            0.258027       0.369836       0.357581    0.213913    0.260529         0.211176         0.258898    0.190309    0.248871          0.0          0.75      0.179194         0.134396     2.116875     0.960593                     11.034520                 0.978102              4               43    493200         9793                  1719      265.196713
# 4      TimeMixer   Solar       96            96               96    0.195299            0.190239    0.241748            0.242083       0.343494       0.343833    0.195299    0.241748         0.191616         0.243226    0.144408    0.213028          0.0          0.75      0.105649         0.079237     2.590790    -0.138523                     26.057682                 0.883212              1               17    557316        10417                  1745       22.499160
# 5      TimeMixer   Solar      192            96               96    0.228547            0.219061    0.269627            0.269107       0.352643       0.345604    0.222038    0.267015         0.225322         0.272228    0.171886    0.240000          0.1          0.75      0.258877         0.219158     4.150787     0.192793                     24.791746                 0.897810              2               16    547452        10321                  1741       22.615550
# 6      TimeMixer   Solar      336            96               96    0.255755            0.233141    0.288708            0.280964       0.368407       0.352304    0.247399    0.284924         0.235809         0.282090    0.198274    0.259645          0.1          0.75      0.251955         0.213967     8.842038     2.682343                     22.474893                 0.992701             12               12    532656        10177                  1735       19.418542
# 7      TimeMixer   Solar      720            96               96    0.253337            0.240181    0.286785            0.284330       0.369836       0.357581    0.245040    0.283392         0.240181         0.284330    0.207260    0.266039          0.1          1.00      0.309048         0.309048     5.192945     0.855962                     18.187904                 0.883212             50               15    493200         9793                  1719       29.525376
# 8   iTransformer   Solar       96            96               96    0.204083            0.182722    0.229920            0.228564       0.343494       0.343833    0.196612    0.229816         0.186018         0.230821    0.132804    0.195239          0.1          0.75      0.217317         0.187988    10.467056     0.589615                     34.926496                 1.000000              7                6    557316        10417                  1745        5.528188
# 9   iTransformer   Solar      192            96               96    0.244628            0.213126    0.263545            0.257533       0.352643       0.345604    0.232189    0.259139         0.220380         0.261517    0.161093    0.226424          0.1          0.75      0.355733         0.291800    12.877345     2.281445                     34.147885                 1.000000             14                6    547452        10321                  1741        5.757673
# 10  iTransformer   Solar      336            96               96    0.252072            0.216806    0.275291            0.265086       0.368407       0.352304    0.239558    0.270414         0.219351         0.266734    0.181095    0.243155          0.1          0.75      0.295691         0.246769    13.990738     3.706958                     28.157633                 1.000000             20                5    532656        10177                  1735        5.327661
# 11  iTransformer   Solar      720            96               96    0.252617            0.225179    0.275918            0.269137       0.369836       0.357581    0.241444    0.272132         0.225179         0.269137    0.197346    0.254522          0.1          1.00      0.330178         0.330178    10.861391     2.457332                     21.879330                 1.000000             25               10    493200         9793                  1719       10.762741

# %% [markdown]
# ## 22. Solar evidence summary

# %%
boot_df = pd.read_csv(
    BOOTSTRAP_PATH
)

boot_key = boot_df[
    boot_df[
        "Comparison"
    ]
    == "Direct-ShrinkAdaptive"
][
    [
        "Backbone",
        "Horizon",
        "CI_Low",
        "CI_High",
        "SignificantPositive",
        "SignificantNegative",
    ]
]

evidence = summary.merge(
    boot_key,
    on=[
        "Backbone",
        "Horizon",
    ],
    how="left",
)

evidence[
    "MSE_Win"
] = (
    evidence[
        "ShrinkAdaptive_MSE"
    ]
    < evidence[
        "Direct_MSE"
    ]
)

evidence[
    "MAE_Win"
] = (
    evidence[
        "ShrinkAdaptive_MAE"
    ]
    < evidence[
        "Direct_MAE"
    ]
)

backbone_summary = (
    evidence
    .groupby(
        "Backbone",
        as_index=False,
    )
    .agg(
        Conditions=(
            "Horizon",
            "size",
        ),
        MSE_Wins=(
            "MSE_Win",
            "sum",
        ),
        SignificantWins=(
            "SignificantPositive",
            "sum",
        ),
        SignificantLosses=(
            "SignificantNegative",
            "sum",
        ),
        MeanMSEGain_pct=(
            "MSEGain_pct",
            "mean",
        ),
        MAE_Wins=(
            "MAE_Win",
            "sum",
        ),
        MeanMAEGain_pct=(
            "MAEGain_pct",
            "mean",
        ),
        MeanOracleHeadroom_pct=(
            "OracleHeadroomFromDirect_pct",
            "mean",
        ),
        MeanShrinkAlpha=(
            "ShrinkMeanAlpha",
            "mean",
        ),
    )
)

display(
    backbone_summary
)

backbone_summary.to_csv(
    ROOT
    / "solar_backbone_summary.csv",
    index=False,
)


task_summary = (
    evidence
    .groupby(
        "Horizon",
        as_index=False,
    )
    .agg(
        BackboneWins=(
            "MSE_Win",
            "sum",
        ),
        SignificantBackboneWins=(
            "SignificantPositive",
            "sum",
        ),
        SignificantBackboneLosses=(
            "SignificantNegative",
            "sum",
        ),
        MeanMSEGain_pct=(
            "MSEGain_pct",
            "mean",
        ),
    )
)

display(
    task_summary
)

task_summary.to_csv(
    ROOT
    / "solar_horizon_three_backbone_summary.csv",
    index=False,
)
# Out:
#        Backbone  Conditions  MSE_Wins  SignificantWins  SignificantLosses  MeanMSEGain_pct  MAE_Wins  MeanMAEGain_pct  MeanOracleHeadroom_pct  MeanShrinkAlpha
# 0      PatchTST           4         4                2                  0         1.547045         3         0.726244               15.458916         0.133170
# 1     TimeMixer           4         4                4                  0         5.194140         3         0.898144               22.878056         0.205352
# 2  iTransformer           4         4                4                  0        12.049133         4         2.258837               29.777836         0.264183
#    Horizon  BackboneWins  SignificantBackboneWins  SignificantBackboneLosses  MeanMSEGain_pct
# 0       96             3                        2                          0         4.893939
# 1      192             3                        2                          0         5.861868
# 2      336             3                        3                          0         8.240880
# 3      720             3                        3                          0         6.057070

# %% [markdown]
# ## 23. Interpretation checkpoint
#
# Solar 결과를 기존 48-condition evidence에 합칠 때 다음처럼 구분합니다.
#
# ### 사용할 수 있는 주장
#
# - 같은 frozen retrieval architecture가 Solar에서도 strong backbones와 결합 가능한가
# - Solar의 effect sign이 backbone을 넘어 반복되는가
# - long-horizon에서 historical memory가 complementary한가
# - adaptive trust가 필요한가
#
# ### 독립 generalization claim에는 제한적으로 사용
#
# Solar는 method-development history가 있기 때문에
#
# \[
# \boxed{
# \text{Solar} \neq
# \text{fully independent confirmatory dataset}
# }
# \]
#
# 입니다.
#
# 따라서 향후 Exchange와 Traffic이 더 중요한 독립 validation이 됩니다.
#
# Experiment 27 이후에는:
#
# 1. 기존 48조건 + Solar 12조건 = 60-condition descriptive audit
# 2. Experiment 28 — Exchange
# 3. Experiment 29 — Traffic
# 4. 이후 네 번째 backbone
#
# 순서로 진행합니다.

# %% [markdown]
# ## 24. Saved artifacts

# %%
print(
    "Experiment root:",
    ROOT,
)

for p in sorted(
    ROOT.rglob(
        "*"
    )
):
    if p.is_file():
        print(
            " -",
            p.relative_to(
                ROOT
            )
        )
# Out:
# Experiment root: /data/dataset/strong_forecaster/solar_three_backbone_frozen_historical_memory
#  - PatchTST/calibration/Solar_H192_lambda_curve.csv
#  - PatchTST/calibration/Solar_H336_lambda_curve.csv
#  - PatchTST/calibration/Solar_H720_lambda_curve.csv
#  - PatchTST/calibration/Solar_H96_lambda_curve.csv
#  - PatchTST/channel_test/Solar_H192_channel.csv
#  - PatchTST/channel_test/Solar_H336_channel.csv
#  - PatchTST/channel_test/Solar_H720_channel.csv
#  - PatchTST/channel_test/Solar_H96_channel.csv
#  - PatchTST/fold_direct/Solar_PatchTST_H192_F1.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H192_F2.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H192_F3.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H336_F1.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H336_F2.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H336_F3.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H720_F1.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H720_F2.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H720_F3.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H96_F1.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H96_F2.pt
#  - PatchTST/fold_direct/Solar_PatchTST_H96_F3.pt
#  - PatchTST/full_direct/Solar_PatchTST_H192.pt
#  - PatchTST/full_direct/Solar_PatchTST_H336.pt
#  - PatchTST/full_direct/Solar_PatchTST_H720.pt
#  - PatchTST/full_direct/Solar_PatchTST_H96.pt
#  - PatchTST/gate/Solar_H192_gate.pt
#  - PatchTST/gate/Solar_H336_gate.pt
#  - PatchTST/gate/Solar_H720_gate.pt
#  - PatchTST/gate/Solar_H96_gate.pt
#  - PatchTST/history/Solar_H192_gate_history.csv
#  - PatchTST/history/Solar_H336_gate_history.csv
#  - PatchTST/history/Solar_H720_gate_history.csv
#  - PatchTST/history/Solar_H96_gate_history.csv
#  - PatchTST/history/Solar_PatchTST_H192_F1_direct.csv
#  - PatchTST/history/Solar_PatchTST_H192_F2_direct.csv
#  - PatchTST/history/Solar_PatchTST_H192_F3_direct.csv
#  - PatchTST/history/Solar_PatchTST_H192_full.csv
#  - PatchTST/history/Solar_PatchTST_H336_F1_direct.csv
#  - PatchTST/history/Solar_PatchTST_H336_F2_direct.csv
#  - PatchTST/history/Solar_PatchTST_H336_F3_direct.csv
#  - PatchTST/history/Solar_PatchTST_H336_full.csv
#  - PatchTST/history/Solar_PatchTST_H720_F1_direct.csv
#  - PatchTST/history/Solar_PatchTST_H720_F2_direct.csv
#  - PatchTST/history/Solar_PatchTST_H720_F3_direct.csv
#  - PatchTST/history/Solar_PatchTST_H720_full.csv
#  - PatchTST/history/Solar_PatchTST_H96_F1_direct.csv
#  - PatchTST/history/Solar_PatchTST_H96_F2_direct.csv
#  - PatchTST/history/Solar_PatchTST_H96_F3_direct.csv
#  - PatchTST/history/Solar_PatchTST_H96_full.csv
#  - PatchTST/oof/Solar_H192_F1_oof.npz
#  - PatchTST/oof/Solar_H192_F2_oof.npz
#  - PatchTST/oof/Solar_H192_F3_oof.npz
#  - PatchTST/oof/Solar_H336_F1_oof.npz
#  - PatchTST/oof/Solar_H336_F2_oof.npz
#  - PatchTST/oof/Solar_H336_F3_oof.npz
#  - PatchTST/oof/Solar_H720_F1_oof.npz
#  - PatchTST/oof/Solar_H720_F2_oof.npz
#  - PatchTST/oof/Solar_H720_F3_oof.npz
#  - PatchTST/oof/Solar_H96_F1_oof.npz
#  - PatchTST/oof/Solar_H96_F2_oof.npz
#  - PatchTST/oof/Solar_H96_F3_oof.npz
#  - PatchTST/paired_test/Solar_H192_anchor_mse.npz
#  - PatchTST/paired_test/Solar_H336_anchor_mse.npz
#  - PatchTST/paired_test/Solar_H720_anchor_mse.npz
#  - PatchTST/paired_test/Solar_H96_anchor_mse.npz
#  - PatchTST/validation/Solar_H192_validation.npz
#  - PatchTST/validation/Solar_H336_validation.npz
#  - PatchTST/validation/Solar_H720_validation.npz
#  - PatchTST/validation/Solar_H96_validation.npz
#  - TimeMixer/calibration/Solar_H192_lambda_curve.csv
#  - TimeMixer/calibration/Solar_H336_lambda_curve.csv
#  - TimeMixer/calibration/Solar_H720_lambda_curve.csv
#  - TimeMixer/calibration/Solar_H96_lambda_curve.csv
#  - TimeMixer/channel_test/Solar_H192_channel.csv
#  - TimeMixer/channel_test/Solar_H336_channel.csv
#  - TimeMixer/channel_test/Solar_H720_channel.csv
#  - TimeMixer/channel_test/Solar_H96_channel.csv
#  - TimeMixer/fold_direct/Solar_TimeMixer_H192_F1.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H192_F2.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H192_F3.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H336_F1.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H336_F2.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H336_F3.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H720_F1.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H720_F2.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H720_F3.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H96_F1.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H96_F2.pt
#  - TimeMixer/fold_direct/Solar_TimeMixer_H96_F3.pt
#  - TimeMixer/full_direct/Solar_TimeMixer_H192.pt
#  - TimeMixer/full_direct/Solar_TimeMixer_H336.pt
#  - TimeMixer/full_direct/Solar_TimeMixer_H720.pt
#  - TimeMixer/full_direct/Solar_TimeMixer_H96.pt
#  - TimeMixer/gate/Solar_H192_gate.pt
#  - TimeMixer/gate/Solar_H336_gate.pt
#  - TimeMixer/gate/Solar_H720_gate.pt
#  - TimeMixer/gate/Solar_H96_gate.pt
#  - TimeMixer/history/Solar_H192_gate_history.csv
#  - TimeMixer/history/Solar_H336_gate_history.csv
#  - TimeMixer/history/Solar_H720_gate_history.csv
#  - TimeMixer/history/Solar_H96_gate_history.csv
#  - TimeMixer/history/Solar_TimeMixer_H192_F1_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H192_F2_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H192_F3_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H192_full.csv
#  - TimeMixer/history/Solar_TimeMixer_H336_F1_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H336_F2_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H336_F3_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H336_full.csv
#  - TimeMixer/history/Solar_TimeMixer_H720_F1_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H720_F2_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H720_F3_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H720_full.csv
#  - TimeMixer/history/Solar_TimeMixer_H96_F1_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H96_F2_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H96_F3_direct.csv
#  - TimeMixer/history/Solar_TimeMixer_H96_full.csv
#  - TimeMixer/oof/Solar_H192_F1_oof.npz
#  - TimeMixer/oof/Solar_H192_F2_oof.npz
#  - TimeMixer/oof/Solar_H192_F3_oof.npz
#  - TimeMixer/oof/Solar_H336_F1_oof.npz
#  - TimeMixer/oof/Solar_H336_F2_oof.npz
#  - TimeMixer/oof/Solar_H336_F3_oof.npz
#  - TimeMixer/oof/Solar_H720_F1_oof.npz
#  - TimeMixer/oof/Solar_H720_F2_oof.npz
#  - TimeMixer/oof/Solar_H720_F3_oof.npz
#  - TimeMixer/oof/Solar_H96_F1_oof.npz
#  - TimeMixer/oof/Solar_H96_F2_oof.npz
#  - TimeMixer/oof/Solar_H96_F3_oof.npz
#  - TimeMixer/paired_test/Solar_H192_anchor_mse.npz
#  - TimeMixer/paired_test/Solar_H336_anchor_mse.npz
#  - TimeMixer/paired_test/Solar_H720_anchor_mse.npz
#  - TimeMixer/paired_test/Solar_H96_anchor_mse.npz
#  - TimeMixer/validation/Solar_H192_validation.npz
#  - TimeMixer/validation/Solar_H336_validation.npz
#  - TimeMixer/validation/Solar_H720_validation.npz
#  - TimeMixer/validation/Solar_H96_validation.npz
#  - artifacts/backbone_repository_commits.csv
#  - bootstrap.csv
#  - direct_baselines.csv
#  - iTransformer/calibration/Solar_H192_lambda_curve.csv
#  - iTransformer/calibration/Solar_H336_lambda_curve.csv
#  - iTransformer/calibration/Solar_H720_lambda_curve.csv
#  - iTransformer/calibration/Solar_H96_lambda_curve.csv
#  - iTransformer/channel_test/Solar_H192_channel.csv
#  - iTransformer/channel_test/Solar_H336_channel.csv
#  - iTransformer/channel_test/Solar_H720_channel.csv
#  - iTransformer/channel_test/Solar_H96_channel.csv
#  - iTransformer/fold_direct/Solar_iTransformer_H192_F1.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H192_F2.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H192_F3.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H336_F1.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H336_F2.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H336_F3.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H720_F1.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H720_F2.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H720_F3.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H96_F1.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H96_F2.pt
#  - iTransformer/fold_direct/Solar_iTransformer_H96_F3.pt
#  - iTransformer/full_direct/Solar_iTransformer_H192.pt
#  - iTransformer/full_direct/Solar_iTransformer_H336.pt
#  - iTransformer/full_direct/Solar_iTransformer_H720.pt
#  - iTransformer/full_direct/Solar_iTransformer_H96.pt
#  - iTransformer/gate/Solar_H192_gate.pt
#  - iTransformer/gate/Solar_H336_gate.pt
#  - iTransformer/gate/Solar_H720_gate.pt
#  - iTransformer/gate/Solar_H96_gate.pt
#  - iTransformer/history/Solar_H192_gate_history.csv
#  - iTransformer/history/Solar_H336_gate_history.csv
#  - iTransformer/history/Solar_H720_gate_history.csv
#  - iTransformer/history/Solar_H96_gate_history.csv
#  - iTransformer/history/Solar_iTransformer_H192_F1_direct.csv
#  - iTransformer/history/Solar_iTransformer_H192_F2_direct.csv
#  - iTransformer/history/Solar_iTransformer_H192_F3_direct.csv
#  - iTransformer/history/Solar_iTransformer_H192_full.csv
#  - iTransformer/history/Solar_iTransformer_H336_F1_direct.csv
#  - iTransformer/history/Solar_iTransformer_H336_F2_direct.csv
#  - iTransformer/history/Solar_iTransformer_H336_F3_direct.csv
#  - iTransformer/history/Solar_iTransformer_H336_full.csv
#  - iTransformer/history/Solar_iTransformer_H720_F1_direct.csv
#  - iTransformer/history/Solar_iTransformer_H720_F2_direct.csv
#  - iTransformer/history/Solar_iTransformer_H720_F3_direct.csv
#  - iTransformer/history/Solar_iTransformer_H720_full.csv
#  - iTransformer/history/Solar_iTransformer_H96_F1_direct.csv
#  - iTransformer/history/Solar_iTransformer_H96_F2_direct.csv
#  - iTransformer/history/Solar_iTransformer_H96_F3_direct.csv
#  - iTransformer/history/Solar_iTransformer_H96_full.csv
#  - iTransformer/oof/Solar_H192_F1_oof.npz
#  - iTransformer/oof/Solar_H192_F2_oof.npz
#  - iTransformer/oof/Solar_H192_F3_oof.npz
#  - iTransformer/oof/Solar_H336_F1_oof.npz
#  - iTransformer/oof/Solar_H336_F2_oof.npz
#  - iTransformer/oof/Solar_H336_F3_oof.npz
#  - iTransformer/oof/Solar_H720_F1_oof.npz
#  - iTransformer/oof/Solar_H720_F2_oof.npz
#  - iTransformer/oof/Solar_H720_F3_oof.npz
#  - iTransformer/oof/Solar_H96_F1_oof.npz
#  - iTransformer/oof/Solar_H96_F2_oof.npz
#  - iTransformer/oof/Solar_H96_F3_oof.npz
#  - iTransformer/paired_test/Solar_H192_anchor_mse.npz
#  - iTransformer/paired_test/Solar_H336_anchor_mse.npz
#  - iTransformer/paired_test/Solar_H720_anchor_mse.npz
#  - iTransformer/paired_test/Solar_H96_anchor_mse.npz
#  - iTransformer/validation/Solar_H192_validation.npz
#  - iTransformer/validation/Solar_H336_validation.npz
#  - iTransformer/validation/Solar_H720_validation.npz
#  - iTransformer/validation/Solar_H96_validation.npz
#  - shared_memory_embeddings/Solar_H192_F1_prefix20235_emb.npy
#  - shared_memory_embeddings/Solar_H192_F2_prefix25754_emb.npy
#  - shared_memory_embeddings/Solar_H192_F3_prefix31273_emb.npy
#  - shared_memory_embeddings/Solar_H192_test_trainval_memory_emb.npy
#  - shared_memory_embeddings/Solar_H192_validation_train_memory_emb.npy
#  - shared_memory_embeddings/Solar_H336_F1_prefix20235_emb.npy
#  - shared_memory_embeddings/Solar_H336_F2_prefix25754_emb.npy
#  - shared_memory_embeddings/Solar_H336_F3_prefix31273_emb.npy
#  - shared_memory_embeddings/Solar_H336_test_trainval_memory_emb.npy
#  - shared_memory_embeddings/Solar_H336_validation_train_memory_emb.npy
#  - shared_memory_embeddings/Solar_H720_F1_prefix20235_emb.npy
#  - shared_memory_embeddings/Solar_H720_F2_prefix25754_emb.npy
#  - shared_memory_embeddings/Solar_H720_F3_prefix31273_emb.npy
#  - shared_memory_embeddings/Solar_H720_test_trainval_memory_emb.npy
#  - shared_memory_embeddings/Solar_H720_validation_train_memory_emb.npy
#  - shared_memory_embeddings/Solar_H96_F1_prefix20235_emb.npy
#  - shared_memory_embeddings/Solar_H96_F2_prefix25754_emb.npy
#  - shared_memory_embeddings/Solar_H96_F3_prefix31273_emb.npy
#  - shared_memory_embeddings/Solar_H96_test_trainval_memory_emb.npy
#  - shared_memory_embeddings/Solar_H96_validation_train_memory_emb.npy
#  - solar_backbone_summary.csv
#  - solar_horizon_three_backbone_summary.csv
#  - summary.csv
