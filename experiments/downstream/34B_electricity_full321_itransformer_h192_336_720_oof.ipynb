# %% [markdown]
# # Experiment 34B — Electricity Full-321 iTransformer OOF Extension
#
# ## 대상 조건
#
# 34A에서 \(H=96\) OOF pilot이 성공했으므로, 동일한 protocol을 iTransformer의 나머지
# 세 horizon에 그대로 적용합니다.
#
# \[
# \boxed{
# \text{Electricity full 321 channels}
# +
# \text{iTransformer}
# +
# H\in\{192,336,720\}
# }
# \]
#
# 34A의 \(H=96\) 설정을 **변경하지 않고** horizon만 확장합니다.
#
# ---
#
# ## OOF protocol
#
# 각 horizon마다 3개의 chronological fold를 사용합니다.
#
# \[
# (0.55,0.70),\qquad
# (0.70,0.85),\qquad
# (0.85,1.00).
# \]
#
# 각 fold에서:
#
# 1. fold prefix까지만 이용해 normalization;
# 2. full-321 iTransformer fold direct model 학습;
# 3. prefix까지만 이용해 channel-exposed retriever 학습;
# 4. 뒤쪽 OOF interval에서 321채널 전체의 direct/retrieval feature 수집.
#
# 3-fold OOF feature를 합쳐 adaptive trust gate를 학습하고,
# standard validation split은 gate best epoch와 scalar/shrinkage calibration에만 사용합니다.
#
# 최종 test는 기존 Experiment 32의 full-321 direct checkpoint와
# Experiment 33C의 horizon별 full-train channel-exposed retriever를 재사용합니다.
#
# Test label은 학습·모델선택·calibration에 사용하지 않습니다.
#
# ---
#
# ## Resume
#
# 실험은 horizon별, fold별 checkpoint/cache를 저장합니다.
# 중간에 중단되어도 `RESUME=True`, `FORCE=False`이면 완료된 단계는 재사용합니다.
#
# 34A의 \(H=96\) 결과는 다시 실행하지 않습니다.

# %%
from pathlib import Path
from types import SimpleNamespace
from contextlib import nullcontext

import gc
import importlib
import math
import os
import random
import subprocess
import sys
import time
import warnings

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

warnings.filterwarnings(
    "ignore"
)

pd.set_option(
    "display.max_columns",
    260,
)

pd.set_option(
    "display.width",
    560,
)

DEVICE = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

DATASET = "Electricity"

BACKBONES = [
    "PatchTST",
    "iTransformer",
    "TimeMixer",
]

HORIZONS = [
    96,
    192,
    336,
    720,
]

RET_SEQ_LEN = 96

TOP_K = 10
MEMORY_STRIDE = 24
OOF_ANCHOR_STRIDE = 4

FOLDS = [
    (
        0.55,
        0.70,
    ),
    (
        0.70,
        0.85,
    ),
    (
        0.85,
        1.00,
    ),
]

# Frozen predictive representation.
REP_PATCH_LEN = 16
REP_PATCH_STRIDE = 16
REP_D_MODEL = 64
REP_N_HEADS = 4
REP_LAYERS = 2
REP_D_FF = 128
REP_DROPOUT = 0.1
REP_DIM = 64

REP_NUM_PATCHES = (
    1
    + (
        RET_SEQ_LEN
        - REP_PATCH_LEN
    )
    // REP_PATCH_STRIDE
)

# Prospectively frozen Electricity retriever training.
# These values are declared before any Electricity test metric is evaluated.
RETRIEVER_CANDIDATE_M = 100
RETRIEVER_TAU = 0.5
RETRIEVER_LR = 1e-3
RETRIEVER_WD = 1e-4
RETRIEVER_BATCH_QUERIES = 32
RETRIEVER_MAX_EPOCHS = 30
RETRIEVER_PATIENCE = 6
RETRIEVER_GRAD_CLIP = 5.0
RETRIEVER_QUERY_STRIDE = 4
RETRIEVER_MEMORY_FRACTION = 0.60
RETRIEVER_PHASEA_TRAIN_FRACTION = 0.80
RETRIEVER_SEED = 0

# Frozen gate.
GATE_DIM = 26
GATE_LR = 1e-3
GATE_WD = 1e-4
GATE_BATCH = 8192
GATE_MAX_EPOCHS = 50
GATE_PATIENCE = 7

ALPHA_GRID = np.round(
    np.arange(
        0.0,
        1.0001,
        0.1,
    ),
    10,
)

LAMBDA_GRID = np.array(
    [
        0.0,
        0.25,
        0.50,
        0.75,
        1.00,
    ],
    dtype=np.float32,
)

TARGET_RETRIEVAL_PAIRS = 672

EPS = 1e-8

RETRIEVER_USE_AMP = (
    torch.cuda.is_available()
)

CROSSFIT_SEED = 3232  # unused for training; retained for deterministic utilities

RESUME = True
FORCE = False

BOOTSTRAP_REPLICATES = 5000
BOOTSTRAP_BLOCK_LEN = 24
BOOTSTRAP_SEED = 323200

ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_full321_frozen_transfer_standard"
)

ROOT.mkdir(
    parents=True,
    exist_ok=True,
)

SHARED_MEMORY_EMB_DIR = (
    ROOT
    / "shared_memory_embeddings"
)

SHARED_MEMORY_EMB_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

ARTIFACT_DIR = (
    ROOT
    / "artifacts"
)

ARTIFACT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

SUMMARY_PATH = (
    ROOT
    / "summary.csv"
)

BOOTSTRAP_PATH = (
    ROOT
    / "bootstrap.csv"
)

CURRENT_BACKBONE = None
DIRS = None

# Conservative direct inference blocks.
DIRECT_ANCHOR_BLOCK = {
    "PatchTST":
        2,
    "iTransformer":
        2,
    "TimeMixer":
        8,
}

SOURCE32_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_three_backbone_frozen_historical_memory"
)

SOURCE32_SUMMARY_PATH = SOURCE32_ROOT / "summary.csv"

FULL_CHANNEL_TRANSFER = True
EXPECTED_FULL_CHANNELS = 321

print(
    "Device:",
    DEVICE,
)

print(
    "Output:",
    ROOT,
)
# Out:
# Device: cuda
# Output: /data/dataset/strong_forecaster/electricity_full321_frozen_transfer_standard

# %%
ELECTRICITY_CANDIDATES = [
    Path("/data/Time-Series-Library/dataset/electricity/electricity.csv"),
    Path("/data/Time-Series-Library_v2/dataset/electricity/electricity.csv"),
    Path("/code/Time-Series-Library/dataset/electricity/electricity.csv"),
    Path("/data/dataset/electricity/electricity.csv"),
    Path("/data/dataset/electricity.csv"),
]

ELECTRICITY_PATH = next((p for p in ELECTRICITY_CANDIDATES if p.is_file()), None)
if ELECTRICITY_PATH is None:
    print("Attempted paths:")
    for p in ELECTRICITY_CANDIDATES:
        print(" -", p)
    raise FileNotFoundError("Could not find Electricity electricity.csv.")


def load_electricity_csv(path):
    df = pd.read_csv(path)

    candidate = df.copy()
    for col in list(candidate.columns):
        if str(col).lower() in {"date", "datetime", "timestamp", "time"}:
            candidate = candidate.drop(columns=[col])

    numeric = candidate.apply(pd.to_numeric, errors="coerce")
    numeric = numeric.dropna(axis=1, how="all")

    numeric = (
        numeric.replace([np.inf, -np.inf], np.nan)
        .interpolate(axis=0, limit_direction="both")
        .ffill()
        .bfill()
    )

    return numeric


raw_all_df = load_electricity_csv(ELECTRICITY_PATH)
raw = raw_all_df.to_numpy(dtype=np.float32)

n_time, n_channels = raw.shape

if n_time != 26304:
    print(
        "WARNING: standard Electricity benchmark has 26,304 rows; "
        f"loaded {n_time}."
    )

if n_channels != EXPECTED_FULL_CHANNELS:
    raise ValueError(
        "Experiment 32 is the full-channel benchmark and expects "
        f"{EXPECTED_FULL_CHANNELS} numeric channels, but loaded {n_channels}."
    )

train_end = int(0.70 * n_time)
num_test = int(0.20 * n_time)
val_end = n_time - num_test
test_end = n_time

# Standard full-channel protocol: retain all 321 benchmark channels.
train_mean = raw[:train_end].mean(axis=0).astype(np.float32)
train_std = raw[:train_end].std(axis=0, ddof=0).astype(np.float32)

if np.any(train_std <= 1e-6):
    bad = np.where(train_std <= 1e-6)[0]
    raise ValueError(
        "Standard full-channel Electricity contains train-degenerate channels "
        f"at indices {bad[:20].tolist()}. "
        "Do not silently drop them in a standard benchmark run."
    )

z_full = ((raw - train_mean[None, :]) / train_std[None, :]).astype(np.float32)

marks = np.zeros((n_time, 0), dtype=np.float32)

DATA = {
    "Electricity": {
        "name": "Electricity",
        "path": ELECTRICITY_PATH,
        "raw": raw,
        "z": z_full,
        "marks": marks,
        "n_channels": n_channels,
        "raw_channel_indices": np.arange(n_channels, dtype=np.int64),
        "train_end": train_end,
        "val_end": val_end,
        "test_end": test_end,
    }
}

display(pd.DataFrame([
    {"Split": "Train", "Start": 0, "EndExclusive": train_end, "Length": train_end},
    {"Split": "Validation", "Start": train_end, "EndExclusive": val_end, "Length": val_end-train_end},
    {"Split": "Test", "Start": val_end, "EndExclusive": test_end, "Length": test_end-val_end},
]))

print("Electricity path:", ELECTRICITY_PATH)
print("Full benchmark shape:", raw.shape)
print("Channels:", n_channels)
print("Channel multiplier vs previous 32-channel study:", f"{n_channels / 32:.2f}x")
# Out:
#         Split  Start  EndExclusive  Length
# 0       Train      0         18412   18412
# 1  Validation  18412         21044    2632
# 2        Test  21044         26304    5260
# Electricity path: /data/Time-Series-Library/dataset/electricity/electricity.csv
# Full benchmark shape: (26304, 321)
# Channels: 321
# Channel multiplier vs previous 32-channel study: 10.03x

# %%
def prefix_normalize(
    raw_array,
    prefix,
):
    prefix = int(
        prefix
    )

    mean = raw_array[
        :prefix
    ].mean(
        axis=0,
    ).astype(
        np.float32
    )

    std = raw_array[
        :prefix
    ].std(
        axis=0,
        ddof=0,
    ).astype(
        np.float32
    )

    if np.any(
        std
        <= 1e-6
    ):
        raise ValueError(
            f"Degenerate prefix channel at prefix={prefix}."
        )

    z = (
        (
            raw_array
            - mean[
                None,
                :
            ]
        )
        / std[
            None,
            :
        ]
    ).astype(
        np.float32
    )

    return (
        z,
        {
            "Mean":
                mean,
            "Std":
                std,
            "Prefix":
                prefix,
        },
    )


def eval_anchors(
    start,
    end,
    horizon,
    stride=1,
    lookback=RET_SEQ_LEN,
):
    return np.arange(
        max(
            int(
                start
            ),
            int(
                lookback
            ),
        ),
        int(
            end
        )
        - int(
            horizon
        )
        + 1,
        int(
            stride
        ),
        dtype=np.int64,
    )

# %%
BASE = Path(
    "/code/stock_regime_retrieval/"
    "strong_forecaster"
)

REPO_CANDIDATES = {
    "PatchTST": [
        BASE
        / "PatchTST_official",
        Path(
            "/code/PatchTST_official"
        ),
        Path(
            "/data/PatchTST_official"
        ),
    ],

    "iTransformer": [
        BASE
        / "iTransformer_official",
        Path(
            "/code/iTransformer"
        ),
        Path(
            "/data/iTransformer"
        ),
    ],

    "TimeMixer": [
        BASE
        / "TimeMixer_official",
        Path(
            "/code/TimeMixer"
        ),
        Path(
            "/data/TimeMixer"
        ),
    ],
}

REPO_URLS = {
    "PatchTST":
        "https://github.com/yuqinie98/PatchTST.git",
    "iTransformer":
        "https://github.com/thuml/iTransformer.git",
    "TimeMixer":
        "https://github.com/kwuking/TimeMixer.git",
}

EXPECTED_FILES = {
    "PatchTST":
        Path(
            "PatchTST_supervised/"
            "models/PatchTST.py"
        ),
    "iTransformer":
        Path(
            "model/"
            "iTransformer.py"
        ),
    "TimeMixer":
        Path(
            "models/"
            "TimeMixer.py"
        ),
}

REPOS = {}

for backbone in BACKBONES:
    repo = next(
        (
            p
            for p in REPO_CANDIDATES[
                backbone
            ]
            if (
                p
                / EXPECTED_FILES[
                    backbone
                ]
            ).is_file()
        ),
        None,
    )

    if repo is None:
        repo = REPO_CANDIDATES[
            backbone
        ][
            0
        ]

        repo.parent.mkdir(
            parents=True,
            exist_ok=True,
        )

        print(
            f"Cloning {backbone} -> {repo}"
        )

        subprocess.run(
            [
                "git",
                "clone",
                "--depth",
                "1",
                REPO_URLS[
                    backbone
                ],
                str(
                    repo
                ),
            ],
            check=True,
        )

    REPOS[
        backbone
    ] = repo

repo_rows = []

for backbone, repo in REPOS.items():
    try:
        commit = subprocess.check_output(
            [
                "git",
                "-C",
                str(
                    repo
                ),
                "rev-parse",
                "HEAD",
            ],
            text=True,
        ).strip()
    except Exception:
        commit = "unknown"

    repo_rows.append({
        "Backbone":
            backbone,
        "Repository":
            str(
                repo
            ),
        "Commit":
            commit,
    })

display(
    pd.DataFrame(
        repo_rows
    )
)

pd.DataFrame(
    repo_rows
).to_csv(
    ARTIFACT_DIR
    / "backbone_repository_commits.csv",
    index=False,
)
# Out:
#        Backbone                                         Repository                                    Commit
# 0      PatchTST  /code/stock_regime_retrieval/strong_forecaster...  204c21efe0b39603ad6e2ca640ef5896646ab1a9
# 1  iTransformer  /code/stock_regime_retrieval/strong_forecaster...  c2426e68ca13f74aaec08045c5c724d8ad328124
# 2     TimeMixer  /code/stock_regime_retrieval/strong_forecaster...  e24610583b36fdd8c76cc17a8df4e65759a5f460

# %%
DIRECT_RECIPES = {
    "PatchTST": {
        "seq_len":
            336,
        "label_len":
            48,
        "batch_size":
            4,
        "effective_batch_size":
            32,
        "eval_batch":
            2,
        "train_epochs":
            100,
        "patience":
            10,
        "learning_rate":
            1e-4,
        "weight_decay":
            0.0,
        "scheduler":
            "TST",
        "pct_start":
            0.2,
        "seed":
            2021,

        "e_layers":
            3,
        "n_heads":
            16,
        "d_model":
            128,
        "d_ff":
            256,
        "dropout":
            0.2,
        "fc_dropout":
            0.2,
        "head_dropout":
            0.0,
        "patch_len":
            16,
        "stride":
            8,
    },

    "iTransformer": {
        "seq_len":
            96,
        "label_len":
            48,
        "batch_size":
            2,
        "effective_batch_size":
            16,
        "eval_batch":
            2,
        "train_epochs":
            10,
        "patience":
            3,
        "learning_rate":
            5e-4,
        "weight_decay":
            0.0,
        "scheduler":
            "type1",
        "seed":
            2023,

        "e_layers":
            3,
        "n_heads":
            8,
        "d_model":
            512,
        "d_ff":
            512,
        "dropout":
            0.1,
        "factor":
            1,
    },

    "TimeMixer": {
        "seq_len":
            96,
        "label_len":
            0,
        "batch_size":
            16,
        "effective_batch_size":
            128,
        "eval_batch":
            8,
        "train_epochs":
            20,
        "patience":
            10,
        "learning_rate":
            0.01,
        "weight_decay":
            0.0,
        "scheduler":
            "OneCycle",
        "pct_start":
            0.2,
        "seed":
            2021,

        "e_layers":
            3,
        "n_heads":
            8,
        "d_model":
            16,
        "d_ff":
            32,
        "dropout":
            0.1,
        "factor":
            3,

        "down_sampling_layers":
            3,
        "down_sampling_window":
            2,
        "down_sampling_method":
            "avg",
    },
}

display(
    pd.DataFrame(
        DIRECT_RECIPES
    ).T
)
# Out:
#              seq_len label_len batch_size effective_batch_size eval_batch train_epochs patience learning_rate weight_decay scheduler pct_start  seed e_layers n_heads d_model d_ff dropout fc_dropout head_dropout patch_len stride factor down_sampling_layers down_sampling_window down_sampling_method
# PatchTST         336        48          4                   32          2          100       10        0.0001          0.0       TST       0.2  2021        3      16     128  256     0.2        0.2          0.0        16      8    NaN                  NaN                  NaN                  NaN
# iTransformer      96        48          2                   16          2           10        3        0.0005          0.0     type1       NaN  2023        3       8     512  512     0.1        NaN          NaN       NaN    NaN      1                  NaN                  NaN                  NaN
# TimeMixer         96         0         16                  128          8           20       10          0.01          0.0  OneCycle       0.2  2021        3       8      16   32     0.1        NaN          NaN       NaN    NaN      3                    3                    2                  avg

# %%
ACTIVE_MODEL_CLASS = None
ACTIVE_REPO = None


def clear_forecasting_modules():
    prefixes = [
        "models",
        "model",
        "layers",
        "utils",
        "data_provider",
        "exp",
        "experiments",
    ]

    for module_name in list(
        sys.modules.keys()
    ):
        if any(
            module_name
            == p
            or module_name.startswith(
                p
                + "."
            )
            for p in prefixes
        ):
            del sys.modules[
                module_name
            ]


def activate_backbone(
    backbone,
):
    global ACTIVE_MODEL_CLASS
    global ACTIVE_REPO

    clear_forecasting_modules()

    # Remove all known forecasting repositories from sys.path.
    repo_paths = []

    for b, r in REPOS.items():
        if b == "PatchTST":
            repo_paths.append(
                str(
                    r
                    / "PatchTST_supervised"
                )
            )
        else:
            repo_paths.append(
                str(
                    r
                )
            )

    sys.path[:] = [
        p
        for p in sys.path
        if p not in repo_paths
    ]

    if backbone == "PatchTST":
        root = (
            REPOS[
                backbone
            ]
            / "PatchTST_supervised"
        )

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "models.PatchTST"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    elif backbone == "iTransformer":
        root = REPOS[
            backbone
        ]

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "model.iTransformer"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    elif backbone == "TimeMixer":
        root = REPOS[
            backbone
        ]

        sys.path.insert(
            0,
            str(
                root
            ),
        )

        module = importlib.import_module(
            "models.TimeMixer"
        )

        ACTIVE_MODEL_CLASS = (
            module.Model
        )

        ACTIVE_REPO = root

    else:
        raise ValueError(
            backbone
        )

    print(
        f"Activated {backbone}: "
        f"{Path(module.__file__).resolve()}"
    )

    return ACTIVE_MODEL_CLASS

# %%
def set_seed(
    seed,
):
    random.seed(
        int(
            seed
        )
    )

    np.random.seed(
        int(
            seed
        )
    )

    torch.manual_seed(
        int(
            seed
        )
    )

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(
            int(
                seed
            )
        )

    torch.backends.cudnn.benchmark = False


def load_torch(
    path,
):
    try:
        return torch.load(
            path,
            map_location=DEVICE,
            weights_only=False,
        )
    except TypeError:
        return torch.load(
            path,
            map_location=DEVICE,
        )


def direct_config(
    backbone,
    horizon,
):
    r = DIRECT_RECIPES[
        backbone
    ]

    if backbone == "PatchTST":
        return SimpleNamespace(
            enc_in=
                n_channels,
            seq_len=
                r[
                    "seq_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            e_layers=
                r[
                    "e_layers"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            d_model=
                r[
                    "d_model"
                ],
            d_ff=
                r[
                    "d_ff"
                ],
            dropout=
                r[
                    "dropout"
                ],
            fc_dropout=
                r[
                    "fc_dropout"
                ],
            head_dropout=
                r[
                    "head_dropout"
                ],
            individual=
                0,
            patch_len=
                r[
                    "patch_len"
                ],
            stride=
                r[
                    "stride"
                ],
            padding_patch=
                "end",
            revin=
                1,
            affine=
                0,
            subtract_last=
                0,
            decomposition=
                0,
            kernel_size=
                25,
        )

    if backbone == "iTransformer":
        return SimpleNamespace(
            task_name=
                "long_term_forecast",
            seq_len=
                r[
                    "seq_len"
                ],
            label_len=
                r[
                    "label_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            enc_in=
                n_channels,
            dec_in=
                n_channels,
            c_out=
                n_channels,
            d_model=
                r[
                    "d_model"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            e_layers=
                r[
                    "e_layers"
                ],
            d_layers=
                1,
            d_ff=
                r[
                    "d_ff"
                ],
            moving_avg=
                25,
            factor=
                r[
                    "factor"
                ],
            distil=
                True,
            dropout=
                r[
                    "dropout"
                ],
            embed=
                "timeF",
            freq=
                "d",
            activation=
                "gelu",
            output_attention=
                False,
            use_norm=
                1,
            class_strategy=
                "projection",
        )

    if backbone == "TimeMixer":
        return SimpleNamespace(
            task_name=
                "long_term_forecast",
            seq_len=
                r[
                    "seq_len"
                ],
            label_len=
                r[
                    "label_len"
                ],
            pred_len=
                int(
                    horizon
                ),
            top_k=
                5,
            num_kernels=
                6,
            enc_in=
                n_channels,
            dec_in=
                n_channels,
            c_out=
                n_channels,
            d_model=
                r[
                    "d_model"
                ],
            n_heads=
                r[
                    "n_heads"
                ],
            e_layers=
                r[
                    "e_layers"
                ],
            d_layers=
                1,
            d_ff=
                r[
                    "d_ff"
                ],
            moving_avg=
                25,
            factor=
                r[
                    "factor"
                ],
            distil=
                True,
            dropout=
                r[
                    "dropout"
                ],
            embed=
                "timeF",
            freq=
                "d",
            activation=
                "gelu",
            output_attention=
                False,
            channel_independence=
                1,
            decomp_method=
                "moving_avg",
            use_norm=
                1,
            down_sampling_layers=
                r[
                    "down_sampling_layers"
                ],
            down_sampling_window=
                r[
                    "down_sampling_window"
                ],
            down_sampling_method=
                r[
                    "down_sampling_method"
                ],
            use_future_temporal_feature=
                0,
            features=
                "M",
        )

    raise ValueError(
        backbone
    )


def build_direct_model(
    backbone,
    horizon,
):
    if ACTIVE_MODEL_CLASS is None:
        raise RuntimeError(
            "Call activate_backbone() first."
        )

    cfg = direct_config(
        backbone,
        horizon,
    )

    model = ACTIVE_MODEL_CLASS(
        cfg
    ).float().to(
        DEVICE
    )

    return (
        model,
        cfg,
    )


def direct_seq_len(
    backbone,
):
    return int(
        DIRECT_RECIPES[
            backbone
        ][
            "seq_len"
        ]
    )


def make_direct_batch(
    z,
    anchors,
    backbone,
    horizon,
):
    anchors = np.asarray(
        anchors,
        dtype=np.int64,
    )

    L = direct_seq_len(
        backbone
    )

    x_idx = (
        anchors[
            :,
            None
        ]
        - L
        + np.arange(
            L
        )[
            None,
            :
        ]
    )

    y_idx = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    x = z[
        x_idx,
        :
    ].astype(
        np.float32
    )

    y = z[
        y_idx,
        :
    ].astype(
        np.float32
    )

    return (
        x,
        y,
    )


def forward_direct(
    backbone,
    model,
    x,
    y,
    horizon,
):
    x_t = torch.from_numpy(
        x
    ).to(
        DEVICE
    )

    y_t = torch.from_numpy(
        y
    ).to(
        DEVICE
    )

    if backbone == "PatchTST":
        pred = model(
            x_t
        )[
            :,
            -horizon:,
            :
        ]

    elif backbone == "iTransformer":
        label_len = DIRECT_RECIPES[
            backbone
        ][
            "label_len"
        ]

        dec_inp = torch.cat(
            [
                x_t[
                    :,
                    -label_len:,
                    :
                ],
                torch.zeros_like(
                    y_t
                ),
            ],
            dim=1,
        )

        pred = model(
            x_t,
            None,
            dec_inp,
            None,
        )[
            :,
            -horizon:,
            :
        ]

    elif backbone == "TimeMixer":
        pred = model(
            x_t,
            None,
            None,
            None,
        )[
            :,
            -horizon:,
            :
        ]

    else:
        raise ValueError(
            backbone
        )

    return (
        pred.float(),
        y_t.float(),
        x_t,
    )


@torch.no_grad()
def direct_residual_block(
    model,
    z,
    marks_unused,
    anchors,
    horizon,
):
    backbone = CURRENT_BACKBONE

    x, y = make_direct_batch(
        z,
        anchors,
        backbone,
        horizon,
    )

    pred, true, x_t = forward_direct(
        backbone,
        model,
        x,
        y,
        horizon,
    )

    current = x_t[
        :,
        -1:,
        :
    ].float()

    return (
        pred
        - current,
        true
        - current,
    )

# %%
def backbone_dirs(
    backbone,
):
    root = (
        ROOT
        / backbone
    )

    dirs = {
        "root":
            root,
        "full_direct":
            root
            / "full_direct",
        "fold_direct":
            root
            / "fold_direct",
        "oof":
            root
            / "oof",
        "validation":
            root
            / "validation",
        "memory_emb":
            SHARED_MEMORY_EMB_DIR,
        "gate":
            root
            / "gate",
        "history":
            root
            / "history",
        "paired":
            root
            / "paired_test",
        "channel":
            root
            / "channel_test",
        "calibration":
            root
            / "calibration",
    }

    for p in dirs.values():
        if isinstance(
            p,
            Path,
        ):
            p.mkdir(
                parents=True,
                exist_ok=True,
            )

    return dirs


def full_direct_path(
    backbone,
    horizon,
):
    return (
        backbone_dirs(
            backbone
        )[
            "full_direct"
        ]
        / (
            f"Electricity_{backbone}_"
            f"H{horizon}.pt"
        )
    )


def full_direct_history_path(
    backbone,
    horizon,
):
    return (
        backbone_dirs(
            backbone
        )[
            "history"
        ]
        / (
            f"Electricity_{backbone}_"
            f"H{horizon}_full.csv"
        )
    )


def train_anchors_for_direct(
    backbone,
    boundary,
    horizon,
):
    L = direct_seq_len(
        backbone
    )

    return np.arange(
        L,
        int(
            boundary
        )
        - int(
            horizon
        )
        + 1,
        dtype=np.int64,
    )


@torch.no_grad()
def evaluate_direct_anchors(
    backbone,
    model,
    z,
    anchors,
    horizon,
    batch_size,
):
    model.eval()

    sse = 0.0
    sae = 0.0
    n = 0

    batch_mse = []

    for i in range(
        0,
        len(
            anchors
        ),
        batch_size,
    ):
        a = anchors[
            i:
            i+batch_size
        ]

        x, y = make_direct_batch(
            z,
            a,
            backbone,
            horizon,
        )

        pred, true, _ = forward_direct(
            backbone,
            model,
            x,
            y,
            horizon,
        )

        e = (
            pred
            - true
        )

        batch_mse.append(
            float(
                (
                    e
                    * e
                ).mean()
            )
        )

        sse += float(
            (
                e
                * e
            ).sum()
        )

        sae += float(
            e.abs().sum()
        )

        n += e.numel()

    return {
        "MSE":
            sse
            / n,
        "MAE":
            sae
            / n,
        "BatchAverageMSE":
            float(
                np.mean(
                    batch_mse
                )
            ),
        "Windows":
            len(
                anchors
            ),
    }


def set_epoch_lr_type1(
    optimizer,
    base_lr,
    epoch,
):
    lr = (
        base_lr
        * (
            0.5
            ** max(
                0,
                epoch
                - 1,
            )
        )
    )

    for group in optimizer.param_groups:
        group[
            "lr"
        ] = lr

    return lr


def train_or_load_full_direct(
    backbone,
    horizon,
):
    path = full_direct_path(
        backbone,
        horizon,
    )

    r = DIRECT_RECIPES[
        backbone
    ]

    model, cfg = build_direct_model(
        backbone,
        horizon,
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        ckpt = load_torch(
            path
        )

        model.load_state_dict(
            ckpt[
                "StateDict"
            ]
        )

        model.eval()

        print(
            f"Loaded full direct | "
            f"{backbone} H={horizon} | "
            f"best={ckpt['BestValMSE']:.6f}"
            f"@{ckpt['BestEpoch']}"
        )

        return (
            model,
            ckpt,
        )

    set_seed(
        r[
            "seed"
        ]
    )

    train_anchors = train_anchors_for_direct(
        backbone,
        train_end,
        horizon,
    )

    val_anchors = eval_anchors(
        train_end,
        val_end,
        horizon,
        stride=1,
        lookback=direct_seq_len(backbone),
    )

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=r["learning_rate"],
        weight_decay=r["weight_decay"],
    )

    micro_batch = int(r["batch_size"])
    effective_batch = int(r.get("effective_batch_size", micro_batch))

    if effective_batch < micro_batch:
        raise ValueError(
            f"effective_batch_size ({effective_batch}) must be >= "
            f"micro batch ({micro_batch})"
        )

    scheduler = None

    if r["scheduler"] in {"TST", "OneCycle"}:
        # Scheduler steps correspond to optimizer updates, not micro-batches.
        steps_per_epoch = max(
            1,
            int(np.ceil(len(train_anchors) / effective_batch)),
        )

        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer,
            steps_per_epoch=steps_per_epoch,
            pct_start=r["pct_start"],
            epochs=r["train_epochs"],
            max_lr=r["learning_rate"],
        )

    best_val = float("inf")
    best_epoch = -1
    best_state = None
    wait = 0
    history = []

    rng = np.random.default_rng(
        r["seed"] + horizon
    )

    print(
        f"{backbone} H={horizon} | "
        f"micro_batch={micro_batch} | "
        f"effective_batch={effective_batch} | "
        f"channels={n_channels}"
    )

    for epoch in range(
        1,
        r["train_epochs"] + 1,
    ):
        model.train()

        if r["scheduler"] == "type1":
            current_lr = set_epoch_lr_type1(
                optimizer,
                r["learning_rate"],
                epoch,
            )

        order = rng.permutation(
            train_anchors
        )

        losses = []
        t0 = time.time()

        # One optimizer update per effective batch.
        for group_left in range(
            0,
            len(order),
            effective_batch,
        ):
            group = order[
                group_left:
                group_left + effective_batch
            ]

            if len(group) == 0:
                continue

            optimizer.zero_grad(
                set_to_none=True
            )

            group_loss = 0.0
            group_n = len(group)

            for micro_left in range(
                0,
                group_n,
                micro_batch,
            ):
                a = group[
                    micro_left:
                    micro_left + micro_batch
                ]

                x, y = make_direct_batch(
                    z_full,
                    a,
                    backbone,
                    horizon,
                )

                pred, true, _ = forward_direct(
                    backbone,
                    model,
                    x,
                    y,
                    horizon,
                )

                loss = F.mse_loss(
                    pred,
                    true,
                )

                # Exact effective-batch mean, because H and C are fixed.
                weight = float(len(a)) / float(group_n)
                (loss * weight).backward()

                group_loss += float(loss.item()) * weight

                del x, y, pred, true, loss

            optimizer.step()

            if scheduler is not None:
                scheduler.step()

            losses.append(
                group_loss
            )

        val = evaluate_direct_anchors(
            backbone,
            model,
            z_full,
            val_anchors,
            horizon,
            r["eval_batch"],
        )

        val_mse = val["MSE"]

        if (
            best_state is None
            or val_mse < best_val - 1e-12
        ):
            best_val = val_mse
            best_epoch = epoch

            best_state = {
                k: v.detach().cpu().clone()
                for k, v in model.state_dict().items()
            }

            wait = 0
        else:
            wait += 1

        if scheduler is not None:
            current_lr = optimizer.param_groups[0]["lr"]

        epoch_seconds = time.time() - t0

        history.append({
            "Epoch": epoch,
            "TrainMSE": float(np.mean(losses)),
            "ValMSE": val_mse,
            "ValMAE": val["MAE"],
            "BestValMSE": best_val,
            "BestEpoch": best_epoch,
            "LR": current_lr,
            "Seconds": epoch_seconds,
            "MicroBatch": micro_batch,
            "EffectiveBatch": effective_batch,
            "Channels": n_channels,
        })

        pd.DataFrame(
            history
        ).to_csv(
            full_direct_history_path(
                backbone,
                horizon,
            ),
            index=False,
        )

        print(
            f"{backbone:12s} "
            f"H={horizon:3d} "
            f"ep={epoch:03d} | "
            f"train={history[-1]['TrainMSE']:.6f} | "
            f"val={val_mse:.6f} | "
            f"best={best_val:.6f}@{best_epoch} | "
            f"wait={wait}/{r['patience']} | "
            f"{epoch_seconds/60.0:.1f} min"
        )

        if wait >= r["patience"]:
            break

    if best_state is None:
        raise RuntimeError(
            f"No full direct checkpoint for {backbone} H={horizon}."
        )

    model.load_state_dict(
        best_state
    )

    model.eval()

    ckpt = {
        "Backbone": backbone,
        "Dataset": "Electricity",
        "Protocol": "Full321_FrozenTransfer",
        "Horizon": int(horizon),
        "SeqLen": direct_seq_len(backbone),
        "BestEpoch": int(best_epoch),
        "BestValMSE": float(best_val),
        "Recipe": r,
        "StateDict": best_state,
    }

    torch.save(
        ckpt,
        path,
    )

    return (
        model,
        ckpt,
    )

# %%
def inv_softplus(
    x,
):
    return math.log(
        math.exp(
            float(
                x
            )
        )
        - 1.0
    )


class PredictivePatchEncoder(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.patch_proj = nn.Linear(
            REP_PATCH_LEN,
            REP_D_MODEL,
        )

        self.pos_embed = nn.Parameter(
            torch.zeros(
                1,
                REP_NUM_PATCHES,
                REP_D_MODEL,
            )
        )

        nn.init.trunc_normal_(
            self.pos_embed,
            std=0.02,
        )

        layer = nn.TransformerEncoderLayer(
            d_model=
                REP_D_MODEL,
            nhead=
                REP_N_HEADS,
            dim_feedforward=
                REP_D_FF,
            dropout=
                REP_DROPOUT,
            activation=
                "gelu",
            batch_first=
                True,
            norm_first=
                True,
        )

        self.encoder = nn.TransformerEncoder(
            layer,
            num_layers=
                REP_LAYERS,
        )

        self.norm = nn.LayerNorm(
            REP_D_MODEL
        )

        self.proj = nn.Linear(
            REP_D_MODEL,
            REP_DIM,
        )

    def forward(
        self,
        x,
    ):
        p = x.unfold(
            1,
            REP_PATCH_LEN,
            REP_PATCH_STRIDE,
        )

        h = (
            self.patch_proj(
                p
            )
            + self.pos_embed[
                :,
                :p.shape[
                    1
                ],
            ]
        )

        h = self.encoder(
            h
        ).mean(
            dim=1
        )

        h = self.proj(
            self.norm(
                h
            )
        )

        return F.normalize(
            h,
            dim=-1,
            eps=1e-8,
        )


class EmbeddingOnlyRetriever(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.encoder = (
            PredictivePatchEncoder()
        )

        self.raw_gamma = nn.Parameter(
            torch.tensor(
                inv_softplus(
                    1.0
                ),
                dtype=torch.float32,
            )
        )

    @property
    def gamma(
        self,
    ):
        return F.softplus(
            self.raw_gamma
        )

    def encode(
        self,
        x,
    ):
        return self.encoder(
            x
        )


def ret_amp():
    if RETRIEVER_USE_AMP:
        return torch.autocast(
            device_type="cuda",
            dtype=torch.float16,
        )

    return nullcontext()




STRONG_FORECASTER_ROOT = Path("/data/dataset/strong_forecaster")

EXP10_ELECTRICITY_ROOT = STRONG_FORECASTER_ROOT / "electricity_predictive_representation"
EXP12_ELECTRICITY_ROOT = STRONG_FORECASTER_ROOT / "electricity_crossfit_adaptive_gate"
EXP10_ELECTRICITY_CKPT = EXP10_ELECTRICITY_ROOT / "checkpoints"
EXP12_ELECTRICITY_FOLD_RET = EXP12_ELECTRICITY_ROOT / "fold_retriever_checkpoints"

_CKPT_RESOLVE_CACHE = {}


def _resolve_electricity_ckpt(filenames, preferred_dirs):
    key = tuple(str(x) for x in filenames)
    if key in _CKPT_RESOLVE_CACHE:
        return _CKPT_RESOLVE_CACHE[key]

    candidates = [Path(d) / fn for d in preferred_dirs for fn in filenames]
    for path in candidates:
        if path.is_file():
            _CKPT_RESOLVE_CACHE[key] = path
            return path

    matches = []
    if STRONG_FORECASTER_ROOT.is_dir():
        for fn in filenames:
            matches.extend(STRONG_FORECASTER_ROOT.rglob(fn))
    matches = sorted(set(p for p in matches if "electricity" in str(p).lower()))

    if len(matches) >= 1:
        if len(matches) > 1:
            print("WARNING: multiple Electricity checkpoint matches; using:", matches[0])
        _CKPT_RESOLVE_CACHE[key] = matches[0]
        return matches[0]

    path = candidates[0]
    _CKPT_RESOLVE_CACHE[key] = path
    return path


def full_retriever_ckpt_path(name, horizon):
    if name != "Electricity":
        raise ValueError(name)
    filenames = [
        f"Electricity_L96_H{horizon}_EmbeddingOnly_Listwise_seed0.pt",
        f"electricity_L96_H{horizon}_EmbeddingOnly_Listwise_seed0.pt",
    ]
    return _resolve_electricity_ckpt(
        filenames,
        [EXP10_ELECTRICITY_CKPT, EXP10_ELECTRICITY_ROOT],
    )


def fold_retriever_ckpt_path(name, horizon, fold):
    if name != "Electricity":
        raise ValueError(name)
    filenames = [
        f"Electricity_H{horizon}_Fold{fold}_EmbeddingOnly.pt",
        f"electricity_H{horizon}_Fold{fold}_EmbeddingOnly.pt",
    ]
    return _resolve_electricity_ckpt(
        filenames,
        [EXP12_ELECTRICITY_FOLD_RET, EXP12_ELECTRICITY_ROOT],
    )


def load_frozen_retriever(
    path,
):
    if not Path(
        path
    ).is_file():
        raise FileNotFoundError(
            path
        )

    ckpt = load_torch(
        path
    )

    model = EmbeddingOnlyRetriever().to(
        DEVICE
    )

    state = (
        ckpt[
            "StateDict"
        ]
        if isinstance(
            ckpt,
            dict,
        )
        and "StateDict"
        in ckpt
        else ckpt
    )

    # Backward-compatible checkpoint key handling.
    #
    # The frozen retriever checkpoints from the earlier experiments
    # were saved with:
    #   encoder.out_norm.* / encoder.out_proj.*
    # while this notebook's PredictivePatchEncoder currently exposes:
    #   encoder.norm.* / encoder.proj.*
    #
    # The modules are architecturally identical; only the attribute
    # names differ. Remap the legacy keys and still load strictly so
    # that any real architecture mismatch is not silently ignored.
    state = dict(
        state
    )

    legacy_to_current = {
        "encoder.out_norm.weight":
            "encoder.norm.weight",
        "encoder.out_norm.bias":
            "encoder.norm.bias",
        "encoder.out_proj.weight":
            "encoder.proj.weight",
        "encoder.out_proj.bias":
            "encoder.proj.bias",
    }

    for old_key, new_key in legacy_to_current.items():
        if (
            old_key in state
            and new_key not in state
        ):
            state[
                new_key
            ] = state.pop(
                old_key
            )

    model.load_state_dict(
        state,
        strict=True,
    )

    model.eval()

    for p in model.parameters():
        p.requires_grad_(
            False
        )

    return (
        model,
        ckpt,
    )


EXP10_ELECTRICITY_CKPT.mkdir(parents=True, exist_ok=True)
EXP12_ELECTRICITY_FOLD_RET.mkdir(parents=True, exist_ok=True)

# %%
def retrieval_anchor_batch(
    name,
):
    C = DATA[
        name
    ][
        "n_channels"
    ]

    return max(
        1,
        TARGET_RETRIEVAL_PAIRS
        // C,
    )


def batch_pattern(
    x,
):
    x = np.asarray(
        x,
        np.float32,
    )

    xc = (
        x
        - x.mean(
            axis=-1,
            keepdims=True,
        )
    )

    n = np.linalg.norm(
        xc,
        axis=-1,
        keepdims=True,
    )

    return np.where(
        n > EPS,
        xc
        / np.maximum(
            n,
            EPS,
        ),
        0.0,
    ).astype(
        np.float32
    )


def context7(
    x,
):
    x = np.asarray(
        x,
        np.float32,
    )

    short = max(
        8,
        RET_SEQ_LEN
        // 4,
    )

    m = x.mean(
        axis=-1
    )

    s = (
        x.std(
            axis=-1
        )
        + EPS
    )

    f1 = (
        x[
            ...,
            -1
        ]
        - m
    ) / s

    f2 = (
        x[
            ...,
            -short:
        ].mean(
            axis=-1
        )
        - m
    ) / s

    f3 = (
        x[
            ...,
            -1
        ]
        - x[
            ...,
            -short
        ]
    ) / s

    f4 = (
        x[
            ...,
            -1
        ]
        - x[
            ...,
            0
        ]
    ) / s

    df = np.diff(
        x,
        axis=-1,
    )

    ds = np.diff(
        x[
            ...,
            -short:
        ],
        axis=-1,
    )

    f5 = (
        ds.std(
            axis=-1
        )
        + EPS
    ) / (
        df.std(
            axis=-1
        )
        + EPS
    )

    t = np.linspace(
        -1.0,
        1.0,
        RET_SEQ_LEN,
        dtype=np.float32,
    )

    t = (
        t
        - t.mean()
    )

    f6 = (
        np.sum(
            t
            * (
                x
                - m[
                    ...,
                    None
                ]
            ),
            axis=-1,
        )
        / (
            np.sum(
                t
                * t
            )
            + EPS
        )
    ) / s

    a = x[
        ...,
        :-1
    ]

    b = x[
        ...,
        1:
    ]

    a = (
        a
        - a.mean(
            axis=-1,
            keepdims=True,
        )
    )

    b = (
        b
        - b.mean(
            axis=-1,
            keepdims=True,
        )
    )

    f7 = np.sum(
        a
        * b,
        axis=-1,
    ) / (
        np.sqrt(
            np.sum(
                a
                * a,
                axis=-1,
            )
            * np.sum(
                b
                * b,
                axis=-1,
            )
        )
        + EPS
    )

    return np.stack(
        [
            f1,
            f2,
            f3,
            f4,
            f5,
            f6,
            f7,
        ],
        axis=-1,
    ).astype(
        np.float32
    )


def extract_channel(
    z,
    c,
    anchors,
    horizon,
):
    anchors = np.asarray(
        anchors,
        np.int64,
    )

    pi = (
        anchors[
            :,
            None
        ]
        - RET_SEQ_LEN
        + np.arange(
            RET_SEQ_LEN
        )[
            None,
            :
        ]
    )

    fi = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    past = z[
        pi,
        c,
    ].astype(
        np.float32
    )

    future = z[
        fi,
        c,
    ].astype(
        np.float32
    )

    current = z[
        anchors
        - 1,
        c,
    ].astype(
        np.float32
    )

    future_residual = (
        future
        - current[
            :,
            None
        ]
    ).astype(
        np.float32
    )

    return (
        past,
        future_residual,
    )


def build_memory(
    z,
    channels,
    boundary,
    horizon,
):
    memory_anchors = np.arange(
        RET_SEQ_LEN,
        int(
            boundary
        )
        - horizon
        + 1,
        MEMORY_STRIDE,
        dtype=np.int64,
    )

    if len(
        memory_anchors
    ) < TOP_K:
        raise ValueError(
            "Insufficient admissible memory."
        )

    past = np.empty(
        (
            channels,
            len(
                memory_anchors
            ),
            RET_SEQ_LEN,
        ),
        dtype=np.float32,
    )

    pattern = np.empty_like(
        past
    )

    future = np.empty(
        (
            channels,
            len(
                memory_anchors
            ),
            horizon,
        ),
        dtype=np.float32,
    )

    for c in range(
        channels
    ):
        p, f = extract_channel(
            z,
            c,
            memory_anchors,
            horizon,
        )

        past[
            c
        ] = p

        pattern[
            c
        ] = batch_pattern(
            p
        )

        future[
            c
        ] = f

    return {
        "anchors":
            memory_anchors,
        "past":
            past,
        "pattern":
            pattern,
        "future":
            future,
        "M":
            len(
                memory_anchors
            ),
        "boundary":
            int(
                boundary
            ),
    }


def query_pairs(
    z,
    anchors,
    channels,
    horizon,
):
    anchors = np.asarray(
        anchors,
        np.int64,
    )

    channels = np.asarray(
        channels,
        np.int64,
    )

    pi = (
        anchors[
            :,
            None
        ]
        - RET_SEQ_LEN
        + np.arange(
            RET_SEQ_LEN
        )[
            None,
            :
        ]
    )

    fi = (
        anchors[
            :,
            None
        ]
        + np.arange(
            horizon
        )[
            None,
            :
        ]
    )

    past = z[
        pi,
        channels[
            :,
            None
        ],
    ].astype(
        np.float32
    )

    future = z[
        fi,
        channels[
            :,
            None
        ],
    ].astype(
        np.float32
    )

    current = z[
        anchors
        - 1,
        channels,
    ].astype(
        np.float32
    )

    true_residual = (
        future
        - current[
            :,
            None
        ]
    ).astype(
        np.float32
    )

    return (
        past,
        batch_pattern(
            past
        ),
        context7(
            past
        ),
        true_residual,
    )

# %%
@torch.no_grad()
def encode_np(
    model,
    x,
    chunk=512,
):
    parts = []

    for i in range(
        0,
        len(
            x
        ),
        chunk,
    ):
        t = torch.from_numpy(
            x[
                i:
                i+chunk
            ]
        ).to(
            DEVICE
        )

        with ret_amp():
            e = model.encode(
                t
            ).float()

        parts.append(
            e.cpu()
        )

        del (
            t,
            e,
        )

    return torch.cat(
        parts,
        dim=0,
    ).numpy().astype(
        np.float32
    )


def memory_embedding_path(
    name,
    horizon,
    tag,
):
    return (
        SHARED_MEMORY_EMB_DIR
        / (
            f"{name}_H{horizon}_"
            f"{tag}_emb.npy"
        )
    )


@torch.no_grad()
def memory_gpu_cached(
    name,
    horizon,
    tag,
    model,
    memory,
    channels,
):
    path = memory_embedding_path(
        name,
        horizon,
        tag,
    )

    expected = (
        channels,
        memory[
            "M"
        ],
        REP_DIM,
    )

    emb_np = None

    if (
        path.exists()
        and RESUME
        and not FORCE
    ):
        candidate = np.load(
            path,
            mmap_mode=None,
        )

        if (
            tuple(
                candidate.shape
            )
            == expected
        ):
            emb_np = candidate.astype(
                np.float32,
                copy=False,
            )

            print(
                "Loaded memory embedding:",
                path.name,
            )

    if emb_np is None:
        emb_np = np.empty(
            expected,
            dtype=np.float32,
        )

        print(
            "Building memory embedding:",
            path.name,
            expected,
        )

        for c in range(
            channels
        ):
            emb_np[
                c
            ] = encode_np(
                model,
                memory[
                    "past"
                ][
                    c
                ],
            )

            if (
                c == 0
                or (
                    c + 1
                )
                % 50
                == 0
                or (
                    c + 1
                    == channels
                )
            ):
                print(
                    f"  channel "
                    f"{c+1}/{channels}"
                )

        np.save(
            path,
            emb_np,
        )

    return {
        "emb":
            torch.from_numpy(
                emb_np
            ).to(
                DEVICE
            ),
        "pattern":
            torch.from_numpy(
                memory[
                    "pattern"
                ]
            ).to(
                DEVICE
            ),
        "future":
            torch.from_numpy(
                memory[
                    "future"
                ]
            ).to(
                DEVICE
            ),
    }

# %%
@torch.no_grad()
def retrieve(
    model,
    memory_gpu_obj,
    z,
    anchors,
    channels,
    horizon,
):
    (
        past,
        pattern,
        ctx,
        true,
    ) = query_pairs(
        z,
        anchors,
        channels,
        horizon,
    )

    past_t = torch.from_numpy(
        past
    ).to(
        DEVICE
    )

    pattern_t = torch.from_numpy(
        pattern
    ).to(
        DEVICE
    )

    with ret_amp():
        qemb = model.encode(
            past_t
        )

    qemb = qemb.float()

    memb = memory_gpu_obj[
        "emb"
    ][
        channels
    ]

    sim = torch.bmm(
        qemb[
            :,
            None,
            :
        ],
        memb.transpose(
            1,
            2,
        ),
    ).squeeze(
        1
    )

    score = (
        model.gamma
        * sim
    )

    idx = torch.topk(
        score,
        TOP_K,
        dim=1,
    ).indices

    row = torch.arange(
        len(
            channels
        ),
        device=DEVICE,
    )[
        :,
        None
    ]

    pfull = torch.bmm(
        pattern_t[
            :,
            None,
            :
        ],
        memory_gpu_obj[
            "pattern"
        ][
            channels
        ].transpose(
            1,
            2,
        ),
    ).squeeze(
        1
    )

    return {
        "score":
            score[
                row,
                idx
            ],
        "sim":
            sim[
                row,
                idx
            ],
        "pattern":
            pfull[
                row,
                idx
            ],
        "cand":
            memory_gpu_obj[
                "future"
            ][
                channels[
                    :,
                    None
                ],
                idx,
            ],
        "ctx":
            torch.from_numpy(
                ctx
            ).to(
                DEVICE
            ),
        "true":
            torch.from_numpy(
                true
            ).to(
                DEVICE
            ),
    }

# %%
class CrossFitAdaptiveGate(
    nn.Module
):
    def __init__(
        self,
    ):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(
                GATE_DIM,
                64,
            ),
            nn.LayerNorm(
                64
            ),
            nn.GELU(),
            nn.Dropout(
                0.1
            ),
            nn.Linear(
                64,
                32,
            ),
            nn.GELU(),
            nn.Dropout(
                0.1
            ),
            nn.Linear(
                32,
                1,
            ),
        )

        nn.init.normal_(
            self.net[
                -1
            ].weight,
            mean=0.0,
            std=1e-3,
        )

        nn.init.constant_(
            self.net[
                -1
            ].bias,
            math.log(
                0.1
                / 0.9
            ),
        )

    def forward(
        self,
        x,
    ):
        return torch.sigmoid(
            self.net(
                x
            ).squeeze(
                -1
            )
        )


def score_entropy(
    s,
):
    p = torch.softmax(
        s,
        dim=1,
    )

    return (
        -(
            p
            * torch.log(
                p.clamp_min(
                    1e-8
                )
            )
        ).sum(
            dim=1
        )
        / math.log(
            TOP_K
        )
    )


def feature_cosine(
    a,
    b,
):
    return (
        (
            a
            * b
        ).sum(
            dim=1
        )
        / (
            torch.sqrt(
                (
                    a
                    * a
                ).sum(
                    dim=1
                )
                + 1e-8
            )
            * torch.sqrt(
                (
                    b
                    * b
                ).sum(
                    dim=1
                )
                + 1e-8
            )
        )
    )


def gate_features(
    r,
    retrieval,
    direct,
):
    s = r[
        "score"
    ]

    sim = r[
        "sim"
    ]

    pattern = r[
        "pattern"
    ]

    sorted_s = torch.sort(
        s,
        dim=1,
        descending=True,
    ).values

    cand_std = r[
        "cand"
    ].std(
        dim=1,
        unbiased=False,
    )

    disp_rms = torch.sqrt(
        (
            cand_std
            * cand_std
        ).mean(
            dim=1
        )
        + 1e-8
    )

    disp_mean = cand_std.mean(
        dim=1
    )

    direct_rms = torch.sqrt(
        (
            direct
            * direct
        ).mean(
            dim=1
        )
        + 1e-8
    )

    retrieval_rms = torch.sqrt(
        (
            retrieval
            * retrieval
        ).mean(
            dim=1
        )
        + 1e-8
    )

    disagreement = (
        retrieval
        - direct
    )

    disagreement_rms = torch.sqrt(
        (
            disagreement
            * disagreement
        ).mean(
            dim=1
        )
        + 1e-8
    )

    relative_disagreement = (
        disagreement_rms
        / (
            direct_rms
            + retrieval_rms
            + 1e-6
        )
    )

    scalars = torch.stack(
        [
            s.mean(
                dim=1
            ),
            s.std(
                dim=1,
                unbiased=False,
            ),
            s.max(
                dim=1
            ).values,
            sorted_s[
                :,
                0
            ]
            - sorted_s[
                :,
                1
            ],
            s.max(
                dim=1
            ).values
            - s.mean(
                dim=1
            ),
            score_entropy(
                s
            ),
            sim.mean(
                dim=1
            ),
            sim.std(
                dim=1,
                unbiased=False,
            ),
            sim.max(
                dim=1
            ).values,
            pattern.mean(
                dim=1
            ),
            pattern.std(
                dim=1,
                unbiased=False,
            ),
            pattern.max(
                dim=1
            ).values,
            disp_rms,
            disp_mean,
            direct_rms,
            retrieval_rms,
            disagreement_rms,
            relative_disagreement,
            feature_cosine(
                direct,
                retrieval,
            ),
        ],
        dim=1,
    )

    out = torch.cat(
        [
            r[
                "ctx"
            ],
            scalars,
        ],
        dim=1,
    )

    if out.shape[
        1
    ] != GATE_DIM:
        raise RuntimeError(
            f"Gate feature dimension mismatch: "
            f"{out.shape}"
        )

    return out


def abc_terms(
    direct,
    retrieval,
    true,
):
    e = (
        direct
        - true
    )

    delta = (
        retrieval
        - direct
    )

    return torch.stack(
        [
            (
                e
                * e
            ).mean(
                dim=1
            ),
            (
                e
                * delta
            ).mean(
                dim=1
            ),
            (
                delta
                * delta
            ).mean(
                dim=1
            ),
        ],
        dim=1,
    )

# %%
@torch.no_grad()
def collect_gate_data(
    data,
    horizon,
    direct_model,
    retriever,
    memory_gpu_obj,
    z,
    anchors,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    ret_block = retrieval_anchor_batch(
        name
    )

    direct_block = DIRECT_ANCHOR_BLOCK[
        CURRENT_BACKBONE
    ]

    features = []
    abcs = []
    anchors_out = []
    channels_out = []

    for outer in range(
        0,
        len(
            anchors
        ),
        direct_block,
    ):
        a_big = anchors[
            outer:
            outer+direct_block
        ]

        direct_big, true_big = (
            direct_residual_block(
                direct_model,
                z,
                data[
                    "marks"
                ],
                a_big,
                horizon,
            )
        )

        # [A, H, C] -> [A, C, H]
        direct_big = direct_big.permute(
            0,
            2,
            1,
        ).contiguous()

        true_big = true_big.permute(
            0,
            2,
            1,
        ).contiguous()

        for inner in range(
            0,
            len(
                a_big
            ),
            ret_block,
        ):
            a = a_big[
                inner:
                inner+ret_block
            ]

            A = len(
                a
            )

            pair_anchor = np.repeat(
                a,
                C,
            )

            pair_channel = np.tile(
                np.arange(
                    C,
                    dtype=np.int64,
                ),
                A,
            )

            r = retrieve(
                retriever,
                memory_gpu_obj,
                z,
                pair_anchor,
                pair_channel,
                horizon,
            )

            retrieval = r[
                "cand"
            ].mean(
                dim=1
            )

            d = direct_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            t = true_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            # Strong consistency check:
            # direct true residual must match retrieval true residual.
            max_true_diff = float(
                (
                    t
                    - r[
                        "true"
                    ]
                ).abs().max()
            )

            if (
                max_true_diff
                > 2e-5
            ):
                raise RuntimeError(
                    f"True residual mismatch: "
                    f"{max_true_diff}"
                )

            feat = gate_features(
                r,
                retrieval,
                d,
            )

            abc = abc_terms(
                d,
                retrieval,
                t,
            )

            features.append(
                feat.cpu()
                .numpy()
                .astype(
                    np.float32
                )
            )

            abcs.append(
                abc.cpu()
                .numpy()
                .astype(
                    np.float32
                )
            )

            anchors_out.append(
                pair_anchor
            )

            channels_out.append(
                pair_channel
            )

            del (
                r,
                retrieval,
                d,
                t,
                feat,
                abc,
            )

        del (
            direct_big,
            true_big,
        )

    return {
        "feature":
            np.concatenate(
                features,
                axis=0,
            ),
        "abc":
            np.concatenate(
                abcs,
                axis=0,
            ),
        "anchor":
            np.concatenate(
                anchors_out,
                axis=0,
            ),
        "channel":
            np.concatenate(
                channels_out,
                axis=0,
            ),
    }

# %%
def fit_feature_scaler(
    x,
):
    median = np.median(
        x,
        axis=0,
    ).astype(
        np.float32
    )

    q25 = np.percentile(
        x,
        25,
        axis=0,
    )

    q75 = np.percentile(
        x,
        75,
        axis=0,
    )

    iqr = (
        q75
        - q25
    ).astype(
        np.float32
    )

    iqr = np.where(
        iqr < 1e-5,
        1.0,
        iqr,
    ).astype(
        np.float32
    )

    return (
        median,
        iqr,
    )


def scale_features(
    x,
    median,
    iqr,
):
    return np.clip(
        (
            x
            - median
        )
        / iqr,
        -8.0,
        8.0,
    ).astype(
        np.float32
    )


def gate_loss(
    alpha,
    abc,
):
    return (
        abc[
            :,
            0
        ]
        + 2.0
        * alpha
        * abc[
            :,
            1
        ]
        + alpha
        * alpha
        * abc[
            :,
            2
        ]
    ).mean()


def gate_checkpoint_path(
    name,
    horizon,
):
    return (
        DIRS[
            "gate"
        ]
        / (
            f"{name}_H{horizon}_"
            "gate.pt"
        )
    )


def train_gate_epoch(
    model,
    optimizer,
    x,
    abc,
    rng,
):
    model.train()

    order = rng.permutation(
        len(
            x
        )
    )

    losses = []

    for i in range(
        0,
        len(
            order
        ),
        GATE_BATCH,
    ):
        ids = order[
            i:
            i+GATE_BATCH
        ]

        xt = torch.from_numpy(
            x[
                ids
            ]
        ).to(
            DEVICE
        )

        at = torch.from_numpy(
            abc[
                ids
            ]
        ).to(
            DEVICE
        )

        optimizer.zero_grad(
            set_to_none=True
        )

        alpha = model(
            xt
        )

        loss = gate_loss(
            alpha,
            at,
        )

        loss.backward()
        optimizer.step()

        losses.append(
            float(
                loss.item()
            )
        )

        del (
            xt,
            at,
            alpha,
            loss,
        )

    return float(
        np.mean(
            losses
        )
    )


@torch.no_grad()
def evaluate_gate(
    model,
    x,
    abc,
):
    model.eval()

    total = 0.0
    n = 0
    alpha_sum = 0.0

    for i in range(
        0,
        len(
            x
        ),
        GATE_BATCH,
    ):
        xt = torch.from_numpy(
            x[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        at = torch.from_numpy(
            abc[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        alpha = model(
            xt
        )

        each = (
            at[
                :,
                0
            ]
            + 2.0
            * alpha
            * at[
                :,
                1
            ]
            + alpha
            * alpha
            * at[
                :,
                2
            ]
        )

        total += float(
            each.sum()
        )

        n += len(
            alpha
        )

        alpha_sum += float(
            alpha.sum()
        )

        del (
            xt,
            at,
            alpha,
            each,
        )

    return (
        total
        / n,
        alpha_sum
        / n,
    )


def train_crossfit_gate(
    name,
    horizon,
    oof_x,
    oof_abc,
    val_x,
    val_abc,
):
    path = gate_checkpoint_path(
        name,
        horizon,
    )

    if (
        path.exists()
        and RESUME
        and not FORCE
    ):
        ckpt = load_torch(
            path
        )

        model = CrossFitAdaptiveGate().to(
            DEVICE
        )

        model.load_state_dict(
            ckpt[
                "StateDict"
            ]
        )

        model.eval()

        print(
            "Loaded gate:",
            path.name,
        )

        return (
            model,
            ckpt,
        )

    median, iqr = fit_feature_scaler(
        oof_x
    )

    train_x = scale_features(
        oof_x,
        median,
        iqr,
    )

    valid_x = scale_features(
        val_x,
        median,
        iqr,
    )

    seed = (
        CROSSFIT_SEED
        + horizon
        * 3000
        + sum(
            map(
                ord,
                name,
            )
        )
    )

    set_seed(
        seed
    )

    model = CrossFitAdaptiveGate().to(
        DEVICE
    )

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=GATE_LR,
        weight_decay=GATE_WD,
    )

    rng = np.random.default_rng(
        seed
        + 1
    )

    best = float(
        "inf"
    )

    best_epoch = -1
    wait = 0
    history = []

    for epoch in range(
        1,
        GATE_MAX_EPOCHS
        + 1,
    ):
        train_mse = train_gate_epoch(
            model,
            optimizer,
            train_x,
            oof_abc,
            rng,
        )

        val_mse, mean_alpha = evaluate_gate(
            model,
            valid_x,
            val_abc,
        )

        history.append({
            "Epoch":
                epoch,
            "OOFTrainMSE":
                train_mse,
            "ValMSE":
                val_mse,
            "ValMeanAlpha":
                mean_alpha,
        })

        if (
            val_mse
            < best
            - 1e-10
        ):
            best = val_mse
            best_epoch = epoch
            wait = 0
        else:
            wait += 1

        print(
            f"Gate {name:11s} H={horizon:3d} "
            f"ep={epoch:02d} "
            f"OOF={train_mse:.6f} "
            f"val={val_mse:.6f} "
            f"alpha={mean_alpha:.3f} "
            f"best={best:.6f}@{best_epoch}"
        )

        if (
            wait
            >= GATE_PATIENCE
        ):
            break

    # Reinitialize and fit only on OOF for the
    # validation-selected number of epochs.
    set_seed(
        seed
    )

    final = CrossFitAdaptiveGate().to(
        DEVICE
    )

    final_opt = torch.optim.AdamW(
        final.parameters(),
        lr=GATE_LR,
        weight_decay=GATE_WD,
    )

    final_rng = np.random.default_rng(
        seed
        + 2
    )

    for _ in range(
        best_epoch
    ):
        train_gate_epoch(
            final,
            final_opt,
            train_x,
            oof_abc,
            final_rng,
        )

    final.eval()

    ckpt = {
        "BestEpoch":
            best_epoch,
        "BestValMSE":
            best,
        "FeatureMedian":
            median,
        "FeatureIQR":
            iqr,
        "StateDict": {
            k:
                v.detach()
                .cpu()
                .clone()
            for k, v
            in final.state_dict().items()
        },
    }

    torch.save(
        ckpt,
        path,
    )

    pd.DataFrame(
        history
    ).to_csv(
        DIRS[
            "history"
        ]
        / (
            f"{name}_H{horizon}_"
            "gate_history.csv"
        ),
        index=False,
    )

    return (
        final,
        ckpt,
    )


def mse_scalar(
    abc,
    alpha,
):
    A = abc.astype(
        np.float64
    )

    x = float(
        alpha
    )

    return float(
        np.mean(
            A[
                :,
                0
            ]
            + 2.0
            * x
            * A[
                :,
                1
            ]
            + x
            * x
            * A[
                :,
                2
            ]
        )
    )


def choose_scalar(
    abc,
):
    rows = []

    best_alpha = None
    best_mse = float(
        "inf"
    )

    for alpha in ALPHA_GRID:
        mse = mse_scalar(
            abc,
            alpha,
        )

        rows.append({
            "Alpha":
                float(
                    alpha
                ),
            "MSE":
                mse,
        })

        if (
            mse
            < best_mse
            - 1e-10
        ):
            best_mse = mse
            best_alpha = float(
                alpha
            )

    return (
        best_alpha,
        pd.DataFrame(
            rows
        ),
    )


@torch.no_grad()
def gate_alpha(
    model,
    ckpt,
    x,
):
    sx = scale_features(
        x,
        ckpt[
            "FeatureMedian"
        ],
        ckpt[
            "FeatureIQR"
        ],
    )

    outputs = []

    for i in range(
        0,
        len(
            sx
        ),
        GATE_BATCH,
    ):
        t = torch.from_numpy(
            sx[
                i:
                i+GATE_BATCH
            ]
        ).to(
            DEVICE
        )

        outputs.append(
            model(
                t
            ).cpu()
            .numpy()
        )

        del t

    return np.concatenate(
        outputs
    ).astype(
        np.float32
    )


def mse_pair(
    abc,
    alpha,
):
    A = abc.astype(
        np.float64
    )

    x = np.asarray(
        alpha,
        dtype=np.float64,
    )

    return float(
        np.mean(
            A[
                :,
                0
            ]
            + 2.0
            * x
            * A[
                :,
                1
            ]
            + x
            * x
            * A[
                :,
                2
            ]
        )
    )


def choose_lambda(
    abc,
    gate_alpha_values,
    scalar_alpha,
):
    rows = []

    best_lambda = None
    best_mse = float(
        "inf"
    )

    for lmb in LAMBDA_GRID:
        alpha = (
            (
                1.0
                - float(
                    lmb
                )
            )
            * scalar_alpha
            + float(
                lmb
            )
            * gate_alpha_values
        )

        mse = mse_pair(
            abc,
            alpha,
        )

        rows.append({
            "Lambda":
                float(
                    lmb
                ),
            "MSE":
                mse,
            "MeanAlpha":
                float(
                    alpha.mean()
                ),
        })

        if (
            mse
            < best_mse
            - 1e-10
        ):
            best_mse = mse
            best_lambda = float(
                lmb
            )

    return (
        best_lambda,
        pd.DataFrame(
            rows
        ),
    )

# %%
def empty_stat():
    return {
        "sse":
            0.0,
        "sae":
            0.0,
        "n":
            0,
    }


def update_stat(
    stat,
    pred,
    true,
):
    e = (
        pred
        - true
    )

    stat[
        "sse"
    ] += float(
        (
            e
            * e
        ).sum()
    )

    stat[
        "sae"
    ] += float(
        e.abs().sum()
    )

    stat[
        "n"
    ] += e.numel()


def finish_stat(
    stat,
):
    return (
        stat[
            "sse"
        ]
        / stat[
            "n"
        ],
        stat[
            "sae"
        ]
        / stat[
            "n"
        ],
    )


def oracle_alpha_and_prediction(
    direct,
    retrieval,
    true,
):
    e = (
        direct
        - true
    )

    delta = (
        retrieval
        - direct
    )

    alpha = torch.clamp(
        -(
            e
            * delta
        ).sum(
            dim=1
        )
        / (
            (
                delta
                * delta
            ).sum(
                dim=1
            )
            + 1e-8
        ),
        0.0,
        1.0,
    )

    pred = (
        direct
        + alpha[
            :,
            None
        ]
        * delta
    )

    return (
        alpha,
        pred,
    )


@torch.no_grad()
def test_evaluate(
    data,
    horizon,
    direct_model,
    retriever,
    memory_gpu_obj,
    gate,
    gate_ckpt,
    scalar_alpha,
    shrink_lambda,
):
    name = data[
        "name"
    ]

    C = data[
        "n_channels"
    ]

    direct_block = DIRECT_ANCHOR_BLOCK[
        CURRENT_BACKBONE
    ]

    ret_block = retrieval_anchor_batch(
        name
    )

    anchors = eval_anchors(
        data[
            "val_end"
        ],
        data[
            "test_end"
        ],
        horizon,
        stride=1,
    )

    keys = [
        "Direct",
        "Retrieval",
        "Scalar",
        "RawAdaptive",
        "ShrinkAdaptive",
        "Oracle",
    ]

    stats = {
        key:
            empty_stat()
        for key in keys
    }

    anchor_mse = {
        key:
            []
        for key in keys
    }

    channel_sse_direct = np.zeros(
        C,
        dtype=np.float64,
    )

    channel_sse_shrink = np.zeros(
        C,
        dtype=np.float64,
    )

    channel_count = np.zeros(
        C,
        dtype=np.int64,
    )

    raw_alpha_sum = 0.0
    shrink_alpha_sum = 0.0
    oracle_alpha_sum = 0.0
    oracle_positive = 0
    n_pairs = 0

    processed = 0

    for outer in range(
        0,
        len(
            anchors
        ),
        direct_block,
    ):
        a_big = anchors[
            outer:
            outer+direct_block
        ]

        direct_big, true_big = (
            direct_residual_block(
                direct_model,
                data[
                    "z"
                ],
                data[
                    "marks"
                ],
                a_big,
                horizon,
            )
        )

        direct_big = direct_big.permute(
            0,
            2,
            1,
        ).contiguous()

        true_big = true_big.permute(
            0,
            2,
            1,
        ).contiguous()

        # anchor-level MSE accumulators within this direct block
        block_anchor_sums = {
            key:
                torch.zeros(
                    len(
                        a_big
                    ),
                    device=DEVICE,
                    dtype=torch.float64,
                )
            for key in keys
        }

        for inner in range(
            0,
            len(
                a_big
            ),
            ret_block,
        ):
            a = a_big[
                inner:
                inner+ret_block
            ]

            A = len(
                a
            )

            pair_anchor = np.repeat(
                a,
                C,
            )

            pair_channel = np.tile(
                np.arange(
                    C,
                    dtype=np.int64,
                ),
                A,
            )

            r = retrieve(
                retriever,
                memory_gpu_obj,
                data[
                    "z"
                ],
                pair_anchor,
                pair_channel,
                horizon,
            )

            retrieval = r[
                "cand"
            ].mean(
                dim=1
            )

            direct = direct_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            true = true_big[
                inner:
                inner+A
            ].reshape(
                -1,
                horizon,
            )

            scalar = (
                direct
                + scalar_alpha
                * (
                    retrieval
                    - direct
                )
            )

            features = gate_features(
                r,
                retrieval,
                direct,
            ).cpu().numpy().astype(
                np.float32
            )

            scaled = scale_features(
                features,
                gate_ckpt[
                    "FeatureMedian"
                ],
                gate_ckpt[
                    "FeatureIQR"
                ],
            )

            gate_alpha_values = gate(
                torch.from_numpy(
                    scaled
                ).to(
                    DEVICE
                )
            )

            shrink_alpha_values = (
                (
                    1.0
                    - shrink_lambda
                )
                * scalar_alpha
                + shrink_lambda
                * gate_alpha_values
            )

            raw_adaptive = (
                direct
                + gate_alpha_values[
                    :,
                    None
                ]
                * (
                    retrieval
                    - direct
                )
            )

            shrink_adaptive = (
                direct
                + shrink_alpha_values[
                    :,
                    None
                ]
                * (
                    retrieval
                    - direct
                )
            )

            (
                oracle_alpha,
                oracle,
            ) = oracle_alpha_and_prediction(
                direct,
                retrieval,
                true,
            )

            predictions = {
                "Direct":
                    direct,
                "Retrieval":
                    retrieval,
                "Scalar":
                    scalar,
                "RawAdaptive":
                    raw_adaptive,
                "ShrinkAdaptive":
                    shrink_adaptive,
                "Oracle":
                    oracle,
            }

            for key, pred in predictions.items():
                update_stat(
                    stats[
                        key
                    ],
                    pred,
                    true,
                )

                per_anchor = (
                    (
                        (
                            pred
                            - true
                        )
                        ** 2
                    )
                    .reshape(
                        A,
                        C,
                        horizon,
                    )
                    .mean(
                        dim=(
                            1,
                            2,
                        )
                    )
                    .double()
                )

                block_anchor_sums[
                    key
                ][
                    inner:
                    inner+A
                ] = per_anchor

            direct_e2 = (
                (
                    direct
                    - true
                )
                ** 2
            ).reshape(
                A,
                C,
                horizon,
            )

            shrink_e2 = (
                (
                    shrink_adaptive
                    - true
                )
                ** 2
            ).reshape(
                A,
                C,
                horizon,
            )

            channel_sse_direct += (
                direct_e2.sum(
                    dim=(
                        0,
                        2,
                    )
                ).cpu()
                .numpy()
            )

            channel_sse_shrink += (
                shrink_e2.sum(
                    dim=(
                        0,
                        2,
                    )
                ).cpu()
                .numpy()
            )

            channel_count += (
                A
                * horizon
            )

            raw_alpha_sum += float(
                gate_alpha_values.sum()
            )

            shrink_alpha_sum += float(
                shrink_alpha_values.sum()
            )

            oracle_alpha_sum += float(
                oracle_alpha.sum()
            )

            oracle_positive += int(
                (
                    oracle_alpha
                    > 0.01
                ).sum()
            )

            n_pairs += len(
                gate_alpha_values
            )

            del (
                r,
                retrieval,
                direct,
                true,
                scalar,
                features,
                scaled,
                gate_alpha_values,
                shrink_alpha_values,
                raw_adaptive,
                shrink_adaptive,
                oracle_alpha,
                oracle,
                predictions,
                direct_e2,
                shrink_e2,
            )

        for key in keys:
            anchor_mse[
                key
            ].extend(
                block_anchor_sums[
                    key
                ].cpu()
                .numpy()
                .astype(
                    np.float32
                )
                .tolist()
            )

        processed += len(
            a_big
        )

        if (
            processed
            == len(
                a_big
            )
            or processed
            % 500
            < len(
                a_big
            )
            or processed
            == len(
                anchors
            )
        ):
            print(
                f"  test anchors "
                f"{processed}/{len(anchors)}"
            )

        del (
            direct_big,
            true_big,
            block_anchor_sums,
        )

    return {
        "anchors":
            anchors,
        "metrics": {
            key:
                finish_stat(
                    value
                )
            for key, value
            in stats.items()
        },
        "anchor_mse": {
            key:
                np.asarray(
                    value,
                    dtype=np.float32,
                )
            for key, value
            in anchor_mse.items()
        },
        "channel_direct_mse":
            channel_sse_direct
            / channel_count,
        "channel_shrink_mse":
            channel_sse_shrink
            / channel_count,
        "raw_mean_alpha":
            raw_alpha_sum
            / n_pairs,
        "shrink_mean_alpha":
            shrink_alpha_sum
            / n_pairs,
        "oracle_mean_alpha":
            oracle_alpha_sum
            / n_pairs,
        "oracle_positive_fraction":
            oracle_positive
            / n_pairs,
    }

# %%
def moving_block_bootstrap(
    difference,
    n_boot=5000,
    block=24,
    seed=222222,
):
    x = np.asarray(
        difference,
        dtype=np.float64,
    )

    n = len(
        x
    )

    L = min(
        block,
        n,
    )

    rng = np.random.default_rng(
        seed
    )

    n_blocks = int(
        np.ceil(
            n
            / L
        )
    )

    max_start = max(
        1,
        n
        - L
        + 1,
    )

    boot = np.empty(
        n_boot,
        dtype=np.float64,
    )

    for b in range(
        n_boot
    ):
        starts = rng.integers(
            0,
            max_start,
            size=n_blocks,
        )

        sample = np.concatenate(
            [
                x[
                    s:
                    s+L
                ]
                for s in starts
            ]
        )[
            :n
        ]

        boot[
            b
        ] = sample.mean()

    return {
        "MeanImprovement":
            float(
                x.mean()
            ),
        "CI_Low":
            float(
                np.quantile(
                    boot,
                    0.025,
                )
            ),
        "CI_High":
            float(
                np.quantile(
                    boot,
                    0.975,
                )
            ),
    }

# %%
def _ret_pattern_np(x):
    x = np.asarray(
        x,
        dtype=np.float32,
    )

    xc = x - x.mean(
        axis=-1,
        keepdims=True,
    )

    norm = np.linalg.norm(
        xc,
        axis=-1,
        keepdims=True,
    )

    return np.where(
        norm > EPS,
        xc / np.maximum(
            norm,
            EPS,
        ),
        0.0,
    ).astype(
        np.float32
    )


def _ret_extract_channel(
    z,
    channel,
    anchors,
    horizon,
):
    anchors = np.asarray(
        anchors,
        dtype=np.int64,
    )

    pi = (
        anchors[:, None]
        - RET_SEQ_LEN
        + np.arange(
            RET_SEQ_LEN
        )[None, :]
    )

    fi = (
        anchors[:, None]
        + np.arange(
            horizon
        )[None, :]
    )

    past = z[
        pi,
        channel,
    ].astype(
        np.float32
    )

    future = z[
        fi,
        channel,
    ].astype(
        np.float32
    )

    current = z[
        anchors - 1,
        channel,
    ].astype(
        np.float32
    )

    future_residual = (
        future
        - current[:, None]
    ).astype(
        np.float32
    )

    return (
        past,
        future_residual,
    )


def _ret_soft_targets(dist):
    dist = np.asarray(
        dist,
        dtype=np.float32,
    )

    mu = dist.mean(
        axis=1,
        keepdims=True,
    )

    sd = dist.std(
        axis=1,
        keepdims=True,
    )

    sd = np.maximum(
        sd,
        1e-6,
    )

    zdist = (
        dist - mu
    ) / sd

    logits = (
        -zdist
        / RETRIEVER_TAU
    )

    logits = (
        logits
        - logits.max(
            axis=1,
            keepdims=True,
        )
    )

    p = np.exp(
        logits
    ).astype(
        np.float32
    )

    p /= np.maximum(
        p.sum(
            axis=1,
            keepdims=True,
        ),
        1e-12,
    )

    return p.astype(
        np.float32
    )


# Fail early if any retriever-preparation dependency is missing.
_required_33c_retriever_helpers = [
    "_ret_extract_channel",
    "_ret_pattern_np",
    "_ret_soft_targets",
]

for _name in _required_33c_retriever_helpers:
    if _name not in globals():
        raise RuntimeError(
            f"Missing 33C retriever helper: {_name}"
        )

print(
    "PASS: 33C retriever preprocessing helpers are available."
)
# Out:
# PASS: 33C retriever preprocessing helpers are available.

# %%
def c33c_balanced_pair_schedule(
    query_anchors,
    C,
    channels_per_query,
    seed,
):
    query_anchors = np.asarray(
        query_anchors,
        dtype=np.int64,
    )

    if not (
        1
        <= channels_per_query
        <= C
    ):
        raise ValueError(
            f"channels_per_query={channels_per_query}, C={C}"
        )

    rng = np.random.default_rng(seed)
    perm = rng.permutation(C).astype(np.int64)

    offsets = np.arange(
        channels_per_query,
        dtype=np.int64,
    )

    pair_anchor = np.repeat(
        query_anchors,
        channels_per_query,
    )

    pair_channel = np.empty(
        len(pair_anchor),
        dtype=np.int16,
    )

    # Step by channels_per_query. gcd(32,321)=1, so the start position
    # eventually traverses every position of the permuted channel ring.
    for j in range(len(query_anchors)):
        start = (
            j
            * channels_per_query
        ) % C

        ids = (
            start
            + offsets
        ) % C

        sl = slice(
            j * channels_per_query,
            (j + 1) * channels_per_query,
        )

        pair_channel[sl] = perm[ids].astype(
            np.int16
        )

    return pair_anchor, pair_channel


def c33c_channel_coverage_table(
    pair_anchor,
    pair_channel,
    train_mask,
    val_mask,
    C,
):
    total = np.bincount(
        pair_channel.astype(np.int64),
        minlength=C,
    )

    train = np.bincount(
        pair_channel[train_mask].astype(np.int64),
        minlength=C,
    )

    val = np.bincount(
        pair_channel[val_mask].astype(np.int64),
        minlength=C,
    )

    return pd.DataFrame({
        "Channel": np.arange(C),
        "TotalPairs": total,
        "TrainPairs": train,
        "ValPairs": val,
    })

# %%
def c33c_prepare_retriever_problem(
    z,
    prefix,
    horizon,
    query_stride=RETRIEVER_QUERY_STRIDE,
):
    prefix = int(prefix)
    horizon = int(horizon)
    C = z.shape[1]

    memory_end = int(
        RETRIEVER_MEMORY_FRACTION
        * prefix
    )

    memory_end = max(
        memory_end,
        RET_SEQ_LEN
        + horizon
        + MEMORY_STRIDE,
    )

    memory_anchors = np.arange(
        RET_SEQ_LEN,
        memory_end - horizon + 1,
        MEMORY_STRIDE,
        dtype=np.int64,
    )

    if len(memory_anchors) < TOP_K:
        raise ValueError(
            f"Too few memory candidates: prefix={prefix}, H={horizon}"
        )

    m_use = min(
        RETRIEVER_CANDIDATE_M,
        len(memory_anchors),
    )

    q_last = prefix - horizon

    if q_last < memory_end:
        raise ValueError(
            f"No retriever supervision interval: prefix={prefix}, H={horizon}"
        )

    query_anchors = np.arange(
        memory_end,
        q_last + 1,
        query_stride,
        dtype=np.int64,
    )

    if len(query_anchors) < 4:
        raise ValueError(
            f"Too few retriever queries: H={horizon}"
        )

    pair_anchor, candidate_channel = c33c_balanced_pair_schedule(
        query_anchors,
        C,
        C33C_CHANNELS_PER_QUERY,
        C33C_CHANNEL_SCHEDULE_SEED + horizon,
    )

    n_pairs = len(pair_anchor)

    # Keep only memory past for training. Memory futures are processed
    # one channel at a time and discarded after future-distance labels
    # have been generated.
    memory_past = np.empty(
        (
            C,
            len(memory_anchors),
            RET_SEQ_LEN,
        ),
        dtype=np.float32,
    )

    query_past = np.empty(
        (
            n_pairs,
            RET_SEQ_LEN,
        ),
        dtype=np.float32,
    )

    candidate_idx = np.empty(
        (
            n_pairs,
            m_use,
        ),
        dtype=np.int32,
    )

    future_dist = np.empty(
        (
            n_pairs,
            m_use,
        ),
        dtype=np.float32,
    )

    print(
        f"33C prep H={horizon} | "
        f"query anchors={len(query_anchors)} | "
        f"pairs={n_pairs:,} | "
        f"all-channel naive pairs={len(query_anchors)*C:,} | "
        f"sampling ratio={n_pairs/(len(query_anchors)*C):.3f}"
    )

    for c in range(C):
        mem_past_c, mem_future_c = _ret_extract_channel(
            z,
            c,
            memory_anchors,
            horizon,
        )

        memory_past[c] = mem_past_c
        mem_pattern_c = _ret_pattern_np(
            mem_past_c
        )

        ids = np.where(
            candidate_channel.astype(np.int64)
            == c
        )[0]

        if len(ids) == 0:
            continue

        q_anchor_c = pair_anchor[ids]

        qpast, qfuture = _ret_extract_channel(
            z,
            c,
            q_anchor_c,
            horizon,
        )

        qpat = _ret_pattern_np(
            qpast
        )

        sim = (
            qpat
            @ mem_pattern_c.T
        )

        if m_use < sim.shape[1]:
            idx0 = np.argpartition(
                sim,
                -m_use,
                axis=1,
            )[:, -m_use:]

            score0 = np.take_along_axis(
                sim,
                idx0,
                axis=1,
            )

            order = np.argsort(
                -score0,
                axis=1,
            )

            idx = np.take_along_axis(
                idx0,
                order,
                axis=1,
            )
        else:
            idx = np.argsort(
                -sim,
                axis=1,
            )[:, :m_use]

        cand_future = mem_future_c[
            idx
        ]

        dist = (
            (
                cand_future
                - qfuture[:, None, :]
            ) ** 2
        ).mean(
            axis=2
        ).astype(
            np.float32
        )

        query_past[ids] = qpast
        candidate_idx[ids] = idx.astype(
            np.int32
        )
        future_dist[ids] = dist

        if (
            c == 0
            or (c + 1) % 50 == 0
            or c + 1 == C
        ):
            print(
                f"  prepared channel {c+1}/{C}"
            )

        del (
            mem_past_c,
            mem_future_c,
            mem_pattern_c,
            qpast,
            qfuture,
            qpat,
            sim,
            idx,
            cand_future,
            dist,
        )

    target_prob = _ret_soft_targets(
        future_dist
    )

    unique_a = np.unique(
        pair_anchor
    )

    cut_n = max(
        1,
        min(
            len(unique_a) - 1,
            int(
                RETRIEVER_PHASEA_TRAIN_FRACTION
                * len(unique_a)
            ),
        ),
    )

    cut_anchor = unique_a[
        cut_n
    ]

    train_mask = (
        pair_anchor
        < cut_anchor
    )

    val_mask = (
        pair_anchor
        >= cut_anchor
    )

    if (
        train_mask.sum() == 0
        or val_mask.sum() == 0
    ):
        raise RuntimeError(
            "Invalid 33C internal chronological split."
        )

    coverage = c33c_channel_coverage_table(
        pair_anchor,
        candidate_channel,
        train_mask,
        val_mask,
        C,
    )

    if (
        coverage["TrainPairs"].min() <= 0
        or coverage["ValPairs"].min() <= 0
    ):
        display(
            coverage.sort_values(
                "ValPairs"
            ).head(20)
        )
        raise RuntimeError(
            "33C channel schedule failed to expose every channel "
            "in both internal train and validation."
        )

    print(
        "Channel coverage | "
        f"train min/max={coverage['TrainPairs'].min()}/"
        f"{coverage['TrainPairs'].max()} | "
        f"val min/max={coverage['ValPairs'].min()}/"
        f"{coverage['ValPairs'].max()}"
    )

    return {
        "prefix": prefix,
        "memory_end": memory_end,
        "memory_anchors": memory_anchors,
        "memory_past": memory_past,
        "query_past": query_past,
        "candidate_idx": candidate_idx,
        "candidate_channel": candidate_channel,
        "future_dist": future_dist,
        "target_prob": target_prob,
        "pair_anchor": pair_anchor,
        "train_ids":
            np.where(train_mask)[0].astype(np.int64),
        "val_ids":
            np.where(val_mask)[0].astype(np.int64),
        "all_ids":
            np.arange(n_pairs, dtype=np.int64),
        "candidate_m": m_use,
        "coverage": coverage,
        "query_anchor_count": len(query_anchors),
    }

# %%
def c33c_retriever_batch_loss(
    model,
    problem,
    ids,
):
    ids = np.asarray(
        ids,
        dtype=np.int64,
    )

    q_np = problem[
        "query_past"
    ][ids]

    ch = problem[
        "candidate_channel"
    ][ids].astype(
        np.int64
    )

    ci = problem[
        "candidate_idx"
    ][ids].astype(
        np.int64
    )

    cand_np = problem[
        "memory_past"
    ][
        ch[:, None],
        ci,
    ]

    tgt_np = problem[
        "target_prob"
    ][ids]

    q = torch.from_numpy(
        q_np
    ).to(DEVICE)

    cand = torch.from_numpy(
        cand_np.reshape(
            -1,
            RET_SEQ_LEN,
        )
    ).to(DEVICE)

    target = torch.from_numpy(
        tgt_np
    ).to(DEVICE)

    qemb = model.encode(q)

    cemb = model.encode(
        cand
    ).reshape(
        len(ids),
        problem["candidate_m"],
        REP_DIM,
    )

    score = (
        model.gamma
        * torch.einsum(
            "bd,bmd->bm",
            qemb,
            cemb,
        )
    )

    loss = -(
        target
        * F.log_softmax(
            score,
            dim=1,
        )
    ).sum(
        dim=1
    ).mean()

    return loss


def c33c_train_one_epoch(
    model,
    optimizer,
    problem,
    ids,
    rng,
):
    model.train()

    order = np.asarray(
        ids,
        dtype=np.int64,
    ).copy()

    rng.shuffle(
        order
    )

    group_losses = []

    for left in range(
        0,
        len(order),
        C33C_EFFECTIVE_BATCH_QUERIES,
    ):
        group = order[
            left:
            left + C33C_EFFECTIVE_BATCH_QUERIES
        ]

        if len(group) == 0:
            continue

        optimizer.zero_grad(
            set_to_none=True
        )

        total_group_loss = 0.0

        for mleft in range(
            0,
            len(group),
            C33C_MICRO_BATCH_QUERIES,
        ):
            micro = group[
                mleft:
                mleft
                + C33C_MICRO_BATCH_QUERIES
            ]

            loss = c33c_retriever_batch_loss(
                model,
                problem,
                micro,
            )

            weight = (
                float(len(micro))
                / float(len(group))
            )

            (
                loss
                * weight
            ).backward()

            total_group_loss += (
                float(loss.item())
                * weight
            )

            del loss

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            RETRIEVER_GRAD_CLIP,
        )

        optimizer.step()

        group_losses.append(
            total_group_loss
        )

    return float(
        np.mean(group_losses)
    )


@torch.no_grad()
def c33c_val_analog_mse(
    model,
    problem,
    ids,
):
    model.eval()

    total = 0.0
    count = 0

    for left in range(
        0,
        len(ids),
        C33C_MICRO_BATCH_QUERIES,
    ):
        bid = ids[
            left:
            left
            + C33C_MICRO_BATCH_QUERIES
        ]

        q_np = problem[
            "query_past"
        ][bid]

        ch = problem[
            "candidate_channel"
        ][bid].astype(
            np.int64
        )

        ci = problem[
            "candidate_idx"
        ][bid].astype(
            np.int64
        )

        cand_np = problem[
            "memory_past"
        ][
            ch[:, None],
            ci,
        ]

        q = torch.from_numpy(
            q_np
        ).to(DEVICE)

        cand = torch.from_numpy(
            cand_np.reshape(
                -1,
                RET_SEQ_LEN,
            )
        ).to(DEVICE)

        with ret_amp():
            qemb = model.encode(
                q
            )

            cemb = model.encode(
                cand
            ).reshape(
                len(bid),
                problem["candidate_m"],
                REP_DIM,
            )

        score = (
            model.gamma.float()
            * torch.einsum(
                "bd,bmd->bm",
                qemb.float(),
                cemb.float(),
            )
        )

        k = min(
            TOP_K,
            score.shape[1],
        )

        top = torch.topk(
            score,
            k,
            dim=1,
        ).indices.cpu().numpy()

        d = problem[
            "future_dist"
        ][bid]

        selected = np.take_along_axis(
            d,
            top,
            axis=1,
        )

        total += float(
            selected.sum()
        )

        count += selected.size

        del (
            q,
            cand,
            qemb,
            cemb,
            score,
        )

    return (
        total
        / max(
            count,
            1,
        )
    )

# %% [markdown]
# ## 34B.1 Configuration and preflight

# %%
PILOT_BACKBONE = "iTransformer"
OOF_HORIZONS = [192, 336, 720]

OOF_FOLDS = [
    (0.55, 0.70),
    (0.70, 0.85),
    (0.85, 1.00),
]

if n_channels != 321:
    raise RuntimeError(
        f"34B requires exactly 321 Electricity channels; got {n_channels}."
    )

EXP32_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_full321_frozen_transfer_standard"
)

EXP33C_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_full321_channel_exposed_retriever"
)

EXP34A_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_full321_oof_pilot_itransformer_h96"
)

EXP34B_ROOT = Path(
    "/data/dataset/strong_forecaster/"
    "electricity_full321_oof_itransformer_h192_336_720"
)
EXP34B_ROOT.mkdir(parents=True, exist_ok=True)

# Inherited checkpoint/cache helpers use global ROOT and SHARED_MEMORY_EMB_DIR.
ROOT = EXP34B_ROOT

SHARED_MEMORY_EMB_DIR = (
    EXP34B_ROOT
    / "memory_embeddings"
)
SHARED_MEMORY_EMB_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

ARTIFACT_DIR = (
    EXP34B_ROOT
    / "artifacts"
)
ARTIFACT_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

CURRENT_BACKBONE = PILOT_BACKBONE
activate_backbone(PILOT_BACKBONE)
DIRS = backbone_dirs(PILOT_BACKBONE)

# Same channel-exposed retriever recipe as 33C/34A.
C33C_CHANNELS_PER_QUERY = 32
C33C_CHANNEL_SCHEDULE_SEED = 33003
C33C_EFFECTIVE_BATCH_QUERIES = 32
C33C_MICRO_BATCH_QUERIES = 8

SUMMARY_34B = EXP34B_ROOT / "summary.csv"
BOOTSTRAP_34B = EXP34B_ROOT / "bootstrap.csv"

print("34B root:", EXP34B_ROOT)
print("Backbone:", PILOT_BACKBONE)
print("Horizons:", OOF_HORIZONS)
print("Channels:", n_channels)
print("OOF folds:", OOF_FOLDS)

# Validate all final direct checkpoints before starting.
audit = []

for horizon in OOF_HORIZONS:
    p = (
        EXP32_ROOT
        / PILOT_BACKBONE
        / "full_direct"
        / f"Electricity_{PILOT_BACKBONE}_H{horizon}.pt"
    )

    if not p.is_file():
        audit.append({
            "Horizon": horizon,
            "Exists": False,
            "Protocol": None,
            "BestEpoch": None,
            "Path": str(p),
        })
        continue

    ck = load_torch(p)

    audit.append({
        "Horizon": horizon,
        "Exists": True,
        "Protocol": ck.get("Protocol", None),
        "BestEpoch": ck.get("BestEpoch", None),
        "Path": str(p),
    })

audit = pd.DataFrame(audit)
display(audit)

bad = audit[
    (~audit["Exists"])
    | (audit["Protocol"] != "Full321_FrozenTransfer")
]

if len(bad):
    display(bad)
    raise RuntimeError(
        "34B preflight failed: missing or invalid Experiment-32 full direct checkpoint."
    )

print("PASS: H=192/336/720 full-321 direct checkpoints are valid.")

# Final retrievers are optional: a missing one is trained as a fallback later.
for horizon in OOF_HORIZONS:
    p = (
        EXP33C_ROOT
        / "retriever"
        / (
            f"ElectricityFull321_H{horizon}_"
            "ChannelExposedRetriever.pt"
        )
    )
    print(
        f"H={horizon} final 33C retriever:",
        "FOUND" if p.is_file() else "MISSING -> 34B fallback training",
    )
# Out:
# Activated iTransformer: /code/stock_regime_retrieval/strong_forecaster/iTransformer_official/model/iTransformer.py
# 34B root: /data/dataset/strong_forecaster/electricity_full321_oof_itransformer_h192_336_720
# Backbone: iTransformer
# Horizons: [192, 336, 720]
# Channels: 321
# OOF folds: [(0.55, 0.7), (0.7, 0.85), (0.85, 1.0)]
#    Horizon  Exists                Protocol  BestEpoch                                               Path
# 0      192    True  Full321_FrozenTransfer          8  /data/dataset/strong_forecaster/electricity_fu...
# 1      336    True  Full321_FrozenTransfer          7  /data/dataset/strong_forecaster/electricity_fu...
# 2      720    True  Full321_FrozenTransfer          3  /data/dataset/strong_forecaster/electricity_fu...
# PASS: H=192/336/720 full-321 direct checkpoints are valid.
# H=192 final 33C retriever: FOUND
# H=336 final 33C retriever: FOUND
# H=720 final 33C retriever: FOUND

# %% [markdown]
# ## 34B.2 Horizon-specific paths and final direct loader

# %%
def exp32_direct_path_34b(horizon):
    return (
        EXP32_ROOT
        / PILOT_BACKBONE
        / "full_direct"
        / f"Electricity_{PILOT_BACKBONE}_H{horizon}.pt"
    )


def exp33c_retriever_path_34b(horizon):
    return (
        EXP33C_ROOT
        / "retriever"
        / (
            f"ElectricityFull321_H{horizon}_"
            "ChannelExposedRetriever.pt"
        )
    )


def load_exp32_full_direct_34b(horizon):
    model, _ = build_direct_model(
        PILOT_BACKBONE,
        horizon,
    )

    path = exp32_direct_path_34b(
        horizon
    )

    ckpt = load_torch(path)

    if (
        ckpt.get("Protocol")
        != "Full321_FrozenTransfer"
    ):
        raise RuntimeError(
            f"Invalid final direct protocol H={horizon}."
        )

    model.load_state_dict(
        ckpt["StateDict"],
        strict=True,
    )

    model.eval()

    print(
        f"Loaded full direct | {PILOT_BACKBONE} H={horizon} | "
        f"best={ckpt['BestValMSE']:.6f}@{ckpt['BestEpoch']}"
    )

    return model, ckpt

# %% [markdown]
# ## 34B.3 Fold-specific full-321 iTransformer
#
# 각 horizon의 fold direct model은 Experiment 32의 해당 horizon에서 선택된 `BestEpoch` 수만큼
# 학습합니다. Architecture/optimizer와 full-channel micro/effective batch는 34A와 동일합니다.

# %%
FOLD_DIRECT_DIR_34B = (
    EXP34B_ROOT
    / "fold_direct"
)
FOLD_DIRECT_DIR_34B.mkdir(
    parents=True,
    exist_ok=True,
)


def fold_direct_path_34b(
    horizon,
    fold,
):
    return (
        FOLD_DIRECT_DIR_34B
        / (
            f"ElectricityFull321_{PILOT_BACKBONE}_"
            f"H{horizon}_F{fold}.pt"
        )
    )


def train_or_load_fold_direct_34b(
    z_fold,
    prefix,
    horizon,
    fold,
    fixed_epochs,
):
    path = fold_direct_path_34b(
        horizon,
        fold,
    )

    model, _ = build_direct_model(
        PILOT_BACKBONE,
        horizon,
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        ckpt = load_torch(path)

        if (
            ckpt.get("Protocol")
            != "Full321OOFDirect34B"
            or int(ckpt.get("Horizon", -1)) != int(horizon)
        ):
            raise RuntimeError(
                f"Invalid 34B fold direct checkpoint: {path}"
            )

        model.load_state_dict(
            ckpt["StateDict"],
            strict=True,
        )
        model.eval()

        print(
            f"Loaded fold direct H={horizon} F{fold} | "
            f"prefix={ckpt['Prefix']} | epochs={ckpt['FixedEpochs']}"
        )

        return model, ckpt

    r = DIRECT_RECIPES[
        PILOT_BACKBONE
    ]

    micro_batch = int(
        r["batch_size"]
    )
    effective_batch = int(
        r["effective_batch_size"]
    )

    if effective_batch % micro_batch != 0:
        raise RuntimeError(
            "34B effective batch must be divisible by micro batch."
        )

    seed = (
        int(r["seed"])
        + 34_200
        + int(horizon) * 10
        + int(fold)
    )

    set_seed(seed)

    anchors = train_anchors_for_direct(
        PILOT_BACKBONE,
        prefix,
        horizon,
    )

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=r["learning_rate"],
        weight_decay=r["weight_decay"],
    )

    rng = np.random.default_rng(
        seed + 1
    )

    history = []

    for epoch in range(
        1,
        int(fixed_epochs) + 1,
    ):
        model.train()

        current_lr = set_epoch_lr_type1(
            optimizer,
            r["learning_rate"],
            epoch,
        )

        order = rng.permutation(
            anchors
        )

        group_losses = []
        et0 = time.time()

        for left in range(
            0,
            len(order),
            effective_batch,
        ):
            group = order[
                left:
                left + effective_batch
            ]

            if len(group) == 0:
                continue

            optimizer.zero_grad(
                set_to_none=True
            )

            group_loss = 0.0

            for mleft in range(
                0,
                len(group),
                micro_batch,
            ):
                a = group[
                    mleft:
                    mleft + micro_batch
                ]

                x, y = make_direct_batch(
                    z_fold,
                    a,
                    PILOT_BACKBONE,
                    horizon,
                )

                pred, true, _ = forward_direct(
                    PILOT_BACKBONE,
                    model,
                    x,
                    y,
                    horizon,
                )

                loss = F.mse_loss(
                    pred,
                    true,
                )

                weight = (
                    float(len(a))
                    / float(len(group))
                )

                (
                    loss
                    * weight
                ).backward()

                group_loss += (
                    float(loss.item())
                    * weight
                )

                del (
                    x,
                    y,
                    pred,
                    true,
                    loss,
                )

            optimizer.step()
            group_losses.append(group_loss)

        epoch_minutes = (
            time.time()
            - et0
        ) / 60.0

        train_mse = float(
            np.mean(group_losses)
        )

        history.append({
            "Epoch": epoch,
            "TrainMSE": train_mse,
            "LR": current_lr,
            "Minutes": epoch_minutes,
        })

        print(
            f"34B FoldDirect H={horizon} F{fold} "
            f"ep={epoch:02d}/{fixed_epochs:02d} | "
            f"train={train_mse:.6f} | "
            f"{epoch_minutes:.1f} min"
        )

    hist_dir = (
        EXP34B_ROOT
        / "history"
    )
    hist_dir.mkdir(
        parents=True,
        exist_ok=True,
    )

    pd.DataFrame(history).to_csv(
        hist_dir
        / f"fold_direct_H{horizon}_F{fold}.csv",
        index=False,
    )

    ckpt = {
        "Protocol":
            "Full321OOFDirect34B",
        "Backbone":
            PILOT_BACKBONE,
        "Dataset":
            "ElectricityFull321",
        "Horizon":
            int(horizon),
        "Fold":
            int(fold),
        "Prefix":
            int(prefix),
        "FixedEpochs":
            int(fixed_epochs),
        "Seed":
            int(seed),
        "StateDict": {
            k: v.detach().cpu().clone()
            for k, v in model.state_dict().items()
        },
    }

    torch.save(
        ckpt,
        path,
    )

    model.eval()

    return model, ckpt

# %% [markdown]
# ## 34B.4 Fold-specific channel-exposed retrievers

# %%
FOLD_RETRIEVER_DIR_34B = (
    EXP34B_ROOT
    / "fold_retriever"
)
FOLD_RETRIEVER_DIR_34B.mkdir(
    parents=True,
    exist_ok=True,
)


def retriever_path_34b(
    horizon,
    tag,
):
    return (
        FOLD_RETRIEVER_DIR_34B
        / (
            f"ElectricityFull321_H{horizon}_"
            f"{tag}_ChannelExposedRetriever34B.pt"
        )
    )


def train_or_load_retriever_34b(
    z_prefix,
    prefix,
    horizon,
    tag,
    seed_offset,
):
    path = retriever_path_34b(
        horizon,
        tag,
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        ckpt = load_torch(path)

        if (
            ckpt.get("Protocol")
            != "Full321ChannelExposedRetriever34B"
            or int(ckpt.get("Horizon", -1)) != int(horizon)
        ):
            raise RuntimeError(
                f"Invalid 34B retriever checkpoint: {path}"
            )

        print(
            f"Loaded 34B retriever H={horizon} {tag} | "
            f"bestEpoch={ckpt['BestEpoch']} | "
            f"valAnalog={ckpt['BestValAnalogMSE']:.6f}"
        )

        return path, ckpt

    prep_t0 = time.time()

    problem = c33c_prepare_retriever_problem(
        z_prefix,
        prefix,
        horizon,
    )

    coverage_path = (
        FOLD_RETRIEVER_DIR_34B
        / f"H{horizon}_{tag}_channel_coverage.csv"
    )

    problem["coverage"].to_csv(
        coverage_path,
        index=False,
    )

    seed = (
        RETRIEVER_SEED
        + 34_200
        + int(horizon) * 10
        + int(seed_offset)
    )

    # Phase A: chronological internal validation selects epoch.
    set_seed(seed)

    model = EmbeddingOnlyRetriever().to(
        DEVICE
    )

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=RETRIEVER_LR,
        weight_decay=RETRIEVER_WD,
    )

    rng = np.random.default_rng(
        seed + 1
    )

    best_val = float("inf")
    best_epoch = 1
    wait = 0
    hist = []

    for epoch in range(
        1,
        RETRIEVER_MAX_EPOCHS + 1,
    ):
        et0 = time.time()

        train_loss = c33c_train_one_epoch(
            model,
            optimizer,
            problem,
            problem["train_ids"],
            rng,
        )

        val_mse = c33c_val_analog_mse(
            model,
            problem,
            problem["val_ids"],
        )

        epoch_minutes = (
            time.time()
            - et0
        ) / 60.0

        hist.append({
            "Epoch": epoch,
            "TrainLoss": train_loss,
            "ValAnalogMSE": val_mse,
            "Gamma": float(
                model.gamma.detach().cpu()
            ),
            "EpochMinutes": epoch_minutes,
        })

        print(
            f"34B Retriever H={horizon} {tag} "
            f"ep={epoch:02d} | "
            f"loss={train_loss:.6f} | "
            f"valAnalog={val_mse:.6f} | "
            f"{epoch_minutes:.1f} min | "
            f"best={best_val:.6f}@{best_epoch}"
        )

        if (
            val_mse
            < best_val - 1e-10
        ):
            best_val = val_mse
            best_epoch = epoch
            wait = 0
        else:
            wait += 1

        if wait >= RETRIEVER_PATIENCE:
            break

    pd.DataFrame(hist).to_csv(
        FOLD_RETRIEVER_DIR_34B
        / f"H{horizon}_{tag}_phaseA_history.csv",
        index=False,
    )

    del model, optimizer
    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Phase B: reinitialize and refit all sampled pairs.
    set_seed(seed)

    model = EmbeddingOnlyRetriever().to(
        DEVICE
    )

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=RETRIEVER_LR,
        weight_decay=RETRIEVER_WD,
    )

    rng = np.random.default_rng(
        seed + 2
    )

    refit_hist = []

    for epoch in range(
        1,
        best_epoch + 1,
    ):
        et0 = time.time()

        loss = c33c_train_one_epoch(
            model,
            optimizer,
            problem,
            problem["all_ids"],
            rng,
        )

        epoch_minutes = (
            time.time()
            - et0
        ) / 60.0

        refit_hist.append({
            "Epoch": epoch,
            "TrainLoss": loss,
            "Gamma": float(
                model.gamma.detach().cpu()
            ),
            "EpochMinutes": epoch_minutes,
        })

        print(
            f"34B Refit H={horizon} {tag} "
            f"ep={epoch:02d}/{best_epoch:02d} | "
            f"loss={loss:.6f} | "
            f"{epoch_minutes:.1f} min"
        )

    pd.DataFrame(refit_hist).to_csv(
        FOLD_RETRIEVER_DIR_34B
        / f"H{horizon}_{tag}_phaseB_history.csv",
        index=False,
    )

    total_minutes = (
        time.time()
        - prep_t0
    ) / 60.0

    ckpt = {
        "Protocol":
            "Full321ChannelExposedRetriever34B",
        "Dataset":
            "ElectricityFull321",
        "Horizon":
            int(horizon),
        "Tag":
            str(tag),
        "Prefix":
            int(prefix),
        "BestEpoch":
            int(best_epoch),
        "BestValAnalogMSE":
            float(best_val),
        "Gamma":
            float(model.gamma.detach().cpu()),
        "TotalTrainingMinutes":
            float(total_minutes),
        "StateDict": {
            k: v.detach().cpu().clone()
            for k, v in model.state_dict().items()
        },
    }

    torch.save(
        ckpt,
        path,
    )

    print(
        f"SAVED 34B retriever H={horizon} {tag} | "
        f"bestEpoch={best_epoch} | total={total_minutes:.1f} min"
    )

    del model, problem
    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return path, ckpt

# %% [markdown]
# ## 34B.5 Build/load three OOF folds per horizon

# %%
OOF_DIR_34B = (
    EXP34B_ROOT
    / "oof"
)
OOF_DIR_34B.mkdir(
    parents=True,
    exist_ok=True,
)


def oof_path_34b(
    horizon,
    fold,
):
    return (
        OOF_DIR_34B
        / (
            f"ElectricityFull321_iTransformer_"
            f"H{horizon}_F{fold}_oof.npz"
        )
    )


def build_oof_fold_34b(
    horizon,
    fold,
    p0,
    p1,
    fixed_epochs,
):
    out_path = oof_path_34b(
        horizon,
        fold,
    )

    if (
        RESUME
        and out_path.is_file()
        and not FORCE
    ):
        obj = np.load(out_path)

        out = {
            key: obj[key]
            for key in [
                "feature",
                "abc",
                "anchor",
                "channel",
            ]
        }

        uc = np.unique(
            out["channel"]
        )

        if (
            len(uc) == 321
            and int(uc.min()) == 0
            and int(uc.max()) == 320
        ):
            print(
                f"Loaded 34B OOF H={horizon} F{fold}: "
                f"{len(out['abc']):,} pairs"
            )
            return out

        print(
            f"Ignoring incompatible 34B OOF H={horizon} F{fold}."
        )

    prefix = int(
        p0
        * train_end
    )

    oof_end = int(
        p1
        * train_end
    )

    z_fold, scaler = prefix_normalize(
        raw,
        prefix,
    )

    direct_model, _ = train_or_load_fold_direct_34b(
        z_fold,
        prefix,
        horizon,
        fold,
        fixed_epochs,
    )

    retriever_path, _ = train_or_load_retriever_34b(
        z_fold,
        prefix,
        horizon,
        tag=f"F{fold}",
        seed_offset=fold,
    )

    retriever, _ = load_frozen_retriever(
        retriever_path
    )

    memory = build_memory(
        z_fold,
        n_channels,
        prefix,
        horizon,
    )

    memory_gpu_obj = memory_gpu_cached(
        "ElectricityFull321_34B",
        horizon,
        f"OOF_F{fold}_prefix{prefix}",
        retriever,
        memory,
        n_channels,
    )

    anchors = eval_anchors(
        prefix,
        oof_end,
        horizon,
        stride=OOF_ANCHOR_STRIDE,
        lookback=direct_seq_len(
            PILOT_BACKBONE
        ),
    )

    print(
        f"34B OOF H={horizon} F{fold} | "
        f"prefix={prefix} | end={oof_end} | "
        f"anchors={len(anchors):,} | "
        f"pairs={len(anchors)*n_channels:,} | "
        f"memory/C={memory['M']}"
    )

    out = collect_gate_data(
        DATA["Electricity"],
        horizon,
        direct_model,
        retriever,
        memory_gpu_obj,
        z_fold,
        anchors,
    )

    uc = np.unique(
        out["channel"]
    )

    if len(uc) != 321:
        raise RuntimeError(
            f"OOF H={horizon} F{fold} missing channels: {len(uc)}."
        )

    np.savez_compressed(
        out_path,
        **out,
    )

    print(
        f"Saved OOF H={horizon} F{fold}: "
        f"{len(out['abc']):,} pairs"
    )

    del (
        direct_model,
        retriever,
        memory,
        memory_gpu_obj,
        z_fold,
        scaler,
    )

    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return out

# %% [markdown]
# ## 34B.6 Final retriever and validation cache

# %%
VALIDATION_DIR_34B = (
    EXP34B_ROOT
    / "validation"
)
VALIDATION_DIR_34B.mkdir(
    parents=True,
    exist_ok=True,
)


def get_full_retriever_34b(
    horizon,
):
    p = exp33c_retriever_path_34b(
        horizon
    )

    if p.is_file():
        ckpt = load_torch(p)

        if (
            ckpt.get("Protocol")
            != "Full321ChannelExposedRetriever33C"
        ):
            raise RuntimeError(
                f"Unexpected Experiment-33C retriever protocol H={horizon}."
            )

        print(
            f"Reusing Experiment-33C full retriever H={horizon} | "
            f"bestEpoch={ckpt['BestEpoch']}"
        )

        return p, ckpt

    print(
        f"No Experiment-33C full retriever H={horizon}; "
        "training 34B full-prefix fallback."
    )

    return train_or_load_retriever_34b(
        z_full,
        train_end,
        horizon,
        tag="FullTrain",
        seed_offset=99,
    )


def validation_path_34b(
    horizon,
):
    return (
        VALIDATION_DIR_34B
        / (
            f"ElectricityFull321_iTransformer_"
            f"H{horizon}_validation.npz"
        )
    )


def build_validation_34b(
    horizon,
    full_direct,
    full_retriever,
):
    path = validation_path_34b(
        horizon
    )

    if (
        RESUME
        and path.is_file()
        and not FORCE
    ):
        obj = np.load(path)

        out = {
            key: obj[key]
            for key in [
                "feature",
                "abc",
                "anchor",
                "channel",
            ]
        }

        uc = np.unique(
            out["channel"]
        )

        if len(uc) == 321:
            print(
                f"Loaded 34B validation H={horizon}: "
                f"{len(out['abc']):,} pairs"
            )
            return out

        print(
            f"Ignoring incompatible validation cache H={horizon}."
        )

    memory = build_memory(
        z_full,
        n_channels,
        train_end,
        horizon,
    )

    memory_gpu_obj = memory_gpu_cached(
        "ElectricityFull321_34B",
        horizon,
        "Validation_TrainMemory",
        full_retriever,
        memory,
        n_channels,
    )

    anchors = eval_anchors(
        train_end,
        val_end,
        horizon,
        stride=1,
        lookback=direct_seq_len(
            PILOT_BACKBONE
        ),
    )

    print(
        f"34B validation H={horizon} | "
        f"anchors={len(anchors):,} | "
        f"pairs={len(anchors)*n_channels:,}"
    )

    out = collect_gate_data(
        DATA["Electricity"],
        horizon,
        full_direct,
        full_retriever,
        memory_gpu_obj,
        z_full,
        anchors,
    )

    np.savez_compressed(
        path,
        **out,
    )

    del (
        memory,
        memory_gpu_obj,
    )

    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return out

# %% [markdown]
# ## 34B.7 Run H=192, 336, 720
#
# 각 horizon이 완료될 때마다 `summary.csv`와 `bootstrap.csv`를 즉시 저장합니다.
# 따라서 여러 시간 실행 중 중단되어도 완료된 horizon 결과는 보존됩니다.

# %%
existing_summary = (
    pd.read_csv(SUMMARY_34B)
    if (
        RESUME
        and SUMMARY_34B.is_file()
    )
    else pd.DataFrame()
)

summary_rows = (
    existing_summary.to_dict("records")
    if len(existing_summary)
    else []
)

existing_boot = (
    pd.read_csv(BOOTSTRAP_34B)
    if (
        RESUME
        and BOOTSTRAP_34B.is_file()
    )
    else pd.DataFrame()
)

bootstrap_rows = (
    existing_boot.to_dict("records")
    if len(existing_boot)
    else []
)


def horizon_completed_34b(
    horizon,
):
    if not len(existing_summary):
        return False

    return bool(
        (
            existing_summary["Horizon"]
            == horizon
        ).any()
    )


for horizon in OOF_HORIZONS:
    if horizon_completed_34b(
        horizon
    ):
        print(
            f"SKIP completed 34B H={horizon}"
        )
        continue

    print(
        "\n"
        + "=" * 120
    )
    print(
        f"EXPERIMENT 34B | Electricity Full321 | "
        f"iTransformer | H={horizon}"
    )
    print(
        "=" * 120
    )

    t_h = time.time()

    # 1) Existing final full direct determines horizon-specific fold epoch budget.
    full_direct, full_direct_ckpt = load_exp32_full_direct_34b(
        horizon
    )

    fixed_fold_epochs = int(
        full_direct_ckpt[
            "BestEpoch"
        ]
    )

    if fixed_fold_epochs < 1:
        raise RuntimeError(
            f"Invalid BestEpoch H={horizon}: {fixed_fold_epochs}"
        )

    print(
        f"H={horizon} fold-direct fixed epochs:",
        fixed_fold_epochs,
    )

    # 2) Three chronological OOF folds.
    oof_parts = []

    for fold, (
        p0,
        p1,
    ) in enumerate(
        OOF_FOLDS,
        start=1,
    ):
        fold_out = build_oof_fold_34b(
            horizon,
            fold,
            p0,
            p1,
            fixed_fold_epochs,
        )

        oof_parts.append(
            fold_out
        )

    oof = {
        key:
            np.concatenate(
                [
                    part[key]
                    for part in oof_parts
                ],
                axis=0,
            )
        for key in [
            "feature",
            "abc",
            "anchor",
            "channel",
        ]
    }

    print(
        f"H={horizon} combined OOF | "
        f"pairs={len(oof['abc']):,} | "
        f"anchors={len(np.unique(oof['anchor'])):,} | "
        f"channels={len(np.unique(oof['channel']))}"
    )

    # 3) Full-train retriever used for validation/test.
    full_retriever_path, full_retriever_ckpt = get_full_retriever_34b(
        horizon
    )

    full_retriever, _ = load_frozen_retriever(
        full_retriever_path
    )

    # 4) Standard validation.
    val = build_validation_34b(
        horizon,
        full_direct,
        full_retriever,
    )

    # 5) Gate trained on OOF, best epoch selected on validation.
    gate_name = (
        f"ElectricityFull321_34B_iTransformer_H{horizon}"
    )

    gate, gate_ckpt = train_crossfit_gate(
        gate_name,
        horizon,
        oof["feature"],
        oof["abc"],
        val["feature"],
        val["abc"],
    )

    # 6) Validation-only scalar and shrinkage calibration.
    scalar_alpha, scalar_table = choose_scalar(
        val["abc"]
    )

    scalar_table.to_csv(
        EXP34B_ROOT
        / f"H{horizon}_validation_scalar_alpha.csv",
        index=False,
    )

    val_gate_alpha = gate_alpha(
        gate,
        gate_ckpt,
        val["feature"],
    )

    shrink_lambda, lambda_table = choose_lambda(
        val["abc"],
        val_gate_alpha,
        scalar_alpha,
    )

    lambda_table.to_csv(
        EXP34B_ROOT
        / f"H{horizon}_validation_shrink_lambda.csv",
        index=False,
    )

    val_direct_mse = mse_scalar(
        val["abc"],
        0.0,
    )

    val_scalar_mse = mse_scalar(
        val["abc"],
        scalar_alpha,
    )

    val_raw_gate_mse = mse_pair(
        val["abc"],
        val_gate_alpha,
    )

    val_final_alpha = (
        (1.0 - shrink_lambda)
        * scalar_alpha
        + shrink_lambda
        * val_gate_alpha
    )

    val_final_mse = mse_pair(
        val["abc"],
        val_final_alpha,
    )

    print(
        f"34B validation H={horizon} | "
        f"Direct={val_direct_mse:.6f} | "
        f"Scalar={val_scalar_mse:.6f} (a={scalar_alpha:.2f}) | "
        f"RawGate={val_raw_gate_mse:.6f} | "
        f"Final={val_final_mse:.6f} (lambda={shrink_lambda:.2f}) | "
        f"gain={100*(val_direct_mse-val_final_mse)/val_direct_mse:+.3f}%"
    )

    # 7) Final test, train+validation memory only.
    test_memory = build_memory(
        z_full,
        n_channels,
        val_end,
        horizon,
    )

    test_memory_gpu = memory_gpu_cached(
        "ElectricityFull321_34B",
        horizon,
        "Test_TrainValMemory",
        full_retriever,
        test_memory,
        n_channels,
    )

    test = test_evaluate(
        DATA["Electricity"],
        horizon,
        full_direct,
        full_retriever,
        test_memory_gpu,
        gate,
        gate_ckpt,
        scalar_alpha,
        shrink_lambda,
    )

    metrics = test["metrics"]

    direct_mse, direct_mae = metrics["Direct"]
    retrieval_mse, retrieval_mae = metrics["Retrieval"]
    scalar_mse, scalar_mae = metrics["Scalar"]
    raw_mse, raw_mae = metrics["RawAdaptive"]
    final_mse, final_mae = metrics["ShrinkAdaptive"]
    oracle_mse, oracle_mae = metrics["Oracle"]

    diff = (
        test["anchor_mse"]["Direct"]
        - test["anchor_mse"]["ShrinkAdaptive"]
    )

    boot = moving_block_bootstrap(
        diff,
        n_boot=BOOTSTRAP_REPLICATES,
        block=BOOTSTRAP_BLOCK_LEN,
        seed=(
            341000
            + horizon
        ),
    )

    channel_df = pd.DataFrame({
        "Channel":
            np.arange(n_channels),
        "Direct_MSE":
            test["channel_direct_mse"],
        "OOF_Memory_MSE":
            test["channel_shrink_mse"],
    })

    channel_df["Gain_pct"] = (
        100.0
        * (
            channel_df["Direct_MSE"]
            - channel_df["OOF_Memory_MSE"]
        )
        / channel_df["Direct_MSE"]
    )

    channel_df.to_csv(
        EXP34B_ROOT
        / f"H{horizon}_channel_results.csv",
        index=False,
    )

    improved_channel_fraction = float(
        (
            channel_df["OOF_Memory_MSE"]
            < channel_df["Direct_MSE"]
        ).mean()
    )

    runtime_minutes = (
        time.time()
        - t_h
    ) / 60.0

    row = {
        "Backbone":
            PILOT_BACKBONE,
        "Dataset":
            "ElectricityFull321",
        "Horizon":
            horizon,
        "Channels":
            n_channels,
        "Protocol":
            "Full321OOFCrossFit34B",
        "OOFFolds":
            len(OOF_FOLDS),
        "FoldDirectEpochs":
            fixed_fold_epochs,
        "Direct_MSE":
            direct_mse,
        "Final_MSE":
            final_mse,
        "Direct_MAE":
            direct_mae,
        "Final_MAE":
            final_mae,
        "Retrieval_MSE":
            retrieval_mse,
        "Scalar_MSE":
            scalar_mse,
        "RawAdaptive_MSE":
            raw_mse,
        "Oracle_MSE":
            oracle_mse,
        "ScalarAlpha":
            scalar_alpha,
        "ShrinkLambda":
            shrink_lambda,
        "RawMeanAlpha":
            test["raw_mean_alpha"],
        "FinalMeanAlpha":
            test["shrink_mean_alpha"],
        "Validation_Direct_MSE":
            val_direct_mse,
        "Validation_Final_MSE":
            val_final_mse,
        "Validation_Gain_pct":
            100.0
            * (
                val_direct_mse
                - val_final_mse
            )
            / val_direct_mse,
        "MSEGain_pct":
            100.0
            * (
                direct_mse
                - final_mse
            )
            / direct_mse,
        "MAEGain_pct":
            100.0
            * (
                direct_mae
                - final_mae
            )
            / direct_mae,
        "ImprovedChannelFraction":
            improved_channel_fraction,
        "OracleHeadroom_pct":
            100.0
            * (
                direct_mse
                - oracle_mse
            )
            / direct_mse,
        "GateBestEpoch":
            gate_ckpt["BestEpoch"],
        "RetrieverBestEpoch":
            int(
                full_retriever_ckpt[
                    "BestEpoch"
                ]
            ),
        "TestAnchors":
            len(test["anchors"]),
        "RuntimeMinutes":
            runtime_minutes,
    }

    summary_rows = [
        r
        for r in summary_rows
        if int(
            r.get(
                "Horizon",
                -1,
            )
        ) != horizon
    ]
    summary_rows.append(row)

    bootstrap_row = {
        "Backbone":
            PILOT_BACKBONE,
        "Dataset":
            "ElectricityFull321",
        "Horizon":
            horizon,
        "Comparison":
            "Direct-OOFCrossFitMemory",
        "MeanImprovement":
            boot["MeanImprovement"],
        "CI_Low":
            boot["CI_Low"],
        "CI_High":
            boot["CI_High"],
        "SignificantPositive":
            bool(
                boot["CI_Low"] > 0
            ),
        "SignificantNegative":
            bool(
                boot["CI_High"] < 0
            ),
        "BlockLen":
            BOOTSTRAP_BLOCK_LEN,
        "Replicates":
            BOOTSTRAP_REPLICATES,
    }

    bootstrap_rows = [
        r
        for r in bootstrap_rows
        if int(
            r.get(
                "Horizon",
                -1,
            )
        ) != horizon
    ]
    bootstrap_rows.append(
        bootstrap_row
    )

    pd.DataFrame(
        summary_rows
    ).sort_values(
        "Horizon"
    ).to_csv(
        SUMMARY_34B,
        index=False,
    )

    pd.DataFrame(
        bootstrap_rows
    ).sort_values(
        "Horizon"
    ).to_csv(
        BOOTSTRAP_34B,
        index=False,
    )

    np.savez_compressed(
        EXP34B_ROOT
        / f"H{horizon}_anchor_mse.npz",
        Anchors=test["anchors"],
        Direct=test["anchor_mse"]["Direct"],
        Retrieval=test["anchor_mse"]["Retrieval"],
        Scalar=test["anchor_mse"]["Scalar"],
        RawAdaptive=test["anchor_mse"]["RawAdaptive"],
        Final=test["anchor_mse"]["ShrinkAdaptive"],
        Oracle=test["anchor_mse"]["Oracle"],
    )

    print(
        f"\nH={horizon} RESULT | "
        f"Direct={direct_mse:.6f} | "
        f"OOF Final={final_mse:.6f} | "
        f"Gain={row['MSEGain_pct']:+.3f}% | "
        f"CI=[{boot['CI_Low']:.6f}, {boot['CI_High']:.6f}] | "
        f"Sig+={boot['CI_Low'] > 0} | "
        f"ImprovedCh={100*improved_channel_fraction:.1f}% | "
        f"Runtime={runtime_minutes:.1f} min"
    )

    del (
        full_direct,
        full_retriever,
        val,
        gate,
        test_memory,
        test_memory_gpu,
        test,
        oof,
        oof_parts,
    )

    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()

print("\nExperiment 34B main loop finished.")
# Out:
# ========================================================================================================================
# EXPERIMENT 34B | Electricity Full321 | iTransformer | H=192
# ========================================================================================================================
# Loaded full direct | iTransformer H=192 | best=0.141826@8
# H=192 fold-direct fixed epochs: 8
# 34B FoldDirect H=192 F1 ep=01/08 | train=0.217285 | 0.7 min
# 34B FoldDirect H=192 F1 ep=02/08 | train=0.184863 | 0.6 min
# 34B FoldDirect H=192 F1 ep=03/08 | train=0.177194 | 0.6 min
# 34B FoldDirect H=192 F1 ep=04/08 | train=0.173271 | 0.6 min
# 34B FoldDirect H=192 F1 ep=05/08 | train=0.171192 | 0.7 min
# 34B FoldDirect H=192 F1 ep=06/08 | train=0.169862 | 0.7 min
# 34B FoldDirect H=192 F1 ep=07/08 | train=0.169176 | 0.6 min
# 34B FoldDirect H=192 F1 ep=08/08 | train=0.168796 | 0.6 min
# 33C prep H=192 | query anchors=965 | pairs=30,880 | all-channel naive pairs=309,765 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=76/77 | val min/max=19/20
# 34B Retriever H=192 F1 ep=01 | loss=4.343530 | valAnalog=2.205205 | 0.5 min | best=inf@1
# 34B Retriever H=192 F1 ep=02 | loss=4.207703 | valAnalog=2.185728 | 0.5 min | best=2.205205@1
# 34B Retriever H=192 F1 ep=03 | loss=4.165363 | valAnalog=2.161970 | 0.5 min | best=2.185728@2
# 34B Retriever H=192 F1 ep=04 | loss=4.143347 | valAnalog=2.159937 | 0.5 min | best=2.161970@3
# 34B Retriever H=192 F1 ep=05 | loss=4.127827 | valAnalog=2.148852 | 0.5 min | best=2.159937@4
# 34B Retriever H=192 F1 ep=06 | loss=4.117427 | valAnalog=2.144581 | 0.5 min | best=2.148852@5
# 34B Retriever H=192 F1 ep=07 | loss=4.107399 | valAnalog=2.137568 | 0.5 min | best=2.144581@6
# 34B Retriever H=192 F1 ep=08 | loss=4.100458 | valAnalog=2.127087 | 0.5 min | best=2.137568@7
# 34B Retriever H=192 F1 ep=09 | loss=4.093893 | valAnalog=2.126045 | 0.5 min | best=2.127087@8
# 34B Retriever H=192 F1 ep=10 | loss=4.088030 | valAnalog=2.117370 | 0.5 min | best=2.126045@9
# 34B Retriever H=192 F1 ep=11 | loss=4.081242 | valAnalog=2.114674 | 0.5 min | best=2.117370@10
# 34B Retriever H=192 F1 ep=12 | loss=4.076804 | valAnalog=2.112879 | 0.5 min | best=2.114674@11
# 34B Retriever H=192 F1 ep=13 | loss=4.072851 | valAnalog=2.105173 | 0.5 min | best=2.112879@12
# 34B Retriever H=192 F1 ep=14 | loss=4.066882 | valAnalog=2.100976 | 0.5 min | best=2.105173@13
# 34B Retriever H=192 F1 ep=15 | loss=4.064147 | valAnalog=2.102895 | 0.5 min | best=2.100976@14
# 34B Retriever H=192 F1 ep=16 | loss=4.060981 | valAnalog=2.098307 | 0.5 min | best=2.100976@14
# 34B Retriever H=192 F1 ep=17 | loss=4.057201 | valAnalog=2.096805 | 0.5 min | best=2.098307@16
# 34B Retriever H=192 F1 ep=18 | loss=4.053957 | valAnalog=2.092737 | 0.5 min | best=2.096805@17
# 34B Retriever H=192 F1 ep=19 | loss=4.051370 | valAnalog=2.096771 | 0.5 min | best=2.092737@18
# 34B Retriever H=192 F1 ep=20 | loss=4.048626 | valAnalog=2.090553 | 0.5 min | best=2.092737@18
# 34B Retriever H=192 F1 ep=21 | loss=4.046574 | valAnalog=2.086686 | 0.5 min | best=2.090553@20
# 34B Retriever H=192 F1 ep=22 | loss=4.043896 | valAnalog=2.087860 | 0.5 min | best=2.086686@21
# 34B Retriever H=192 F1 ep=23 | loss=4.042412 | valAnalog=2.079658 | 0.5 min | best=2.086686@21
# 34B Retriever H=192 F1 ep=24 | loss=4.039703 | valAnalog=2.078540 | 0.5 min | best=2.079658@23
# 34B Retriever H=192 F1 ep=25 | loss=4.037908 | valAnalog=2.077426 | 0.5 min | best=2.078540@24
# 34B Retriever H=192 F1 ep=26 | loss=4.035898 | valAnalog=2.074904 | 0.5 min | best=2.077426@25
# 34B Retriever H=192 F1 ep=27 | loss=4.034319 | valAnalog=2.073632 | 0.5 min | best=2.074904@26
# 34B Retriever H=192 F1 ep=28 | loss=4.032563 | valAnalog=2.069467 | 0.5 min | best=2.073632@27
# 34B Retriever H=192 F1 ep=29 | loss=4.030406 | valAnalog=2.069651 | 0.5 min | best=2.069467@28
# 34B Retriever H=192 F1 ep=30 | loss=4.029920 | valAnalog=2.071989 | 0.5 min | best=2.069467@28
# 34B Refit H=192 F1 ep=01/28 | loss=4.324705 | 0.6 min
# 34B Refit H=192 F1 ep=02/28 | loss=4.189277 | 0.6 min
# 34B Refit H=192 F1 ep=03/28 | loss=4.149949 | 0.6 min
# 34B Refit H=192 F1 ep=04/28 | loss=4.130252 | 0.6 min
# 34B Refit H=192 F1 ep=05/28 | loss=4.116232 | 0.6 min
# 34B Refit H=192 F1 ep=06/28 | loss=4.104076 | 0.6 min
# 34B Refit H=192 F1 ep=07/28 | loss=4.094173 | 0.6 min
# 34B Refit H=192 F1 ep=08/28 | loss=4.086717 | 0.6 min
# 34B Refit H=192 F1 ep=09/28 | loss=4.078494 | 0.6 min
# 34B Refit H=192 F1 ep=10/28 | loss=4.072955 | 0.6 min
# 34B Refit H=192 F1 ep=11/28 | loss=4.066626 | 0.6 min
# 34B Refit H=192 F1 ep=12/28 | loss=4.062039 | 0.6 min
# 34B Refit H=192 F1 ep=13/28 | loss=4.057786 | 0.6 min
# 34B Refit H=192 F1 ep=14/28 | loss=4.053578 | 0.6 min
# 34B Refit H=192 F1 ep=15/28 | loss=4.050040 | 0.6 min
# 34B Refit H=192 F1 ep=16/28 | loss=4.046890 | 0.6 min
# 34B Refit H=192 F1 ep=17/28 | loss=4.043832 | 0.6 min
# 34B Refit H=192 F1 ep=18/28 | loss=4.040823 | 0.6 min
# 34B Refit H=192 F1 ep=19/28 | loss=4.038149 | 0.6 min
# 34B Refit H=192 F1 ep=20/28 | loss=4.036123 | 0.6 min
# 34B Refit H=192 F1 ep=21/28 | loss=4.033528 | 0.6 min
# 34B Refit H=192 F1 ep=22/28 | loss=4.030697 | 0.6 min
# 34B Refit H=192 F1 ep=23/28 | loss=4.029404 | 0.6 min
# 34B Refit H=192 F1 ep=24/28 | loss=4.027234 | 0.6 min
# 34B Refit H=192 F1 ep=25/28 | loss=4.025739 | 0.6 min
# 34B Refit H=192 F1 ep=26/28 | loss=4.023556 | 0.6 min
# 34B Refit H=192 F1 ep=27/28 | loss=4.021896 | 0.6 min
# 34B Refit H=192 F1 ep=28/28 | loss=4.020820 | 0.6 min
# SAVED 34B retriever H=192 F1 | bestEpoch=28 | total=31.5 min
# Building memory embedding: ElectricityFull321_34B_H192_OOF_F1_prefix10126_emb.npy (321, 410, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=192 F1 | prefix=10126 | end=12888 | anchors=643 | pairs=206,403 | memory/C=410
# Saved OOF H=192 F1: 206,403 pairs
# 34B FoldDirect H=192 F2 ep=01/08 | train=0.208148 | 0.8 min
# 34B FoldDirect H=192 F2 ep=02/08 | train=0.178021 | 0.8 min
# 34B FoldDirect H=192 F2 ep=03/08 | train=0.170998 | 0.8 min
# 34B FoldDirect H=192 F2 ep=04/08 | train=0.167535 | 0.8 min
# 34B FoldDirect H=192 F2 ep=05/08 | train=0.165406 | 0.8 min
# 34B FoldDirect H=192 F2 ep=06/08 | train=0.164221 | 0.8 min
# 34B FoldDirect H=192 F2 ep=07/08 | train=0.163455 | 0.8 min
# 34B FoldDirect H=192 F2 ep=08/08 | train=0.163104 | 0.8 min
# 33C prep H=192 | query anchors=1242 | pairs=39,744 | all-channel naive pairs=398,682 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=98/99 | val min/max=24/25
# 34B Retriever H=192 F2 ep=01 | loss=4.325607 | valAnalog=1.861040 | 0.7 min | best=inf@1
# 34B Retriever H=192 F2 ep=02 | loss=4.187328 | valAnalog=1.842569 | 0.7 min | best=1.861040@1
# 34B Retriever H=192 F2 ep=03 | loss=4.150586 | valAnalog=1.828864 | 0.7 min | best=1.842569@2
# 34B Retriever H=192 F2 ep=04 | loss=4.131507 | valAnalog=1.823212 | 0.7 min | best=1.828864@3
# 34B Retriever H=192 F2 ep=05 | loss=4.118927 | valAnalog=1.817077 | 0.7 min | best=1.823212@4
# 34B Retriever H=192 F2 ep=06 | loss=4.109205 | valAnalog=1.809549 | 0.7 min | best=1.817077@5
# 34B Retriever H=192 F2 ep=07 | loss=4.100862 | valAnalog=1.806364 | 0.6 min | best=1.809549@6
# 34B Retriever H=192 F2 ep=08 | loss=4.093695 | valAnalog=1.804110 | 0.6 min | best=1.806364@7
# 34B Retriever H=192 F2 ep=09 | loss=4.087789 | valAnalog=1.799779 | 0.7 min | best=1.804110@8
# 34B Retriever H=192 F2 ep=10 | loss=4.082190 | valAnalog=1.796041 | 0.7 min | best=1.799779@9
# 34B Retriever H=192 F2 ep=11 | loss=4.076935 | valAnalog=1.791868 | 0.7 min | best=1.796041@10
# 34B Retriever H=192 F2 ep=12 | loss=4.072741 | valAnalog=1.793570 | 0.7 min | best=1.791868@11
# 34B Retriever H=192 F2 ep=13 | loss=4.068979 | valAnalog=1.785704 | 0.7 min | best=1.791868@11
# 34B Retriever H=192 F2 ep=14 | loss=4.065016 | valAnalog=1.786631 | 0.7 min | best=1.785704@13
# 34B Retriever H=192 F2 ep=15 | loss=4.061417 | valAnalog=1.781520 | 0.7 min | best=1.785704@13
# 34B Retriever H=192 F2 ep=16 | loss=4.058520 | valAnalog=1.783013 | 0.6 min | best=1.781520@15
# 34B Retriever H=192 F2 ep=17 | loss=4.055709 | valAnalog=1.779336 | 0.6 min | best=1.781520@15
# 34B Retriever H=192 F2 ep=18 | loss=4.052573 | valAnalog=1.776211 | 0.6 min | best=1.779336@17
# 34B Retriever H=192 F2 ep=19 | loss=4.050315 | valAnalog=1.777043 | 0.6 min | best=1.776211@18
# 34B Retriever H=192 F2 ep=20 | loss=4.048662 | valAnalog=1.773544 | 0.6 min | best=1.776211@18
# 34B Retriever H=192 F2 ep=21 | loss=4.046072 | valAnalog=1.768568 | 0.6 min | best=1.773544@20
# 34B Retriever H=192 F2 ep=22 | loss=4.043548 | valAnalog=1.769813 | 0.7 min | best=1.768568@21
# 34B Retriever H=192 F2 ep=23 | loss=4.041950 | valAnalog=1.766743 | 0.6 min | best=1.768568@21
# 34B Retriever H=192 F2 ep=24 | loss=4.040777 | valAnalog=1.766319 | 0.6 min | best=1.766743@23
# 34B Retriever H=192 F2 ep=25 | loss=4.038326 | valAnalog=1.764140 | 0.6 min | best=1.766319@24
# 34B Retriever H=192 F2 ep=26 | loss=4.037506 | valAnalog=1.765185 | 0.6 min | best=1.764140@25
# 34B Retriever H=192 F2 ep=27 | loss=4.035442 | valAnalog=1.763708 | 0.7 min | best=1.764140@25
# 34B Retriever H=192 F2 ep=28 | loss=4.034641 | valAnalog=1.764078 | 0.7 min | best=1.763708@27
# 34B Retriever H=192 F2 ep=29 | loss=4.032864 | valAnalog=1.760493 | 0.6 min | best=1.763708@27
# 34B Retriever H=192 F2 ep=30 | loss=4.031154 | valAnalog=1.760016 | 0.7 min | best=1.760493@29
# 34B Refit H=192 F2 ep=01/30 | loss=4.303318 | 0.8 min
# 34B Refit H=192 F2 ep=02/30 | loss=4.174898 | 0.7 min
# 34B Refit H=192 F2 ep=03/30 | loss=4.142735 | 0.7 min
# 34B Refit H=192 F2 ep=04/30 | loss=4.126569 | 0.8 min
# 34B Refit H=192 F2 ep=05/30 | loss=4.114703 | 0.8 min
# 34B Refit H=192 F2 ep=06/30 | loss=4.103973 | 0.8 min
# 34B Refit H=192 F2 ep=07/30 | loss=4.095757 | 0.7 min
# 34B Refit H=192 F2 ep=08/30 | loss=4.088731 | 0.7 min
# 34B Refit H=192 F2 ep=09/30 | loss=4.082480 | 0.7 min
# 34B Refit H=192 F2 ep=10/30 | loss=4.076576 | 0.8 min
# 34B Refit H=192 F2 ep=11/30 | loss=4.072252 | 0.8 min
# 34B Refit H=192 F2 ep=12/30 | loss=4.067369 | 0.8 min
# 34B Refit H=192 F2 ep=13/30 | loss=4.063234 | 0.7 min
# 34B Refit H=192 F2 ep=14/30 | loss=4.060787 | 0.8 min
# 34B Refit H=192 F2 ep=15/30 | loss=4.056626 | 0.8 min
# 34B Refit H=192 F2 ep=16/30 | loss=4.054116 | 0.8 min
# 34B Refit H=192 F2 ep=17/30 | loss=4.051540 | 0.8 min
# 34B Refit H=192 F2 ep=18/30 | loss=4.049299 | 0.8 min
# 34B Refit H=192 F2 ep=19/30 | loss=4.046350 | 0.8 min
# 34B Refit H=192 F2 ep=20/30 | loss=4.044859 | 0.8 min
# 34B Refit H=192 F2 ep=21/30 | loss=4.043102 | 0.8 min
# 34B Refit H=192 F2 ep=22/30 | loss=4.041796 | 0.8 min
# 34B Refit H=192 F2 ep=23/30 | loss=4.039399 | 0.8 min
# 34B Refit H=192 F2 ep=24/30 | loss=4.037997 | 0.8 min
# 34B Refit H=192 F2 ep=25/30 | loss=4.036761 | 0.8 min
# 34B Refit H=192 F2 ep=26/30 | loss=4.035221 | 0.7 min
# 34B Refit H=192 F2 ep=27/30 | loss=4.034216 | 0.7 min
# 34B Refit H=192 F2 ep=28/30 | loss=4.033076 | 0.7 min
# 34B Refit H=192 F2 ep=29/30 | loss=4.031715 | 0.7 min
# 34B Refit H=192 F2 ep=30/30 | loss=4.030752 | 0.8 min
# SAVED 34B retriever H=192 F2 | bestEpoch=30 | total=42.2 min
# Building memory embedding: ElectricityFull321_34B_H192_OOF_F2_prefix12888_emb.npy (321, 526, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=192 F2 | prefix=12888 | end=15650 | anchors=643 | pairs=206,403 | memory/C=526
# Saved OOF H=192 F2: 206,403 pairs
# 34B FoldDirect H=192 F3 ep=01/08 | train=0.206965 | 1.0 min
# 34B FoldDirect H=192 F3 ep=02/08 | train=0.178316 | 1.0 min
# 34B FoldDirect H=192 F3 ep=03/08 | train=0.171522 | 1.0 min
# 34B FoldDirect H=192 F3 ep=04/08 | train=0.167932 | 1.0 min
# 34B FoldDirect H=192 F3 ep=05/08 | train=0.165545 | 1.0 min
# 34B FoldDirect H=192 F3 ep=06/08 | train=0.164150 | 1.0 min
# 34B FoldDirect H=192 F3 ep=07/08 | train=0.163348 | 1.0 min
# 34B FoldDirect H=192 F3 ep=08/08 | train=0.162903 | 1.0 min
# 33C prep H=192 | query anchors=1518 | pairs=48,576 | all-channel naive pairs=487,278 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=121/122 | val min/max=30/31
# 34B Retriever H=192 F3 ep=01 | loss=4.267693 | valAnalog=2.204431 | 0.8 min | best=inf@1
# 34B Retriever H=192 F3 ep=02 | loss=4.136926 | valAnalog=2.184127 | 0.8 min | best=2.204431@1
# 34B Retriever H=192 F3 ep=03 | loss=4.103512 | valAnalog=2.177782 | 0.8 min | best=2.184127@2
# 34B Retriever H=192 F3 ep=04 | loss=4.087120 | valAnalog=2.160968 | 0.8 min | best=2.177782@3
# 34B Retriever H=192 F3 ep=05 | loss=4.077037 | valAnalog=2.155849 | 0.8 min | best=2.160968@4
# 34B Retriever H=192 F3 ep=06 | loss=4.067458 | valAnalog=2.146436 | 0.8 min | best=2.155849@5
# 34B Retriever H=192 F3 ep=07 | loss=4.059583 | valAnalog=2.142534 | 0.8 min | best=2.146436@6
# 34B Retriever H=192 F3 ep=08 | loss=4.053467 | valAnalog=2.137885 | 0.8 min | best=2.142534@7
# 34B Retriever H=192 F3 ep=09 | loss=4.047566 | valAnalog=2.131196 | 0.8 min | best=2.137885@8
# 34B Retriever H=192 F3 ep=10 | loss=4.042499 | valAnalog=2.128501 | 0.8 min | best=2.131196@9
# 34B Retriever H=192 F3 ep=11 | loss=4.037089 | valAnalog=2.126528 | 0.8 min | best=2.128501@10
# 34B Retriever H=192 F3 ep=12 | loss=4.034067 | valAnalog=2.126113 | 0.8 min | best=2.126528@11
# 34B Retriever H=192 F3 ep=13 | loss=4.032263 | valAnalog=2.120846 | 0.8 min | best=2.126113@12
# 34B Retriever H=192 F3 ep=14 | loss=4.027323 | valAnalog=2.117430 | 0.8 min | best=2.120846@13
# 34B Retriever H=192 F3 ep=15 | loss=4.024412 | valAnalog=2.117177 | 0.8 min | best=2.117430@14
# 34B Retriever H=192 F3 ep=16 | loss=4.021813 | valAnalog=2.114646 | 0.8 min | best=2.117177@15
# 34B Retriever H=192 F3 ep=17 | loss=4.019238 | valAnalog=2.113412 | 0.8 min | best=2.114646@16
# 34B Retriever H=192 F3 ep=18 | loss=4.016776 | valAnalog=2.110159 | 0.8 min | best=2.113412@17
# 34B Retriever H=192 F3 ep=19 | loss=4.014439 | valAnalog=2.110296 | 0.8 min | best=2.110159@18
# 34B Retriever H=192 F3 ep=20 | loss=4.012171 | valAnalog=2.106080 | 0.8 min | best=2.110159@18
# 34B Retriever H=192 F3 ep=21 | loss=4.010659 | valAnalog=2.104895 | 0.8 min | best=2.106080@20
# 34B Retriever H=192 F3 ep=22 | loss=4.008304 | valAnalog=2.103892 | 0.8 min | best=2.104895@21
# 34B Retriever H=192 F3 ep=23 | loss=4.006963 | valAnalog=2.108069 | 0.8 min | best=2.103892@22
# 34B Retriever H=192 F3 ep=24 | loss=4.005079 | valAnalog=2.104494 | 0.8 min | best=2.103892@22
# 34B Retriever H=192 F3 ep=25 | loss=4.003753 | valAnalog=2.099345 | 0.8 min | best=2.103892@22
# 34B Retriever H=192 F3 ep=26 | loss=4.002826 | valAnalog=2.098552 | 0.8 min | best=2.099345@25
# 34B Retriever H=192 F3 ep=27 | loss=4.001363 | valAnalog=2.096318 | 0.8 min | best=2.098552@26
# 34B Retriever H=192 F3 ep=28 | loss=4.000137 | valAnalog=2.096333 | 0.8 min | best=2.096318@27
# 34B Retriever H=192 F3 ep=29 | loss=3.998843 | valAnalog=2.096324 | 0.8 min | best=2.096318@27
# 34B Retriever H=192 F3 ep=30 | loss=3.997560 | valAnalog=2.095823 | 0.8 min | best=2.096318@27
# 34B Refit H=192 F3 ep=01/30 | loss=4.241973 | 0.9 min
# 34B Refit H=192 F3 ep=02/30 | loss=4.120100 | 0.9 min
# 34B Refit H=192 F3 ep=03/30 | loss=4.089374 | 0.9 min
# 34B Refit H=192 F3 ep=04/30 | loss=4.072587 | 0.9 min
# 34B Refit H=192 F3 ep=05/30 | loss=4.060953 | 0.9 min
# 34B Refit H=192 F3 ep=06/30 | loss=4.050760 | 0.9 min
# 34B Refit H=192 F3 ep=07/30 | loss=4.043490 | 0.9 min
# 34B Refit H=192 F3 ep=08/30 | loss=4.037281 | 0.9 min
# 34B Refit H=192 F3 ep=09/30 | loss=4.031876 | 0.9 min
# 34B Refit H=192 F3 ep=10/30 | loss=4.026096 | 0.9 min
# 34B Refit H=192 F3 ep=11/30 | loss=4.022530 | 0.9 min
# 34B Refit H=192 F3 ep=12/30 | loss=4.018457 | 0.9 min
# 34B Refit H=192 F3 ep=13/30 | loss=4.015353 | 0.9 min
# 34B Refit H=192 F3 ep=14/30 | loss=4.012683 | 0.9 min
# 34B Refit H=192 F3 ep=15/30 | loss=4.009348 | 0.9 min
# 34B Refit H=192 F3 ep=16/30 | loss=4.007168 | 0.9 min
# 34B Refit H=192 F3 ep=17/30 | loss=4.005136 | 0.9 min
# 34B Refit H=192 F3 ep=18/30 | loss=4.002981 | 0.9 min
# 34B Refit H=192 F3 ep=19/30 | loss=4.001309 | 0.9 min
# 34B Refit H=192 F3 ep=20/30 | loss=3.999325 | 0.9 min
# 34B Refit H=192 F3 ep=21/30 | loss=3.997155 | 0.9 min
# 34B Refit H=192 F3 ep=22/30 | loss=3.996041 | 0.9 min
# 34B Refit H=192 F3 ep=23/30 | loss=3.994312 | 0.9 min
# 34B Refit H=192 F3 ep=24/30 | loss=3.993230 | 0.9 min
# 34B Refit H=192 F3 ep=25/30 | loss=3.991895 | 0.9 min
# 34B Refit H=192 F3 ep=26/30 | loss=3.990349 | 0.9 min
# 34B Refit H=192 F3 ep=27/30 | loss=3.989339 | 0.9 min
# 34B Refit H=192 F3 ep=28/30 | loss=3.988104 | 0.9 min
# 34B Refit H=192 F3 ep=29/30 | loss=3.987410 | 0.9 min
# 34B Refit H=192 F3 ep=30/30 | loss=3.985888 | 0.9 min
# SAVED 34B retriever H=192 F3 | bestEpoch=30 | total=51.5 min
# Building memory embedding: ElectricityFull321_34B_H192_OOF_F3_prefix15650_emb.npy (321, 641, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=192 F3 | prefix=15650 | end=18412 | anchors=643 | pairs=206,403 | memory/C=641
# Saved OOF H=192 F3: 206,403 pairs
# H=192 combined OOF | pairs=619,209 | anchors=1,929 | channels=321
# Reusing Experiment-33C full retriever H=192 | bestEpoch=29
# Building memory embedding: ElectricityFull321_34B_H192_Validation_TrainMemory_emb.npy (321, 756, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B validation H=192 | anchors=2,441 | pairs=783,561
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=01 OOF=0.186958 val=0.141083 alpha=0.027 best=0.141083@1
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=02 OOF=0.182500 val=0.140868 alpha=0.021 best=0.140868@2
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=03 OOF=0.181947 val=0.140615 alpha=0.020 best=0.140615@3
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=04 OOF=0.181722 val=0.140459 alpha=0.023 best=0.140459@4
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=05 OOF=0.181563 val=0.140451 alpha=0.022 best=0.140451@5
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=06 OOF=0.181498 val=0.140480 alpha=0.024 best=0.140451@5
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=07 OOF=0.181357 val=0.140574 alpha=0.018 best=0.140451@5
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=08 OOF=0.181331 val=0.140600 alpha=0.019 best=0.140451@5
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=09 OOF=0.181220 val=0.140333 alpha=0.022 best=0.140333@9
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=10 OOF=0.181213 val=0.140278 alpha=0.024 best=0.140278@10
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=11 OOF=0.181078 val=0.140426 alpha=0.023 best=0.140278@10
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=12 OOF=0.180977 val=0.140255 alpha=0.024 best=0.140255@12
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=13 OOF=0.180981 val=0.140178 alpha=0.024 best=0.140178@13
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=14 OOF=0.180974 val=0.140213 alpha=0.025 best=0.140178@13
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=15 OOF=0.180925 val=0.140050 alpha=0.028 best=0.140050@15
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=16 OOF=0.180896 val=0.140039 alpha=0.025 best=0.140039@16
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=17 OOF=0.180840 val=0.139897 alpha=0.036 best=0.139897@17
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=18 OOF=0.180776 val=0.140006 alpha=0.022 best=0.139897@17
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=19 OOF=0.180806 val=0.140044 alpha=0.026 best=0.139897@17
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=20 OOF=0.180729 val=0.139927 alpha=0.025 best=0.139897@17
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=21 OOF=0.180679 val=0.140053 alpha=0.026 best=0.139897@17
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=22 OOF=0.180707 val=0.139890 alpha=0.033 best=0.139890@22
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=23 OOF=0.180674 val=0.139830 alpha=0.026 best=0.139830@23
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=24 OOF=0.180506 val=0.140010 alpha=0.028 best=0.139830@23
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=25 OOF=0.180597 val=0.139943 alpha=0.025 best=0.139830@23
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=26 OOF=0.180653 val=0.140001 alpha=0.026 best=0.139830@23
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=27 OOF=0.180523 val=0.139846 alpha=0.027 best=0.139830@23
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=28 OOF=0.180584 val=0.139788 alpha=0.026 best=0.139788@28
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=29 OOF=0.180482 val=0.139771 alpha=0.027 best=0.139771@29
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=30 OOF=0.180427 val=0.139695 alpha=0.026 best=0.139695@30
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=31 OOF=0.180481 val=0.139757 alpha=0.029 best=0.139695@30
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=32 OOF=0.180444 val=0.139668 alpha=0.029 best=0.139668@32
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=33 OOF=0.180388 val=0.139679 alpha=0.025 best=0.139668@32
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=34 OOF=0.180372 val=0.139764 alpha=0.029 best=0.139668@32
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=35 OOF=0.180402 val=0.139703 alpha=0.025 best=0.139668@32
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=36 OOF=0.180365 val=0.139610 alpha=0.031 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=37 OOF=0.180335 val=0.139614 alpha=0.029 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=38 OOF=0.180231 val=0.139743 alpha=0.027 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=39 OOF=0.180371 val=0.139699 alpha=0.024 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=40 OOF=0.180208 val=0.139794 alpha=0.028 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=41 OOF=0.180249 val=0.139635 alpha=0.028 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=42 OOF=0.180276 val=0.139805 alpha=0.026 best=0.139610@36
# Gate ElectricityFull321_34B_iTransformer_H192 H=192 ep=43 OOF=0.180260 val=0.139902 alpha=0.023 best=0.139610@36
# 34B validation H=192 | Direct=0.141826 | Scalar=0.141826 (a=0.00) | RawGate=0.139696 | Final=0.139696 (lambda=1.00) | gain=+1.502%
# Building memory embedding: ElectricityFull321_34B_H192_Test_TrainValMemory_emb.npy (321, 865, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
#   test anchors 2/5069
#   test anchors 500/5069
#   test anchors 1000/5069
#   test anchors 1500/5069
#   test anchors 2000/5069
#   test anchors 2500/5069
#   test anchors 3000/5069
#   test anchors 3500/5069
#   test anchors 4000/5069
#   test anchors 4500/5069
#   test anchors 5000/5069
#   test anchors 5069/5069
#
# H=192 RESULT | Direct=0.163223 | OOF Final=0.161652 | Gain=+0.962% | CI=[0.001271, 0.001889] | Sig+=True | ImprovedCh=77.6% | Runtime=146.7 min
#
# ========================================================================================================================
# EXPERIMENT 34B | Electricity Full321 | iTransformer | H=336
# ========================================================================================================================
# Loaded full direct | iTransformer H=336 | best=0.158973@7
# H=336 fold-direct fixed epochs: 7
# 34B FoldDirect H=336 F1 ep=01/07 | train=0.241046 | 0.7 min
# 34B FoldDirect H=336 F1 ep=02/07 | train=0.207657 | 0.7 min
# 34B FoldDirect H=336 F1 ep=03/07 | train=0.199694 | 0.6 min
# 34B FoldDirect H=336 F1 ep=04/07 | train=0.195730 | 0.6 min
# 34B FoldDirect H=336 F1 ep=05/07 | train=0.193176 | 0.6 min
# 34B FoldDirect H=336 F1 ep=06/07 | train=0.191486 | 0.6 min
# 34B FoldDirect H=336 F1 ep=07/07 | train=0.190471 | 0.6 min
# 33C prep H=336 | query anchors=929 | pairs=29,728 | all-channel naive pairs=298,209 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=74/75 | val min/max=18/19
# 34B Retriever H=336 F1 ep=01 | loss=4.338496 | valAnalog=2.203636 | 0.5 min | best=inf@1
# 34B Retriever H=336 F1 ep=02 | loss=4.202995 | valAnalog=2.190645 | 0.5 min | best=2.203636@1
# 34B Retriever H=336 F1 ep=03 | loss=4.160586 | valAnalog=2.169422 | 0.5 min | best=2.190645@2
# 34B Retriever H=336 F1 ep=04 | loss=4.135298 | valAnalog=2.157409 | 0.5 min | best=2.169422@3
# 34B Retriever H=336 F1 ep=05 | loss=4.121125 | valAnalog=2.153168 | 0.5 min | best=2.157409@4
# 34B Retriever H=336 F1 ep=06 | loss=4.108391 | valAnalog=2.145410 | 0.5 min | best=2.153168@5
# 34B Retriever H=336 F1 ep=07 | loss=4.098349 | valAnalog=2.134832 | 0.5 min | best=2.145410@6
# 34B Retriever H=336 F1 ep=08 | loss=4.089261 | valAnalog=2.131752 | 0.5 min | best=2.134832@7
# 34B Retriever H=336 F1 ep=09 | loss=4.082182 | valAnalog=2.124904 | 0.5 min | best=2.131752@8
# 34B Retriever H=336 F1 ep=10 | loss=4.074649 | valAnalog=2.119778 | 0.5 min | best=2.124904@9
# 34B Retriever H=336 F1 ep=11 | loss=4.068854 | valAnalog=2.113900 | 0.5 min | best=2.119778@10
# 34B Retriever H=336 F1 ep=12 | loss=4.063539 | valAnalog=2.109227 | 0.5 min | best=2.113900@11
# 34B Retriever H=336 F1 ep=13 | loss=4.058363 | valAnalog=2.104936 | 0.5 min | best=2.109227@12
# 34B Retriever H=336 F1 ep=14 | loss=4.053911 | valAnalog=2.101849 | 0.5 min | best=2.104936@13
# 34B Retriever H=336 F1 ep=15 | loss=4.049397 | valAnalog=2.101073 | 0.5 min | best=2.101849@14
# 34B Retriever H=336 F1 ep=16 | loss=4.046215 | valAnalog=2.093365 | 0.5 min | best=2.101073@15
# 34B Retriever H=336 F1 ep=17 | loss=4.042706 | valAnalog=2.094362 | 0.5 min | best=2.093365@16
# 34B Retriever H=336 F1 ep=18 | loss=4.038228 | valAnalog=2.088172 | 0.5 min | best=2.093365@16
# 34B Retriever H=336 F1 ep=19 | loss=4.035982 | valAnalog=2.090242 | 0.5 min | best=2.088172@18
# 34B Retriever H=336 F1 ep=20 | loss=4.033285 | valAnalog=2.083962 | 0.5 min | best=2.088172@18
# 34B Retriever H=336 F1 ep=21 | loss=4.029850 | valAnalog=2.082021 | 0.5 min | best=2.083962@20
# 34B Retriever H=336 F1 ep=22 | loss=4.027727 | valAnalog=2.086282 | 0.5 min | best=2.082021@21
# 34B Retriever H=336 F1 ep=23 | loss=4.025539 | valAnalog=2.078099 | 0.5 min | best=2.082021@21
# 34B Retriever H=336 F1 ep=24 | loss=4.024262 | valAnalog=2.081710 | 0.5 min | best=2.078099@23
# 34B Retriever H=336 F1 ep=25 | loss=4.021380 | valAnalog=2.076910 | 0.5 min | best=2.078099@23
# 34B Retriever H=336 F1 ep=26 | loss=4.018422 | valAnalog=2.073521 | 0.5 min | best=2.076910@25
# 34B Retriever H=336 F1 ep=27 | loss=4.016744 | valAnalog=2.077015 | 0.5 min | best=2.073521@26
# 34B Retriever H=336 F1 ep=28 | loss=4.015621 | valAnalog=2.069615 | 0.5 min | best=2.073521@26
# 34B Retriever H=336 F1 ep=29 | loss=4.013229 | valAnalog=2.072105 | 0.5 min | best=2.069615@28
# 34B Retriever H=336 F1 ep=30 | loss=4.012150 | valAnalog=2.069877 | 0.5 min | best=2.069615@28
# 34B Refit H=336 F1 ep=01/28 | loss=4.318746 | 0.5 min
# 34B Refit H=336 F1 ep=02/28 | loss=4.186487 | 0.5 min
# 34B Refit H=336 F1 ep=03/28 | loss=4.148253 | 0.5 min
# 34B Refit H=336 F1 ep=04/28 | loss=4.127705 | 0.5 min
# 34B Refit H=336 F1 ep=05/28 | loss=4.114791 | 0.6 min
# 34B Refit H=336 F1 ep=06/28 | loss=4.102819 | 0.6 min
# 34B Refit H=336 F1 ep=07/28 | loss=4.092137 | 0.6 min
# 34B Refit H=336 F1 ep=08/28 | loss=4.083214 | 0.6 min
# 34B Refit H=336 F1 ep=09/28 | loss=4.075629 | 0.5 min
# 34B Refit H=336 F1 ep=10/28 | loss=4.067965 | 0.6 min
# 34B Refit H=336 F1 ep=11/28 | loss=4.062217 | 0.6 min
# 34B Refit H=336 F1 ep=12/28 | loss=4.056461 | 0.6 min
# 34B Refit H=336 F1 ep=13/28 | loss=4.050580 | 0.6 min
# 34B Refit H=336 F1 ep=14/28 | loss=4.046560 | 0.6 min
# 34B Refit H=336 F1 ep=15/28 | loss=4.041767 | 0.6 min
# 34B Refit H=336 F1 ep=16/28 | loss=4.037833 | 0.6 min
# 34B Refit H=336 F1 ep=17/28 | loss=4.034879 | 0.6 min
# 34B Refit H=336 F1 ep=18/28 | loss=4.031450 | 0.5 min
# 34B Refit H=336 F1 ep=19/28 | loss=4.028311 | 0.6 min
# 34B Refit H=336 F1 ep=20/28 | loss=4.025664 | 0.5 min
# 34B Refit H=336 F1 ep=21/28 | loss=4.023318 | 0.5 min
# 34B Refit H=336 F1 ep=22/28 | loss=4.020556 | 0.5 min
# 34B Refit H=336 F1 ep=23/28 | loss=4.018361 | 0.5 min
# 34B Refit H=336 F1 ep=24/28 | loss=4.016130 | 0.6 min
# 34B Refit H=336 F1 ep=25/28 | loss=4.014143 | 0.6 min
# 34B Refit H=336 F1 ep=26/28 | loss=4.011823 | 0.6 min
# 34B Refit H=336 F1 ep=27/28 | loss=4.010494 | 0.6 min
# 34B Refit H=336 F1 ep=28/28 | loss=4.008936 | 0.6 min
# SAVED 34B retriever H=336 F1 | bestEpoch=28 | total=30.4 min
# Building memory embedding: ElectricityFull321_34B_H336_OOF_F1_prefix10126_emb.npy (321, 404, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=336 F1 | prefix=10126 | end=12888 | anchors=607 | pairs=194,847 | memory/C=404
# Saved OOF H=336 F1: 194,847 pairs
# 34B FoldDirect H=336 F2 ep=01/07 | train=0.230102 | 0.8 min
# 34B FoldDirect H=336 F2 ep=02/07 | train=0.198815 | 0.9 min
# 34B FoldDirect H=336 F2 ep=03/07 | train=0.191434 | 0.9 min
# 34B FoldDirect H=336 F2 ep=04/07 | train=0.187597 | 0.9 min
# 34B FoldDirect H=336 F2 ep=05/07 | train=0.185161 | 0.9 min
# 34B FoldDirect H=336 F2 ep=06/07 | train=0.183683 | 0.8 min
# 34B FoldDirect H=336 F2 ep=07/07 | train=0.182736 | 0.8 min
# 33C prep H=336 | query anchors=1206 | pairs=38,592 | all-channel naive pairs=387,126 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=96/97 | val min/max=24/25
# 34B Retriever H=336 F2 ep=01 | loss=4.323762 | valAnalog=1.868792 | 0.6 min | best=inf@1
# 34B Retriever H=336 F2 ep=02 | loss=4.192546 | valAnalog=1.857550 | 0.6 min | best=1.868792@1
# 34B Retriever H=336 F2 ep=03 | loss=4.157375 | valAnalog=1.849062 | 0.6 min | best=1.857550@2
# 34B Retriever H=336 F2 ep=04 | loss=4.137058 | valAnalog=1.841443 | 0.6 min | best=1.849062@3
# 34B Retriever H=336 F2 ep=05 | loss=4.122973 | valAnalog=1.829079 | 0.6 min | best=1.841443@4
# 34B Retriever H=336 F2 ep=06 | loss=4.112136 | valAnalog=1.820624 | 0.6 min | best=1.829079@5
# 34B Retriever H=336 F2 ep=07 | loss=4.101858 | valAnalog=1.817392 | 0.6 min | best=1.820624@6
# 34B Retriever H=336 F2 ep=08 | loss=4.093660 | valAnalog=1.809615 | 0.6 min | best=1.817392@7
# 34B Retriever H=336 F2 ep=09 | loss=4.086442 | valAnalog=1.810361 | 0.6 min | best=1.809615@8
# 34B Retriever H=336 F2 ep=10 | loss=4.079709 | valAnalog=1.804433 | 0.6 min | best=1.809615@8
# 34B Retriever H=336 F2 ep=11 | loss=4.074229 | valAnalog=1.800623 | 0.6 min | best=1.804433@10
# 34B Retriever H=336 F2 ep=12 | loss=4.069370 | valAnalog=1.799099 | 0.6 min | best=1.800623@11
# 34B Retriever H=336 F2 ep=13 | loss=4.065229 | valAnalog=1.792535 | 0.6 min | best=1.799099@12
# 34B Retriever H=336 F2 ep=14 | loss=4.060539 | valAnalog=1.792160 | 0.6 min | best=1.792535@13
# 34B Retriever H=336 F2 ep=15 | loss=4.057118 | valAnalog=1.787832 | 0.6 min | best=1.792160@14
# 34B Retriever H=336 F2 ep=16 | loss=4.053552 | valAnalog=1.785837 | 0.6 min | best=1.787832@15
# 34B Retriever H=336 F2 ep=17 | loss=4.050430 | valAnalog=1.785727 | 0.6 min | best=1.785837@16
# 34B Retriever H=336 F2 ep=18 | loss=4.047962 | valAnalog=1.782472 | 0.6 min | best=1.785727@17
# 34B Retriever H=336 F2 ep=19 | loss=4.044549 | valAnalog=1.779970 | 0.6 min | best=1.782472@18
# 34B Retriever H=336 F2 ep=20 | loss=4.042151 | valAnalog=1.780765 | 0.7 min | best=1.779970@19
# 34B Retriever H=336 F2 ep=21 | loss=4.039270 | valAnalog=1.775938 | 0.7 min | best=1.779970@19
# 34B Retriever H=336 F2 ep=22 | loss=4.037606 | valAnalog=1.775646 | 0.6 min | best=1.775938@21
# 34B Retriever H=336 F2 ep=23 | loss=4.035629 | valAnalog=1.777384 | 0.6 min | best=1.775646@22
# 34B Retriever H=336 F2 ep=24 | loss=4.033843 | valAnalog=1.773434 | 0.6 min | best=1.775646@22
# 34B Retriever H=336 F2 ep=25 | loss=4.031985 | valAnalog=1.774596 | 0.6 min | best=1.773434@24
# 34B Retriever H=336 F2 ep=26 | loss=4.030537 | valAnalog=1.769056 | 0.6 min | best=1.773434@24
# 34B Retriever H=336 F2 ep=27 | loss=4.029053 | valAnalog=1.767887 | 0.6 min | best=1.769056@26
# 34B Retriever H=336 F2 ep=28 | loss=4.026988 | valAnalog=1.766284 | 0.6 min | best=1.767887@27
# 34B Retriever H=336 F2 ep=29 | loss=4.026216 | valAnalog=1.768699 | 0.6 min | best=1.766284@28
# 34B Retriever H=336 F2 ep=30 | loss=4.024875 | valAnalog=1.765620 | 0.6 min | best=1.766284@28
# 34B Refit H=336 F2 ep=01/30 | loss=4.297035 | 0.8 min
# 34B Refit H=336 F2 ep=02/30 | loss=4.177634 | 0.8 min
# 34B Refit H=336 F2 ep=03/30 | loss=4.144977 | 0.8 min
# 34B Refit H=336 F2 ep=04/30 | loss=4.125451 | 0.8 min
# 34B Refit H=336 F2 ep=05/30 | loss=4.111384 | 0.7 min
# 34B Refit H=336 F2 ep=06/30 | loss=4.100797 | 0.7 min
# 34B Refit H=336 F2 ep=07/30 | loss=4.090687 | 0.7 min
# 34B Refit H=336 F2 ep=08/30 | loss=4.082928 | 0.7 min
# 34B Refit H=336 F2 ep=09/30 | loss=4.076272 | 0.7 min
# 34B Refit H=336 F2 ep=10/30 | loss=4.069979 | 0.7 min
# 34B Refit H=336 F2 ep=11/30 | loss=4.065035 | 0.8 min
# 34B Refit H=336 F2 ep=12/30 | loss=4.060727 | 0.8 min
# 34B Refit H=336 F2 ep=13/30 | loss=4.056694 | 0.7 min
# 34B Refit H=336 F2 ep=14/30 | loss=4.052867 | 0.7 min
# 34B Refit H=336 F2 ep=15/30 | loss=4.049037 | 0.7 min
# 34B Refit H=336 F2 ep=16/30 | loss=4.046178 | 0.7 min
# 34B Refit H=336 F2 ep=17/30 | loss=4.043031 | 0.7 min
# 34B Refit H=336 F2 ep=18/30 | loss=4.040515 | 0.7 min
# 34B Refit H=336 F2 ep=19/30 | loss=4.038668 | 0.7 min
# 34B Refit H=336 F2 ep=20/30 | loss=4.035903 | 0.7 min
# 34B Refit H=336 F2 ep=21/30 | loss=4.034190 | 0.8 min
# 34B Refit H=336 F2 ep=22/30 | loss=4.031658 | 0.8 min
# 34B Refit H=336 F2 ep=23/30 | loss=4.030125 | 0.7 min
# 34B Refit H=336 F2 ep=24/30 | loss=4.028736 | 0.7 min
# 34B Refit H=336 F2 ep=25/30 | loss=4.028065 | 0.7 min
# 34B Refit H=336 F2 ep=26/30 | loss=4.026206 | 0.8 min
# 34B Refit H=336 F2 ep=27/30 | loss=4.024785 | 0.7 min
# 34B Refit H=336 F2 ep=28/30 | loss=4.023301 | 0.7 min
# 34B Refit H=336 F2 ep=29/30 | loss=4.022137 | 0.7 min
# 34B Refit H=336 F2 ep=30/30 | loss=4.021072 | 0.7 min
# SAVED 34B retriever H=336 F2 | bestEpoch=30 | total=40.8 min
# Building memory embedding: ElectricityFull321_34B_H336_OOF_F2_prefix12888_emb.npy (321, 520, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=336 F2 | prefix=12888 | end=15650 | anchors=607 | pairs=194,847 | memory/C=520
# Saved OOF H=336 F2: 194,847 pairs
# 34B FoldDirect H=336 F3 ep=01/07 | train=0.231600 | 1.0 min
# 34B FoldDirect H=336 F3 ep=02/07 | train=0.201942 | 1.0 min
# 34B FoldDirect H=336 F3 ep=03/07 | train=0.194480 | 1.0 min
# 34B FoldDirect H=336 F3 ep=04/07 | train=0.189865 | 1.0 min
# 34B FoldDirect H=336 F3 ep=05/07 | train=0.186433 | 1.0 min
# 34B FoldDirect H=336 F3 ep=06/07 | train=0.184328 | 1.0 min
# 34B FoldDirect H=336 F3 ep=07/07 | train=0.183288 | 1.0 min
# 33C prep H=336 | query anchors=1482 | pairs=47,424 | all-channel naive pairs=475,722 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=118/119 | val min/max=29/30
# 34B Retriever H=336 F3 ep=01 | loss=4.279305 | valAnalog=2.262923 | 0.8 min | best=inf@1
# 34B Retriever H=336 F3 ep=02 | loss=4.142470 | valAnalog=2.257057 | 0.8 min | best=2.262923@1
# 34B Retriever H=336 F3 ep=03 | loss=4.108905 | valAnalog=2.237551 | 0.8 min | best=2.257057@2
# 34B Retriever H=336 F3 ep=04 | loss=4.091960 | valAnalog=2.227600 | 0.8 min | best=2.237551@3
# 34B Retriever H=336 F3 ep=05 | loss=4.080843 | valAnalog=2.219839 | 0.8 min | best=2.227600@4
# 34B Retriever H=336 F3 ep=06 | loss=4.070288 | valAnalog=2.212135 | 0.8 min | best=2.219839@5
# 34B Retriever H=336 F3 ep=07 | loss=4.062298 | valAnalog=2.207094 | 0.8 min | best=2.212135@6
# 34B Retriever H=336 F3 ep=08 | loss=4.055293 | valAnalog=2.209189 | 0.8 min | best=2.207094@7
# 34B Retriever H=336 F3 ep=09 | loss=4.049790 | valAnalog=2.198387 | 0.7 min | best=2.207094@7
# 34B Retriever H=336 F3 ep=10 | loss=4.042881 | valAnalog=2.192017 | 0.8 min | best=2.198387@9
# 34B Retriever H=336 F3 ep=11 | loss=4.038112 | valAnalog=2.189404 | 0.8 min | best=2.192017@10
# 34B Retriever H=336 F3 ep=12 | loss=4.034181 | valAnalog=2.184919 | 0.8 min | best=2.189404@11
# 34B Retriever H=336 F3 ep=13 | loss=4.030401 | valAnalog=2.181988 | 0.8 min | best=2.184919@12
# 34B Retriever H=336 F3 ep=14 | loss=4.027353 | valAnalog=2.179341 | 0.8 min | best=2.181988@13
# 34B Retriever H=336 F3 ep=15 | loss=4.024060 | valAnalog=2.176212 | 0.8 min | best=2.179341@14
# 34B Retriever H=336 F3 ep=16 | loss=4.020763 | valAnalog=2.175684 | 0.8 min | best=2.176212@15
# 34B Retriever H=336 F3 ep=17 | loss=4.018847 | valAnalog=2.174944 | 0.8 min | best=2.175684@16
# 34B Retriever H=336 F3 ep=18 | loss=4.015988 | valAnalog=2.171275 | 0.8 min | best=2.174944@17
# 34B Retriever H=336 F3 ep=19 | loss=4.013686 | valAnalog=2.169379 | 0.8 min | best=2.171275@18
# 34B Retriever H=336 F3 ep=20 | loss=4.011899 | valAnalog=2.168462 | 0.8 min | best=2.169379@19
# 34B Retriever H=336 F3 ep=21 | loss=4.009769 | valAnalog=2.164392 | 0.8 min | best=2.168462@20
# 34B Retriever H=336 F3 ep=22 | loss=4.008105 | valAnalog=2.168033 | 0.8 min | best=2.164392@21
# 34B Retriever H=336 F3 ep=23 | loss=4.006228 | valAnalog=2.164582 | 0.8 min | best=2.164392@21
# 34B Retriever H=336 F3 ep=24 | loss=4.004554 | valAnalog=2.160456 | 0.8 min | best=2.164392@21
# 34B Retriever H=336 F3 ep=25 | loss=4.002898 | valAnalog=2.159647 | 0.8 min | best=2.160456@24
# 34B Retriever H=336 F3 ep=26 | loss=4.001437 | valAnalog=2.163453 | 0.8 min | best=2.159647@25
# 34B Retriever H=336 F3 ep=27 | loss=4.000283 | valAnalog=2.153625 | 0.7 min | best=2.159647@25
# 34B Retriever H=336 F3 ep=28 | loss=3.998795 | valAnalog=2.155344 | 0.8 min | best=2.153625@27
# 34B Retriever H=336 F3 ep=29 | loss=3.998347 | valAnalog=2.156411 | 0.8 min | best=2.153625@27
# 34B Retriever H=336 F3 ep=30 | loss=3.996259 | valAnalog=2.156445 | 0.8 min | best=2.153625@27
# 34B Refit H=336 F3 ep=01/27 | loss=4.246249 | 0.9 min
# 34B Refit H=336 F3 ep=02/27 | loss=4.123594 | 0.9 min
# 34B Refit H=336 F3 ep=03/27 | loss=4.092526 | 0.9 min
# 34B Refit H=336 F3 ep=04/27 | loss=4.076260 | 0.9 min
# 34B Refit H=336 F3 ep=05/27 | loss=4.064516 | 0.9 min
# 34B Refit H=336 F3 ep=06/27 | loss=4.054669 | 0.9 min
# 34B Refit H=336 F3 ep=07/27 | loss=4.046941 | 0.9 min
# 34B Refit H=336 F3 ep=08/27 | loss=4.039482 | 0.9 min
# 34B Refit H=336 F3 ep=09/27 | loss=4.033919 | 0.9 min
# 34B Refit H=336 F3 ep=10/27 | loss=4.029059 | 0.9 min
# 34B Refit H=336 F3 ep=11/27 | loss=4.024113 | 0.9 min
# 34B Refit H=336 F3 ep=12/27 | loss=4.020210 | 0.9 min
# 34B Refit H=336 F3 ep=13/27 | loss=4.016836 | 0.9 min
# 34B Refit H=336 F3 ep=14/27 | loss=4.013556 | 0.9 min
# 34B Refit H=336 F3 ep=15/27 | loss=4.010401 | 0.9 min
# 34B Refit H=336 F3 ep=16/27 | loss=4.007513 | 0.9 min
# 34B Refit H=336 F3 ep=17/27 | loss=4.005302 | 0.9 min
# 34B Refit H=336 F3 ep=18/27 | loss=4.002996 | 0.9 min
# 34B Refit H=336 F3 ep=19/27 | loss=4.001018 | 0.9 min
# 34B Refit H=336 F3 ep=20/27 | loss=3.998951 | 0.9 min
# 34B Refit H=336 F3 ep=21/27 | loss=3.997948 | 0.9 min
# 34B Refit H=336 F3 ep=22/27 | loss=3.995068 | 0.9 min
# 34B Refit H=336 F3 ep=23/27 | loss=3.993966 | 0.9 min
# 34B Refit H=336 F3 ep=24/27 | loss=3.992289 | 0.9 min
# 34B Refit H=336 F3 ep=25/27 | loss=3.991296 | 0.9 min
# 34B Refit H=336 F3 ep=26/27 | loss=3.990717 | 0.9 min
# 34B Refit H=336 F3 ep=27/27 | loss=3.989000 | 0.9 min
# SAVED 34B retriever H=336 F3 | bestEpoch=27 | total=47.8 min
# Building memory embedding: ElectricityFull321_34B_H336_OOF_F3_prefix15650_emb.npy (321, 635, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=336 F3 | prefix=15650 | end=18412 | anchors=607 | pairs=194,847 | memory/C=635
# Saved OOF H=336 F3: 194,847 pairs
# H=336 combined OOF | pairs=584,541 | anchors=1,821 | channels=321
# Reusing Experiment-33C full retriever H=336 | bestEpoch=30
# Building memory embedding: ElectricityFull321_34B_H336_Validation_TrainMemory_emb.npy (321, 750, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B validation H=336 | anchors=2,297 | pairs=737,337
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=01 OOF=0.220628 val=0.157836 alpha=0.034 best=0.157836@1
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=02 OOF=0.215779 val=0.157368 alpha=0.029 best=0.157368@2
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=03 OOF=0.215058 val=0.157227 alpha=0.031 best=0.157227@3
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=04 OOF=0.214627 val=0.157118 alpha=0.029 best=0.157118@4
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=05 OOF=0.214544 val=0.157019 alpha=0.029 best=0.157019@5
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=06 OOF=0.214240 val=0.156918 alpha=0.032 best=0.156918@6
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=07 OOF=0.214232 val=0.156741 alpha=0.030 best=0.156741@7
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=08 OOF=0.214022 val=0.156682 alpha=0.028 best=0.156682@8
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=09 OOF=0.213957 val=0.156866 alpha=0.025 best=0.156682@8
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=10 OOF=0.213731 val=0.156671 alpha=0.030 best=0.156671@10
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=11 OOF=0.213802 val=0.156546 alpha=0.032 best=0.156546@11
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=12 OOF=0.213595 val=0.156574 alpha=0.024 best=0.156546@11
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=13 OOF=0.213588 val=0.156520 alpha=0.029 best=0.156520@13
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=14 OOF=0.213715 val=0.156459 alpha=0.028 best=0.156459@14
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=15 OOF=0.213547 val=0.156618 alpha=0.023 best=0.156459@14
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=16 OOF=0.213504 val=0.156515 alpha=0.025 best=0.156459@14
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=17 OOF=0.213316 val=0.156407 alpha=0.027 best=0.156407@17
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=18 OOF=0.213363 val=0.156417 alpha=0.026 best=0.156407@17
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=19 OOF=0.213313 val=0.156305 alpha=0.026 best=0.156305@19
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=20 OOF=0.213287 val=0.156478 alpha=0.023 best=0.156305@19
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=21 OOF=0.213260 val=0.156498 alpha=0.021 best=0.156305@19
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=22 OOF=0.213211 val=0.156245 alpha=0.027 best=0.156245@22
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=23 OOF=0.213062 val=0.156340 alpha=0.025 best=0.156245@22
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=24 OOF=0.213136 val=0.156281 alpha=0.023 best=0.156245@22
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=25 OOF=0.213167 val=0.156151 alpha=0.028 best=0.156151@25
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=26 OOF=0.213205 val=0.156128 alpha=0.026 best=0.156128@26
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=27 OOF=0.212995 val=0.156246 alpha=0.033 best=0.156128@26
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=28 OOF=0.212975 val=0.156239 alpha=0.028 best=0.156128@26
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=29 OOF=0.213115 val=0.156013 alpha=0.034 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=30 OOF=0.212979 val=0.156290 alpha=0.022 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=31 OOF=0.212926 val=0.156368 alpha=0.033 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=32 OOF=0.212887 val=0.156264 alpha=0.027 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=33 OOF=0.212924 val=0.156221 alpha=0.029 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=34 OOF=0.212911 val=0.156283 alpha=0.025 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=35 OOF=0.212762 val=0.156241 alpha=0.026 best=0.156013@29
# Gate ElectricityFull321_34B_iTransformer_H336 H=336 ep=36 OOF=0.212795 val=0.156138 alpha=0.027 best=0.156013@29
# 34B validation H=336 | Direct=0.158973 | Scalar=0.158973 (a=0.00) | RawGate=0.156218 | Final=0.156218 (lambda=1.00) | gain=+1.733%
# Building memory embedding: ElectricityFull321_34B_H336_Test_TrainValMemory_emb.npy (321, 859, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
#   test anchors 2/4925
#   test anchors 500/4925
#   test anchors 1000/4925
#   test anchors 1500/4925
#   test anchors 2000/4925
#   test anchors 2500/4925
#   test anchors 3000/4925
#   test anchors 3500/4925
#   test anchors 4000/4925
#   test anchors 4500/4925
#   test anchors 4925/4925
#
# H=336 RESULT | Direct=0.177195 | OOF Final=0.175403 | Gain=+1.011% | CI=[0.001378, 0.002265] | Sig+=True | ImprovedCh=77.9% | Runtime=138.1 min
#
# ========================================================================================================================
# EXPERIMENT 34B | Electricity Full321 | iTransformer | H=720
# ========================================================================================================================
# Loaded full direct | iTransformer H=720 | best=0.206504@3
# H=720 fold-direct fixed epochs: 3
# 34B FoldDirect H=720 F1 ep=01/03 | train=0.292225 | 0.7 min
# 34B FoldDirect H=720 F1 ep=02/03 | train=0.254406 | 0.7 min
# 34B FoldDirect H=720 F1 ep=03/03 | train=0.242627 | 0.6 min
# 33C prep H=720 | query anchors=833 | pairs=26,656 | all-channel naive pairs=267,393 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=66/67 | val min/max=16/17
# 34B Retriever H=720 F1 ep=01 | loss=4.361639 | valAnalog=2.316090 | 0.5 min | best=inf@1
# 34B Retriever H=720 F1 ep=02 | loss=4.202910 | valAnalog=2.287156 | 0.4 min | best=2.316090@1
# 34B Retriever H=720 F1 ep=03 | loss=4.154444 | valAnalog=2.261913 | 0.5 min | best=2.287156@2
# 34B Retriever H=720 F1 ep=04 | loss=4.126956 | valAnalog=2.256128 | 0.5 min | best=2.261913@3
# 34B Retriever H=720 F1 ep=05 | loss=4.106674 | valAnalog=2.243905 | 0.5 min | best=2.256128@4
# 34B Retriever H=720 F1 ep=06 | loss=4.092257 | valAnalog=2.241893 | 0.4 min | best=2.243905@5
# 34B Retriever H=720 F1 ep=07 | loss=4.082761 | valAnalog=2.233960 | 0.4 min | best=2.241893@6
# 34B Retriever H=720 F1 ep=08 | loss=4.071854 | valAnalog=2.220157 | 0.4 min | best=2.233960@7
# 34B Retriever H=720 F1 ep=09 | loss=4.062064 | valAnalog=2.214561 | 0.4 min | best=2.220157@8
# 34B Retriever H=720 F1 ep=10 | loss=4.053557 | valAnalog=2.213744 | 0.4 min | best=2.214561@9
# 34B Retriever H=720 F1 ep=11 | loss=4.046812 | valAnalog=2.210541 | 0.4 min | best=2.213744@10
# ...
# 34B Refit H=720 F1 ep=11/29 | loss=4.031858 | 0.5 min
# 34B Refit H=720 F1 ep=12/29 | loss=4.026542 | 0.5 min
# 34B Refit H=720 F1 ep=13/29 | loss=4.021302 | 0.5 min
# 34B Refit H=720 F1 ep=14/29 | loss=4.015950 | 0.5 min
# 34B Refit H=720 F1 ep=15/29 | loss=4.011587 | 0.5 min
# 34B Refit H=720 F1 ep=16/29 | loss=4.008634 | 0.5 min
# 34B Refit H=720 F1 ep=17/29 | loss=4.005135 | 0.5 min
# 34B Refit H=720 F1 ep=18/29 | loss=4.002326 | 0.5 min
# 34B Refit H=720 F1 ep=19/29 | loss=3.997328 | 0.5 min
# 34B Refit H=720 F1 ep=20/29 | loss=3.994009 | 0.5 min
# 34B Refit H=720 F1 ep=21/29 | loss=3.992431 | 0.5 min
# 34B Refit H=720 F1 ep=22/29 | loss=3.989070 | 0.5 min
# 34B Refit H=720 F1 ep=23/29 | loss=3.986869 | 0.5 min
# 34B Refit H=720 F1 ep=24/29 | loss=3.984596 | 0.5 min
# 34B Refit H=720 F1 ep=25/29 | loss=3.981237 | 0.5 min
# 34B Refit H=720 F1 ep=26/29 | loss=3.980226 | 0.5 min
# 34B Refit H=720 F1 ep=27/29 | loss=3.977257 | 0.5 min
# 34B Refit H=720 F1 ep=28/29 | loss=3.975674 | 0.5 min
# 34B Refit H=720 F1 ep=29/29 | loss=3.973455 | 0.5 min
# SAVED 34B retriever H=720 F1 | bestEpoch=29 | total=27.9 min
# Building memory embedding: ElectricityFull321_34B_H720_OOF_F1_prefix10126_emb.npy (321, 388, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=720 F1 | prefix=10126 | end=12888 | anchors=511 | pairs=164,031 | memory/C=388
# Saved OOF H=720 F1: 164,031 pairs
# 34B FoldDirect H=720 F2 ep=01/03 | train=0.276760 | 0.9 min
# 34B FoldDirect H=720 F2 ep=02/03 | train=0.241179 | 0.9 min
# 34B FoldDirect H=720 F2 ep=03/03 | train=0.230066 | 0.9 min
# 33C prep H=720 | query anchors=1110 | pairs=35,520 | all-channel naive pairs=356,310 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=88/89 | val min/max=22/23
# 34B Retriever H=720 F2 ep=01 | loss=4.341782 | valAnalog=1.935785 | 0.6 min | best=inf@1
# 34B Retriever H=720 F2 ep=02 | loss=4.203428 | valAnalog=1.906715 | 0.6 min | best=1.935785@1
# 34B Retriever H=720 F2 ep=03 | loss=4.166261 | valAnalog=1.905186 | 0.6 min | best=1.906715@2
# 34B Retriever H=720 F2 ep=04 | loss=4.145010 | valAnalog=1.903083 | 0.6 min | best=1.905186@3
# 34B Retriever H=720 F2 ep=05 | loss=4.129406 | valAnalog=1.887441 | 0.6 min | best=1.903083@4
# 34B Retriever H=720 F2 ep=06 | loss=4.114995 | valAnalog=1.885392 | 0.6 min | best=1.887441@5
# 34B Retriever H=720 F2 ep=07 | loss=4.105338 | valAnalog=1.864876 | 0.6 min | best=1.885392@6
# 34B Retriever H=720 F2 ep=08 | loss=4.095669 | valAnalog=1.871062 | 0.6 min | best=1.864876@7
# 34B Retriever H=720 F2 ep=09 | loss=4.087311 | valAnalog=1.859357 | 0.6 min | best=1.864876@7
# 34B Retriever H=720 F2 ep=10 | loss=4.081084 | valAnalog=1.859468 | 0.6 min | best=1.859357@9
# 34B Retriever H=720 F2 ep=11 | loss=4.073728 | valAnalog=1.853035 | 0.6 min | best=1.859357@9
# 34B Retriever H=720 F2 ep=12 | loss=4.068646 | valAnalog=1.845847 | 0.6 min | best=1.853035@11
# 34B Retriever H=720 F2 ep=13 | loss=4.063469 | valAnalog=1.846968 | 0.6 min | best=1.845847@12
# 34B Retriever H=720 F2 ep=14 | loss=4.059154 | valAnalog=1.842149 | 0.6 min | best=1.845847@12
# 34B Retriever H=720 F2 ep=15 | loss=4.054570 | valAnalog=1.838012 | 0.6 min | best=1.842149@14
# 34B Retriever H=720 F2 ep=16 | loss=4.050715 | valAnalog=1.841891 | 0.6 min | best=1.838012@15
# 34B Retriever H=720 F2 ep=17 | loss=4.046280 | valAnalog=1.831357 | 0.6 min | best=1.838012@15
# 34B Retriever H=720 F2 ep=18 | loss=4.043213 | valAnalog=1.828063 | 0.6 min | best=1.831357@17
# 34B Retriever H=720 F2 ep=19 | loss=4.040045 | valAnalog=1.829361 | 0.6 min | best=1.828063@18
# 34B Retriever H=720 F2 ep=20 | loss=4.037416 | valAnalog=1.830046 | 0.6 min | best=1.828063@18
# 34B Retriever H=720 F2 ep=21 | loss=4.034420 | valAnalog=1.819952 | 0.6 min | best=1.828063@18
# 34B Retriever H=720 F2 ep=22 | loss=4.032436 | valAnalog=1.827308 | 0.6 min | best=1.819952@21
# 34B Retriever H=720 F2 ep=23 | loss=4.029730 | valAnalog=1.819064 | 0.6 min | best=1.819952@21
# 34B Retriever H=720 F2 ep=24 | loss=4.027001 | valAnalog=1.820723 | 0.6 min | best=1.819064@23
# 34B Retriever H=720 F2 ep=25 | loss=4.025104 | valAnalog=1.817227 | 0.6 min | best=1.819064@23
# 34B Retriever H=720 F2 ep=26 | loss=4.022927 | valAnalog=1.812231 | 0.6 min | best=1.817227@25
# 34B Retriever H=720 F2 ep=27 | loss=4.021543 | valAnalog=1.814568 | 0.6 min | best=1.812231@26
# 34B Retriever H=720 F2 ep=28 | loss=4.019109 | valAnalog=1.813235 | 0.6 min | best=1.812231@26
# 34B Retriever H=720 F2 ep=29 | loss=4.018131 | valAnalog=1.809452 | 0.6 min | best=1.812231@26
# 34B Retriever H=720 F2 ep=30 | loss=4.016365 | valAnalog=1.808195 | 0.6 min | best=1.809452@29
# 34B Refit H=720 F2 ep=01/30 | loss=4.316806 | 0.6 min
# 34B Refit H=720 F2 ep=02/30 | loss=4.191410 | 0.6 min
# 34B Refit H=720 F2 ep=03/30 | loss=4.157018 | 0.6 min
# 34B Refit H=720 F2 ep=04/30 | loss=4.134922 | 0.6 min
# 34B Refit H=720 F2 ep=05/30 | loss=4.120496 | 0.7 min
# 34B Refit H=720 F2 ep=06/30 | loss=4.107334 | 0.7 min
# 34B Refit H=720 F2 ep=07/30 | loss=4.097399 | 0.7 min
# 34B Refit H=720 F2 ep=08/30 | loss=4.088921 | 0.7 min
# 34B Refit H=720 F2 ep=09/30 | loss=4.082556 | 0.7 min
# 34B Refit H=720 F2 ep=10/30 | loss=4.074502 | 0.7 min
# 34B Refit H=720 F2 ep=11/30 | loss=4.069184 | 0.7 min
# 34B Refit H=720 F2 ep=12/30 | loss=4.063172 | 0.7 min
# 34B Refit H=720 F2 ep=13/30 | loss=4.058456 | 0.7 min
# 34B Refit H=720 F2 ep=14/30 | loss=4.053782 | 0.7 min
# 34B Refit H=720 F2 ep=15/30 | loss=4.049969 | 0.7 min
# 34B Refit H=720 F2 ep=16/30 | loss=4.046422 | 0.7 min
# 34B Refit H=720 F2 ep=17/30 | loss=4.043180 | 0.7 min
# 34B Refit H=720 F2 ep=18/30 | loss=4.040655 | 0.7 min
# 34B Refit H=720 F2 ep=19/30 | loss=4.037075 | 0.7 min
# 34B Refit H=720 F2 ep=20/30 | loss=4.034072 | 0.6 min
# 34B Refit H=720 F2 ep=21/30 | loss=4.032370 | 0.6 min
# 34B Refit H=720 F2 ep=22/30 | loss=4.030354 | 0.7 min
# 34B Refit H=720 F2 ep=23/30 | loss=4.027946 | 0.7 min
# 34B Refit H=720 F2 ep=24/30 | loss=4.025658 | 0.7 min
# 34B Refit H=720 F2 ep=25/30 | loss=4.024303 | 0.7 min
# 34B Refit H=720 F2 ep=26/30 | loss=4.021931 | 0.7 min
# 34B Refit H=720 F2 ep=27/30 | loss=4.020856 | 0.7 min
# 34B Refit H=720 F2 ep=28/30 | loss=4.018708 | 0.6 min
# 34B Refit H=720 F2 ep=29/30 | loss=4.017330 | 0.7 min
# 34B Refit H=720 F2 ep=30/30 | loss=4.015884 | 0.7 min
# SAVED 34B retriever H=720 F2 | bestEpoch=30 | total=37.8 min
# Building memory embedding: ElectricityFull321_34B_H720_OOF_F2_prefix12888_emb.npy (321, 504, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=720 F2 | prefix=12888 | end=15650 | anchors=511 | pairs=164,031 | memory/C=504
# Saved OOF H=720 F2: 164,031 pairs
# 34B FoldDirect H=720 F3 ep=01/03 | train=0.282763 | 1.0 min
# 34B FoldDirect H=720 F3 ep=02/03 | train=0.248190 | 1.1 min
# 34B FoldDirect H=720 F3 ep=03/03 | train=0.233454 | 1.0 min
# 33C prep H=720 | query anchors=1386 | pairs=44,352 | all-channel naive pairs=444,906 | sampling ratio=0.100
#   prepared channel 1/321
#   prepared channel 50/321
#   prepared channel 100/321
#   prepared channel 150/321
#   prepared channel 200/321
#   prepared channel 250/321
#   prepared channel 300/321
#   prepared channel 321/321
# Channel coverage | train min/max=110/111 | val min/max=27/28
# 34B Retriever H=720 F3 ep=01 | loss=4.292476 | valAnalog=2.435482 | 0.7 min | best=inf@1
# 34B Retriever H=720 F3 ep=02 | loss=4.156877 | valAnalog=2.401170 | 0.7 min | best=2.435482@1
# 34B Retriever H=720 F3 ep=03 | loss=4.120457 | valAnalog=2.386764 | 0.7 min | best=2.401170@2
# 34B Retriever H=720 F3 ep=04 | loss=4.100087 | valAnalog=2.378110 | 0.7 min | best=2.386764@3
# 34B Retriever H=720 F3 ep=05 | loss=4.086035 | valAnalog=2.368848 | 0.7 min | best=2.378110@4
# 34B Retriever H=720 F3 ep=06 | loss=4.076688 | valAnalog=2.361537 | 0.7 min | best=2.368848@5
# 34B Retriever H=720 F3 ep=07 | loss=4.066535 | valAnalog=2.353325 | 0.7 min | best=2.361537@6
# 34B Retriever H=720 F3 ep=08 | loss=4.059219 | valAnalog=2.346793 | 0.7 min | best=2.353325@7
# 34B Retriever H=720 F3 ep=09 | loss=4.053244 | valAnalog=2.343082 | 0.7 min | best=2.346793@8
# 34B Retriever H=720 F3 ep=10 | loss=4.047158 | valAnalog=2.337160 | 0.7 min | best=2.343082@9
# 34B Retriever H=720 F3 ep=11 | loss=4.042728 | valAnalog=2.329288 | 0.7 min | best=2.337160@10
# 34B Retriever H=720 F3 ep=12 | loss=4.037927 | valAnalog=2.329667 | 0.7 min | best=2.329288@11
# 34B Retriever H=720 F3 ep=13 | loss=4.033096 | valAnalog=2.326530 | 0.7 min | best=2.329288@11
# 34B Retriever H=720 F3 ep=14 | loss=4.029903 | valAnalog=2.321793 | 0.7 min | best=2.326530@13
# 34B Retriever H=720 F3 ep=15 | loss=4.025561 | valAnalog=2.322123 | 0.7 min | best=2.321793@14
# 34B Retriever H=720 F3 ep=16 | loss=4.022871 | valAnalog=2.318262 | 0.7 min | best=2.321793@14
# 34B Retriever H=720 F3 ep=17 | loss=4.020072 | valAnalog=2.315096 | 0.7 min | best=2.318262@16
# 34B Retriever H=720 F3 ep=18 | loss=4.017118 | valAnalog=2.314300 | 0.7 min | best=2.315096@17
# 34B Retriever H=720 F3 ep=19 | loss=4.015248 | valAnalog=2.310498 | 0.7 min | best=2.314300@18
# 34B Retriever H=720 F3 ep=20 | loss=4.013397 | valAnalog=2.312880 | 0.7 min | best=2.310498@19
# 34B Retriever H=720 F3 ep=21 | loss=4.009784 | valAnalog=2.310325 | 0.7 min | best=2.310498@19
# 34B Retriever H=720 F3 ep=22 | loss=4.008090 | valAnalog=2.305209 | 0.7 min | best=2.310325@21
# 34B Retriever H=720 F3 ep=23 | loss=4.006055 | valAnalog=2.302624 | 0.7 min | best=2.305209@22
# 34B Retriever H=720 F3 ep=24 | loss=4.004291 | valAnalog=2.305436 | 0.7 min | best=2.302624@23
# 34B Retriever H=720 F3 ep=25 | loss=4.002643 | valAnalog=2.303039 | 0.7 min | best=2.302624@23
# 34B Retriever H=720 F3 ep=26 | loss=4.001962 | valAnalog=2.303466 | 0.7 min | best=2.302624@23
# 34B Retriever H=720 F3 ep=27 | loss=3.999531 | valAnalog=2.301500 | 0.7 min | best=2.302624@23
# 34B Retriever H=720 F3 ep=28 | loss=3.998116 | valAnalog=2.302672 | 0.7 min | best=2.301500@27
# 34B Retriever H=720 F3 ep=29 | loss=3.996845 | valAnalog=2.297940 | 0.7 min | best=2.301500@27
# 34B Retriever H=720 F3 ep=30 | loss=3.995795 | valAnalog=2.297985 | 0.7 min | best=2.297940@29
# 34B Refit H=720 F3 ep=01/29 | loss=4.266315 | 0.8 min
# 34B Refit H=720 F3 ep=02/29 | loss=4.132540 | 0.9 min
# 34B Refit H=720 F3 ep=03/29 | loss=4.100960 | 0.9 min
# 34B Refit H=720 F3 ep=04/29 | loss=4.083637 | 0.9 min
# 34B Refit H=720 F3 ep=05/29 | loss=4.071665 | 0.8 min
# 34B Refit H=720 F3 ep=06/29 | loss=4.061520 | 0.8 min
# 34B Refit H=720 F3 ep=07/29 | loss=4.051768 | 0.9 min
# 34B Refit H=720 F3 ep=08/29 | loss=4.044044 | 0.8 min
# 34B Refit H=720 F3 ep=09/29 | loss=4.037402 | 0.8 min
# 34B Refit H=720 F3 ep=10/29 | loss=4.029897 | 0.9 min
# 34B Refit H=720 F3 ep=11/29 | loss=4.026180 | 0.9 min
# 34B Refit H=720 F3 ep=12/29 | loss=4.021085 | 0.8 min
# 34B Refit H=720 F3 ep=13/29 | loss=4.016448 | 0.9 min
# 34B Refit H=720 F3 ep=14/29 | loss=4.013085 | 0.8 min
# 34B Refit H=720 F3 ep=15/29 | loss=4.009785 | 0.8 min
# 34B Refit H=720 F3 ep=16/29 | loss=4.007283 | 0.9 min
# 34B Refit H=720 F3 ep=17/29 | loss=4.003739 | 0.9 min
# 34B Refit H=720 F3 ep=18/29 | loss=4.001350 | 0.9 min
# 34B Refit H=720 F3 ep=19/29 | loss=3.999077 | 0.9 min
# 34B Refit H=720 F3 ep=20/29 | loss=3.997010 | 0.9 min
# 34B Refit H=720 F3 ep=21/29 | loss=3.994884 | 0.8 min
# 34B Refit H=720 F3 ep=22/29 | loss=3.992540 | 0.8 min
# 34B Refit H=720 F3 ep=23/29 | loss=3.991729 | 0.8 min
# 34B Refit H=720 F3 ep=24/29 | loss=3.989250 | 0.8 min
# 34B Refit H=720 F3 ep=25/29 | loss=3.987821 | 0.8 min
# 34B Refit H=720 F3 ep=26/29 | loss=3.986890 | 0.9 min
# 34B Refit H=720 F3 ep=27/29 | loss=3.985000 | 0.8 min
# 34B Refit H=720 F3 ep=28/29 | loss=3.984501 | 0.8 min
# 34B Refit H=720 F3 ep=29/29 | loss=3.982739 | 0.8 min
# SAVED 34B retriever H=720 F3 | bestEpoch=29 | total=46.3 min
# Building memory embedding: ElectricityFull321_34B_H720_OOF_F3_prefix15650_emb.npy (321, 619, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B OOF H=720 F3 | prefix=15650 | end=18412 | anchors=511 | pairs=164,031 | memory/C=619
# Saved OOF H=720 F3: 164,031 pairs
# H=720 combined OOF | pairs=492,093 | anchors=1,533 | channels=321
# Reusing Experiment-33C full retriever H=720 | bestEpoch=29
# Building memory embedding: ElectricityFull321_34B_H720_Validation_TrainMemory_emb.npy (321, 734, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
# 34B validation H=720 | anchors=1,913 | pairs=614,073
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=01 OOF=0.282796 val=0.203813 alpha=0.039 best=0.203813@1
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=02 OOF=0.276341 val=0.203443 alpha=0.034 best=0.203443@2
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=03 OOF=0.275498 val=0.202872 alpha=0.035 best=0.202872@3
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=04 OOF=0.273958 val=0.202410 alpha=0.037 best=0.202410@4
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=05 OOF=0.274282 val=0.202399 alpha=0.033 best=0.202399@5
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=06 OOF=0.273445 val=0.202028 alpha=0.034 best=0.202028@6
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=07 OOF=0.273852 val=0.201753 alpha=0.041 best=0.201753@7
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=08 OOF=0.273423 val=0.201864 alpha=0.032 best=0.201753@7
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=09 OOF=0.273295 val=0.201808 alpha=0.033 best=0.201753@7
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=10 OOF=0.272367 val=0.201646 alpha=0.034 best=0.201646@10
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=11 OOF=0.272182 val=0.201657 alpha=0.033 best=0.201646@10
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=12 OOF=0.271683 val=0.201655 alpha=0.037 best=0.201646@10
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=13 OOF=0.272163 val=0.201392 alpha=0.035 best=0.201392@13
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=14 OOF=0.271404 val=0.201475 alpha=0.039 best=0.201392@13
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=15 OOF=0.271561 val=0.201243 alpha=0.041 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=16 OOF=0.271402 val=0.201349 alpha=0.039 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=17 OOF=0.271546 val=0.201424 alpha=0.033 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=18 OOF=0.271277 val=0.201514 alpha=0.041 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=19 OOF=0.271520 val=0.201530 alpha=0.037 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=20 OOF=0.270906 val=0.201337 alpha=0.040 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=21 OOF=0.271160 val=0.201353 alpha=0.043 best=0.201243@15
# Gate ElectricityFull321_34B_iTransformer_H720 H=720 ep=22 OOF=0.270809 val=0.201298 alpha=0.041 best=0.201243@15
# 34B validation H=720 | Direct=0.206504 | Scalar=0.206504 (a=0.00) | RawGate=0.201537 | Final=0.201537 (lambda=1.00) | gain=+2.405%
# Building memory embedding: ElectricityFull321_34B_H720_Test_TrainValMemory_emb.npy (321, 843, 64)
#   channel 1/321
#   channel 50/321
#   channel 100/321
#   channel 150/321
#   channel 200/321
#   channel 250/321
#   channel 300/321
#   channel 321/321
#   test anchors 2/4541
#   test anchors 500/4541
#   test anchors 1000/4541
#   test anchors 1500/4541
#   test anchors 2000/4541
#   test anchors 2500/4541
#   test anchors 3000/4541
#   test anchors 3500/4541
#   test anchors 4000/4541
#   test anchors 4500/4541
#   test anchors 4541/4541
#
# H=720 RESULT | Direct=0.216770 | OOF Final=0.216575 | Gain=+0.090% | CI=[-0.001219, 0.001564] | Sig+=False | ImprovedCh=71.7% | Runtime=121.2 min
#
# Experiment 34B main loop finished.

# %% [markdown]
# ## 34B.8 Final audit and optional 4-horizon table

# %%
s = pd.read_csv(
    SUMMARY_34B
)

b = pd.read_csv(
    BOOTSTRAP_34B
)

if len(s) != 3:
    raise RuntimeError(
        f"34B incomplete: expected 3 horizons, found {len(s)}."
    )

final = s.merge(
    b[
        [
            "Horizon",
            "CI_Low",
            "CI_High",
            "SignificantPositive",
            "SignificantNegative",
        ]
    ],
    on="Horizon",
    how="left",
)

display(
    final[
        [
            "Horizon",
            "Direct_MSE",
            "Final_MSE",
            "MSEGain_pct",
            "MAEGain_pct",
            "ScalarAlpha",
            "ShrinkLambda",
            "FinalMeanAlpha",
            "ImprovedChannelFraction",
            "OracleHeadroom_pct",
            "CI_Low",
            "CI_High",
            "SignificantPositive",
            "SignificantNegative",
            "RuntimeMinutes",
        ]
    ].sort_values(
        "Horizon"
    )
)

print("=" * 96)
print("EXPERIMENT 34B — iTransformer FULL321 OOF")
print("=" * 96)

print(
    "Horizons:",
    sorted(
        final["Horizon"].tolist()
    ),
)

print(
    "MSE wins:",
    int(
        (
            final["MSEGain_pct"]
            > 0
        ).sum()
    ),
    "/ 3",
)

print(
    "Significant wins:",
    int(
        final[
            "SignificantPositive"
        ]
        .fillna(False)
        .sum()
    ),
    "/ 3",
)

print(
    "Significant losses:",
    int(
        final[
            "SignificantNegative"
        ]
        .fillna(False)
        .sum()
    ),
    "/ 3",
)

print(
    "Mean MSE gain:",
    f"{final['MSEGain_pct'].mean():+.3f}%",
)

print(
    "Mean improved-channel fraction:",
    f"{100*final['ImprovedChannelFraction'].mean():.1f}%",
)

print(
    "Total runtime:",
    f"{final['RuntimeMinutes'].sum():.1f} min",
)

# Optional: combine the successful 34A H=96 result if it exists.
h96_summary = (
    EXP34A_ROOT
    / "summary.csv"
)

h96_boot = (
    EXP34A_ROOT
    / "bootstrap.csv"
)

if (
    h96_summary.is_file()
    and h96_boot.is_file()
):
    s96 = pd.read_csv(
        h96_summary
    )

    b96 = pd.read_csv(
        h96_boot
    )

    combined = pd.concat(
        [
            s96,
            s,
        ],
        ignore_index=True,
        sort=False,
    ).sort_values(
        "Horizon"
    )

    combined_boot = pd.concat(
        [
            b96,
            b,
        ],
        ignore_index=True,
        sort=False,
    ).sort_values(
        "Horizon"
    )

    combined.to_csv(
        EXP34B_ROOT
        / "itransformer_all4_horizons_summary.csv",
        index=False,
    )

    combined_boot.to_csv(
        EXP34B_ROOT
        / "itransformer_all4_horizons_bootstrap.csv",
        index=False,
    )

    print("\nCombined H=96/192/336/720:")
    display(
        combined[
            [
                "Horizon",
                "Direct_MSE",
                "Final_MSE",
                "MSEGain_pct",
                "FinalMeanAlpha",
                "ImprovedChannelFraction",
            ]
        ]
    )

    print(
        "4-horizon mean MSE gain:",
        f"{combined['MSEGain_pct'].mean():+.3f}%",
    )

    print(
        "Saved combined table:",
        EXP34B_ROOT
        / "itransformer_all4_horizons_summary.csv",
    )

print("\nSaved 34B summary:", SUMMARY_34B)
print("Saved 34B bootstrap:", BOOTSTRAP_34B)
# Out:
#    Horizon  Direct_MSE  Final_MSE  MSEGain_pct  MAEGain_pct  ScalarAlpha  ShrinkLambda  FinalMeanAlpha  ImprovedChannelFraction  OracleHeadroom_pct    CI_Low   CI_High  SignificantPositive  SignificantNegative  RuntimeMinutes
# 0      192    0.163223   0.161652     0.962485    -0.039164          0.0           1.0        0.031302                 0.775701            6.993821  0.001271  0.001889                 True                False      146.669609
# 1      336    0.177195   0.175403     1.010948    -0.214987          0.0           1.0        0.032550                 0.778816            7.008661  0.001378  0.002265                 True                False      138.062168
# 2      720    0.216770   0.216575     0.089924    -0.441287          0.0           1.0        0.037694                 0.716511            7.885399 -0.001219  0.001564                False                False      121.236398
# ================================================================================================
# EXPERIMENT 34B — iTransformer FULL321 OOF
# ================================================================================================
# Horizons: [192, 336, 720]
# MSE wins: 3 / 3
# Significant wins: 2 / 3
# Significant losses: 0 / 3
# Mean MSE gain: +0.688%
# Mean improved-channel fraction: 75.7%
# Total runtime: 406.0 min
#
# Combined H=96/192/336/720:
#    Horizon  Direct_MSE  Final_MSE  MSEGain_pct  FinalMeanAlpha  ImprovedChannelFraction
# 0       96    0.150067   0.147866     1.466603        0.026113                 0.872274
# 1      192    0.163223   0.161652     0.962485        0.031302                 0.775701
# 2      336    0.177195   0.175403     1.010948        0.032550                 0.778816
# 3      720    0.216770   0.216575     0.089924        0.037694                 0.716511
# 4-horizon mean MSE gain: +0.882%
# Saved combined table: /data/dataset/strong_forecaster/electricity_full321_oof_itransformer_h192_336_720/itransformer_all4_horizons_summary.csv
#
# Saved 34B summary: /data/dataset/strong_forecaster/electricity_full321_oof_itransformer_h192_336_720/summary.csv
# Saved 34B bootstrap: /data/dataset/strong_forecaster/electricity_full321_oof_itransformer_h192_336_720/bootstrap.csv
